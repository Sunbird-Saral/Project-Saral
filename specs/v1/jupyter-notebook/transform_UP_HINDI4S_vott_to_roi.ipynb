# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                 extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                 extractionValue = "CELL_OMR"
    
            
            rois.append({
                "annotationTags": region['tags'][0],
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "UP HINDI4S Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("UP_HINDI4S_vottraw.json")

# %%
# tagGroups = ["ROLLNUMBERID1", "ROLLNUMBER1_QONE","ROLLNUMBER1_QTWO","ROLLNUMBER1_QTHREE","ROLLNUMBER1_QFOUR","ROLLNUMBER1_Q5","ROLLNUMBER1_Q6","ROLLNUMBER1_Q7","ROLLNUMBER1_Q8","ROLLNUMBER1_Q9","ROLLNUMBER1_QTEN","ROLLNUMBER1_Q11","ROLLNUMBER1_Q12","ROLLNUMBER1_Q13","ROLLNUMBER1_Q14","ROLLNUMBER1_Q15","ROLLNUMBER1_Q16","ROLLNUMBER1_Q17","ROLLNUMBER1_Q18","ROLLNUMBER1_Q19","ROLLNUMBER1_Q20","ROLLNUMBERID2","ROLLNUMBER2_Q1","ROLLNUMBER2_Q2","ROLLNUMBER2_Q3","ROLLNUMBER2_Q4","ROLLNUMBER2_Q5","ROLLNUMBER2_Q6","ROLLNUMBER2_Q7","ROLLNUMBER2_Q8","ROLLNUMBER2_Q9","ROLLNUMBER2_QTEN","ROLLNUMBER2_Q11","ROLLNUMBER2_Q12","ROLLNUMBER2_Q13","ROLLNUMBER2_Q14","ROLLNUMBER2_Q15","ROLLNUMBER2_Q16","ROLLNUMBER2_Q17","ROLLNUMBER2_Q18","ROLLNUMBER2_Q19","ROLLNUMBER2_QTWENTY","ROLLNUMBERID3", "ROLLNUMBER3_Q1","ROLLNUMBER3_Q2","ROLLNUMBER3_Q3","ROLLNUMBER3_Q4","ROLLNUMBER3_Q5","ROLLNUMBER3_Q6","ROLLNUMBER3_Q7","ROLLNUMBER3_Q8","ROLLNUMBER3_Q9","ROLLNUMBER3_Q10","ROLLNUMBER3_Q11","ROLLNUMBER3_Q12","ROLLNUMBER3_Q13","ROLLNUMBERID4", "ROLLNUMBER4_Q1","ROLLNUMBER4_Q2","ROLLNUMBER4_Q3","ROLLNUMBER4_Q4","ROLLNUMBER4_Q5","ROLLNUMBER4_Q6","ROLLNUMBER4_Q7","ROLLNUMBER4_Q8","ROLLNUMBER4_Q9","ROLLNUMBER4_Q10","ROLLNUMBER4_Q11","ROLLNUMBER4_Q12","ROLLNUMBER4_Q13","ROLLNUMBER4_Q14","ROLLNUMBER4_Q15","ROLLNUMBER4_Q16","ROLLNUMBER4_Q17","ROLLNUMBER4_Q18","ROLLNUMBER4_Q19","ROLLNUMBER4_Q20"]
tagGroups = []
for i in range(1,5):
  tagGroups.append("ROLLNUMBERID"+str(i))
  for j in ["ONE","TWO","THREE","FOUR","FIVE","SIX","SEVEN","EIGHT","NINE","TEN","ELEVEN","TWL","THIR","FOURT","FIFT","SIXT","SEVENT","EIGHTN","NINT","TWENTY"]:
    tagGroups.append("ROLLNUMBER"+str(i)+"_Q"+str(j))


formatLookup= { 
    'ROLLNUMBERID1': 'छात्र आईडी',
    'ROLLNUMBER1_QONE': 'छात्र आईडी1 Q1 ',
    'ROLLNUMBER1_QTWO': 'छात्र आईडी1 Q2',
    'ROLLNUMBER1_QTHREE': 'छात्र आईडी1 Q3 ',
    'ROLLNUMBER1_QFOUR': 'छात्र आईडी1 Q4',
    'ROLLNUMBER1_QFIVE': 'छात्र आईडी1 Q5',
    'ROLLNUMBER1_QSIX': 'छात्र आईडी1 Q6',
    'ROLLNUMBER1_QSEVEN': 'छात्र आईडी1 Q7',
    'ROLLNUMBER1_QEIGHT': 'छात्र आईडी1 Q8',
    'ROLLNUMBER1_QNINE': 'छात्र आईडी1 Q9',
    'ROLLNUMBER1_QTEN': 'छात्र आईडी1 Q10',
    'ROLLNUMBER1_QELEVEN': 'छात्र आईडी1 Q11',
    'ROLLNUMBER1_QTWL': 'छात्र आईडी1 Q12',
    'ROLLNUMBER1_QTHIR': 'छात्र आईडी1 Q13',
    'ROLLNUMBER1_QFOURT': 'छात्र आईडी1 Q14 ',
    'ROLLNUMBER1_QFIFT': 'छात्र आईडी1 Q15',
    'ROLLNUMBER1_QSIXT': 'छात्र आईडी1 Q16',
    'ROLLNUMBER1_QSEVENT': 'छात्र आईडी1 Q17',
    'ROLLNUMBER1_QEIGHTN': 'छात्र आईडी1 Q18',
    'ROLLNUMBER1_QNINT': 'छात्र आईडी1 Q19',
    'ROLLNUMBER1_QTWENTY': 'छात्र आईडी1 Q20',
    'ROLLNUMBERID2': 'छात्र आईडी',
    'ROLLNUMBER2_QONE': 'छात्र आईडी2 Q1',
    'ROLLNUMBER2_QTWO': 'छात्र आईडी2 Q2',
    'ROLLNUMBER2_QTHREE': 'छात्र आईडी2 Q3',
    'ROLLNUMBER2_QFOUR': 'छात्र आईडी2 Q4',
    'ROLLNUMBER2_QFIVE': 'छात्र आईडी2 Q5',
    'ROLLNUMBER2_QSIX': 'छात्र आईडी2 Q6',
    'ROLLNUMBER2_QSEVEN': 'छात्र आईडी2 Q7',
    'ROLLNUMBER2_QEIGHT': 'छात्र आईडी2 Q8',
    'ROLLNUMBER2_QNINE': 'छात्र आईडी2 Q9',
    'ROLLNUMBER2_QTEN': 'छात्र आईडी2 Q10',
    'ROLLNUMBER2_QELEVEN': 'छात्र आईडी2 Q11',
    'ROLLNUMBER2_QTWL': 'छात्र आईडी2 Q12',
    'ROLLNUMBER2_QTHIR': 'छात्र आईडी2 Q13',
    'ROLLNUMBER2_QFOURT': 'छात्र आईडी2 Q14 ',
    'ROLLNUMBER2_QFIFT': 'छात्र आईडी2 Q15',
    'ROLLNUMBER2_QSIXT': 'छात्र आईडी2 Q16',
    'ROLLNUMBER2_QSEVENT': 'छात्र आईडी2 Q17',
    'ROLLNUMBER2_QEIGHTN': 'छात्र आईडी2 Q18',
    'ROLLNUMBER2_QNINT': 'छात्र आईडी2 Q19',
    'ROLLNUMBER2_QTWENTY': 'छात्र आईडी2 Q20',
    'ROLLNUMBERID3': 'छात्र आईडी',
    'ROLLNUMBER3_QONE': 'छात्र आईडी3 Q1',
    'ROLLNUMBER3_QTWO': 'छात्र आईडी3 Q2',
    'ROLLNUMBER3_QTHREE': 'छात्र आईडी3 Q3',
    'ROLLNUMBER3_QFOUR': 'छात्र आईडी3 Q4',
    'ROLLNUMBER3_QFIVE': 'छात्र आईडी3 Q5',
    'ROLLNUMBER3_QSIX': 'छात्र आईडी3 Q6',
    'ROLLNUMBER3_QSEVEN': 'छात्र आईडी3 Q7',
    'ROLLNUMBER3_QEIGHT': 'छात्र आईडी3 Q8',
    'ROLLNUMBER3_QNINE': 'छात्र आईडी3 Q9',
    'ROLLNUMBER3_QTEN': 'छात्र आईडी3 Q10',
    'ROLLNUMBER3_QELEVEN': 'छात्र आईडी3 Q11',
    'ROLLNUMBER3_QTWL': 'छात्र आईडी3 Q12',
    'ROLLNUMBER3_QTHIR': 'छात्र आईडी3 Q13',
    'ROLLNUMBER3_QFOURT': 'छात्र आईडी3 Q14 ',
    'ROLLNUMBER3_QFIFT': 'छात्र आईडी3 Q15',
    'ROLLNUMBER3_QSIXT': 'छात्र आईडी3 Q16',
    'ROLLNUMBER3_QSEVENT': 'छात्र आईडी3 Q17',
    'ROLLNUMBER3_QEIGHTN': 'छात्र आईडी3 Q18',
    'ROLLNUMBER3_QNINT': 'छात्र आईडी3 Q19',
    'ROLLNUMBER3_QTWENTY': 'छात्र आईडी3 Q20',
    'ROLLNUMBERID4': 'छात्र आईडी',
    'ROLLNUMBER4_QONE': 'छात्र आईडी4 Q1',
    'ROLLNUMBER4_QTWO': 'छात्र आईडी4 Q2',
    'ROLLNUMBER4_QTHREE': 'छात्र आईडी4 Q3',
    'ROLLNUMBER4_QFOUR': 'छात्र आईडी4 Q4',
    'ROLLNUMBER4_QFIVE': 'छात्र आईडी4 Q5',
    'ROLLNUMBER4_QSIX': 'छात्र आईडी4 Q6',
    'ROLLNUMBER4_QSEVEN': 'छात्र आईडी4 Q7',
    'ROLLNUMBER4_QEIGHT': 'छात्र आईडी4 Q8',
    'ROLLNUMBER4_QNINE': 'छात्र आईडी4 Q9',
    'ROLLNUMBER4_QTEN': 'छात्र आईडी4 Q10',
    'ROLLNUMBER4_QELEVEN': 'छात्र आईडी4 Q11',
    'ROLLNUMBER4_QTWL': 'छात्र आईडी4 Q12',
    'ROLLNUMBER4_QTHIR': 'छात्र आईडी4 Q13',
    'ROLLNUMBER4_QFOURT': 'छात्र आईडी4 Q14 ',
    'ROLLNUMBER4_QFIFT': 'छात्र आईडी4 Q15',
    'ROLLNUMBER4_QSIXT': 'छात्र आईडी4 Q16',
    'ROLLNUMBER4_QSEVENT': 'छात्र आईडी4 Q17',
    'ROLLNUMBER4_QEIGHTN': 'छात्र आईडी4 Q18',
    'ROLLNUMBER4_QNINT': 'छात्र आईडी4 Q19',
    'ROLLNUMBER4_QTWENTY': 'छात्र आईडी4 Q20'
}

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "UP HINDI4S Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 129,
#                             "left": 56,
#                             "bottom": 156,
#                             "right": 73
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 130,
#                             "left": 73,
#                             "bottom": 156,
#                             "right": 88
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 130,
#                             "left": 90,
#                             "bottom": 157,
#                             "right": 106
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 130,
#                             "left": 107,
#                             "bottom": 156,
#                             "right": 122
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 130,
#                             "left": 123,
#                             "bottom": 157,
#                             "right": 138
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 130,
#                             "left": 138,
#                             "bottom": 157,
#                             "right": 154
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 130,
#                             "left": 156,
#                             "bottom": 158,
#                             "right": 172
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "ROLLNUMBERID1",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u0940"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QONE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "8",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 187,
#                             "bottom": 129,
#                             "right": 202
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QONE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q1 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QTWO",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "9",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 222,
#                             "bottom": 128,
#                             "right": 236
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QTWO",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QTHREE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "10",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 255,
#                             "bottom": 127,
#                             "right": 271
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QTHREE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q3 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QFOUR",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "11",
#                         "index": 0,
#                         "rect": {
#                             "top": 111,
#                             "left": 288,
#                             "bottom": 125,
#                             "right": 302
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_QFOURT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "12",
#                         "index": 1,
#                         "rect": {
#                             "top": 160,
#                             "left": 190,
#                             "bottom": 174,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QFOUR",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QFIVE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "13",
#                         "index": 0,
#                         "rect": {
#                             "top": 113,
#                             "left": 325,
#                             "bottom": 128,
#                             "right": 336
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QFIVE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QSIX",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "14",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 357,
#                             "bottom": 126,
#                             "right": 371
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_QSIXT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "15",
#                         "index": 1,
#                         "rect": {
#                             "top": 158,
#                             "left": 256,
#                             "bottom": 172,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QSIX",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QSEVEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "16",
#                         "index": 0,
#                         "rect": {
#                             "top": 111,
#                             "left": 392,
#                             "bottom": 126,
#                             "right": 405
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_QSEVENT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "17",
#                         "index": 1,
#                         "rect": {
#                             "top": 160,
#                             "left": 291,
#                             "bottom": 172,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QSEVEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QEIGHT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "18",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 428,
#                             "bottom": 125,
#                             "right": 441
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_QEIGHTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "19",
#                         "index": 1,
#                         "rect": {
#                             "top": 160,
#                             "left": 326,
#                             "bottom": 171,
#                             "right": 336
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QEIGHT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QNINE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "20",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 463,
#                             "bottom": 125,
#                             "right": 475
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QNINE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QTEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "21",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 497,
#                             "bottom": 126,
#                             "right": 508
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QTEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QELEVEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "22",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 533,
#                             "bottom": 127,
#                             "right": 543
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QELEVEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QTWL",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "23",
#                         "index": 0,
#                         "rect": {
#                             "top": 112,
#                             "left": 567,
#                             "bottom": 126,
#                             "right": 578
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QTWL",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QTHIRT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "24",
#                         "index": 0,
#                         "rect": {
#                             "top": 111,
#                             "left": 603,
#                             "bottom": 125,
#                             "right": 612
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QTHIR",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "15",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QFOURT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "25",
#                         "index": 0,
#                         "rect": {
#                             "top": 160,
#                             "left": 190,
#                             "bottom": 174,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QFOURT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q14 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "16",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QFIFT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "26",
#                         "index": 0,
#                         "rect": {
#                             "top": 159,
#                             "left": 225,
#                             "bottom": 173,
#                             "right": 235
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QFIFT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "17",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QSIXT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "27",
#                         "index": 0,
#                         "rect": {
#                             "top": 158,
#                             "left": 256,
#                             "bottom": 172,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QSIXT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QSEVENT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "28",
#                         "index": 0,
#                         "rect": {
#                             "top": 160,
#                             "left": 291,
#                             "bottom": 172,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QSEVENT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "19",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QEIGHTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "29",
#                         "index": 0,
#                         "rect": {
#                             "top": 160,
#                             "left": 326,
#                             "bottom": 171,
#                             "right": 336
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QEIGHTN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "20",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QNINTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "30",
#                         "index": 0,
#                         "rect": {
#                             "top": 158,
#                             "left": 361,
#                             "bottom": 172,
#                             "right": 370
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QNINT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "21",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QTWENTY",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "31",
#                         "index": 0,
#                         "rect": {
#                             "top": 158,
#                             "left": 394,
#                             "bottom": 173,
#                             "right": 405
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_QTWENTY",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "22",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "32",
#                         "index": 0,
#                         "rect": {
#                             "top": 211,
#                             "left": 57,
#                             "bottom": 235,
#                             "right": 72
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "33",
#                         "index": 1,
#                         "rect": {
#                             "top": 210,
#                             "left": 73,
#                             "bottom": 236,
#                             "right": 88
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "34",
#                         "index": 2,
#                         "rect": {
#                             "top": 210,
#                             "left": 91,
#                             "bottom": 236,
#                             "right": 105
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "35",
#                         "index": 3,
#                         "rect": {
#                             "top": 211,
#                             "left": 108,
#                             "bottom": 237,
#                             "right": 122
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "36",
#                         "index": 4,
#                         "rect": {
#                             "top": 210,
#                             "left": 123,
#                             "bottom": 237,
#                             "right": 138
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "37",
#                         "index": 5,
#                         "rect": {
#                             "top": 212,
#                             "left": 139,
#                             "bottom": 237,
#                             "right": 154
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "38",
#                         "index": 6,
#                         "rect": {
#                             "top": 212,
#                             "left": 156,
#                             "bottom": 236,
#                             "right": 172
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "ROLLNUMBERID2",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u0940"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "23",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QONE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "39",
#                         "index": 0,
#                         "rect": {
#                             "top": 206,
#                             "left": 190,
#                             "bottom": 220,
#                             "right": 201
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QONE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "24",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QTWO",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "40",
#                         "index": 0,
#                         "rect": {
#                             "top": 207,
#                             "left": 223,
#                             "bottom": 220,
#                             "right": 234
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QTWO",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "25",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QTHREE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "41",
#                         "index": 0,
#                         "rect": {
#                             "top": 207,
#                             "left": 258,
#                             "bottom": 219,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QTHREE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "26",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QFOUR",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "42",
#                         "index": 0,
#                         "rect": {
#                             "top": 207,
#                             "left": 294,
#                             "bottom": 219,
#                             "right": 303
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER2_QFOURT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "43",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 190,
#                             "bottom": 266,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QFOUR",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "27",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QFIVE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "44",
#                         "index": 0,
#                         "rect": {
#                             "top": 207,
#                             "left": 327,
#                             "bottom": 219,
#                             "right": 337
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QFIVE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "28",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QSIX",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "45",
#                         "index": 0,
#                         "rect": {
#                             "top": 207,
#                             "left": 361,
#                             "bottom": 220,
#                             "right": 370
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER2_QSIXT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "46",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 257,
#                             "bottom": 266,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 28
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QSIX",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "29",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QSEVEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "47",
#                         "index": 0,
#                         "rect": {
#                             "top": 208,
#                             "left": 395,
#                             "bottom": 220,
#                             "right": 405
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER2_QSEVENT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "48",
#                         "index": 1,
#                         "rect": {
#                             "top": 254,
#                             "left": 292,
#                             "bottom": 267,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 29
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QSEVEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "30",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QEIGHT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "49",
#                         "index": 0,
#                         "rect": {
#                             "top": 206,
#                             "left": 430,
#                             "bottom": 219,
#                             "right": 441
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER2_QEIGHTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "50",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 326,
#                             "bottom": 266,
#                             "right": 337
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 30
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QEIGHT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "31",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QNINE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "51",
#                         "index": 0,
#                         "rect": {
#                             "top": 206,
#                             "left": 463,
#                             "bottom": 219,
#                             "right": 472
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 31
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QNINE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "32",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QTEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "52",
#                         "index": 0,
#                         "rect": {
#                             "top": 205,
#                             "left": 498,
#                             "bottom": 219,
#                             "right": 508
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 32
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QTEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "33",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QELEVEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "53",
#                         "index": 0,
#                         "rect": {
#                             "top": 206,
#                             "left": 534,
#                             "bottom": 219,
#                             "right": 543
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 33
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QELEVEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "34",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QTWL",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "54",
#                         "index": 0,
#                         "rect": {
#                             "top": 206,
#                             "left": 567,
#                             "bottom": 219,
#                             "right": 578
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 34
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QTWL",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "35",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QTHIR",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "55",
#                         "index": 0,
#                         "rect": {
#                             "top": 205,
#                             "left": 602,
#                             "bottom": 218,
#                             "right": 611
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 35
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QTHIR",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "36",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QFOURT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "56",
#                         "index": 0,
#                         "rect": {
#                             "top": 252,
#                             "left": 190,
#                             "bottom": 266,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 36
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QFOURT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q14 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "37",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QFIFT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "57",
#                         "index": 0,
#                         "rect": {
#                             "top": 252,
#                             "left": 223,
#                             "bottom": 266,
#                             "right": 234
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 37
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QFIFT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "38",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QSIXT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "58",
#                         "index": 0,
#                         "rect": {
#                             "top": 252,
#                             "left": 257,
#                             "bottom": 266,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 38
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QSIXT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "39",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QSEVENT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "59",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 292,
#                             "bottom": 267,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 39
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QSEVENT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "40",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QEIGHTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "60",
#                         "index": 0,
#                         "rect": {
#                             "top": 252,
#                             "left": 326,
#                             "bottom": 266,
#                             "right": 337
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 40
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QEIGHTN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "41",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QNINT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "61",
#                         "index": 0,
#                         "rect": {
#                             "top": 252,
#                             "left": 361,
#                             "bottom": 264,
#                             "right": 372
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 41
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QNINT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "42",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_QTWENTY",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "62",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 394,
#                             "bottom": 265,
#                             "right": 404
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 42
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_QTWENTY",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q20"
#                 },
#                 "validate": {
# ...
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "106",
#                         "index": 0,
#                         "rect": {
#                             "top": 391,
#                             "left": 324,
#                             "bottom": 406,
#                             "right": 338
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 69
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QFIVE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "70",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QSIX",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "107",
#                         "index": 0,
#                         "rect": {
#                             "top": 391,
#                             "left": 358,
#                             "bottom": 406,
#                             "right": 373
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER4_QSIXT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "108",
#                         "index": 1,
#                         "rect": {
#                             "top": 438,
#                             "left": 258,
#                             "bottom": 452,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 70
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QSIX",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "71",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QSEVEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "109",
#                         "index": 0,
#                         "rect": {
#                             "top": 389,
#                             "left": 390,
#                             "bottom": 406,
#                             "right": 406
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER4_QSEVENT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "110",
#                         "index": 1,
#                         "rect": {
#                             "top": 437,
#                             "left": 293,
#                             "bottom": 451,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 71
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QSEVEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "72",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QEIGHT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "111",
#                         "index": 0,
#                         "rect": {
#                             "top": 393,
#                             "left": 429,
#                             "bottom": 406,
#                             "right": 439
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER4_QEIGHTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "112",
#                         "index": 1,
#                         "rect": {
#                             "top": 437,
#                             "left": 325,
#                             "bottom": 453,
#                             "right": 338
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 72
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QEIGHT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "73",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QNINE",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "113",
#                         "index": 0,
#                         "rect": {
#                             "top": 392,
#                             "left": 464,
#                             "bottom": 406,
#                             "right": 474
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 73
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QNINE",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "74",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QTEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "114",
#                         "index": 0,
#                         "rect": {
#                             "top": 392,
#                             "left": 498,
#                             "bottom": 406,
#                             "right": 509
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 74
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QTEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "75",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QELEVEN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "115",
#                         "index": 0,
#                         "rect": {
#                             "top": 393,
#                             "left": 533,
#                             "bottom": 406,
#                             "right": 543
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 75
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QELEVEN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "76",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QTWL",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "116",
#                         "index": 0,
#                         "rect": {
#                             "top": 393,
#                             "left": 567,
#                             "bottom": 406,
#                             "right": 577
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 76
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QTWL",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "77",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QTHIRT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "117",
#                         "index": 0,
#                         "rect": {
#                             "top": 393,
#                             "left": 602,
#                             "bottom": 406,
#                             "right": 612
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 77
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QTHIR",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "78",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QFOURT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "118",
#                         "index": 0,
#                         "rect": {
#                             "top": 439,
#                             "left": 190,
#                             "bottom": 452,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 78
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QFOURT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q14 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "79",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QFIFT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "119",
#                         "index": 0,
#                         "rect": {
#                             "top": 438,
#                             "left": 225,
#                             "bottom": 452,
#                             "right": 235
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 79
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QFIFT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "80",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QSIXT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "120",
#                         "index": 0,
#                         "rect": {
#                             "top": 438,
#                             "left": 258,
#                             "bottom": 452,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 80
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QSIXT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "81",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QSEVENT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "121",
#                         "index": 0,
#                         "rect": {
#                             "top": 437,
#                             "left": 293,
#                             "bottom": 451,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 81
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QSEVENT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "82",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QEIGHTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "122",
#                         "index": 0,
#                         "rect": {
#                             "top": 437,
#                             "left": 325,
#                             "bottom": 453,
#                             "right": 338
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 82
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QEIGHTN",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "83",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QNINT",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "123",
#                         "index": 0,
#                         "rect": {
#                             "top": 437,
#                             "left": 359,
#                             "bottom": 452,
#                             "right": 373
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 83
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QNINT",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "84",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER4_QTWENTY",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "124",
#                         "index": 0,
#                         "rect": {
#                             "top": 437,
#                             "left": 392,
#                             "bottom": 453,
#                             "right": 408
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 84
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER4_QTWENTY",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09404 Q20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
