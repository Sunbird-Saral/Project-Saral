# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,checkForExtraction):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if  region['tags'][0] in checkForExtraction:
               extractionValue = "NUMERIC_CLASSIFICATION"
            else:
               extractionValue = "CELL_OMR"
            
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,checkForExtraction),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "UP PAT HINDI4S Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("pat_UP_HINDI4S_vottraw.json")

# %%
tagGroups = ["ROLLNUMBERID1", "ROLLNUMBER1_Q1","ROLLNUMBER1_Q2","ROLLNUMBER1_Q3","ROLLNUMBER1_Q4","ROLLNUMBER1_Q5","ROLLNUMBER1_Q6","ROLLNUMBER1_Q7","ROLLNUMBER1_Q8","ROLLNUMBER1_Q9","ROLLNUMBER2_Q10","ROLLNUMBER1_Q11","ROLLNUMBER1_Q12","ROLLNUMBER1_Q13","ROLLNUMBER1_Q14","ROLLNUMBER1_Q15","ROLLNUMBER1_Q16","ROLLNUMBER1_Q17","ROLLNUMBER1_Q18","ROLLNUMBER1_Q19","ROLLNUMBER1_Q20","ROLLNUMBERID2","ROLLNUMBER2_Q1","ROLLNUMBER2_Q2","ROLLNUMBER2_Q3","ROLLNUMBER2_Q4","ROLLNUMBER2_Q5","ROLLNUMBER2_Q6","ROLLNUMBER2_Q7","ROLLNUMBER2_Q8","ROLLNUMBER2_Q9","ROLLNUMBER2_Q10","ROLLNUMBER2_Q11","ROLLNUMBER2_Q12","ROLLNUMBER2_Q13","ROLLNUMBER2_Q14","ROLLNUMBER2_Q15","ROLLNUMBER2_Q16","ROLLNUMBER2_Q17","ROLLNUMBER2_Q18","ROLLNUMBER2_Q19","ROLLNUMBER2_Q20","ROLLNUMBERID3", "ROLLNUMBER3_Q1","ROLLNUMBER3_Q2","ROLLNUMBER3_Q3","ROLLNUMBER3_Q4","ROLLNUMBER3_Q5","ROLLNUMBER3_Q6","ROLLNUMBER3_Q7","ROLLNUMBER3_Q8","ROLLNUMBER3_Q9","ROLLNUMBER3_Q10","ROLLNUMBER3_Q11","ROLLNUMBER3_Q12","ROLLNUMBER3_Q13","ROLLNUMBERID4", "ROLLNUMBER4_Q1","ROLLNUMBER4_Q2","ROLLNUMBER4_Q3","ROLLNUMBER4_Q4","ROLLNUMBER4_Q5","ROLLNUMBER4_Q6","ROLLNUMBER4_Q7","ROLLNUMBER4_Q8","ROLLNUMBER4_Q9","ROLLNUMBER4_Q10","ROLLNUMBER4_Q11","ROLLNUMBER4_Q12","ROLLNUMBER4_Q13","ROLLNUMBER4_Q14","ROLLNUMBER4_Q15","ROLLNUMBER4_Q16","ROLLNUMBER4_Q17","ROLLNUMBER4_Q18","ROLLNUMBER4_Q19","ROLLNUMBER4_Q20"]
formatLookup= {
    
    'ROLLNUMBERID1': 'छात्र आईडी',
    'ROLLNUMBER1_Q1': 'छात्र आईडी1 Q1 ',
    'ROLLNUMBER1_Q2': 'छात्र आईडी1 Q2',
    'ROLLNUMBER1_Q3': 'छात्र आईडी1 Q3 ',
    'ROLLNUMBER1_Q4': 'छात्र आईडी1 Q4',
    'ROLLNUMBER1_Q5': 'छात्र आईडी1 Q5',
    'ROLLNUMBER1_Q6': 'छात्र आईडी1 Q6',
    'ROLLNUMBER1_Q7': 'छात्र आईडी1 Q7',
    'ROLLNUMBER1_Q8': 'छात्र आईडी1 Q8',
    'ROLLNUMBER1_Q9': 'छात्र आईडी1 Q9',
    'ROLLNUMBER1_Q10': 'छात्र आईडी1 Q10',
    'ROLLNUMBER1_Q11': 'छात्र आईडी1 Q11',
    'ROLLNUMBER1_Q12': 'छात्र आईडी1 Q12',
    'ROLLNUMBER1_Q13': 'छात्र आईडी1 Q13',
    'ROLLNUMBER1_Q14': 'छात्र आईडी1 Q14 ',
    'ROLLNUMBER1_Q15': 'छात्र आईडी1 Q15',
    'ROLLNUMBER1_Q16': 'छात्र आईडी1 Q16',
    'ROLLNUMBER1_Q17': 'छात्र आईडी1 Q17',
    'ROLLNUMBER1_Q18': 'छात्र आईडी1 Q18',
    'ROLLNUMBER1_Q19': 'छात्र आईडी1 Q19',
    'ROLLNUMBER1_Q20': 'छात्र आईडी1 Q20',
    'ROLLNUMBERID2': 'छात्र आईडी',
    'ROLLNUMBER2_Q1': 'छात्र आईडी2 Q1',
    'ROLLNUMBER2_Q2': 'छात्र आईडी2 Q2',
    'ROLLNUMBER2_Q3': 'छात्र आईडी2 Q3',
    'ROLLNUMBER2_Q4': 'छात्र आईडी2 Q4',
    'ROLLNUMBER2_Q5': 'छात्र आईडी2 Q5',
    'ROLLNUMBER2_Q6': 'छात्र आईडी2 Q6',
    'ROLLNUMBER2_Q7': 'छात्र आईडी2 Q7',
    'ROLLNUMBER2_Q8': 'छात्र आईडी2 Q8',
    'ROLLNUMBER2_Q9': 'छात्र आईडी2 Q9',
    'ROLLNUMBER2_Q10': 'छात्र आईडी2 Q10',
    'ROLLNUMBER2_Q11': 'छात्र आईडी2 Q11',
    'ROLLNUMBER2_Q12': 'छात्र आईडी2 Q12',
    'ROLLNUMBER2_Q13': 'छात्र आईडी2 Q13',
    'ROLLNUMBER2_Q14': 'छात्र आईडी2 Q14 ',
    'ROLLNUMBER2_Q15': 'छात्र आईडी2 Q15',
    'ROLLNUMBER2_Q16': 'छात्र आईडी2 Q16',
    'ROLLNUMBER2_Q17': 'छात्र आईडी2 Q17',
    'ROLLNUMBER2_Q18': 'छात्र आईडी2 Q18',
    'ROLLNUMBER2_Q19': 'छात्र आईडी2 Q19',
    'ROLLNUMBER2_Q20': 'छात्र आईडी2 Q20',
    'ROLLNUMBERID3': 'छात्र आईडी',
    'ROLLNUMBER3_Q1': 'छात्र आईडी3 Q1',
    'ROLLNUMBER3_Q2': 'छात्र आईडी3 Q2',
    'ROLLNUMBER3_Q3': 'छात्र आईडी3 Q3',
    'ROLLNUMBER3_Q4': 'छात्र आईडी3 Q4',
    'ROLLNUMBER3_Q5': 'छात्र आईडी3 Q5',
    'ROLLNUMBER3_Q6': 'छात्र आईडी3 Q6',
    'ROLLNUMBER3_Q7': 'छात्र आईडी3 Q7',
    'ROLLNUMBER3_Q8': 'छात्र आईडी3 Q8',
    'ROLLNUMBER3_Q9': 'छात्र आईडी3 Q9',
    'ROLLNUMBER3_Q10': 'छात्र आईडी3 Q10',
    'ROLLNUMBER3_Q11': 'छात्र आईडी3 Q11',
    'ROLLNUMBER3_Q12': 'छात्र आईडी3 Q12',
    'ROLLNUMBER3_Q13': 'छात्र आईडी3 Q13',
    'ROLLNUMBER3_Q14': 'छात्र आईडी3 Q14 ',
    'ROLLNUMBER3_Q15': 'छात्र आईडी3 Q15',
    'ROLLNUMBER3_Q16': 'छात्र आईडी3 Q16',
    'ROLLNUMBER3_Q17': 'छात्र आईडी3 Q17',
    'ROLLNUMBER3_Q18': 'छात्र आईडी3 Q18',
    'ROLLNUMBER3_Q19': 'छात्र आईडी3 Q19',
    'ROLLNUMBER3_Q20': 'छात्र आईडी3 Q20',
    'ROLLNUMBERID4': 'छात्र आईडी',
    'ROLLNUMBER4_Q1': 'छात्र आईडी4 Q1',
    'ROLLNUMBER4_Q2': 'छात्र आईडी4 Q2',
    'ROLLNUMBER4_Q3': 'छात्र आईडी4 Q3',
    'ROLLNUMBER4_Q4': 'छात्र आईडी4 Q4',
    'ROLLNUMBER4_Q5': 'छात्र आईडी4 Q5',
    'ROLLNUMBER4_Q6': 'छात्र आईडी4 Q6',
    'ROLLNUMBER4_Q7': 'छात्र आईडी4 Q7',
    'ROLLNUMBER4_Q8': 'छात्र आईडी4 Q8',
    'ROLLNUMBER4_Q9': 'छात्र आईडी4 Q9',
    'ROLLNUMBER4_Q10': 'छात्र आईडी4 Q10',
    'ROLLNUMBER4_Q11': 'छात्र आईडी4 Q11',
    'ROLLNUMBER4_Q12': 'छात्र आईडी4 Q12',
    'ROLLNUMBER4_Q13': 'छात्र आईडी4 Q13',
    'ROLLNUMBER4_Q14': 'छात्र आईडी4 Q14 ',
    'ROLLNUMBER4_Q15': 'छात्र आईडी4 Q15',
    'ROLLNUMBER4_Q16': 'छात्र आईडी4 Q16',
    'ROLLNUMBER4_Q17': 'छात्र आईडी4 Q17',
    'ROLLNUMBER4_Q18': 'छात्र आईडी4 Q18',
    'ROLLNUMBER4_Q19': 'छात्र आईडी4 Q19',
    'ROLLNUMBER4_Q20': 'छात्र आईडी4 Q20'
}



checkForExtraction= ["ROLLNUMBERID1_1","ROLLNUMBERID1_2","ROLLNUMBERID1_3","ROLLNUMBERID1_4","ROLLNUMBERID1_5","ROLLNUMBERID1_6","ROLLNUMBERID1_7","ROLLNUMBERID2_1","ROLLNUMBERID2_2","ROLLNUMBERID2_3","ROLLNUMBERID2_4","ROLLNUMBERID2_5","ROLLNUMBERID2_6","ROLLNUMBERID2_7","ROLLNUMBERID3_1","ROLLNUMBERID3_2","ROLLNUMBERID3_3","ROLLNUMBERID3_4","ROLLNUMBERID3_5","ROLLNUMBERID3_6","ROLLNUMBERID3_7","ROLLNUMBERID4_1","ROLLNUMBERID4_2","ROLLNUMBERID4_3","ROLLNUMBERID4_4","ROLLNUMBERID4_5","ROLLNUMBERID4_6","ROLLNUMBERID4_7"]

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "UP PAT HINDI4S Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 130,
#                             "left": 55,
#                             "bottom": 156,
#                             "right": 72
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
