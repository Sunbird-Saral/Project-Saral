# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(uuid.uuid4()),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""

              cells_data.append({
                          "cellId": str(uuid.uuid4()),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "UP SAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("sat_up_vottraw.json")
#regions

# %%
tagGroups = ["ROLLID", "HINDIID1","HINDIID2","HINDIID3","HINDIID4","HINDIID5","HINDIID6","HINDIID7","HINDIID8","HINDIID9","HINDIIDTEN","ENGLISHID1","ENGLISHID2","ENGLISHID3","ENGLISHID4","ENGLISHID5","ENGLISHID6","ENGLISHID7","ENGLISHID8","ENGLISHID9","ENGLISHIDTEN","MATHSID1","MATHSID2","MATHSID3","MATHSID4","MATHSID5","MATHSID6","MATHSID7","MATHSID8","MATHSID9","MATHSIDTEN","EVS/SOCIALSCIENCEID1","EVS/SOCIALSCIENCEID2","EVS/SOCIALSCIENCEID3","EVS/SOCIALSCIENCEID4","EVS/SOCIALSCIENCEID5","EVS/SOCIALSCIENCEID6","EVS/SOCIALSCIENCEID7","EVS/SOCIALSCIENCEID8","EVS/SOCIALSCIENCEID9","EVS/SOCIALSCIENCEIDTEN","SCIENCEID1","SCIENCEID2","SCIENCEID3","SCIENCEID4","SCIENCEID5","SCIENCEID6","SCIENCEID7","SCIENCEID8","SCIENCEID9","SCIENCEIDTEN"]
#rois=get_rois(regions,tagGroups[0])
formatLookup = {
    'HINDIID1':'HINDI 1',
    'HINDIID2':'HINDI 2',
    'HINDIID3':'HINDI 3',
    'HINDIID4':'HINDI 4',
    'HINDIID5':'HINDI 5',
    'HINDIID6':'HINDI 6',
    'HINDIID7':'HINDI 7',
    'HINDIID8':'HINDI 8',
    'HINDIID9':'HINDI 9',
    'HINDIIDTEN':'HINDI 10',
    'ENGLISHID1':'ENGLISH 1',
    'ENGLISHID2':'ENGLISH 2',
    'ENGLISHID3':'ENGLISH 3',
    'ENGLISHID4':'ENGLISH 4',
    'ENGLISHID5':'ENGLISH 5',
    'ENGLISHID6':'ENGLISH 6',
    'ENGLISHID7':'ENGLISH 7',
    'ENGLISHID8':'ENGLISH 8',
    'ENGLISHID9':'ENGLISH 9',
    'ENGLISHIDTEN':'ENGLISH 10',
    'MATHSID1': 'MATHS 1',
    'MATHSID2':'MATHS 2',
    'MATHSID3':'MATHS 3',
    'MATHSID4':'MATHS 4',
    'MATHSID5':'MATHS 5',
    'MATHSID6':'MATHS 6',
    'MATHSID7':'MATHS 7',
    'MATHSID8':'MATHS 8',
    'MATHSID9':'MATHS 9',
    'MATHSIDTEN':'MATHS 10',
    'EVS/SOCIALSCIENCEID1': 'EVS/SOCIALSCIENCE 1',
    'EVS/SOCIALSCIENCEID2':'EVS/SOCIALSCIENCE 2',
    'EVS/SOCIALSCIENCEID3':'EVS/SOCIALSCIENCE 3',
    'EVS/SOCIALSCIENCEID4':'EVS/SOCIALSCIENCE 4',
    'EVS/SOCIALSCIENCEID5':'EVS/SOCIALSCIENCE 5',
    'EVS/SOCIALSCIENCEID6':'EVS/SOCIALSCIENCE 6',
    'EVS/SOCIALSCIENCEID7':'EVS/SOCIALSCIENCE 7',
    'EVSI/SOCIALSCIENCEID8':'EVS/SOCIALSCIENCE 8',
    'EVS/SOCIALSCIENCEID9':'EVS/SOCIALSCIENCE 9',
    'EVS/SOCIALSCIENCEIDTEN':'EVS/SOCIALSCIENCE 10',
    'SCIENCEID1': 'SCIENCE 1',
    'SCIENCEID2':'SCIENCE 2',
    'SCIENCEID3':'SCIENCE 3',
    'SCIENCEID4':'SCIENCE 4',
    'SCIENCEID5':'SCIENCE 5',
    'SCIENCEID6':'SCIENCE 6',
    'SCIENCEID7':'SCIENCE 7',
    'SCIENCEID8':'SCIENCE 8',
    'SCIENCEID9':'SCIENCE 9',
    'SCIENCEIDTEN': 'SCIENCE 10'    
}

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "UP SAT Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "da45954a-a2b1-482b-9125-34dcd2bfd56c",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5d7644a7-46e3-4464-8f47-fad3e46166af",
#                         "index": 0,
#                         "rect": {
#                             "top": 40,
#                             "left": 155,
#                             "bottom": 73,
#                             "right": 181
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f3a8c9be-de05-4dcb-9870-6c5b94edabb4",
#                         "index": 1,
#                         "rect": {
#                             "top": 41,
#                             "left": 204,
#                             "bottom": 72,
#                             "right": 226
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a1f670b0-2dff-4c06-8fae-8237b859dda9",
#                         "index": 2,
#                         "rect": {
#                             "top": 41,
#                             "left": 249,
#                             "bottom": 74,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "ROLLID",
#                     "value": ""
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9d21d493-decc-4fa1-8c9d-6c0176f87d37",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "69cc78eb-293f-4baf-9be5-b97cdcb4d7fa",
#                         "index": 0,
#                         "rect": {
#                             "top": 200,
#                             "left": 155,
#                             "bottom": 235,
#                             "right": 179
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "HINDIID1",
#                     "value": "HINDI 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c32bf7dd-8b13-4f75-acee-f2c6b8c446f5",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3e2bc779-80a4-4246-9a9d-03ceeb626c25",
#                         "index": 0,
#                         "rect": {
#                             "top": 200,
#                             "left": 202,
#                             "bottom": 235,
#                             "right": 228
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "HINDIID2",
#                     "value": "HINDI 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "eef81f53-9194-4a12-bd90-a9d99bc7d4c3",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3d5aa8ad-3b45-4421-8dbc-7ef82b10372b",
#                         "index": 0,
#                         "rect": {
#                             "top": 201,
#                             "left": 251,
#                             "bottom": 236,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "HINDIID3",
#                     "value": "HINDI 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "49e47b46-b6b5-4dd8-9ed0-eba2727e0542",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "83323609-5612-4085-8e52-6a820c933203",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 297,
#                             "bottom": 236,
#                             "right": 324
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "HINDIID4",
#                     "value": "HINDI 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a6e748fb-8da2-4c74-8d5c-14a5b4315039",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7993fb60-d58d-4ea5-b346-270bc40d490e",
#                         "index": 0,
#                         "rect": {
#                             "top": 200,
#                             "left": 344,
#                             "bottom": 236,
#                             "right": 369
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "HINDIID5",
#                     "value": "HINDI 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b05e9477-7e4e-47d5-9906-3a29aaea1139",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "525465cb-1758-42a8-ad94-6080976b735d",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 392,
#                             "bottom": 236,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "HINDIID6",
#                     "value": "HINDI 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "60d84599-aaa4-45eb-b8d6-151d1a85bd82",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d295a5f7-33ea-498e-b5a4-ba8935e4ad65",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 439,
#                             "bottom": 237,
#                             "right": 464
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "HINDIID7",
#                     "value": "HINDI 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13d56163-d358-467f-8555-0bcf3e35e8ef",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "670eed29-a299-41fb-9272-4b28863608a3",
#                         "index": 0,
#                         "rect": {
#                             "top": 201,
#                             "left": 486,
#                             "bottom": 235,
#                             "right": 512
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "HINDIID8",
#                     "value": "HINDI 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "0e7880c6-2ff4-48b5-8e6c-5f6c17f27e91",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ffb451d9-4473-4fac-b730-f31282e8e459",
#                         "index": 0,
#                         "rect": {
#                             "top": 201,
#                             "left": 534,
#                             "bottom": 237,
#                             "right": 561
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "HINDIID9",
#                     "value": "HINDI 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "72bee0b0-f55b-4243-973b-7cba00c06ada",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "30b383a4-ef53-4d8a-8156-d4f49824f9e0",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 582,
#                             "bottom": 237,
#                             "right": 607
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "HINDIIDTEN",
#                     "value": "HINDI 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b3e892cb-a9b9-41cd-a8a0-472776f00390",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7657e89c-34f1-4ad3-b358-6b905eeb121e",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 155,
#                             "bottom": 287,
#                             "right": 182
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "ENGLISHID1",
#                     "value": "ENGLISH 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "57c7f232-dcf8-4e53-b4fd-88b3bbb59b53",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "345cd0c0-38f6-4a8f-8efc-b862087c6b43",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 203,
#                             "bottom": 288,
#                             "right": 229
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "ENGLISHID2",
#                     "value": "ENGLISH 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "340cc751-507c-4a53-9ed5-440bb248b5b4",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8f012cdf-a684-4b00-9668-f00048f5fa88",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 250,
#                             "bottom": 288,
#                             "right": 274
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "ENGLISHID3",
#                     "value": "ENGLISH 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f6ed7783-ffab-49da-89d8-4d5e901840bc",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7653e8f8-f04c-4d10-974d-184612dbeb15",
#                         "index": 0,
#                         "rect": {
#                             "top": 255,
#                             "left": 296,
#                             "bottom": 290,
#                             "right": 322
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "ENGLISHID4",
#                     "value": "ENGLISH 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "41776b69-4b15-48b8-a3f1-0505f3f10652",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "77ef52b1-a633-4303-86f6-686e632614aa",
#                         "index": 0,
#                         "rect": {
#                             "top": 255,
#                             "left": 345,
#                             "bottom": 289,
#                             "right": 371
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "ENGLISHID5",
#                     "value": "ENGLISH 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5ae5ec53-b5ba-4d98-a439-ad316a8a6ec4",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "366324b0-5ef1-4402-a6e9-c0717b1b5b11",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 392,
#                             "bottom": 288,
#                             "right": 416
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "ENGLISHID6",
#                     "value": "ENGLISH 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3c271702-0ec9-4f4c-a302-c113e3351c36",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3bd7669e-1893-4969-a57d-453cd118b6b6",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 439,
#                             "bottom": 289,
#                             "right": 466
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "ENGLISHID7",
#                     "value": "ENGLISH 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "70606695-5668-4496-9ec6-45721ffa66ec",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "863c2da6-25de-4e32-a283-3249bd940a88",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 488,
#                             "bottom": 288,
#                             "right": 513
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "ENGLISHID8",
#                     "value": "ENGLISH 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8830f387-02c7-478c-bafb-b387e5738fa2",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "14ba004c-a60a-4215-9598-cbc7ad7b796c",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 535,
#                             "bottom": 289,
#                             "right": 561
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "ENGLISHID9",
#                     "value": "ENGLISH 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "bbe0c300-b2be-45ec-b2b5-0d9c565146f3",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "65090f86-d93d-4daa-b31d-66bcceffe6ce",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 583,
#                             "bottom": 289,
#                             "right": 608
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "ENGLISHIDTEN",
#                     "value": "ENGLISH 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "71757a33-0a24-4ef8-b577-86807e03e069",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "764be008-047a-4253-b3de-48c7813f3e88",
#                         "index": 0,
#                         "rect": {
#                             "top": 304,
#                             "left": 155,
#                             "bottom": 340,
#                             "right": 179
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "MATHSID1",
#                     "value": "MATHS 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "194bd5f3-8485-4fc8-bc04-ec6e2f0b3886",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "165a9a42-e4e3-45da-8091-f20ad4ecfc92",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 203,
#                             "bottom": 339,
#                             "right": 229
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "MATHSID2",
#                     "value": "MATHS 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7987dc1b-1d68-43ac-a15a-63f9b6d585a2",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a2e3246a-44e6-4ea3-9022-8e1178f65861",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 252,
#                             "bottom": 339,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "MATHSID3",
#                     "value": "MATHS 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d04227d2-41b4-4639-b023-da405f2502fa",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ad01e923-2484-40dd-9c89-9ace5c86b61c",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 299,
#                             "bottom": 341,
#                             "right": 323
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "MATHSID4",
#                     "value": "MATHS 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "45110d8c-0192-4216-801d-d6bd73c0d083",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d60ce5ef-6193-4220-978c-19c17005e0ab",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 345,
#                             "bottom": 341,
#                             "right": 371
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "MATHSID5",
#                     "value": "MATHS 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "748f9542-1e77-4c4c-ab5c-ab8017ce5153",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d85e4a21-9d5e-496f-9216-6163e34d67b9",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 392,
#                             "bottom": 343,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "MATHSID6",
#                     "value": "MATHS 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c7e02910-11ab-40c0-aebb-c08119e2c323",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7fc19e3e-976b-4fbe-8ee1-b7384e2d8227",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 440,
#                             "bottom": 343,
#                             "right": 466
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 28
#                 },
#                 "format": {
#                     "name": "MATHSID7",
#                     "value": "MATHS 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d8f42ef9-a348-4a6b-8a92-ae02a60262eb",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "137e69fc-71b7-4bae-904b-c75398238b36",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 487,
#                             "bottom": 343,
#                             "right": 513
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 29
#                 },
#                 "format": {
#                     "name": "MATHSID8",
#                     "value": "MATHS 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "29eab8f2-532d-43b6-a8a6-663c8f9e0fd2",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f160dac0-6d4e-4266-9e95-b412b6ea2563",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 534,
#                             "bottom": 343,
#                             "right": 563
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 30
#                 },
#                 "format": {
#                     "name": "MATHSID9",
#                     "value": "MATHS 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "166feb36-8c34-4284-a56e-7b8051ef7d4b",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d5d1fce5-251f-4052-a66e-aa8abca51bb2",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 584,
#                             "bottom": 341,
#                             "right": 610
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 31
#                 },
#                 "format": {
#                     "name": "MATHSIDTEN",
#                     "value": "MATHS 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18b6a2cc-8d75-48fe-94ce-c7ac282ae04c",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1e82c8e7-4846-49dd-96eb-638054b52787",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 155,
#                             "bottom": 394,
#                             "right": 181
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 32
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID1",
#                     "value": "EVS/SOCIALSCIENCE 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "417aea16-849e-42cb-a028-de76b48ccc36",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2cb99477-0003-47f4-94b3-97c082093ec6",
#                         "index": 0,
#                         "rect": {
#                             "top": 358,
#                             "left": 203,
#                             "bottom": 395,
#                             "right": 229
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 33
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID2",
#                     "value": "EVS/SOCIALSCIENCE 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "84a579bc-8d37-45a7-b509-606f96b32e03",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "68225985-5ed6-4ab2-818a-3f3ed567cd7e",
#                         "index": 0,
#                         "rect": {
#                             "top": 357,
#                             "left": 251,
#                             "bottom": 393,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 34
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID3",
#                     "value": "EVS/SOCIALSCIENCE 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8d1e6fa2-ca27-4433-ad20-fea1d509b194",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "35afeafa-47f2-47cd-b9e3-4a215c170d9d",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 298,
#                             "bottom": 395,
#                             "right": 322
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 35
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID4",
#                     "value": "EVS/SOCIALSCIENCE 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7050fd56-172c-45f1-8a86-e021e7804bfc",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "31541d5b-2815-490f-a65f-44422a025093",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 345,
#                             "bottom": 395,
#                             "right": 372
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 36
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID5",
#                     "value": "EVS/SOCIALSCIENCE 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f177fe89-b57d-46d7-90ed-a42a094299d7",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e89b4a99-57e7-4460-8051-15a8aa4ce7c0",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 393,
#                             "bottom": 394,
#                             "right": 417
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 37
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID6",
#                     "value": "EVS/SOCIALSCIENCE 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18021370-135a-476e-afbb-b33a336c0687",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ac801fb1-fa8d-41e7-900b-dd79dda80b6c",
#                         "index": 0,
#                         "rect": {
#                             "top": 360,
#                             "left": 441,
#                             "bottom": 396,
#                             "right": 465
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 38
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID7",
#                     "value": "EVS/SOCIALSCIENCE 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a8b7241d-b1f4-419c-8b34-bf0cd47f575b",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b0dce6e2-6a7d-4b2f-9777-20bff4906fb3",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 489,
#                             "bottom": 394,
#                             "right": 513
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 39
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID8",
#                     "value": ""
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "75302a02-b535-4ab3-93de-d4de0d223dc5",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b10559a7-1943-4dc3-a959-b5163a9b496d",
#                         "index": 0,
#                         "rect": {
#                             "top": 361,
#                             "left": 534,
#                             "bottom": 394,
#                             "right": 562
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 40
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEID9",
#                     "value": "EVS/SOCIALSCIENCE 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "86207215-f6f8-4b81-889a-bba07058bd0b",
#                 "rois": [
#                     {
#                         "annotationTags": "EVS/SOCIALSCIENCEIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f4646810-802e-4248-baf7-534a36398495",
#                         "index": 0,
#                         "rect": {
#                             "top": 360,
#                             "left": 582,
#                             "bottom": 394,
#                             "right": 610
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 41
#                 },
#                 "format": {
#                     "name": "EVS/SOCIALSCIENCEIDTEN",
#                     "value": "EVS/SOCIALSCIENCE 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "716b7ad3-39f0-4643-9431-f50734f8bc32",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f68199e6-b6e9-4514-8709-62efd9188ed1",
#                         "index": 0,
#                         "rect": {
#                             "top": 413,
#                             "left": 155,
#                             "bottom": 448,
#                             "right": 182
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 42
#                 },
#                 "format": {
#                     "name": "SCIENCEID1",
#                     "value": "SCIENCE 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dd87e0dc-1e8d-442e-ab19-48a05ffdb3b3",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "74d7651e-418a-4b25-bd34-46e029dca96b",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 202,
#                             "bottom": 449,
#                             "right": 230
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 43
#                 },
#                 "format": {
#                     "name": "SCIENCEID2",
#                     "value": "SCIENCE 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8ea1d206-4e5a-49d2-a47b-fb774b4d6109",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f4bd747a-5188-4485-9743-09fc3134e6d0",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 251,
#                             "bottom": 447,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 44
#                 },
#                 "format": {
#                     "name": "SCIENCEID3",
#                     "value": "SCIENCE 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2c67e8ce-d0d1-458f-8759-aab6503356bd",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6573ab50-643b-4239-9c03-d8423a3e22df",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 298,
#                             "bottom": 448,
#                             "right": 324
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 45
#                 },
#                 "format": {
#                     "name": "SCIENCEID4",
#                     "value": "SCIENCE 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6a2c7a29-ca56-4516-9065-0190d1227593",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "73eb5157-facd-4035-a35f-50829c5d09ae",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 346,
#                             "bottom": 447,
#                             "right": 370
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 46
#                 },
#                 "format": {
#                     "name": "SCIENCEID5",
#                     "value": "SCIENCE 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "59b10dfd-2e2c-420e-a2e2-ee75ef0d69f3",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5dcfe7c0-fe9d-4c86-9e8d-4a4dfd1d691e",
#                         "index": 0,
#                         "rect": {
#                             "top": 412,
#                             "left": 393,
#                             "bottom": 448,
#                             "right": 419
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 47
#                 },
#                 "format": {
#                     "name": "SCIENCEID6",
#                     "value": "SCIENCE 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4e5aedbf-1893-4808-ba3f-ca14fdf8a9bc",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d9f99b75-0190-4ab7-b2fd-ec651e440322",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 439,
#                             "bottom": 447,
#                             "right": 466
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 48
#                 },
#                 "format": {
#                     "name": "SCIENCEID7",
#                     "value": "SCIENCE 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "71821427-d1db-4f6e-a7cf-890cc0cace0a",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4b376fa1-b9fa-4f97-94d7-0d294622a5ec",
#                         "index": 0,
#                         "rect": {
#                             "top": 412,
#                             "left": 488,
#                             "bottom": 446,
#                             "right": 515
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 49
#                 },
#                 "format": {
#                     "name": "SCIENCEID8",
#                     "value": "SCIENCE 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dae64456-c8f7-44b6-997c-c3d9fa9516dc",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5709075f-d360-42e8-8c98-dd8334a6fb8f",
#                         "index": 0,
#                         "rect": {
#                             "top": 413,
#                             "left": 536,
#                             "bottom": 445,
#                             "right": 562
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 50
#                 },
#                 "format": {
#                     "name": "SCIENCEID9",
#                     "value": "SCIENCE 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "01cdf656-96f1-4c9c-b0ff-f80e8e003371",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "47c1a29d-18b4-4f3f-8cb3-3742d7104947",
#                         "index": 0,
#                         "rect": {
#                             "top": 412,
#                             "left": 582,
#                             "bottom": 447,
#                             "right": 607
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 51
#                 },
#                 "format": {
#                     "name": "SCIENCEIDTEN",
#                     "value": "SCIENCE 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
