# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,checkForExtraction):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if  region['tags'][0] in checkForExtraction:
               extractionValue = "Numeric Classification"
            else:
               extractionValue = "Cell OMR"
            
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""

              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,checkForExtraction),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": ""
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "UP PAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("pat_UP_vottraw.json")

# %%
tagGroups = ["ROLLNUMBER1", "ROLLNUMBER1_Q1_1","ROLLNUMBER1_Q2_1","ROLLNUMBER1_Q3_1","ROLLNUMBER1_Q4_2","ROLLNUMBER1_Q5_2","ROLLNUMBER1_Q6_2","ROLLNUMBER1_Q7_3","ROLLNUMBER1_Q8_2","ROLLNUMBER1_Q9_3","ROLLNUMBER2_Q10_3","ROLLNUMBER2_Q11_3","ROLLNUMBER2_Q12_3","ROLLNUMBER1_Q13_3", "ROLLNUMBER2","ROLLNUMBER1_Q1_1","ROLLNUMBER1_Q2_1","ROLLNUMBER1_Q3_1","ROLLNUMBER1_Q4_2","ROLLNUMBER1_Q5_2","ROLLNUMBER1_Q6_2","ROLLNUMBER1_Q7_2","ROLLNUMBER1_Q8_3","ROLLNUMBER1_Q9_3","ROLLNUMBER1_Q10_3","ROLLNUMBER1_Q11_3","ROLLNUMBER1_Q12_3","ROLLNUMBER1_Q13_3","ROLLNUMBER3", "ROLLNUMBER3_Q1_1","ROLLNUMBER3_Q2_1","ROLLNUMBER3_Q3_1","ROLLNUMBER3_Q4_2","ROLLNUMBER3_Q5_2","ROLLNUMBER3_Q6_2","ROLLNUMBER3_Q7_3","ROLLNUMBER3_Q8_2","ROLLNUMBER3_Q9_3","ROLLNUMBER3_Q10_3","ROLLNUMBER3_Q11_3","ROLLNUMBER3_Q12_3","ROLLNUMBER3_Q13_3","ROLLNUMBER4", "ROLLNUMBER4_Q1_1","ROLLNUMBER4_Q2_1","ROLLNUMBER4_Q3_1","ROLLNUMBER4_Q4_2","ROLLNUMBER4_Q5_2","ROLLNUMBER4_Q6_2","ROLLNUMBER4_Q7_3","ROLLNUMBER4_Q8_2","ROLLNUMBER4_Q9_3","ROLLNUMBER4_Q10_3","ROLLNUMBER4_Q11_3","ROLLNUMBER4_Q12_3","ROLLNUMBER4_Q13_3", "ROLLNUMBER5","ROLLNUMBER5_Q1_1","ROLLNUMBER5_Q2_1","ROLLNUMBER5_Q3_1","ROLLNUMBER5_Q4_2","ROLLNUMBER5_Q5_2","ROLLNUMBER5_Q6_2","ROLLNUMBER5_Q7_2","ROLLNUMBER5_Q8_3","ROLLNUMBER5_Q9_3","ROLLNUMBER5_Q10_3","ROLLNUMBER5_Q11_3","ROLLNUMBER5_Q12_3","ROLLNUMBER5_Q13_3","ROLLNUMBER6", "ROLLNUMBE6_Q1_1","ROLLNUMBER6_Q2_1","ROLLNUMBER6_Q3_1","ROLLNUMBER6_Q4_2","ROLLNUMBER6_Q5_2","ROLLNUMBER6_Q6_2","ROLLNUMBER6_Q7_3","ROLLNUMBER6_Q8_2","ROLLNUMBER6_Q9_3","ROLLNUMBER6_Q10_3","ROLLNUMBER6_Q11_3","ROLLNUMBER6_Q12_3","ROLLNUMBER6_Q13_3","ROLLNUMBER7", "ROLLNUMBER7_Q1_1","ROLLNUMBER7_Q2_1","ROLLNUMBER7_Q3_1","ROLLNUMBER7_Q4_2","ROLLNUMBER7_Q5_2","ROLLNUMBER7_Q6_2","ROLLNUMBER7_Q7_3","ROLLNUMBER7_Q8_2","ROLLNUMBER7_Q9_3","ROLLNUMBER7_Q10_3","ROLLNUMBER7_Q11_3","ROLLNUMBER7Q12_3","ROLLNUMBER7_Q13_3","ROLLNUMBER8","ROLLNUMBER8_Q1_1","ROLLNUMBER8_Q2_1","ROLLNUMBER8_Q3_1","ROLLNUMBER8_Q4_2","ROLLNUMBER8_Q5_2","ROLLNUMBER8_Q6_2","ROLLNUMBER8_Q7_2","ROLLNUMBER8_Q8_3","ROLLNUMBER8_Q9_3","ROLLNUMBER8_Q10_3","ROLLNUMBER8_Q11_3","ROLLNUMBER8_Q12_3","ROLLNUMBER8_Q13_3"]
formatLookup= {
    
    'ROLLNUMBER1': 'छात्र आईडी',
    'ROLLNUMBER1_Q1_1': 'छात्र आईडी1_Q1_1',
    'ROLLNUMBER1_Q2_1': 'छात्र आईडी1_Q2_1',
    'ROLLNUMBER1_Q3_1': 'छात्र आईडी1_Q3_1',
    'ROLLNUMBER1_Q4_2': 'छात्र आईडी1_Q4_2',
    'ROLLNUMBER1_Q5_2': 'छात्र आईडी1_Q5_2',
    'ROLLNUMBER1_Q6_2': 'छात्र आईडी1_Q6_2',
    'ROLLNUMBER1_Q7_2': 'छात्र आईडी1_Q7_2',
    'ROLLNUMBER1_Q8_3': 'छात्र आईडी1_Q8_3',
    'ROLLNUMBER1_Q9_3': 'छात्र आईडी1_Q9_3',
    'ROLLNUMBER1_Q10_3': 'छात्र आईडी1_Q10_3',
    'ROLLNUMBER1_Q11_3': 'छात्र आईडी1_Q11_3',
    'ROLLNUMBER1_Q12_3': 'छात्र आईडी1_Q12_3',
    'ROLLNUMBER1_Q13_3': 'छात्र आईडी1_Q13_3',
    'ROLLNUMBER2': 'छात्र आईडी',
    'ROLLNUMBER2_Q1_1': 'छात्र आईडी2_Q1_1',
    'ROLLNUMBER2_Q2_1': 'छात्र आईडी2_Q2_1',
    'ROLLNUMBER2_Q3_1': 'छात्र आईडी2_Q3_1',
    'ROLLNUMBER2_Q4_2': 'छात्र आईडी2_Q4_2',
    'ROLLNUMBER2_Q5_2': 'छात्र आईडी2_Q5_2',
    'ROLLNUMBER2_Q6_2': 'छात्र आईडी2_Q6_2',
    'ROLLNUMBER2_Q7_2': 'छात्र आईडी2_Q7_2',
    'ROLLNUMBER2_Q8_3': 'छात्र आईडी2_Q8_3',
    'ROLLNUMBER2_Q9_3': 'छात्र आईडी2_Q9_3',
    'ROLLNUMBER2_Q10_3': 'छात्र आईडी2_Q10_3',
    'ROLLNUMBER2_Q11_3': 'छात्र आईडी2_Q11_3',
    'ROLLNUMBER2_Q12_3': 'छात्र आईडी2_Q12_3',
    'ROLLNUMBER2_Q13_3': 'छात्र आईडी2_Q13_3',
    'ROLLNUMBER3': 'छात्र आईडी',
    'ROLLNUMBER3_Q1_1': 'छात्र आईडी3_Q1_1',
    'ROLLNUMBER3_Q2_1': 'छात्र आईडी3_Q2_1',
    'ROLLNUMBER3_Q3_1': 'छात्र आईडी3_Q3_1',
    'ROLLNUMBER3_Q4_2': 'छात्र आईडी3_Q4_2',
    'ROLLNUMBER3_Q5_2': 'छात्र आईडी3_Q5_2',
    'ROLLNUMBER3_Q6_2': 'छात्र आईडी3_Q6_2',
    'ROLLNUMBER3_Q7_2': 'छात्र आईडी3_Q7_2',
    'ROLLNUMBER3_Q8_3': 'छात्र आईडी3_Q8_3',
    'ROLLNUMBER3_Q9_3': 'छात्र आईडी3_Q9_3',
    'ROLLNUMBER3_Q10_3': 'छात्र आईडी3_Q10_3',
    'ROLLNUMBER3_Q11_3': 'छात्र आईडी3_Q11_3',
    'ROLLNUMBER3_Q12_3': 'छात्र आईडी3_Q12_3',
    'ROLLNUMBER3_Q13_3': 'छात्र आईडी3_Q13_3',
    'ROLLNUMBER4': 'छात्र आईडी',
    'ROLLNUMBER4_Q1_1': 'छात्र आईडी4_Q1_1',
    'ROLLNUMBER4_Q2_1': 'छात्र आईडी4_Q2_1',
    'ROLLNUMBER4_Q3_1': 'छात्र आईडी4_Q3_1',
    'ROLLNUMBER4_Q4_2': 'छात्र आईडी4_Q4_2',
    'ROLLNUMBER4_Q5_2': 'छात्र आईडी4_Q5_2',
    'ROLLNUMBER4_Q6_2': 'छात्र आईडी4_Q6_2',
    'ROLLNUMBER4_Q7_2': 'छात्र आईडी4_Q7_2',
    'ROLLNUMBER4_Q8_3': 'छात्र आईडी4_Q8_3',
    'ROLLNUMBER4_Q9_3': 'छात्र आईडी4_Q9_3',
    'ROLLNUMBER4_Q10_3': 'छात्र आईडी4_Q10_3',
    'ROLLNUMBER4_Q11_3': 'छात्र आईडी4_Q11_3',
    'ROLLNUMBER4_Q12_3': 'छात्र आईडी4_Q12_3',
    'ROLLNUMBER4_Q13_3': 'छात्र आईडी4_Q13_3',
    'ROLLNUMBER5': 'छात्र आईडी',
    'ROLLNUMBER5_Q1_1': 'छात्र आईडी5_Q1_1',
    'ROLLNUMBER5_Q2_1': 'छात्र आईडी5_Q2_1',
    'ROLLNUMBER5_Q3_1': 'छात्र आईडी5_Q3_1',
    'ROLLNUMBER5_Q4_2': 'छात्र आईडी5_Q4_2',
    'ROLLNUMBER5_Q5_2': 'छात्र आईडी5_Q5_2',
    'ROLLNUMBER5_Q6_2': 'छात्र आईडी5_Q6_2',
    'ROLLNUMBER5_Q7_2': 'छात्र आईडी5_Q7_2',
    'ROLLNUMBER5_Q8_3': 'छात्र आईडी5_Q8_3',
    'ROLLNUMBER5_Q9_3': 'छात्र आईडी5_Q9_3',
    'ROLLNUMBER5_Q10_3': 'छात्र आईडी5_Q10_3',
    'ROLLNUMBER5_Q11_3': 'छात्र आईडी5_Q11_3',
    'ROLLNUMBER5_Q12_3': 'छात्र आईडी5_Q12_3',
    'ROLLNUMBER5_Q13_3': 'छात्र आईडी5_Q13_3',
    'ROLLNUMBER6': 'छात्र आईडी',
    'ROLLNUMBER6_Q1_1': 'छात्र आईडी6_Q1_1',
    'ROLLNUMBER6_Q2_1': 'छात्र आईडी6_Q2_1',
    'ROLLNUMBER6_Q3_1': 'छात्र आईडी6_Q3_1',
    'ROLLNUMBER6_Q4_2': 'छात्र आईडी6_Q4_2',
    'ROLLNUMBER6_Q5_2': 'छात्र आईडी6_Q5_2',
    'ROLLNUMBER6_Q6_2': 'छात्र आईडी6_Q6_2',
    'ROLLNUMBER6_Q7_2': 'छात्र आईडी6_Q7_2',
    'ROLLNUMBER6_Q8_3': 'छात्र आईडी6_Q8_3',
    'ROLLNUMBER6_Q9_3': 'छात्र आईडी6_Q9_3',
    'ROLLNUMBER6_Q10_3': 'छात्र आईडी6_Q10_3',
    'ROLLNUMBER6_Q11_3': 'छात्र आईडी6_Q11_3',
    'ROLLNUMBER6_Q12_3': 'छात्र आईडी6_Q12_3',
    'ROLLNUMBER6_Q13_3': 'छात्र आईडी6_Q13_3',
    'ROLLNUMBER7': 'छात्र आईडी',
    'ROLLNUMBER7_Q1_1': 'छात्र आईडी7_Q1_1',
    'ROLLNUMBER7_Q2_1': 'छात्र आईडी7_Q2_1',
    'ROLLNUMBER7_Q3_1': 'छात्र आईडी7_Q3_1',
    'ROLLNUMBER7_Q4_2': 'छात्र आईडी7_Q4_2',
    'ROLLNUMBER7_Q5_2': 'छात्र आईडी7_Q5_2',
    'ROLLNUMBER7_Q6_2': 'छात्र आईडी7_Q6_2',
    'ROLLNUMBER7_Q7_2': 'छात्र आईडी7_Q7_2',
    'ROLLNUMBER7_Q8_3': 'छात्र आईडी7_Q8_3',
    'ROLLNUMBER7_Q9_3': 'छात्र आईडी7_Q9_3',
    'ROLLNUMBER7_Q10_3': 'छात्र आईडी7_Q10_3',
    'ROLLNUMBER7_Q11_3': 'छात्र आईडी7_Q11_3',
    'ROLLNUMBER7_Q12_3': 'छात्र आईडी7_Q12_3',
    'ROLLNUMBER7_Q13_3': 'छात्र आईडी7_Q13_3',
    'ROLLNUMBER8': 'छात्र आईडी',
    'ROLLNUMBER8_Q1_1': 'छात्र आईडी8_Q1_1',
    'ROLLNUMBER8_Q2_1': 'छात्र आईडी8_Q2_1',
    'ROLLNUMBER8_Q3_1': 'छात्र आईडी8_Q3_1',
    'ROLLNUMBER8_Q4_2': 'छात्र आईडी8_Q4_2',
    'ROLLNUMBER8_Q5_2': 'छात्र आईडी8_Q5_2',
    'ROLLNUMBER8_Q6_2': 'छात्र आईडी8_Q6_2',
    'ROLLNUMBER8_Q7_2': 'छात्र आईडी8_Q7_2',
    'ROLLNUMBER8_Q8_3': 'छात्र आईडी8_Q8_3',
    'ROLLNUMBER8_Q9_3': 'छात्र आईडी8_Q9_3',
    'ROLLNUMBER8_Q10_3': 'छात्र आईडी8_Q10_3',
    'ROLLNUMBER8_Q11_3': 'छात्र आईडी8_Q11_3',
    'ROLLNUMBER8_Q12_3': 'छात्र आईडी8_Q12_3',
    'ROLLNUMBER8_Q13_3': 'छात्र आईडी8_Q13_3'
}

# formatLookup= {
    
#     'ROLLNUMBER1': 'ROLLNUMBER1',
#     'ROLLNUMBER1_Q1_1': 'ROLLNUMBER1_Q1',
#     'ROLLNUMBER1_Q2_1': 'ROLLNUMBER1_Q2',
#     'ROLLNUMBER1_Q3_1': 'ROLLNUMBER1_Q3',
#     'ROLLNUMBER1_Q4_2': 'ROLLNUMBER1_Q4',
#     'ROLLNUMBER1_Q5_2': 'ROLLNUMBER1_Q5',
#     'ROLLNUMBER1_Q6_2': 'ROLLNUMBER1_Q6',
#     'ROLLNUMBER1_Q7_2': 'ROLLNUMBER1_Q7',
#     'ROLLNUMBER1_Q8_3': 'ROLLNUMBER1_Q8',
#     'ROLLNUMBER1_Q9_3': 'ROLLNUMBER1_Q9',
#     'ROLLNUMBER1_Q10_3': 'ROLLNUMBER1_Q10',
#     'ROLLNUMBER1_Q11_3': 'ROLLNUMBER1_Q11',
#     'ROLLNUMBER1_Q12_3': 'ROLLNUMBER1_Q12',
#     'ROLLNUMBER1_Q13_3': 'ROLLNUMBER1_Q13',
#     'ROLLNUMBER2': 'ROLLNUMBER2',
#     'ROLLNUMBER2_Q1_1': 'ROLLNUMBER2_Q1',
#     'ROLLNUMBER2_Q2_1': 'ROLLNUMBER2_Q2',
#     'ROLLNUMBER2_Q3_1': 'ROLLNUMBER2_Q3',
#     'ROLLNUMBER2_Q4_2': 'ROLLNUMBER2_Q4',
#     'ROLLNUMBER2_Q5_2': 'ROLLNUMBER2_Q5',
#     'ROLLNUMBER2_Q6_2': 'ROLLNUMBER2_Q6',
#     'ROLLNUMBER2_Q7_2': 'ROLLNUMBER2_Q7',
#     'ROLLNUMBER2_Q8_3': 'ROLLNUMBER2_Q8',
#     'ROLLNUMBER2_Q9_3': 'ROLLNUMBER2_Q9',
#     'ROLLNUMBER2_Q10_3': 'ROLLNUMBER2_Q10',
#     'ROLLNUMBER2_Q11_3': 'ROLLNUMBER2_Q11',
#     'ROLLNUMBER2_Q12_3': 'ROLLNUMBER2_Q12',
#     'ROLLNUMBER2_Q13_3': 'ROLLNUMBER2_Q13',
#     'ROLLNUMBER3': 'ROLLNUMBER3',
#     'ROLLNUMBER3_Q1_1': 'ROLLNUMBER3_Q1',
#     'ROLLNUMBER3_Q2_1': 'ROLLNUMBER3_Q2',
#     'ROLLNUMBER3_Q3_1': 'ROLLNUMBER3_Q3',
#     'ROLLNUMBER3_Q4_2': 'ROLLNUMBER3_Q4',
#     'ROLLNUMBER3_Q5_2': 'ROLLNUMBER3_Q5',
#     'ROLLNUMBER3_Q6_2': 'ROLLNUMBER3_Q6',
#     'ROLLNUMBER3_Q7_2': 'ROLLNUMBER3_Q7',
#     'ROLLNUMBER3_Q8_3': 'ROLLNUMBER3_Q8',
#     'ROLLNUMBER3_Q9_3': 'ROLLNUMBER3_Q9',
#     'ROLLNUMBER3_Q10_3': 'ROLLNUMBER3_Q10',
#     'ROLLNUMBER3_Q11_3': 'ROLLNUMBER3_Q11',
#     'ROLLNUMBER3_Q12_3': 'ROLLNUMBER3_Q12',
#     'ROLLNUMBER3_Q13_3': 'ROLLNUMBER3_Q13',
#     'ROLLNUMBER4': 'ROLLNUMBER4',
#     'ROLLNUMBER4_Q1_1': 'ROLLNUMBER4_Q1',
#     'ROLLNUMBER4_Q2_1': 'ROLLNUMBER4_Q2',
#     'ROLLNUMBER4_Q3_1': 'ROLLNUMBER4_Q3',
#     'ROLLNUMBER4_Q4_2': 'ROLLNUMBER4_Q4',
#     'ROLLNUMBER4_Q5_2': 'ROLLNUMBER4_Q5',
#     'ROLLNUMBER4_Q6_2': 'ROLLNUMBER4_Q6',
#     'ROLLNUMBER4_Q7_2': 'ROLLNUMBER4_Q7',
#     'ROLLNUMBER4_Q8_3': 'ROLLNUMBER4_Q8',
#     'ROLLNUMBER4_Q9_3': 'ROLLNUMBER4_Q9',
#     'ROLLNUMBER4_Q10_3': 'ROLLNUMBER4_Q10',
#     'ROLLNUMBER4_Q11_3': 'ROLLNUMBER4_Q11',
#     'ROLLNUMBER4_Q12_3': 'ROLLNUMBER4_Q12',
#     'ROLLNUMBER4_Q13_3': 'ROLLNUMBER4_Q13',
#     'ROLLNUMBER5': 'ROLLNUMBER5',
#     'ROLLNUMBER5_Q1_1': 'ROLLNUMBER5_Q1',
#     'ROLLNUMBER5_Q2_1': 'ROLLNUMBER5_Q2',
#     'ROLLNUMBER5_Q3_1': 'ROLLNUMBER5_Q3',
#     'ROLLNUMBER5_Q4_2': 'ROLLNUMBER5_Q4',
#     'ROLLNUMBER5_Q5_2': 'ROLLNUMBER5_Q5',
#     'ROLLNUMBER5_Q6_2': 'ROLLNUMBER5_Q6',
#     'ROLLNUMBER5_Q7_2': 'ROLLNUMBER5_Q7',
#     'ROLLNUMBER5_Q8_3': 'ROLLNUMBER5_Q8',
#     'ROLLNUMBER5_Q9_3': 'ROLLNUMBER5_Q9',
#     'ROLLNUMBER5_Q10_3': 'ROLLNUMBER5_Q10',
#     'ROLLNUMBER5_Q11_3': 'ROLLNUMBER5_Q11',
#     'ROLLNUMBER5_Q12_3': 'ROLLNUMBER5_Q12',
#     'ROLLNUMBER5_Q13_3': 'ROLLNUMBER5_Q13',
#     'ROLLNUMBER6': 'ROLLNUMBER6',
#     'ROLLNUMBER6_Q1_1': 'ROLLNUMBER6_Q1',
#     'ROLLNUMBER6_Q2_1': 'ROLLNUMBER6_Q2',
#     'ROLLNUMBER6_Q3_1': 'ROLLNUMBER6_Q3',
#     'ROLLNUMBER6_Q4_2': 'ROLLNUMBER6_Q4',
#     'ROLLNUMBER6_Q5_2': 'ROLLNUMBER6_Q5',
#     'ROLLNUMBER6_Q6_2': 'ROLLNUMBER6_Q6',
#     'ROLLNUMBER6_Q7_2': 'ROLLNUMBER6_Q7',
#     'ROLLNUMBER6_Q8_3': 'ROLLNUMBER6_Q8',
#     'ROLLNUMBER6_Q9_3': 'ROLLNUMBER6_Q9',
#     'ROLLNUMBER6_Q10_3': 'ROLLNUMBER6_Q10',
#     'ROLLNUMBER6_Q11_3': 'ROLLNUMBER6_Q11',
#     'ROLLNUMBER6_Q12_3': 'ROLLNUMBER6_Q12',
#     'ROLLNUMBER6_Q13_3': 'ROLLNUMBER6_Q13',
#     'ROLLNUMBER7': 'ROLLNUMBER7',
#     'ROLLNUMBER7_Q1_1': 'ROLLNUMBER7_Q1',
#     'ROLLNUMBER7_Q2_1': 'ROLLNUMBER7_Q2',
#     'ROLLNUMBER7_Q3_1': 'ROLLNUMBER7_Q3',
#     'ROLLNUMBER7_Q4_2': 'ROLLNUMBER7_Q4',
#     'ROLLNUMBER7_Q5_2': 'ROLLNUMBER7_Q5',
#     'ROLLNUMBER7_Q6_2': 'ROLLNUMBER7_Q6',
#     'ROLLNUMBER7_Q7_2': 'ROLLNUMBER7_Q7',
#     'ROLLNUMBER7_Q8_3': 'ROLLNUMBER7_Q8',
#     'ROLLNUMBER7_Q9_3': 'ROLLNUMBER7_Q9',
#     'ROLLNUMBER7_Q10_3': 'ROLLNUMBER7_Q10',
#     'ROLLNUMBER7_Q11_3': 'ROLLNUMBER7_Q11',
#     'ROLLNUMBER7_Q12_3': 'ROLLNUMBER7_Q12',
#     'ROLLNUMBER7_Q13_3': 'ROLLNUMBER7_Q13',
#     'ROLLNUMBER8': 'ROLLNUMBER8',
#     'ROLLNUMBER8_Q1_1': 'ROLLNUMBER8_Q1',
#     'ROLLNUMBER8_Q2_1': 'ROLLNUMBER8_Q2',
#     'ROLLNUMBER8_Q3_1': 'ROLLNUMBER8_Q3',
#     'ROLLNUMBER8_Q4_2': 'ROLLNUMBER8_Q4',
#     'ROLLNUMBER8_Q5_2': 'ROLLNUMBER8_Q5',
#     'ROLLNUMBER8_Q6_2': 'ROLLNUMBER8_Q6',
#     'ROLLNUMBER8_Q7_2': 'ROLLNUMBER8_Q7',
#     'ROLLNUMBER8_Q8_3': 'ROLLNUMBER8_Q8',
#     'ROLLNUMBER8_Q9_3': 'ROLLNUMBER8_Q9',
#     'ROLLNUMBER8_Q10_3': 'ROLLNUMBER8_Q10',
#     'ROLLNUMBER8_Q11_3': 'ROLLNUMBER8_Q11',
#     'ROLLNUMBER8_Q12_3': 'ROLLNUMBER8_Q12',
#     'ROLLNUMBER8_Q13_3': 'ROLLNUMBER8_Q13'
# }

checkForExtraction= ["ROLLNUMBER1_1","ROLLNUMBER1_2","ROLLNUMBER1_3","ROLLNUMBER1_4","ROLLNUMBER1_5","ROLLNUMBER1_6","ROLLNUMBER1_7","ROLLNUMBER2_1","ROLLNUMBER2_2","ROLLNUMBER2_3","ROLLNUMBER2_4","ROLLNUMBER2_5","ROLLNUMBER2_6","ROLLNUMBER2_7","ROLLNUMBER3_1","ROLLNUMBER3_2","ROLLNUMBER3_3","ROLLNUMBER3_4","ROLLNUMBER3_5","ROLLNUMBER3_6","ROLLNUMBER3_7","ROLLNUMBER4_1","ROLLNUMBER4_2","ROLLNUMBER4_3","ROLLNUMBER4_4","ROLLNUMBER4_5","ROLLNUMBER4_6","ROLLNUMBER4_7","ROLLNUMBER5_1","ROLLNUMBER5_2","ROLLNUMBER5_3","ROLLNUMBER5_4","ROLLNUMBER5_5","ROLLNUMBER5_6","ROLLNUMBER5_7","ROLLNUMBER6_1","ROLLNUMBER6_2","ROLLNUMBER6_3","ROLLNUMBER6_4","ROLLNUMBER6_5","ROLLNUMBER6_6","ROLLNUMBER6_7","ROLLNUMBER7_1","ROLLNUMBER7_2","ROLLNUMBER7_3","ROLLNUMBER7_4","ROLLNUMBER7_5","ROLLNUMBER7_6","ROLLNUMBER7_7","ROLLNUMBER8_1","ROLLNUMBER8_2","ROLLNUMBER8_3","ROLLNUMBER8_4","ROLLNUMBER8_5","ROLLNUMBER8_6","ROLLNUMBER8_7"]

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "UP PAT Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_1",
#                         "extractionMethod": "Numeric Classification",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 150,
#                             "left": 56,
#                             "bottom": 178,
#                             "right": 72
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_2",
#                         "extractionMethod": "Numeric Classification",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 151,
# ...
