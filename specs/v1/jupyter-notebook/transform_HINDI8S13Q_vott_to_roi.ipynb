# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatNameLookup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                 extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                 extractionValue = "CELL_OMR"
                    
                                            
            try:
                 annotationTagsValue = formatNameLookup[region['tags'][0]]
            except KeyError as ke:
                 annotationTagsValue =  region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
                    
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatNameLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "HINDI8S13QOMR Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("HINDI8S13Q_vottraw.json")

# %%
tagGroups = ["ROLLNUMBERID1", "ROLLNUMBER1_Q1_1","ROLLNUMBER1_Q2_1","ROLLNUMBER1_Q3_1","ROLLNUMBER1_Q4_2","ROLLNUMBER1_Q5_2","ROLLNUMBER1_Q6_2","ROLLNUMBER1_Q7_2","ROLLNUMBER1_Q8_3","ROLLNUMBER1_Q9_3","ROLLNUMBER1_QTEN_3","ROLLNUMBER1_QELEVN_3","ROLLNUMBER1_QTWL_3","ROLLNUMBER1_QTHRTN_3", "ROLLNUMBERID2","ROLLNUMBER2_Q1_1","ROLLNUMBER2_Q2_1","ROLLNUMBER2_Q3_1","ROLLNUMBER2_Q4_2","ROLLNUMBER2_Q5_2","ROLLNUMBER2_Q6_2","ROLLNUMBER2_Q7_2","ROLLNUMBER2_Q8_3","ROLLNUMBER2_Q9_3","ROLLNUMBER2_QTEN_3","ROLLNUMBER2_QELEVN_3","ROLLNUMBER2_QTWL_3","ROLLNUMBER2_QTHRTN_3","ROLLNUMBERID3", "ROLLNUMBER3_Q1_1","ROLLNUMBER3_Q2_1","ROLLNUMBER3_Q3_1","ROLLNUMBER3_Q4_2","ROLLNUMBER3_Q5_2","ROLLNUMBER3_Q6_2","ROLLNUMBER3_Q7_2","ROLLNUMBER3_Q8_3","ROLLNUMBER3_Q9_3","ROLLNUMBER3_QTEN_3","ROLLNUMBER3_QELEVN_3","ROLLNUMBER3_QTWL_3","ROLLNUMBER3_QTHRTN_3","ROLLNUMBERID4", "ROLLNUMBER4_Q1_1","ROLLNUMBER4_Q2_1","ROLLNUMBER4_Q3_1","ROLLNUMBER4_Q4_2","ROLLNUMBER4_Q5_2","ROLLNUMBER4_Q6_2","ROLLNUMBER4_Q7_2","ROLLNUMBER4_Q8_3","ROLLNUMBER4_Q9_3","ROLLNUMBER4_QTEN_3","ROLLNUMBER4_QELEVN_3","ROLLNUMBER4_QTWL_3","ROLLNUMBER4_QTHRTN_3", "ROLLNUMBERID5","ROLLNUMBER5_Q1_1","ROLLNUMBER5_Q2_1","ROLLNUMBER5_Q3_1","ROLLNUMBER5_Q4_2","ROLLNUMBER5_Q5_2","ROLLNUMBER5_Q6_2","ROLLNUMBER5_Q7_2","ROLLNUMBER5_Q8_3","ROLLNUMBER5_Q9_3","ROLLNUMBER5_QTEN_3","ROLLNUMBER5_QELEVN_3","ROLLNUMBER5_QTWL_3","ROLLNUMBER5_QTHRTN_3","ROLLNUMBERID6", "ROLLNUMBER6_Q1_1","ROLLNUMBER6_Q2_1","ROLLNUMBER6_Q3_1","ROLLNUMBER6_Q4_2","ROLLNUMBER6_Q5_2","ROLLNUMBER6_Q6_2","ROLLNUMBER6_Q7_2","ROLLNUMBER6_Q8_3","ROLLNUMBER6_Q9_3","ROLLNUMBER6_QTEN_3","ROLLNUMBER6_QELEVN_3","ROLLNUMBER6_QTWL_3","ROLLNUMBER6_QTHRTN_3","ROLLNUMBERID7", "ROLLNUMBER7_Q1_1","ROLLNUMBER7_Q2_1","ROLLNUMBER7_Q3_1","ROLLNUMBER7_Q4_2","ROLLNUMBER7_Q5_2","ROLLNUMBER7_Q6_2","ROLLNUMBER7_Q7_2","ROLLNUMBER7_Q8_3","ROLLNUMBER7_Q9_3","ROLLNUMBER7_QTEN_3","ROLLNUMBER7_QELEVN_3","ROLLNUMBER7_QTWL_3","ROLLNUMBER7_QTHRTN_3","ROLLNUMBERID8","ROLLNUMBER8_Q1_1","ROLLNUMBER8_Q2_1","ROLLNUMBER8_Q3_1","ROLLNUMBER8_Q4_2","ROLLNUMBER8_Q5_2","ROLLNUMBER8_Q6_2","ROLLNUMBER8_Q7_2","ROLLNUMBER8_Q8_3","ROLLNUMBER8_Q9_3","ROLLNUMBER8_QTEN_3","ROLLNUMBER8_QELEVN_3","ROLLNUMBER8_QTWL_3","ROLLNUMBER8_QTHRTN_3"]


formatLookup= {
    
    'ROLLNUMBERID1': 'छात्र आईडी1',
    'ROLLNUMBER1_Q1_1': 'छात्र आईडी1 Q1 1',
    'ROLLNUMBER1_Q2_1': 'छात्र आईडी1 Q2 1',
    'ROLLNUMBER1_Q3_1': 'छात्र आईडी1 Q3 1',
    'ROLLNUMBER1_Q4_2': 'छात्र आईडी1 Q4 2',
    'ROLLNUMBER1_Q5_2': 'छात्र आईडी1 Q5 2',
    'ROLLNUMBER1_Q6_2': 'छात्र आईडी1 Q6 2',
    'ROLLNUMBER1_Q7_2': 'छात्र आईडी1 Q7 2',
    'ROLLNUMBER1_Q8_3': 'छात्र आईडी1 Q8 3',
    'ROLLNUMBER1_Q9_3': 'छात्र आईडी1 Q9 3',
    'ROLLNUMBER1_QTEN_3': 'छात्र आईडी1 Q10 3',
    'ROLLNUMBER1_QELEVN_3': 'छात्र आईडी1 Q11 3',
    'ROLLNUMBER1_QTWL_3': 'छात्र आईडी1 Q12 3',
    'ROLLNUMBER1_QTHRTN_3': 'छात्र आईडी1 Q13 3',
    'ROLLNUMBERID2': 'छात्र आईडी2',
    'ROLLNUMBER2_Q1_1': 'छात्र आईडी2 Q1 1',
    'ROLLNUMBER2_Q2_1': 'छात्र आईडी2 Q2 1',
    'ROLLNUMBER2_Q3_1': 'छात्र आईडी2 Q3 1',
    'ROLLNUMBER2_Q4_2': 'छात्र आईडी2 Q4 2',
    'ROLLNUMBER2_Q5_2': 'छात्र आईडी2 Q5 2',
    'ROLLNUMBER2_Q6_2': 'छात्र आईडी2 Q6 2',
    'ROLLNUMBER2_Q7_2': 'छात्र आईडी2 Q7 2',
    'ROLLNUMBER2_Q8_3': 'छात्र आईडी2 Q8 3',
    'ROLLNUMBER2_Q9_3': 'छात्र आईडी2 Q9 3',
    'ROLLNUMBER2_QTEN_3': 'छात्र आईडी2 Q10 3',
    'ROLLNUMBER2_QELEVN_3': 'छात्र आईडी2 Q11 3',
    'ROLLNUMBER2_QTWL_3': 'छात्र आईडी2 Q12 3',
    'ROLLNUMBER2_QTHRTN_3': 'छात्र आईडी2 Q13 3',
    'ROLLNUMBERID3': 'छात्र आईडी3',
    'ROLLNUMBER3_Q1_1': 'छात्र आईडी3 Q1 1',
    'ROLLNUMBER3_Q2_1': 'छात्र आईडी3 Q2 1',
    'ROLLNUMBER3_Q3_1': 'छात्र आईडी3 Q3 1',
    'ROLLNUMBER3_Q4_2': 'छात्र आईडी3 Q4 2',
    'ROLLNUMBER3_Q5_2': 'छात्र आईडी3 Q5 2',
    'ROLLNUMBER3_Q6_2': 'छात्र आईडी3 Q6 2',
    'ROLLNUMBER3_Q7_2': 'छात्र आईडी3 Q7 2',
    'ROLLNUMBER3_Q8_3': 'छात्र आईडी3 Q8 3',
    'ROLLNUMBER3_Q9_3': 'छात्र आईडी3 Q9 3',
    'ROLLNUMBER3_QTEN_3': 'छात्र आईडी3 Q10 3',
    'ROLLNUMBER3_QELEVN_3': 'छात्र आईडी3 Q11 3',
    'ROLLNUMBER3_QTWL_3': 'छात्र आईडी3 Q12 3',
    'ROLLNUMBER3_QTHRTN_3': 'छात्र आईडी3 Q13 3',
    'ROLLNUMBERID4': 'छात्र आईडी4',
    'ROLLNUMBER4_Q1_1': 'छात्र आईडी4 Q1 1',
    'ROLLNUMBER4_Q2_1': 'छात्र आईडी4 Q2 1',
    'ROLLNUMBER4_Q3_1': 'छात्र आईडी4 Q3 1',
    'ROLLNUMBER4_Q4_2': 'छात्र आईडी4 Q4 2',
    'ROLLNUMBER4_Q5_2': 'छात्र आईडी4 Q5 2',
    'ROLLNUMBER4_Q6_2': 'छात्र आईडी4 Q6 2',
    'ROLLNUMBER4_Q7_2': 'छात्र आईडी4 Q7 2',
    'ROLLNUMBER4_Q8_3': 'छात्र आईडी4 Q8 3',
    'ROLLNUMBER4_Q9_3': 'छात्र आईडी4 Q9 3',
    'ROLLNUMBER4_QTEN_3': 'छात्र आईडी4 Q10 3',
    'ROLLNUMBER4_QELEVN_3': 'छात्र आईडी4 Q11 3',
    'ROLLNUMBER4_QTWL_3': 'छात्र आईडी4 Q12 3',
    'ROLLNUMBER4_QTHRTN_3': 'छात्र आईडी4 Q13 3',
    'ROLLNUMBERID5': 'छात्र आईडी5',
    'ROLLNUMBER5_Q1_1': 'छात्र आईडी5 Q1 1',
    'ROLLNUMBER5_Q2_1': 'छात्र आईडी5 Q2 1',
    'ROLLNUMBER5_Q3_1': 'छात्र आईडी5 Q3 1',
    'ROLLNUMBER5_Q4_2': 'छात्र आईडी5 Q4 2',
    'ROLLNUMBER5_Q5_2': 'छात्र आईडी5 Q5 2',
    'ROLLNUMBER5_Q6_2': 'छात्र आईडी5 Q6 2',
    'ROLLNUMBER5_Q7_2': 'छात्र आईडी5 Q7 2',
    'ROLLNUMBER5_Q8_3': 'छात्र आईडी5 Q8 3',
    'ROLLNUMBER5_Q9_3': 'छात्र आईडी5 Q9 3',
    'ROLLNUMBER5_QTEN_3': 'छात्र आईडी5 Q10 3',
    'ROLLNUMBER5_QELEVN_3': 'छात्र आईडी5 Q11 3',
    'ROLLNUMBER5_QTWL_3': 'छात्र आईडी5 Q12 3',
    'ROLLNUMBER5_QTHRTN_3': 'छात्र आईडी5 Q13 3',
    'ROLLNUMBERID6': 'छात्र आईडी6',
    'ROLLNUMBER6_Q1_1': 'छात्र आईडी6 Q1 1',
    'ROLLNUMBER6_Q2_1': 'छात्र आईडी6 Q2 1',
    'ROLLNUMBER6_Q3_1': 'छात्र आईडी6 Q3 1',
    'ROLLNUMBER6_Q4_2': 'छात्र आईडी6 Q4 2',
    'ROLLNUMBER6_Q5_2': 'छात्र आईडी6 Q5 2',
    'ROLLNUMBER6_Q6_2': 'छात्र आईडी6 Q6 2',
    'ROLLNUMBER6_Q7_2': 'छात्र आईडी6 Q7 2',
    'ROLLNUMBER6_Q8_3': 'छात्र आईडी6 Q8 3',
    'ROLLNUMBER6_Q9_3': 'छात्र आईडी6 Q9 3',
    'ROLLNUMBER6_QTEN_3': 'छात्र आईडी6 Q10 3',
    'ROLLNUMBER6_QELEVN_3': 'छात्र आईडी6 Q11 3',
    'ROLLNUMBER6_QTWL_3': 'छात्र आईडी6 Q12 3',
    'ROLLNUMBER6_QTHRTN_3': 'छात्र आईडी6 Q13 3',
    'ROLLNUMBERID7': 'छात्र आईड7ी',
    'ROLLNUMBER7_Q1_1': 'छात्र आईडी7 Q1 1',
    'ROLLNUMBER7_Q2_1': 'छात्र आईडी7 Q2 1',
    'ROLLNUMBER7_Q3_1': 'छात्र आईडी7 Q3 1',
    'ROLLNUMBER7_Q4_2': 'छात्र आईडी7 Q4 2',
    'ROLLNUMBER7_Q5_2': 'छात्र आईडी7 Q5 2',
    'ROLLNUMBER7_Q6_2': 'छात्र आईडी7 Q6 2',
    'ROLLNUMBER7_Q7_2': 'छात्र आईडी7 Q7 2',
    'ROLLNUMBER7_Q8_3': 'छात्र आईडी7 Q8 3',
    'ROLLNUMBER7_Q9_3': 'छात्र आईडी7 Q9 3',
    'ROLLNUMBER7_QTEN_3': 'छात्र आईडी7 Q10 3',
    'ROLLNUMBER7_QELEVN_3': 'छात्र आईडी7 Q11 3',
    'ROLLNUMBER7_QTWL_3': 'छात्र आईडी7 Q12 3',
    'ROLLNUMBER7_QTHRTN_3': 'छात्र आईडी7 Q13 3',
    'ROLLNUMBERID8': 'छात्र आईडी8',
    'ROLLNUMBER8_Q1_1': 'छात्र आईडी8 Q1 1',
    'ROLLNUMBER8_Q2_1': 'छात्र आईडी8 Q2 1',
    'ROLLNUMBER8_Q3_1': 'छात्र आईडी8 Q3 1',
    'ROLLNUMBER8_Q4_2': 'छात्र आईडी8 Q4 2',
    'ROLLNUMBER8_Q5_2': 'छात्र आईडी8 Q5 2',
    'ROLLNUMBER8_Q6_2': 'छात्र आईडी8 Q6 2',
    'ROLLNUMBER8_Q7_2': 'छात्र आईडी8 Q7 2',
    'ROLLNUMBER8_Q8_3': 'छात्र आईडी8 Q8 3',
    'ROLLNUMBER8_Q9_3': 'छात्र आईडी8 Q9 3',
    'ROLLNUMBER8_QTEN_3': 'छात्र आईडी8 Q10 3',
    'ROLLNUMBER8_QELEVN_3': 'छात्र आईडी8 Q11 3',
    'ROLLNUMBER8_QTWL_3': 'छात्र आईडी8 Q12 3',
    'ROLLNUMBER8_QTHRTN_3': 'छात्र आईडी8 Q13 3'
}

formatNameLookup= {
'ROLLNUMBER1_Q1_1': 'ROLLNUMBER1_Q1_1',
'ROLLNUMBER1_Q2_1': 'ROLLNUMBER1_Q2_1',
'ROLLNUMBER1_Q3_1': 'ROLLNUMBER1_Q3_1',
'ROLLNUMBER1_Q4_2': 'ROLLNUMBER1_Q4_2',
'ROLLNUMBER1_Q5_2': 'ROLLNUMBER1_Q5_2',
'ROLLNUMBER1_Q6_2': 'ROLLNUMBER1_Q6_2',
'ROLLNUMBER1_Q7_2': 'ROLLNUMBER1_Q7_2',
'ROLLNUMBER1_Q8_3': 'ROLLNUMBER1_Q8_3',
'ROLLNUMBER1_Q9_3': 'ROLLNUMBER1_Q9_3',
'ROLLNUMBER1_QTEN_3': 'ROLLNUMBER1_Q10_3',
'ROLLNUMBER1_QELEVN_3': 'ROLLNUMBER1_Q11_3',
'ROLLNUMBER1_QTWL_3': 'ROLLNUMBER1_Q12_3', 
'ROLLNUMBER1_QTHRTN_3': 'ROLLNUMBER1_Q13_3',
'ROLLNUMBER2_Q1_1': 'ROLLNUMBER2_Q1_1',
'ROLLNUMBER2_Q2_1': 'ROLLNUMBER2_Q2_1',
'ROLLNUMBER2_Q3_1': 'ROLLNUMBER2_Q3_1',
'ROLLNUMBER2_Q4_2': 'ROLLNUMBER2_Q4_2',
'ROLLNUMBER2_Q5_2': 'ROLLNUMBER2_Q5_2',
'ROLLNUMBER2_Q6_2': 'ROLLNUMBER2_Q6_2',
'ROLLNUMBER2_Q7_2': 'ROLLNUMBER2_Q7_2',
'ROLLNUMBER2_Q8_3': 'ROLLNUMBER2_Q8_3',
'ROLLNUMBER2_Q9_3': 'ROLLNUMBER2_Q9_3',
'ROLLNUMBER2_QTEN_3': 'ROLLNUMBER2_Q10_3',
'ROLLNUMBER2_QELEVN_3': 'ROLLNUMBER2_Q11_3',
'ROLLNUMBER2_QTWL_3': 'ROLLNUMBER2_Q12_3',
'ROLLNUMBER2_QTHRTN_3': 'ROLLNUMBER2_Q13_3',
'ROLLNUMBER3_Q1_1': 'ROLLNUMBER3_Q1_1',
'ROLLNUMBER3_Q2_1': 'ROLLNUMBER3_Q2_1',
'ROLLNUMBER3_Q3_1': 'ROLLNUMBER3_Q3_1',
'ROLLNUMBER3_Q4_2': 'ROLLNUMBER3_Q4_2',
'ROLLNUMBER3_Q5_2': 'ROLLNUMBER3_Q5_2',
'ROLLNUMBER3_Q6_2': 'ROLLNUMBER3_Q6_2',
'ROLLNUMBER3_Q7_2': 'ROLLNUMBER3_Q7_2',
'ROLLNUMBER3_Q8_3': 'ROLLNUMBER3_Q8_3',
'ROLLNUMBER3_Q9_3': 'ROLLNUMBER3_Q9_3',
'ROLLNUMBER3_QTEN_3': 'ROLLNUMBER3_Q10_3',
'ROLLNUMBER3_QELEVN_3': 'ROLLNUMBER3_Q11_3',
'ROLLNUMBER3_QTWL_3': 'ROLLNUMBER3_Q12_3',
'ROLLNUMBER3_QTHRTN_3': 'ROLLNUMBER3_Q13_3',
'ROLLNUMBER4_Q1_1': 'ROLLNUMBER4_Q1_1',
'ROLLNUMBER4_Q2_1': 'ROLLNUMBER4_Q2_1',
'ROLLNUMBER4_Q3_1': 'ROLLNUMBER4_Q3_1',
'ROLLNUMBER4_Q4_2': 'ROLLNUMBER4_Q4_2',
'ROLLNUMBER4_Q5_2': 'ROLLNUMBER4_Q5_2',
'ROLLNUMBER4_Q6_2': 'ROLLNUMBER4_Q6_2',
'ROLLNUMBER4_Q7_2': 'ROLLNUMBER4_Q7_2',
'ROLLNUMBER4_Q8_3': 'ROLLNUMBER4_Q8_3',
'ROLLNUMBER4_Q9_3': 'ROLLNUMBER4_Q9_3',
'ROLLNUMBER4_QTEN_3': 'ROLLNUMBER4_Q10_3',
'ROLLNUMBER4_QELEVN_3': 'ROLLNUMBER4_Q11_3',
'ROLLNUMBER4_QTWL_3': 'ROLLNUMBER4_Q12_3',
'ROLLNUMBER4_QTHRTN_3': 'ROLLNUMBER4_Q13_3',
'ROLLNUMBER5_Q1_1': 'ROLLNUMBER5_Q1_1',
'ROLLNUMBER5_Q2_1': 'ROLLNUMBER5_Q2_1',
'ROLLNUMBER5_Q3_1': 'ROLLNUMBER5_Q3_1',
'ROLLNUMBER5_Q4_2': 'ROLLNUMBER5_Q4_2',
'ROLLNUMBER5_Q5_2': 'ROLLNUMBER5_Q5_2',
'ROLLNUMBER5_Q6_2': 'ROLLNUMBER5_Q6_2',
'ROLLNUMBER5_Q7_2': 'ROLLNUMBER5_Q7_2',
'ROLLNUMBER5_Q8_3': 'ROLLNUMBER5_Q8_3',
'ROLLNUMBER5_Q9_3': 'ROLLNUMBER5_Q9_3',
'ROLLNUMBER5_QTEN_3': 'ROLLNUMBER5_Q10_3',
'ROLLNUMBER5_QELEVN_3': 'ROLLNUMBER5_Q11_3',
'ROLLNUMBER5_QTWL_3': 'ROLLNUMBER5_Q12_3',
'ROLLNUMBER5_QTHRTN_3': 'ROLLNUMBER5_Q13_3',
'ROLLNUMBER6_Q1_1': 'ROLLNUMBER6_Q1_1',
'ROLLNUMBER6_Q2_1': 'ROLLNUMBER6_Q2_1',
'ROLLNUMBER6_Q3_1': 'ROLLNUMBER6_Q3_1',
'ROLLNUMBER6_Q4_2': 'ROLLNUMBER6_Q4_2',
'ROLLNUMBER6_Q5_2': 'ROLLNUMBER6_Q5_2',
'ROLLNUMBER6_Q6_2': 'ROLLNUMBER6_Q6_2',
'ROLLNUMBER6_Q7_2': 'ROLLNUMBER6_Q7_2',
'ROLLNUMBER6_Q8_3': 'ROLLNUMBER6_Q8_3',
'ROLLNUMBER6_Q9_3': 'ROLLNUMBER6_Q9_3',
'ROLLNUMBER6_QTEN_3': 'ROLLNUMBER6_Q10_3',
'ROLLNUMBER6_QELEVN_3': 'ROLLNUMBER6_Q11_3',
'ROLLNUMBER6_QTWL_3': 'ROLLNUMBER6_Q12_3',
'ROLLNUMBER6_QTHRTN_3': 'ROLLNUMBER6_Q13_3',
'ROLLNUMBER7_Q1_1': 'ROLLNUMBER7_Q1_1',
'ROLLNUMBER7_Q2_1': 'ROLLNUMBER7_Q2_1',
'ROLLNUMBER7_Q3_1': 'ROLLNUMBER7_Q3_1',
'ROLLNUMBER7_Q4_2': 'ROLLNUMBER7_Q4_2',
'ROLLNUMBER7_Q5_2': 'ROLLNUMBER7_Q5_2',
'ROLLNUMBER7_Q6_2': 'ROLLNUMBER7_Q6_2',
'ROLLNUMBER7_Q7_2': 'ROLLNUMBER7_Q7_2',
'ROLLNUMBER7_Q8_3': 'ROLLNUMBER7_Q8_3',
'ROLLNUMBER7_Q9_3': 'ROLLNUMBER7_Q9_3',
'ROLLNUMBER7_QTEN_3': 'ROLLNUMBER7_Q10_3',
'ROLLNUMBER7_QELEVN_3': 'ROLLNUMBER7_Q11_3',
'ROLLNUMBER7_QTWL_3': 'ROLLNUMBER7_Q12_3',
'ROLLNUMBER7_QTHRTN_3': 'ROLLNUMBER7_Q13_3',
'ROLLNUMBER8_Q1_1': 'ROLLNUMBER8_Q1_1',
'ROLLNUMBER8_Q2_1': 'ROLLNUMBER8_Q2_1',
'ROLLNUMBER8_Q3_1': 'ROLLNUMBER8_Q3_1',
'ROLLNUMBER8_Q4_2': 'ROLLNUMBER8_Q4_2',
'ROLLNUMBER8_Q5_2': 'ROLLNUMBER8_Q5_2',
'ROLLNUMBER8_Q6_2': 'ROLLNUMBER8_Q6_2',
'ROLLNUMBER8_Q7_2': 'ROLLNUMBER8_Q7_2',
'ROLLNUMBER8_Q8_3': 'ROLLNUMBER8_Q8_3',
'ROLLNUMBER8_Q9_3': 'ROLLNUMBER8_Q9_3',
'ROLLNUMBER8_QTEN_3': 'ROLLNUMBER8_Q10_3', 
'ROLLNUMBER8_QELEVN_3': 'ROLLNUMBER8_Q11_3',  
'ROLLNUMBER8_QTWL_3': 'ROLLNUMBER8_Q12_3',
'ROLLNUMBER8_QTHRTN_3': 'ROLLNUMBER8_Q13_3'
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "HINDI8S13QOMR Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 151,
#                             "left": 54,
#                             "bottom": 178,
#                             "right": 69
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
