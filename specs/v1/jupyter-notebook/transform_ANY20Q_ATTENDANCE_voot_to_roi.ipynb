# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatNameLookup):


    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                 extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                 extractionValue = "CELL_OMR"
                    
            try:
                annotationTagsValue = formatNameLookup[region['tags'][0]]
            except KeyError as ke:
                 annotationTagsValue =  region['tags'][0]

            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = str(tagGroup)
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
             
                    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatNameLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              print(formatName,formatValue)
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data


def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "ANY20QATTENDANCE Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("ANY_20S_attendance_vottraw.json")

# %%
tagGroups = ["ROLLNUMBERID1","ROLLNUMBER1_Q1","ROLLNUMBERID2","ROLLNUMBER2_Q1","ROLLNUMBERID3","ROLLNUMBER3_Q1","ROLLNUMBERID4","ROLLNUMBER4_Q1","ROLLNUMBERID5","ROLLNUMBER5_Q1","ROLLNUMBERID6","ROLLNUMBER6_Q1","ROLLNUMBERID7","ROLLNUMBER7_Q1","ROLLNUMBERID8","ROLLNUMBER8_Q1","ROLLNUMBERID9","ROLLNUMBER9_Q1","ROLLNUMBERID10","ROLLNUMBER10_Q1","ROLLNUMBERID11","ROLLNUMBER11_Q1","ROLLNUMBERID12","ROLLNUMBER12_Q1","ROLLNUMBERID13","ROLLNUMBER13_Q1","ROLLNUMBERID14","ROLLNUMBER14_Q1","ROLLNUMBERID15","ROLLNUMBER15_Q1"]

formatLookup = {
    "ROLLNUMBERID1": "ROLLNUMBERID1",
    "ROLLNUMBER1_Q1": "ROLLNUMBER1 Q1",
    "ROLLNUMBERID2": "ROLLNUMBERID2",
    "ROLLNUMBER2_Q1": "ROLLNUMBER2 Q1",
    "ROLLNUMBERID3": "ROLLNUMBERID3",
    "ROLLNUMBER3_Q1": "ROLLNUMBER3 Q1",
    "ROLLNUMBERID4": "ROLLNUMBERID4",
    "ROLLNUMBER4_Q1": "ROLLNUMBER4 Q1",
    "ROLLNUMBERID5": "ROLLNUMBERID5",
    "ROLLNUMBER5_Q1": "ROLLNUMBER5 Q1",
    "ROLLNUMBERID6": "ROLLNUMBERID6",
    "ROLLNUMBER6_Q1": "ROLLNUMBER6 Q1",
    "ROLLNUMBERID7": "ROLLNUMBERID7",
    "ROLLNUMBER7_Q1": "ROLLNUMBER7 Q1",
    "ROLLNUMBERID8": "ROLLNUMBERID8",
    "ROLLNUMBER8_Q1": "ROLLNUMBER8 Q1",
    "ROLLNUMBERID9": "ROLLNUMBERID9",
    "ROLLNUMBER9_Q1": "ROLLNUMBER9 Q1",
    "ROLLNUMBERID10": "ROLLNUMBERID10",
    "ROLLNUMBER10_Q1": "ROLLNUMBER10 Q1",
    "ROLLNUMBERID11": "ROLLNUMBERID11",
    "ROLLNUMBER11_Q1": "ROLLNUMBER11 Q1",
    "ROLLNUMBERID12": "ROLLNUMBERID12",
    "ROLLNUMBER12_Q1": "ROLLNUMBER12 Q1",
    "ROLLNUMBERID13": "ROLLNUMBERID13",
    "ROLLNUMBER13_Q1": "ROLLNUMBER13 Q1",
    "ROLLNUMBERID14": "ROLLNUMBERID14",
    "ROLLNUMBER14_Q1": "ROLLNUMBER14 Q1",
    "ROLLNUMBERID15": "ROLLNUMBERID15",
    "ROLLNUMBER15_Q1": "ROLLNUMBER15 Q1"
}

formatNameLookup = {
'ROLLNUMBERID1_1': 'ROLLNUMBERID1_1',
'ROLLNUMBERID1_2': 'ROLLNUMBERID1_2',
'ROLLNUMBERID1_3': 'ROLLNUMBERID1_3',
'ROLLNUMBERID1_4': 'ROLLNUMBERID1_4',
'ROLLNUMBERID1_5': 'ROLLNUMBERID1_5',
'ROLLNUMBERID1_6': 'ROLLNUMBERID1_6',
'ROLLNUMBERID1_7': 'ROLLNUMBERID1_7',
'ROLLNUMBER1_Q1':'ROLLNUMBER1_Q1',
'ROLLNUMBERID2_1': 'ROLLNUMBERID2_1 ',
'ROLLNUMBERID2_2': 'ROLLNUMBERID2_2',
'ROLLNUMBERID2_3': 'ROLLNUMBERID2_3 ',
'ROLLNUMBERID2_4': 'ROLLNUMBERID2_4',
'ROLLNUMBERID2_5': 'ROLLNUMBERID2_5',
'ROLLNUMBERID2_6': 'ROLLNUMBERID2_6',
'ROLLNUMBERID2_7': 'ROLLNUMBERID2_7',
'ROLLNUMBER2_Q1':'ROLLNUMBER2_Q1',
'ROLLNUMBERID3_1': 'ROLLNUMBERID3_1 ',
'ROLLNUMBERID3_2': 'ROLLNUMBERID3_2',
'ROLLNUMBERID3_3': 'ROLLNUMBERID3_3 ',
'ROLLNUMBERID3_4': 'ROLLNUMBERID3_4',
'ROLLNUMBERID3_5': 'ROLLNUMBERID3_5',
'ROLLNUMBERID3_6': 'ROLLNUMBERID3_6',
'ROLLNUMBERID3_7': 'ROLLNUMBERID3_7',
'ROLLNUMBER3_Q1': 'ROLLNUMBER3_Q1', 
'ROLLNUMBERID4_1': 'ROLLNUMBERID4_1 ',
'ROLLNUMBERID4_2': 'ROLLNUMBERID4_2',
'ROLLNUMBERID4_3': 'ROLLNUMBERID4_3 ',
'ROLLNUMBERID4_4': 'ROLLNUMBERID4_4',
'ROLLNUMBERID4_5': 'ROLLNUMBERID4_5',
'ROLLNUMBERID4_6': 'ROLLNUMBERID4_6',
'ROLLNUMBERID4_7': 'ROLLNUMBERID4_7',
'ROLLNUMBER4_Q1': 'ROLLNUMBER4_Q1',
'ROLLNUMBERID5_1': 'ROLLNUMBERID5_1 ',
'ROLLNUMBERID5_2': 'ROLLNUMBERID5_2',
'ROLLNUMBERID5_3': 'ROLLNUMBERID5_3 ',
'ROLLNUMBERID5_4': 'ROLLNUMBERID5_4',
'ROLLNUMBERID5_5': 'ROLLNUMBERID5_5',
'ROLLNUMBERID5_6': 'ROLLNUMBERID5_6',
'ROLLNUMBERID5_7': 'ROLLNUMBERID5_7',
'ROLLNUMBER5_Q1': 'ROLLNUMBER5_Q1',
'ROLLNUMBERID6_1': 'ROLLNUMBERID6_1 ',
'ROLLNUMBERID6_2': 'ROLLNUMBERID6_2',
'ROLLNUMBERID6_3': 'ROLLNUMBERID6_3 ',
'ROLLNUMBERID6_4': 'ROLLNUMBERID6_4',
'ROLLNUMBERID6_5': 'ROLLNUMBERID6_5',
'ROLLNUMBERID6_6': 'ROLLNUMBERID6_6',
'ROLLNUMBERID6_7': 'ROLLNUMBERID6_7',
'ROLLNUMBER6_Q1': 'ROLLNUMBER6_Q1',
'ROLLNUMBERID7_1': 'ROLLNUMBERID7_1 ',
'ROLLNUMBERID7_2': 'ROLLNUMBERID7_2',
'ROLLNUMBERID7_3': 'ROLLNUMBERID7_3 ',
'ROLLNUMBERID7_4': 'ROLLNUMBERID7_4',
'ROLLNUMBERID7_5': 'ROLLNUMBERID7_5',
'ROLLNUMBERID7_6': 'ROLLNUMBERID7_6',
'ROLLNUMBERID7_7': 'ROLLNUMBERID7_7',
'ROLLNUMBER7_Q1': 'ROLLNUMBER7_Q1',
'ROLLNUMBERID8_1': 'ROLLNUMBERID8_1 ',
'ROLLNUMBERID8_2': 'ROLLNUMBERID8_2',
'ROLLNUMBERID8_3': 'ROLLNUMBERID8_3 ',
'ROLLNUMBERID8_4': 'ROLLNUMBERID8_4',
'ROLLNUMBERID8_5': 'ROLLNUMBERID8_5',
'ROLLNUMBERID8_6': 'ROLLNUMBERID8_6',
'ROLLNUMBERID8_7': 'ROLLNUMBERID8_7',
'ROLLNUMBER8_Q1': 'ROLLNUMBER8_Q1', 
'ROLLNUMBERID9_1': 'ROLLNUMBERID9_1 ',
'ROLLNUMBERID9_2': 'ROLLNUMBERID9_2',
'ROLLNUMBERID9_3': 'ROLLNUMBERID9_3 ',
'ROLLNUMBERID9_4': 'ROLLNUMBERID9_4',
'ROLLNUMBERID9_5': 'ROLLNUMBERID9_5',
'ROLLNUMBERID9_6': 'ROLLNUMBERID9_6',
'ROLLNUMBERID9_7': 'ROLLNUMBERID9_7',
'ROLLNUMBER9_Q1': 'ROLLNUMBER9_Q1',
'ROLLNUMBERID10_1': 'ROLLNUMBERID10_1',
'ROLLNUMBERID10_2': 'ROLLNUMBERID10_2',
'ROLLNUMBERID10_3': 'ROLLNUMBERID10_3 ',
'ROLLNUMBERID10_4': 'ROLLNUMBERID10_4',
'ROLLNUMBERID10_5': 'ROLLNUMBERID10_5',
'ROLLNUMBERID10_6': 'ROLLNUMBERID10_6',
'ROLLNUMBERID10_7': 'ROLLNUMBERID10_7',
'ROLLNUMBER10_Q1': 'ROLLNUMBER10_Q1',
'ROLLNUMBERID11_1': 'ROLLNUMBERID11_1',
'ROLLNUMBERID11_2': 'ROLLNUMBERID11_2',
'ROLLNUMBERID11_3': 'ROLLNUMBERID11_3 ',
'ROLLNUMBERID11_4': 'ROLLNUMBERID11_4',
'ROLLNUMBERID11_5': 'ROLLNUMBERID11_5',
'ROLLNUMBERID11_6': 'ROLLNUMBERID11_6',
'ROLLNUMBERID11_7': 'ROLLNUMBERID11_7',
'ROLLNUMBER11_Q1': 'ROLLNUMBER11_Q1',   
'ROLLNUMBERID12_1': 'ROLLNUMBERID12_1',
'ROLLNUMBERID12_2': 'ROLLNUMBERID12_2',
'ROLLNUMBERID12_3': 'ROLLNUMBERID12_3 ',
'ROLLNUMBERID12_4': 'ROLLNUMBERID12_4',
'ROLLNUMBERID12_5': 'ROLLNUMBERID12_5',
'ROLLNUMBERID12_6': 'ROLLNUMBERID12_6',
'ROLLNUMBERID12_7': 'ROLLNUMBERID12_7',
'ROLLNUMBER12_Q1': 'ROLLNUMBER12_Q1',  
'ROLLNUMBERID13_1': 'ROLLNUMBERID13_1',
'ROLLNUMBERID13_2': 'ROLLNUMBERID13_2',
'ROLLNUMBERID13_3': 'ROLLNUMBERID13_3 ',
'ROLLNUMBERID13_4': 'ROLLNUMBERID13_4',
'ROLLNUMBERID13_5': 'ROLLNUMBERID13_5',
'ROLLNUMBERID13_6': 'ROLLNUMBERID13_6',
'ROLLNUMBERID13_7': 'ROLLNUMBERID13_7',
'ROLLNUMBER13_Q1': 'ROLLNUMBER13_Q1',   
'ROLLNUMBERID14_1': 'ROLLNUMBERID14_1',
'ROLLNUMBERID14_2': 'ROLLNUMBERID14_2',
'ROLLNUMBERID14_3': 'ROLLNUMBERID14_3 ',
'ROLLNUMBERID14_4': 'ROLLNUMBERID14_4',
'ROLLNUMBERID14_5': 'ROLLNUMBERID14_5',
'ROLLNUMBERID14_6': 'ROLLNUMBERID14_6',
'ROLLNUMBERID14_7': 'ROLLNUMBERID14_7',
'ROLLNUMBER14_Q1': 'ROLLNUMBER14_Q1',
'ROLLNUMBERID15_1': 'ROLLNUMBERID15_1',
'ROLLNUMBERID15_2': 'ROLLNUMBERID15_2',
'ROLLNUMBERID15_3': 'ROLLNUMBERID15_3 ',
'ROLLNUMBERID15_4': 'ROLLNUMBERID15_4',
'ROLLNUMBERID15_5': 'ROLLNUMBERID15_5',
'ROLLNUMBERID15_6': 'ROLLNUMBERID15_6',
'ROLLNUMBERID15_7': 'ROLLNUMBERID15_7',
'ROLLNUMBER15_Q1': 'ROLLNUMBER15_Q1'   
# 'ROLLNUMBERIDSIXT_1': 'ROLLNUMBERID16_1',
# 'ROLLNUMBERIDSIXT_2': 'ROLLNUMBERID16_2',
# 'ROLLNUMBERIDSIXT_3': 'ROLLNUMBERID16_3 ',
# 'ROLLNUMBERIDSIXT_4': 'ROLLNUMBERID16_4',
# 'ROLLNUMBERIDSIXT_5': 'ROLLNUMBERID16_5',
# 'ROLLNUMBERIDSIXT_6': 'ROLLNUMBERID16_6',
# 'ROLLNUMBERIDSIXT_7': 'ROLLNUMBERID16_7',
# 'ROLLNUMBERSIXT_Q1': 'ROLLNUMBER16_Q1',   
# 'ROLLNUMBERIDSVNT_1': 'ROLLNUMBERID17_1',
# 'ROLLNUMBERIDSVNT_2': 'ROLLNUMBERID17_2',
# 'ROLLNUMBERIDSVNT_3': 'ROLLNUMBERID17_3 ',
# 'ROLLNUMBERIDSVNT_4': 'ROLLNUMBERID17_4',
# 'ROLLNUMBERIDSVNT_5': 'ROLLNUMBERID17_5',
# 'ROLLNUMBERIDSVNT_6': 'ROLLNUMBERID17_6',
# 'ROLLNUMBERIDSVNT_7': 'ROLLNUMBERID17_7',
# 'ROLLNUMBERSVNT_Q1': 'ROLLNUMBER17_Q1',   
# 'ROLLNUMBERIDEGTN_1': 'ROLLNUMBERID18_1',
# 'ROLLNUMBERIDEGTN_2': 'ROLLNUMBERID18_2',
# 'ROLLNUMBERIDEGTN_3': 'ROLLNUMBERID18_3 ',
# 'ROLLNUMBERIDEGTN_4': 'ROLLNUMBERID18_4',
# 'ROLLNUMBERIDEGTN_5': 'ROLLNUMBERID18_5',
# 'ROLLNUMBERIDEGTN_6': 'ROLLNUMBERID18_6',
# 'ROLLNUMBERIDEGTN_7': 'ROLLNUMBERID18_7',
# 'ROLLNUMBEREGTN_Q1': 'ROLLNUMBER18_Q1',   
# 'ROLLNUMBERIDNINT_1': 'ROLLNUMBERID19_1',
# 'ROLLNUMBERIDNINT_2': 'ROLLNUMBERID19_2',
# 'ROLLNUMBERIDNINT_3': 'ROLLNUMBERID19_3 ',
# 'ROLLNUMBERIDNINT_4': 'ROLLNUMBERID19_4',
# 'ROLLNUMBERIDNINT_5': 'ROLLNUMBERID19_5',
# 'ROLLNUMBERIDNINT_6': 'ROLLNUMBERID19_6',
# 'ROLLNUMBERIDNINT_7': 'ROLLNUMBERID19_7',
# 'ROLLNUMBERNINT_Q1': 'ROLLNUMBER19_Q1',   
# 'ROLLNUMBERIDTWNTY_1': 'ROLLNUMBERID20_1',
# 'ROLLNUMBERIDTWNTY_2': 'ROLLNUMBERID20_2',
# 'ROLLNUMBERIDTWNTY_3': 'ROLLNUMBERID20_3 ',
# 'ROLLNUMBERIDTWNTY_4': 'ROLLNUMBERID20_4',
# 'ROLLNUMBERIDTWNTY_5': 'ROLLNUMBERID20_5',
# 'ROLLNUMBERIDTWNTY_6': 'ROLLNUMBERID20_6',
# 'ROLLNUMBERIDTWNTY_7': 'ROLLNUMBERID20_7',
# 'ROLLNUMBERTWNTY_Q1': 'ROLLNUMBER20_Q1'  
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup)
# Out:
# ROLLNUMBERID1 ROLLNUMBERID1
# ROLLNUMBER1_Q1 ROLLNUMBER1 Q1
# ROLLNUMBERID2 ROLLNUMBERID2
# ROLLNUMBER2_Q1 ROLLNUMBER2 Q1
# ROLLNUMBERID3 ROLLNUMBERID3
# ROLLNUMBER3_Q1 ROLLNUMBER3 Q1
# ROLLNUMBERID4 ROLLNUMBERID4
# ROLLNUMBER4_Q1 ROLLNUMBER4 Q1
# ROLLNUMBERID5 ROLLNUMBERID5
# ROLLNUMBER5_Q1 ROLLNUMBER5 Q1
# ROLLNUMBERID6 ROLLNUMBERID6
# ROLLNUMBER6_Q1 ROLLNUMBER6 Q1
# ROLLNUMBERID7 ROLLNUMBERID7
# ROLLNUMBER7_Q1 ROLLNUMBER7 Q1
# ROLLNUMBERID8 ROLLNUMBERID8
# ROLLNUMBER8_Q1 ROLLNUMBER8 Q1
# ROLLNUMBERID9 ROLLNUMBERID9
# ROLLNUMBER9_Q1 ROLLNUMBER9 Q1
# ROLLNUMBERID10 ROLLNUMBERID10
# ROLLNUMBER10_Q1 ROLLNUMBER10 Q1
# ROLLNUMBERID11 ROLLNUMBERID11
# ROLLNUMBER11_Q1 ROLLNUMBER11 Q1
# ROLLNUMBERID12 ROLLNUMBERID12
# ROLLNUMBER12_Q1 ROLLNUMBER12 Q1
# ROLLNUMBERID13 ROLLNUMBERID13
# ROLLNUMBER13_Q1 ROLLNUMBER13 Q1
# ROLLNUMBERID14 ROLLNUMBERID14
# ROLLNUMBER14_Q1 ROLLNUMBER14 Q1
# ROLLNUMBERID15 ROLLNUMBERID15
# ROLLNUMBER15_Q1 ROLLNUMBER15 Q1

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "ANY20QATTENDANCE Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 118,
#                             "left": 70,
#                             "bottom": 142,
#                             "right": 92
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
