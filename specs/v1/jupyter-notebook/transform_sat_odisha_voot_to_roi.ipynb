# %%
# Dileep Gadiraju - Odisha ROI Transformation from VoTT Raw format
# Takes filename of VoTT raw format file and generates ROI configuration
import uuid
import json

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    roiIndex = 1 

    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            rois.append({
                "annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": roiIndex,
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups):
    
    cells_data = []
    renderIndex = 1
    cellIndex = 1
    for tagGroup in tagGroups: 
              cells_data.append({
                          "cellId": cellIndex,
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.replace("_", ""),
                              "value": tagGroup.replace("_", "")
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "Odisha SAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

pp_json(get_layout(cells))
# Out:
# {
#     "layout": {
#         "cells": [
#             {
#                 "cellId": 1,
#                 "format": {
#                     "name": "STUDENTID",
#                     "value": "STUDENTID"
#                 },
#                 "render": {
#                     "index": 1
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "eKS5GDoKy",
#                         "annotationTags": "STUDENTID_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 192,
#                             "right": 210,
#                             "top": 30
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "07gfo-X6k",
#                         "annotationTags": "STUDENTID_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 51,
#                             "left": 215,
#                             "right": 238,
#                             "top": 29
#                         },
#                         "roiId": 2
#                     },
#                     {
#                         "annotationId": "bv3o6dbOL",
#                         "annotationTags": "STUDENTID_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 2,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 242,
#                             "right": 265,
#                             "top": 30
#                         },
#                         "roiId": 3
#                     },
#                     {
#                         "annotationId": "bxUpSr1kN",
#                         "annotationTags": "STUDENTID_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 3,
#                         "rect": {
#                             "bottom": 49,
#                             "left": 269,
#                             "right": 291,
#                             "top": 30
#                         },
#                         "roiId": 4
#                     },
#                     {
#                         "annotationId": "2AjEL9QuH",
#                         "annotationTags": "STUDENTID_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 4,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 294,
#                             "right": 315,
#                             "top": 31
#                         },
#                         "roiId": 5
#                     },
#                     {
#                         "annotationId": "sVXs9IDX3",
#                         "annotationTags": "STUDENTID_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 5,
#                         "rect": {
#                             "bottom": 49,
#                             "left": 319,
#                             "right": 340,
#                             "top": 31
#                         },
#                         "roiId": 6
#                     },
#                     {
#                         "annotationId": "AcbEHjPdD",
#                         "annotationTags": "STUDENTID_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 6,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 344,
#                             "right": 367,
#                             "top": 31
#                         },
#                         "roiId": 7
#                     },
#                     {
#                         "annotationId": "Om50EqhmL",
#                         "annotationTags": "STUDENTID_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 7,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 371,
#                             "right": 392,
#                             "top": 31
#                         },
#                         "roiId": 8
#                     },
#                     {
#                         "annotationId": "_EITxSSf2",
#                         "annotationTags": "STUDENTID_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 8,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 395,
#                             "right": 417,
#                             "top": 31
#                         },
#                         "roiId": 9
#                     },
#                     {
#                         "annotationId": "RouzCuE85",
#                         "annotationTags": "STUDENTID_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 9,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 421,
#                             "right": 442,
#                             "top": 31
#                         },
#                         "roiId": 10
#                     },
#                     {
#                         "annotationId": "KMkXP1EDG",
#                         "annotationTags": "STUDENTID_11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 10,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 446,
#                             "right": 468,
#                             "top": 31
#                         },
#                         "roiId": 11
#                     },
#                     {
#                         "annotationId": "11AKDb31Z",
#                         "annotationTags": "STUDENTID_12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 11,
#                         "rect": {
#                             "bottom": 48,
#                             "left": 472,
#                             "right": 494,
#                             "top": 30
#                         },
#                         "roiId": 12
#                     },
#                     {
#                         "annotationId": "fL6XpwpwP",
#                         "annotationTags": "STUDENTID_13",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 12,
#                         "rect": {
#                             "bottom": 51,
#                             "left": 498,
#                             "right": 519,
#                             "top": 30
#                         },
#                         "roiId": 13
#                     },
#                     {
#                         "annotationId": "7_X3wXjhL",
#                         "annotationTags": "STUDENTID_14",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 13,
#                         "rect": {
#                             "bottom": 51,
#                             "left": 522,
#                             "right": 544,
#                             "top": 31
#                         },
#                         "roiId": 14
#                     },
#                     {
#                         "annotationId": "9jfgY1qtO",
#                         "annotationTags": "STUDENTID_15",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 14,
#                         "rect": {
#                             "bottom": 51,
#                             "left": 548,
#                             "right": 570,
#                             "top": 31
#                         },
#                         "roiId": 15
#                     },
#                     {
#                         "annotationId": "QcswxWY1s",
#                         "annotationTags": "STUDENTID_16",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 15,
#                         "rect": {
#                             "bottom": 50,
#                             "left": 573,
#                             "right": 596,
#                             "top": 30
#                         },
#                         "roiId": 16
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 2,
#                 "format": {
#                     "name": "QUESTION1",
#                     "value": "QUESTION1"
#                 },
#                 "render": {
#                     "index": 2
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "vFcepRW2k",
#                         "annotationTags": "QUESTION1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 115,
#                             "left": 215,
#                             "right": 238,
#                             "top": 96
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "Z4Q8hjcR7",
#                         "annotationTags": "QUESTION1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 117,
#                             "left": 252,
#                             "right": 276,
#                             "top": 97
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 3,
#                 "format": {
#                     "name": "QUESTION2",
#                     "value": "QUESTION2"
#                 },
#                 "render": {
#                     "index": 3
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "MvthTtZS0",
#                         "annotationTags": "QUESTION2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 147,
#                             "left": 216,
#                             "right": 240,
#                             "top": 128
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "9NsptTzne",
#                         "annotationTags": "QUESTION2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 148,
#                             "left": 253,
#                             "right": 275,
#                             "top": 128
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 4,
#                 "format": {
#                     "name": "QUESTION3",
#                     "value": "QUESTION3"
#                 },
#                 "render": {
#                     "index": 4
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "Y1tY6l4N3",
#                         "annotationTags": "QUESTION3_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 179,
#                             "left": 216,
#                             "right": 239,
#                             "top": 158
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "2B7hKNVlm",
#                         "annotationTags": "QUESTION3_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 179,
#                             "left": 254,
#                             "right": 277,
#                             "top": 159
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 5,
#                 "format": {
#                     "name": "QUESTION4",
#                     "value": "QUESTION4"
#                 },
#                 "render": {
#                     "index": 5
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "lJajZC-En",
#                         "annotationTags": "QUESTION4_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 211,
#                             "left": 215,
#                             "right": 239,
#                             "top": 191
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "a27bXhfIq",
#                         "annotationTags": "QUESTION4_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 211,
#                             "left": 254,
#                             "right": 277,
#                             "top": 190
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 6,
#                 "format": {
#                     "name": "QUESTION5",
#                     "value": "QUESTION5"
#                 },
#                 "render": {
#                     "index": 6
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "dwrADIlko",
#                         "annotationTags": "QUESTION5_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 241,
#                             "left": 217,
#                             "right": 240,
#                             "top": 221
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "5G1m9rB0M",
#                         "annotationTags": "QUESTION5_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 240,
#                             "left": 254,
#                             "right": 277,
#                             "top": 221
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 7,
#                 "format": {
#                     "name": "QUESTION6",
#                     "value": "QUESTION6"
#                 },
#                 "render": {
#                     "index": 7
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "n4Q67gnZH",
#                         "annotationTags": "QUESTION6_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 272,
#                             "left": 216,
#                             "right": 239,
#                             "top": 253
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "IK_dnNCHL",
#                         "annotationTags": "QUESTION6_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 272,
#                             "left": 255,
#                             "right": 277,
#                             "top": 252
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 8,
#                 "format": {
#                     "name": "QUESTION7",
#                     "value": "QUESTION7"
#                 },
#                 "render": {
#                     "index": 8
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "zF7l1F1E6",
#                         "annotationTags": "QUESTION7_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 304,
#                             "left": 217,
#                             "right": 240,
#                             "top": 284
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "yqb811NKt",
#                         "annotationTags": "QUESTION7_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 303,
#                             "left": 255,
#                             "right": 277,
#                             "top": 282
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 9,
#                 "format": {
#                     "name": "QUESTION8",
#                     "value": "QUESTION8"
#                 },
#                 "render": {
#                     "index": 9
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "-m8mtkweq",
#                         "annotationTags": "QUESTION8_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 333,
#                             "left": 216,
#                             "right": 238,
#                             "top": 315
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "mhXVeEpNP",
#                         "annotationTags": "QUESTION8_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 334,
#                             "left": 254,
#                             "right": 276,
#                             "top": 314
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 10,
#                 "format": {
#                     "name": "QUESTION9",
#                     "value": "QUESTION9"
#                 },
#                 "render": {
#                     "index": 10
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "obB0ldNIa",
#                         "annotationTags": "QUESTION9_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 364,
#                             "left": 217,
#                             "right": 240,
#                             "top": 346
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "rXbrEobnu",
#                         "annotationTags": "QUESTION9_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 365,
#                             "left": 254,
#                             "right": 277,
#                             "top": 346
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 11,
#                 "format": {
#                     "name": "QUESTION10",
#                     "value": "QUESTION10"
#                 },
#                 "render": {
#                     "index": 11
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "Ifp71Rcwk",
#                         "annotationTags": "QUESTION10_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 396,
#                             "left": 217,
#                             "right": 239,
#                             "top": 378
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "0Ef9J59as",
#                         "annotationTags": "QUESTION10_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 396,
#                             "left": 254,
#                             "right": 277,
#                             "top": 378
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 12,
#                 "format": {
#                     "name": "QUESTION11",
#                     "value": "QUESTION11"
#                 },
#                 "render": {
#                     "index": 12
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "jrwUFusmU",
#                         "annotationTags": "QUESTION11_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 115,
#                             "left": 512,
#                             "right": 534,
#                             "top": 96
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "CWIYnEzlF",
#                         "annotationTags": "QUESTION11_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 115,
#                             "left": 550,
#                             "right": 571,
#                             "top": 97
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 13,
#                 "format": {
#                     "name": "QUESTION12",
#                     "value": "QUESTION12"
#                 },
#                 "render": {
#                     "index": 13
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "zk0eRRqMi",
#                         "annotationTags": "QUESTION12_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 148,
#                             "left": 512,
#                             "right": 534,
#                             "top": 129
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "D_jFs5_Zc",
#                         "annotationTags": "QUESTION12_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 147,
#                             "left": 551,
#                             "right": 572,
#                             "top": 128
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 14,
#                 "format": {
#                     "name": "QUESTION13",
#                     "value": "QUESTION13"
#                 },
#                 "render": {
#                     "index": 14
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "d-bW8vYQG",
#                         "annotationTags": "QUESTION13_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 178,
#                             "left": 512,
#                             "right": 534,
#                             "top": 160
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "1ZoWIQLxG",
#                         "annotationTags": "QUESTION13_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 177,
#                             "left": 550,
#                             "right": 572,
#                             "top": 160
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 15,
#                 "format": {
#                     "name": "QUESTION14",
#                     "value": "QUESTION14"
#                 },
#                 "render": {
#                     "index": 15
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "VqzZ0uw_h",
#                         "annotationTags": "QUESTION14_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 210,
#                             "left": 511,
#                             "right": 533,
#                             "top": 191
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "aQ6stvzCG",
#                         "annotationTags": "QUESTION14_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 210,
#                             "left": 549,
#                             "right": 570,
#                             "top": 190
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 16,
#                 "format": {
#                     "name": "QUESTION15",
#                     "value": "QUESTION15"
#                 },
#                 "render": {
#                     "index": 16
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "S3MWGUi8W",
#                         "annotationTags": "QUESTION15_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 240,
#                             "left": 511,
#                             "right": 532,
#                             "top": 222
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "IxTpX_Nwm",
#                         "annotationTags": "QUESTION15_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 239,
#                             "left": 549,
#                             "right": 570,
#                             "top": 222
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 17,
#                 "format": {
#                     "name": "QUESTION16",
#                     "value": "QUESTION16"
#                 },
#                 "render": {
#                     "index": 17
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "oVk3gXqe7",
#                         "annotationTags": "QUESTION16_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 272,
#                             "left": 511,
#                             "right": 532,
#                             "top": 253
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "zxLlGErzP",
#                         "annotationTags": "QUESTION16_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 272,
#                             "left": 549,
#                             "right": 570,
#                             "top": 253
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 18,
#                 "format": {
#                     "name": "QUESTION17",
#                     "value": "QUESTION17"
#                 },
#                 "render": {
#                     "index": 18
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "vvri1ICpi",
#                         "annotationTags": "QUESTION17_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 302,
#                             "left": 512,
#                             "right": 535,
#                             "top": 284
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "XRYDpDPhu",
#                         "annotationTags": "QUESTION17_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 303,
#                             "left": 550,
#                             "right": 571,
#                             "top": 284
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 19,
#                 "format": {
#                     "name": "QUESTION18",
#                     "value": "QUESTION18"
#                 },
#                 "render": {
#                     "index": 19
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "LVFeB7Esk",
#                         "annotationTags": "QUESTION18_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 333,
#                             "left": 512,
#                             "right": 534,
#                             "top": 315
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "kmFd_TUYR",
#                         "annotationTags": "QUESTION18_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 334,
#                             "left": 550,
#                             "right": 570,
#                             "top": 315
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 20,
#                 "format": {
#                     "name": "QUESTION19",
#                     "value": "QUESTION19"
#                 },
#                 "render": {
#                     "index": 20
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "E-P0HcZDx",
#                         "annotationTags": "QUESTION19_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 365,
#                             "left": 512,
#                             "right": 534,
#                             "top": 346
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "bH-bcnmQt",
#                         "annotationTags": "QUESTION19_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 365,
#                             "left": 551,
#                             "right": 570,
#                             "top": 347
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 21,
#                 "format": {
#                     "name": "QUESTION20",
#                     "value": "QUESTION20"
#                 },
#                 "render": {
#                     "index": 21
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "mbxoMePCZ",
#                         "annotationTags": "QUESTION20_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 396,
#                             "left": 512,
#                             "right": 534,
#                             "top": 378
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "uK2ozwlw5",
#                         "annotationTags": "QUESTION20_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 395,
#                             "left": 551,
#                             "right": 571,
#                             "top": 377
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 22,
#                 "format": {
#                     "name": "MAXMARKS",
#                     "value": "MAXMARKS"
#                 },
#                 "render": {
#                     "index": 22
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "T2kCVI_K3",
#                         "annotationTags": "MAX_MARKS_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 449,
#                             "left": 133,
#                             "right": 156,
#                             "top": 430
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "8htMWqCEw",
#                         "annotationTags": "MAX_MARKS_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 450,
#                             "left": 159,
#                             "right": 181,
#                             "top": 431
#                         },
#                         "roiId": 2
#                     },
#                     {
#                         "annotationId": "WGj6_lo-N",
#                         "annotationTags": "MAX_MARKS_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 2,
#                         "rect": {
#                             "bottom": 451,
#                             "left": 185,
#                             "right": 207,
#                             "top": 431
#                         },
#                         "roiId": 3
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": 23,
#                 "format": {
#                     "name": "MARKSOBTAINED",
#                     "value": "MARKSOBTAINED"
#                 },
#                 "render": {
#                     "index": 23
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "RXj9Bn8hV",
#                         "annotationTags": "MARKS_OBTAINED_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "rect": {
#                             "bottom": 449,
#                             "left": 333,
#                             "right": 354,
#                             "top": 430
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "8dMmpKvYj",
#                         "annotationTags": "MARKS_OBTAINED_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "rect": {
#                             "bottom": 448,
#                             "left": 358,
#                             "right": 380,
#                             "top": 430
#                         },
#                         "roiId": 2
#                     },
#                     {
#                         "annotationId": "AgmM8n0lW",
#                         "annotationTags": "MARKS_OBTAINED_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 2,
#                         "rect": {
#                             "bottom": 450,
#                             "left": 384,
#                             "right": 405,
#                             "top": 430
#                         },
#                         "roiId": 3
#                     }
#                 ],
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ],
#         "name": "Odisha SAT Exam Sheet Form",
#         "version": "1.0"
#     }
# }

# %%
regions=get_annotation("sat_odisha_vottraw.json")
regions
# Out:
# [{'id': 'eKS5GDoKy',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_1'],
#   'boundingBox': {'height': 20.06715689132463,
#    'width': 18.818058473389357,
#    'left': 192.39873293067228,
#    'top': 30.094832235307837},
#   'points': [{'x': 192.39873293067228, 'y': 30.094832235307837},
#    {'x': 211.21679140406164, 'y': 30.094832235307837},
#    {'x': 211.21679140406164, 'y': 50.16198912663246},
#    {'x': 192.39873293067228, 'y': 50.16198912663246}]},
#  {'id': '07gfo-X6k',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_2'],
#   'boundingBox': {'height': 22.313025323275863,
#    'width': 23.851433234229575,
#    'left': 215.7896926706308,
#    'top': 29.783081896551725},
#   'points': [{'x': 215.7896926706308, 'y': 29.783081896551725},
#    {'x': 239.6411259048604, 'y': 29.783081896551725},
#    {'x': 239.6411259048604, 'y': 52.09610721982759},
#    {'x': 215.7896926706308, 'y': 52.09610721982759}]},
#  {'id': 'bv3o6dbOL',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_3'],
#   'boundingBox': {'height': 20.170698887645056,
#    'width': 23.76111847085541,
#    'left': 242.40983984670703,
#    'top': 30.323832460898082},
#   'points': [{'x': 242.40983984670703, 'y': 30.323832460898082},
#    {'x': 266.17095831756245, 'y': 30.323832460898082},
#    {'x': 266.17095831756245, 'y': 50.49453134854314},
#    {'x': 242.40983984670703, 'y': 50.49453134854314}]},
#  {'id': 'bxUpSr1kN',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_4', 'STUDENTID_1'],
#   'boundingBox': {'height': 19.446044675517154,
#    'width': 22.577533591975776,
#    'left': 269.1274366010598,
#    'top': 30.870687752270435},
#   'points': [{'x': 269.1274366010598, 'y': 30.870687752270435},
#    {'x': 291.7049701930356, 'y': 30.870687752270435},
#    {'x': 291.7049701930356, 'y': 50.316732427787585},
#    {'x': 269.1274366010598, 'y': 50.316732427787585}]},
#  {'id': '2AjEL9QuH',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_5'],
#   'boundingBox': {'height': 19.288693493559162,
#    'width': 21.51372776982829,
#    'left': 294.87789375511034,
#    'top': 31.311258796517176},
#   'points': [{'x': 294.87789375511034, 'y': 31.311258796517176},
#    {'x': 316.39162152493867, 'y': 31.311258796517176},
#    {'x': 316.39162152493867, 'y': 50.59995229007634},
#    {'x': 294.87789375511034, 'y': 50.59995229007634}]},
#  {'id': 'sVXs9IDX3',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_6'],
#   'boundingBox': {'height': 18.619633698541442,
#    'width': 21.679304221177432,
#    'left': 319.5983557338512,
#    'top': 31.25411870825382},
#   'points': [{'x': 319.5983557338512, 'y': 31.25411870825382},
#    {'x': 341.2776599550286, 'y': 31.25411870825382},
#    {'x': 341.2776599550286, 'y': 49.87375240679526},
#    {'x': 319.5983557338512, 'y': 49.87375240679526}]},
#  {'id': 'AcbEHjPdD',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_7'],
#   'boundingBox': {'height': 19.549330250647493,
#    'width': 23.046236201962387,
#    'left': 344.7365596892886,
#    'top': 31.386984988413307},
#   'points': [{'x': 344.7365596892886, 'y': 31.386984988413307},
#    {'x': 367.782795891251, 'y': 31.386984988413307},
#    {'x': 367.782795891251, 'y': 50.9363152390608},
#    {'x': 344.7365596892886, 'y': 50.9363152390608}]},
#  {'id': 'Om50EqhmL',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_8'],
#   'boundingBox': {'height': 19.178614559194386,
#    'width': 21.92552892477514,
#    'left': 371.21544102616514,
#    'top': 31.25473371898855},
#   'points': [{'x': 371.21544102616514, 'y': 31.25473371898855},
#    {'x': 393.1409699509403, 'y': 31.25473371898855},
#    {'x': 393.1409699509403, 'y': 50.43334827818293},
#    {'x': 371.21544102616514, 'y': 50.43334827818293}]},
#  {'id': '_EITxSSf2',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_9'],
#   'boundingBox': {'height': 19.70837841637132,
#    'width': 22.279231398201144,
#    'left': 395.97474192559275,
#    'top': 31.52033848486914},
#   'points': [{'x': 395.97474192559275, 'y': 31.52033848486914},
#    {'x': 418.2539733237939, 'y': 31.52033848486914},
#    {'x': 418.2539733237939, 'y': 51.22871690124046},
#    {'x': 395.97474192559275, 'y': 51.22871690124046}]},
#  {'id': 'RouzCuE85',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_10'],
#   'boundingBox': {'height': 19.75462402876227,
#    'width': 21.980657195421095,
#    'left': 421.80741516762055,
#    'top': 31.40094653080698},
#   'points': [{'x': 421.80741516762055, 'y': 31.40094653080698},
#    {'x': 443.7880723630417, 'y': 31.40094653080698},
#    {'x': 443.7880723630417, 'y': 51.15557055956925},
#    {'x': 421.80741516762055, 'y': 51.15557055956925}]},
#  {'id': 'KMkXP1EDG',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_11'],
#   'boundingBox': {'height': 19.346456579709653,
#    'width': 22.9153464840556,
#    'left': 446.90879241618967,
#    'top': 31.35205717097192},
#   'points': [{'x': 446.90879241618967, 'y': 31.35205717097192},
#    {'x': 469.82413890024526, 'y': 31.35205717097192},
#    {'x': 469.82413890024526, 'y': 50.69851375068157},
#    {'x': 446.90879241618967, 'y': 50.69851375068157}]},
#  {'id': '11AKDb31Z',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_12'],
#   'boundingBox': {'height': 18.941571850293077,
#    'width': 22.9000153311529,
#    'left': 472.7548804170073,
#    'top': 30.41988460162214},
#   'points': [{'x': 472.7548804170073, 'y': 30.41988460162214},
#    {'x': 495.65489574816024, 'y': 30.41988460162214},
#    {'x': 495.65489574816024, 'y': 49.36145645191522},
#    {'x': 472.7548804170073, 'y': 49.36145645191522}]},
#  {'id': 'fL6XpwpwP',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_13'],
#   'boundingBox': {'height': 21.032847962956655,
#    'width': 21.38370042927228,
#    'left': 498.4239574816026,
#    'top': 30.463837901274538},
#   'points': [{'x': 498.4239574816026, 'y': 30.463837901274538},
#    {'x': 519.8076579108748, 'y': 30.463837901274538},
#    {'x': 519.8076579108748, 'y': 51.49668586423119},
#    {'x': 498.4239574816026, 'y': 51.49668586423119}]},
#  {'id': '7_X3wXjhL',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_14'],
#   'boundingBox': {'height': 20.9784075322042,
#    'width': 22.66397945625511,
#    'left': 522.5820216680294,
#    'top': 31.105190264619687},
#   'points': [{'x': 522.5820216680294, 'y': 31.105190264619687},
#    {'x': 545.2460011242845, 'y': 31.105190264619687},
#    {'x': 545.2460011242845, 'y': 52.08359779682389},
#    {'x': 522.5820216680294, 'y': 52.08359779682389}]},
#  {'id': '9jfgY1qtO',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_15'],
#   'boundingBox': {'height': 20.691772594056708,
#    'width': 22.5247214840556,
#    'left': 548.1679272281275,
#    'top': 31.010246984051257},
#   'points': [{'x': 548.1679272281275, 'y': 31.010246984051257},
#    {'x': 570.6926487121831, 'y': 31.010246984051257},
#    {'x': 570.6926487121831, 'y': 51.702019578107965},
#    {'x': 548.1679272281275, 'y': 51.702019578107965}]},
#  {'id': 'QcswxWY1s',
#   'type': 'RECTANGLE',
#   'tags': ['STUDENTID_16'],
#   'boundingBox': {'height': 20.92273707998228,
#    'width': 23.13892579721995,
#    'left': 573.3932951757972,
#    'top': 30.47855023599373},
#   'points': [{'x': 573.3932951757972, 'y': 30.47855023599373},
#    {'x': 596.5322209730172, 'y': 30.47855023599373},
#    {'x': 596.5322209730172, 'y': 51.40128731597601},
#    {'x': 573.3932951757972, 'y': 51.40128731597601}]},
#  {'id': 'vFcepRW2k',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION1_1'],
#   'boundingBox': {'height': 19.759828663498357,
#    'width': 23.614482926579164,
#    'left': 215.8819024302707,
#    'top': 96.72126085544309},
#   'points': [{'x': 215.8819024302707, 'y': 96.72126085544309},
#    {'x': 239.49638535684988, 'y': 96.72126085544309},
#    {'x': 239.49638535684988, 'y': 116.48108951894146},
#    {'x': 215.8819024302707, 'y': 116.48108951894146}]},
#  {'id': 'Z4Q8hjcR7',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION1_2'],
#   'boundingBox': {'height': 20.555796550191463,
#    'width': 24.99391150533224,
#    'left': 252.67967468211648,
#    'top': 97.24352412985502},
#   'points': [{'x': 252.67967468211648, 'y': 97.24352412985502},
#    {'x': 277.67358618744873, 'y': 97.24352412985502},
#    {'x': 277.67358618744873, 'y': 117.79932068004649},
#    {'x': 252.67967468211648, 'y': 117.79932068004649}]},
#  {'id': 'MvthTtZS0',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION2_1'],
#   'boundingBox': {'height': 19.939552490768595,
#    'width': 24.500038453650532,
#    'left': 216.3842673297785,
#    'top': 128.15453193380742},
#   'points': [{'x': 216.3842673297785, 'y': 128.15453193380742},
#    {'x': 240.88430578342903, 'y': 128.15453193380742},
#    {'x': 240.88430578342903, 'y': 148.094084424576},
#    {'x': 216.3842673297785, 'y': 148.094084424576}]},
#  {'id': '9NsptTzne',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION2_2'],
#   'boundingBox': {'height': 20.592770232152624,
#    'width': 22.743475697292862,
#    'left': 253.8783711033634,
#    'top': 128.32161066568653},
#   'points': [{'x': 253.8783711033634, 'y': 128.32161066568653},
#    {'x': 276.6218468006563, 'y': 128.32161066568653},
#    {'x': 276.6218468006563, 'y': 148.91438089783915},
#    {'x': 253.8783711033634, 'y': 148.91438089783915}]},
#  {'id': 'Y1tY6l4N3',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION3_1'],
#   'boundingBox': {'height': 21.555143727776255,
#    'width': 23.86943062961444,
#    'left': 216.2663428014766,
#    'top': 158.4434939995897},
#   'points': [{'x': 216.2663428014766, 'y': 158.4434939995897},
#    {'x': 240.13577343109105, 'y': 158.4434939995897},
#    {'x': 240.13577343109105, 'y': 179.99863772736595},
#    {'x': 216.2663428014766, 'y': 179.99863772736595}]},
#  {'id': '2B7hKNVlm',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION3_2'],
#   'boundingBox': {'height': 20.016064132590262,
#    'width': 23.394367821985234,
#    'left': 254.26188217801476,
#    'top': 159.25944722716082},
#   'points': [{'x': 254.26188217801476, 'y': 159.25944722716082},
#    {'x': 277.65625, 'y': 159.25944722716082},
#    {'x': 277.65625, 'y': 179.27551135975108},
#    {'x': 254.26188217801476, 'y': 179.27551135975108}]},
#  {'id': 'lJajZC-En',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION4_1'],
#   'boundingBox': {'height': 20.841985990495075,
#    'width': 24.611009280147663,
#    'left': 215.7839738002461,
#    'top': 191.01262800020513},
#   'points': [{'x': 215.7839738002461, 'y': 191.01262800020513},
#    {'x': 240.39498308039376, 'y': 191.01262800020513},
#    {'x': 240.39498308039376, 'y': 211.8546139907002},
#    {'x': 215.7839738002461, 'y': 211.8546139907002}]},
#  {'id': 'a27bXhfIq',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION4_2'],
#   'boundingBox': {'height': 21.21542498632385,
#    'width': 23.66504947703035,
#    'left': 254.38637587161608,
#    'top': 190.78500025642776},
#   'points': [{'x': 254.38637587161608, 'y': 190.78500025642776},
#    {'x': 278.05142534864643, 'y': 190.78500025642776},
#    {'x': 278.05142534864643, 'y': 212.00042524275162},
#    {'x': 254.38637587161608, 'y': 212.00042524275162}]},
#  {'id': 'dwrADIlko',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION5_1'],
#   'boundingBox': {'height': 20.417069115836977,
#    'width': 23.616822190319933,
#    'left': 217.072908121411,
#    'top': 221.31292096895513},
#   'points': [{'x': 217.072908121411, 'y': 221.31292096895513},
#    {'x': 240.68973031173093, 'y': 221.31292096895513},
#    {'x': 240.68973031173093, 'y': 241.7299900847921},
#    {'x': 217.072908121411, 'y': 241.7299900847921}]},
#  {'id': '5G1m9rB0M',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION5_2'],
#   'boundingBox': {'height': 19.491845596280086,
#    'width': 23.59041735028712,
#    'left': 254.52669965135357,
#    'top': 221.8663883000547},
#   'points': [{'x': 254.52669965135357, 'y': 221.8663883000547},
#    {'x': 278.1171170016407, 'y': 221.8663883000547},
#    {'x': 278.1171170016407, 'y': 241.35823389633478},
#    {'x': 254.52669965135357, 'y': 241.35823389633478}]},
#  {'id': 'n4Q67gnZH',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION6_1'],
#   'boundingBox': {'height': 19.745292413156452,
#    'width': 23.526584290401967,
#    'left': 216.27114950779327,
#    'top': 253.24452740358313},
#   'points': [{'x': 216.27114950779327, 'y': 253.24452740358313},
#    {'x': 239.79773379819522, 'y': 253.24452740358313},
#    {'x': 239.79773379819522, 'y': 272.98981981673955},
#    {'x': 216.27114950779327, 'y': 272.98981981673955}]},
#  {'id': 'IK_dnNCHL',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION6_2'],
#   'boundingBox': {'height': 20.554354143873084,
#    'width': 22.563288299835932,
#    'left': 255.33284839007382,
#    'top': 252.5256641479759},
#   'points': [{'x': 255.33284839007382, 'y': 252.5256641479759},
#    {'x': 277.8961366899098, 'y': 252.5256641479759},
#    {'x': 277.8961366899098, 'y': 273.080018291849},
#    {'x': 255.33284839007382, 'y': 273.080018291849}]},
#  {'id': 'zF7l1F1E6',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION7_1'],
#   'boundingBox': {'height': 20.47463715467724,
#    'width': 23.049694934372436,
#    'left': 217.1450087161608,
#    'top': 284.07461621307436},
#   'points': [{'x': 217.1450087161608, 'y': 284.07461621307436},
#    {'x': 240.19470365053323, 'y': 284.07461621307436},
#    {'x': 240.19470365053323, 'y': 304.5492533677516},
#    {'x': 217.1450087161608, 'y': 304.5492533677516}]},
#  {'id': 'yqb811NKt',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION7_2'],
#   'boundingBox': {'height': 21.572853272018598,
#    'width': 22.604754152994257,
#    'left': 255.46003383921246,
#    'top': 282.772443842314},
#   'points': [{'x': 255.46003383921246, 'y': 282.772443842314},
#    {'x': 278.06478799220673, 'y': 282.772443842314},
#    {'x': 278.06478799220673, 'y': 304.3452971143326},
#    {'x': 255.46003383921246, 'y': 304.3452971143326}]},
#  {'id': '-m8mtkweq',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION8_1'],
#   'boundingBox': {'height': 18.362217074671772,
#    'width': 22.569440883921246,
#    'left': 216.85526045939295,
#    'top': 315.9035233178337},
#   'points': [{'x': 216.85526045939295, 'y': 315.9035233178337},
#    {'x': 239.42470134331418, 'y': 315.9035233178337},
#    {'x': 239.42470134331418, 'y': 334.26574039250545},
#    {'x': 216.85526045939295, 'y': 334.26574039250545}]},
#  {'id': 'mhXVeEpNP',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION8_2'],
#   'boundingBox': {'height': 20.938803507932164,
#    'width': 22.41370359926169,
#    'left': 254.55025251230515,
#    'top': 314.6335005812363},
#   'points': [{'x': 254.55025251230515, 'y': 314.6335005812363},
#    {'x': 276.96395611156686, 'y': 314.6335005812363},
#    {'x': 276.96395611156686, 'y': 335.5723040891685},
#    {'x': 254.55025251230515, 'y': 335.5723040891685}]},
#  {'id': 'obB0ldNIa',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION9_1'],
#   'boundingBox': {'height': 18.836352058260392,
#    'width': 23.045561166940114,
#    'left': 217.00359541632486,
#    'top': 346.1251089818107},
#   'points': [{'x': 217.00359541632486, 'y': 346.1251089818107},
#    {'x': 240.04915658326496, 'y': 346.1251089818107},
#    {'x': 240.04915658326496, 'y': 364.9614610400711},
#    {'x': 217.00359541632486, 'y': 364.9614610400711}]},
#  {'id': 'rXbrEobnu',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION9_2'],
#   'boundingBox': {'height': 19.960916131017505,
#    'width': 23.187935808039377,
#    'left': 254.76985490155866,
#    'top': 346.05558499726476},
#   'points': [{'x': 254.76985490155866, 'y': 346.05558499726476},
#    {'x': 277.95779070959804, 'y': 346.05558499726476},
#    {'x': 277.95779070959804, 'y': 366.01650112828224},
#    {'x': 254.76985490155866, 'y': 366.01650112828224}]},
#  {'id': 'Ifp71Rcwk',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION10_1'],
#   'boundingBox': {'height': 18.90940192491794,
#    'width': 22.581746052091876,
#    'left': 217.2808462366694,
#    'top': 378.3832762069201},
#   'points': [{'x': 217.2808462366694, 'y': 378.3832762069201},
#    {'x': 239.86259228876128, 'y': 378.3832762069201},
#    {'x': 239.86259228876128, 'y': 397.29267813183804},
#    {'x': 217.2808462366694, 'y': 397.29267813183804}]},
#  {'id': '0Ef9J59as',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION10_2'],
#   'boundingBox': {'height': 18.941775933397153,
#    'width': 23.213283172682527,
#    'left': 254.39993078342903,
#    'top': 378.6457941568654},
#   'points': [{'x': 254.39993078342903, 'y': 378.6457941568654},
#    {'x': 277.61321395611157, 'y': 378.6457941568654},
#    {'x': 277.61321395611157, 'y': 397.58757009026255},
#    {'x': 254.39993078342903, 'y': 397.58757009026255}]},
#  {'id': 'jrwUFusmU',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION11_1'],
#   'boundingBox': {'height': 19.697228229280633,
#    'width': 22.769239643150122,
#    'left': 512.8108336751435,
#    'top': 96.85620597989605},
#   'points': [{'x': 512.8108336751435, 'y': 96.85620597989605},
#    {'x': 535.5800733182937, 'y': 96.85620597989605},
#    {'x': 535.5800733182937, 'y': 116.55343420917669},
#    {'x': 512.8108336751435, 'y': 116.55343420917669}]},
#  {'id': 'CWIYnEzlF',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION11_2'],
#   'boundingBox': {'height': 18.814748016958422,
#    'width': 21.799246308449547,
#    'left': 550.7709956931911,
#    'top': 97.59292302037746},
#   'points': [{'x': 550.7709956931911, 'y': 97.59292302037746},
#    {'x': 572.5702420016406, 'y': 97.59292302037746},
#    {'x': 572.5702420016406, 'y': 116.40767103733587},
#    {'x': 550.7709956931911, 'y': 116.40767103733587}]},
#  {'id': 'zk0eRRqMi',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION12_1'],
#   'boundingBox': {'height': 19.17291353254923,
#    'width': 22.21826292042658,
#    'left': 512.7154686218212,
#    'top': 129.335894762035},
#   'points': [{'x': 512.7154686218212, 'y': 129.335894762035},
#    {'x': 534.9337315422478, 'y': 129.335894762035},
#    {'x': 534.9337315422478, 'y': 148.50880829458424},
#    {'x': 512.7154686218212, 'y': 148.50880829458424}]},
#  {'id': 'D_jFs5_Zc',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION12_2'],
#   'boundingBox': {'height': 19.03298409292943,
#    'width': 21.873654122231336,
#    'left': 551.091442780968,
#    'top': 128.81528224152078},
#   'points': [{'x': 551.091442780968, 'y': 128.81528224152078},
#    {'x': 572.9650969031993, 'y': 128.81528224152078},
#    {'x': 572.9650969031993, 'y': 147.84826633445022},
#    {'x': 551.091442780968, 'y': 147.84826633445022}]},
#  {'id': 'd-bW8vYQG',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION13_1'],
#   'boundingBox': {'height': 18.47711275129923,
#    'width': 22.18359054552912,
#    'left': 512.6392663043479,
#    'top': 160.37359392095183},
#   'points': [{'x': 512.6392663043479, 'y': 160.37359392095183},
#    {'x': 534.822856849877, 'y': 160.37359392095183},
#    {'x': 534.822856849877, 'y': 178.85070667225108},
#    {'x': 512.6392663043479, 'y': 178.85070667225108}]},
#  {'id': '1ZoWIQLxG',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION13_2'],
#   'boundingBox': {'height': 17.00404728528446,
#    'width': 22.25870334290402,
#    'left': 550.8875102543068,
#    'top': 160.55302926695842},
#   'points': [{'x': 550.8875102543068, 'y': 160.55302926695842},
#    {'x': 573.1462135972108, 'y': 160.55302926695842},
#    {'x': 573.1462135972108, 'y': 177.55707655224288},
#    {'x': 550.8875102543068, 'y': 177.55707655224288}]},
#  {'id': 'VqzZ0uw_h',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION14_1'],
#   'boundingBox': {'height': 19.05764924097374,
#    'width': 22.401879101722724,
#    'left': 511.7383613617719,
#    'top': 191.3132094502188},
#   'points': [{'x': 511.7383613617719, 'y': 191.3132094502188},
#    {'x': 534.1402404634947, 'y': 191.3132094502188},
#    {'x': 534.1402404634947, 'y': 210.37085869119255},
#    {'x': 511.7383613617719, 'y': 210.37085869119255}]},
#  {'id': 'aQ6stvzCG',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION14_2'],
#   'boundingBox': {'height': 20.21112554704595,
#    'width': 21.38420324036095,
#    'left': 549.4196703240361,
#    'top': 190.89042413156454},
#   'points': [{'x': 549.4196703240361, 'y': 190.89042413156454},
#    {'x': 570.803873564397, 'y': 190.89042413156454},
#    {'x': 570.803873564397, 'y': 211.1015496786105},
#    {'x': 549.4196703240361, 'y': 211.1015496786105}]},
#  {'id': 'S3MWGUi8W',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION15_1'],
#   'boundingBox': {'height': 18.83933303131838,
#    'width': 21.95267637407711,
#    'left': 511.26339468826905,
#    'top': 222.7134013436816},
#   'points': [{'x': 511.26339468826905, 'y': 222.7134013436816},
#    {'x': 533.2160710623461, 'y': 222.7134013436816},
#    {'x': 533.2160710623461, 'y': 241.55273437499997},
#    {'x': 511.26339468826905, 'y': 241.55273437499997}]},
#  {'id': 'IxTpX_Nwm',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION15_2'],
#   'boundingBox': {'height': 17.589279608862142,
#    'width': 21.9758126538146,
#    'left': 549.5074087366694,
#    'top': 222.8539878795131},
#   'points': [{'x': 549.5074087366694, 'y': 222.8539878795131},
#    {'x': 571.483221390484, 'y': 222.8539878795131},
#    {'x': 571.483221390484, 'y': 240.44326748837526},
#    {'x': 549.5074087366694, 'y': 240.44326748837526}]},
#  {'id': 'oVk3gXqe7',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION16_1'],
#   'boundingBox': {'height': 19.243847869939824,
#    'width': 21.303386484823626,
#    'left': 511.8825625512715,
#    'top': 253.78594262855577},
#   'points': [{'x': 511.8825625512715, 'y': 253.78594262855577},
#    {'x': 533.1859490360952, 'y': 253.78594262855577},
#    {'x': 533.1859490360952, 'y': 273.0297904984956},
#    {'x': 511.8825625512715, 'y': 273.0297904984956}]},
#  {'id': 'zxLlGErzP',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION16_2'],
#   'boundingBox': {'height': 19.02296738238512,
#    'width': 21.665619872846595,
#    'left': 549.7051886792452,
#    'top': 253.35520804841354},
#   'points': [{'x': 549.7051886792452, 'y': 253.35520804841354},
#    {'x': 571.3708085520918, 'y': 253.35520804841354},
#    {'x': 571.3708085520918, 'y': 272.37817543079865},
#    {'x': 549.7051886792452, 'y': 272.37817543079865}]},
#  {'id': 'vvri1ICpi',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION17_1'],
#   'boundingBox': {'height': 18.32968279882385,
#    'width': 23.590096903199342,
#    'left': 512.0886741181296,
#    'top': 284.69113272702407},
#   'points': [{'x': 512.0886741181296, 'y': 284.69113272702407},
#    {'x': 535.678771021329, 'y': 284.69113272702407},
#    {'x': 535.678771021329, 'y': 303.0208155258479},
#    {'x': 512.0886741181296, 'y': 303.0208155258479}]},
#  {'id': 'XRYDpDPhu',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION17_2'],
#   'boundingBox': {'height': 19.325520121033914,
#    'width': 21.462456419196062,
#    'left': 550.1009408326497,
#    'top': 284.3908237315372},
#   'points': [{'x': 550.1009408326497, 'y': 284.3908237315372},
#    {'x': 571.5633972518458, 'y': 284.3908237315372},
#    {'x': 571.5633972518458, 'y': 303.7163438525711},
#    {'x': 550.1009408326497, 'y': 303.7163438525711}]},
#  {'id': 'LVFeB7Esk',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION18_1'],
#   'boundingBox': {'height': 18.704259692970457,
#    'width': 22.027596903199342,
#    'left': 512.7434116078753,
#    'top': 315.51410566534463},
#   'points': [{'x': 512.7434116078753, 'y': 315.51410566534463},
#    {'x': 534.7710085110747, 'y': 315.51410566534463},
#    {'x': 534.7710085110747, 'y': 334.21836535831505},
#    {'x': 512.7434116078753, 'y': 334.21836535831505}]},
#  {'id': 'kmFd_TUYR',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION18_2'],
#   'boundingBox': {'height': 19.678204492614878,
#    'width': 20.6208341878589,
#    'left': 550.6660813166529,
#    'top': 315.41339365084787},
#   'points': [{'x': 550.6660813166529, 'y': 315.41339365084787},
#    {'x': 571.2869155045119, 'y': 315.41339365084787},
#    {'x': 571.2869155045119, 'y': 335.09159814346276},
#    {'x': 550.6660813166529, 'y': 335.09159814346276}]},
#  {'id': 'E-P0HcZDx',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION19_1'],
#   'boundingBox': {'height': 19.03992366999453,
#    'width': 22.007472826086957,
#    'left': 512.982144688269,
#    'top': 346.8319842382385},
#   'points': [{'x': 512.982144688269, 'y': 346.8319842382385},
#    {'x': 534.989617514356, 'y': 346.8319842382385},
#    {'x': 534.989617514356, 'y': 365.871907908233},
#    {'x': 512.982144688269, 'y': 365.871907908233}]},
#  {'id': 'bH-bcnmQt',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION19_2'],
#   'boundingBox': {'height': 18.6400245315919,
#    'width': 19.984426271534044,
#    'left': 551.3381229491387,
#    'top': 347.35439175328224},
#   'points': [{'x': 551.3381229491387, 'y': 347.35439175328224},
#    {'x': 571.3225492206727, 'y': 347.35439175328224},
#    {'x': 571.3225492206727, 'y': 365.99441628487415},
#    {'x': 551.3381229491387, 'y': 365.99441628487415}]},
#  {'id': 'mbxoMePCZ',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION20_1'],
#   'boundingBox': {'height': 18.865905361050327,
#    'width': 22.284980004101723,
#    'left': 512.9543298810501,
#    'top': 378.1901540276258},
#   'points': [{'x': 512.9543298810501, 'y': 378.1901540276258},
#    {'x': 535.2393098851518, 'y': 378.1901540276258},
#    {'x': 535.2393098851518, 'y': 397.0560593886761},
#    {'x': 512.9543298810501, 'y': 397.0560593886761}]},
#  {'id': 'uK2ozwlw5',
#   'type': 'RECTANGLE',
#   'tags': ['QUESTION20_2'],
#   'boundingBox': {'height': 18.518285438320568,
#    'width': 20.10690114848236,
#    'left': 551.6136433552092,
#    'top': 377.93879068654263},
#   'points': [{'x': 551.6136433552092, 'y': 377.93879068654263},
#    {'x': 571.7205445036915, 'y': 377.93879068654263},
#    {'x': 571.7205445036915, 'y': 396.4570761248632},
#    {'x': 551.6136433552092, 'y': 396.4570761248632}]},
#  {'id': 'T2kCVI_K3',
#   'type': 'RECTANGLE',
#   'tags': ['MAX_MARKS_1'],
#   'boundingBox': {'height': 19.606853460065643,
#    'width': 23.58394431911403,
#    'left': 133.1594801066448,
#    'top': 430.6282267163566},
#   'points': [{'x': 133.1594801066448, 'y': 430.6282267163566},
#    {'x': 156.7434244257588, 'y': 430.6282267163566},
#    {'x': 156.7434244257588, 'y': 450.2350801764223},
#    {'x': 133.1594801066448, 'y': 450.2350801764223}]},
#  {'id': '8htMWqCEw',
#   'type': 'RECTANGLE',
#   'tags': ['MAX_MARKS_2'],
#   'boundingBox': {'height': 19.41603913088074,
#    'width': 22.85999025840853,
#    'left': 159.87297477440524,
#    'top': 431.0980985879376},
#   'points': [{'x': 159.87297477440524, 'y': 431.0980985879376},
#    {'x': 182.73296503281378, 'y': 431.0980985879376},
#    {'x': 182.73296503281378, 'y': 450.51413771881835},
#    {'x': 159.87297477440524, 'y': 450.51413771881835}]},
#  {'id': 'WGj6_lo-N',
#   'type': 'RECTANGLE',
#   'tags': ['MAX_MARKS_3'],
#   'boundingBox': {'height': 20.174552533506564,
#    'width': 22.469140945447087,
#    'left': 185.783557219032,
#    'top': 431.0471976716356},
#   'points': [{'x': 185.783557219032, 'y': 431.0471976716356},
#    {'x': 208.25269816447909, 'y': 431.0471976716356},
#    {'x': 208.25269816447909, 'y': 451.2217502051422},
#    {'x': 185.783557219032, 'y': 451.2217502051422}]},
#  {'id': 'RXj9Bn8hV',
#   'type': 'RECTANGLE',
#   'tags': ['MARKS_OBTAINED_1'],
#   'boundingBox': {'height': 19.23144317560175,
#    'width': 21.645271482772763,
#    'left': 333.3365271226415,
#    'top': 430.5678379718271},
#   'points': [{'x': 333.3365271226415, 'y': 430.5678379718271},
#    {'x': 354.98179860541427, 'y': 430.5678379718271},
#    {'x': 354.98179860541427, 'y': 449.79928114742887},
#    {'x': 333.3365271226415, 'y': 449.79928114742887}]},
#  {'id': '8dMmpKvYj',
#   'type': 'RECTANGLE',
#   'tags': ['MARKS_OBTAINED_2'],
#   'boundingBox': {'height': 18.500175225656452,
#    'width': 22.07627281583265,
#    'left': 358.9387112899918,
#    'top': 430.35423362281176},
#   'points': [{'x': 358.9387112899918, 'y': 430.35423362281176},
#    {'x': 381.01498410582445, 'y': 430.35423362281176},
#    {'x': 381.01498410582445, 'y': 448.8544088484682},
#    {'x': 358.9387112899918, 'y': 448.8544088484682}]},
#  {'id': 'AgmM8n0lW',
#   'type': 'RECTANGLE',
#   'tags': ['MARKS_OBTAINED_3'],
#   'boundingBox': {'height': 20.83882872333151,
#    'width': 21.96104004306809,
#    'left': 384.3013292145201,
#    'top': 430.3034929738785},
#   'points': [{'x': 384.3013292145201, 'y': 430.3034929738785},
#    {'x': 406.2623692575882, 'y': 430.3034929738785},
#    {'x': 406.2623692575882, 'y': 451.14232169721004},
#    {'x': 384.3013292145201, 'y': 451.14232169721004}]}]

# %%
tagGroups = ["STUDENTID_", "QUESTION1_", "QUESTION2_","QUESTION3_","QUESTION4_","QUESTION5_","QUESTION6_","QUESTION7_","QUESTION8_","QUESTION9_","QUESTION10_","QUESTION11_","QUESTION12_","QUESTION13_","QUESTION14_","QUESTION15_","QUESTION16_","QUESTION17_","QUESTION18_","QUESTION19_","QUESTION20_","MAX_MARKS_","MARKS_OBTAINED_"]
rois=get_rois(regions,tagGroups[0])

# %%
cells=get_cells(regions,tagGroups)

# %%
get_layout(cells)
# Out:
# {'layout': {'version': '1.0',
#   'name': 'Odisha SAT Exam Sheet Form',
#   'cells': [{'cellId': 1,
#     'rois': [{'annotationId': 'eKS5GDoKy',
#       'annotationTags': 'STUDENTID_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 30, 'left': 192, 'bottom': 50, 'right': 210}},
#      {'annotationId': '07gfo-X6k',
#       'annotationTags': 'STUDENTID_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 29, 'left': 215, 'bottom': 51, 'right': 238}},
#      {'annotationId': 'bv3o6dbOL',
#       'annotationTags': 'STUDENTID_3',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 3,
#       'index': 2,
#       'rect': {'top': 30, 'left': 242, 'bottom': 50, 'right': 265}},
#      {'annotationId': 'bxUpSr1kN',
#       'annotationTags': 'STUDENTID_4',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 4,
#       'index': 3,
#       'rect': {'top': 30, 'left': 269, 'bottom': 49, 'right': 291}},
#      {'annotationId': '2AjEL9QuH',
#       'annotationTags': 'STUDENTID_5',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 5,
#       'index': 4,
#       'rect': {'top': 31, 'left': 294, 'bottom': 50, 'right': 315}},
#      {'annotationId': 'sVXs9IDX3',
#       'annotationTags': 'STUDENTID_6',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 6,
#       'index': 5,
#       'rect': {'top': 31, 'left': 319, 'bottom': 49, 'right': 340}},
#      {'annotationId': 'AcbEHjPdD',
#       'annotationTags': 'STUDENTID_7',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 7,
#       'index': 6,
#       'rect': {'top': 31, 'left': 344, 'bottom': 50, 'right': 367}},
#      {'annotationId': 'Om50EqhmL',
#       'annotationTags': 'STUDENTID_8',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 8,
#       'index': 7,
#       'rect': {'top': 31, 'left': 371, 'bottom': 50, 'right': 392}},
#      {'annotationId': '_EITxSSf2',
#       'annotationTags': 'STUDENTID_9',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 9,
#       'index': 8,
#       'rect': {'top': 31, 'left': 395, 'bottom': 50, 'right': 417}},
#      {'annotationId': 'RouzCuE85',
#       'annotationTags': 'STUDENTID_10',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 10,
#       'index': 9,
#       'rect': {'top': 31, 'left': 421, 'bottom': 50, 'right': 442}},
#      {'annotationId': 'KMkXP1EDG',
#       'annotationTags': 'STUDENTID_11',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 11,
#       'index': 10,
#       'rect': {'top': 31, 'left': 446, 'bottom': 50, 'right': 468}},
#      {'annotationId': '11AKDb31Z',
#       'annotationTags': 'STUDENTID_12',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 12,
#       'index': 11,
#       'rect': {'top': 30, 'left': 472, 'bottom': 48, 'right': 494}},
#      {'annotationId': 'fL6XpwpwP',
#       'annotationTags': 'STUDENTID_13',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 13,
#       'index': 12,
#       'rect': {'top': 30, 'left': 498, 'bottom': 51, 'right': 519}},
#      {'annotationId': '7_X3wXjhL',
#       'annotationTags': 'STUDENTID_14',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 14,
#       'index': 13,
#       'rect': {'top': 31, 'left': 522, 'bottom': 51, 'right': 544}},
#      {'annotationId': '9jfgY1qtO',
#       'annotationTags': 'STUDENTID_15',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 15,
#       'index': 14,
#       'rect': {'top': 31, 'left': 548, 'bottom': 51, 'right': 570}},
#      {'annotationId': 'QcswxWY1s',
#       'annotationTags': 'STUDENTID_16',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 16,
#       'index': 15,
#       'rect': {'top': 30, 'left': 573, 'bottom': 50, 'right': 596}}],
#     'render': {'index': 1},
#     'format': {'name': 'STUDENTID', 'value': 'STUDENTID'},
#     'validate': {'regExp': ''}},
#    {'cellId': 2,
#     'rois': [{'annotationId': 'vFcepRW2k',
#       'annotationTags': 'QUESTION1_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 96, 'left': 215, 'bottom': 115, 'right': 238}},
#      {'annotationId': 'Z4Q8hjcR7',
#       'annotationTags': 'QUESTION1_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 97, 'left': 252, 'bottom': 117, 'right': 276}}],
#     'render': {'index': 2},
#     'format': {'name': 'QUESTION1', 'value': 'QUESTION1'},
#     'validate': {'regExp': ''}},
#    {'cellId': 3,
#     'rois': [{'annotationId': 'MvthTtZS0',
#       'annotationTags': 'QUESTION2_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 128, 'left': 216, 'bottom': 147, 'right': 240}},
#      {'annotationId': '9NsptTzne',
#       'annotationTags': 'QUESTION2_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 128, 'left': 253, 'bottom': 148, 'right': 275}}],
#     'render': {'index': 3},
#     'format': {'name': 'QUESTION2', 'value': 'QUESTION2'},
#     'validate': {'regExp': ''}},
#    {'cellId': 4,
#     'rois': [{'annotationId': 'Y1tY6l4N3',
#       'annotationTags': 'QUESTION3_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 158, 'left': 216, 'bottom': 179, 'right': 239}},
#      {'annotationId': '2B7hKNVlm',
#       'annotationTags': 'QUESTION3_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 159, 'left': 254, 'bottom': 179, 'right': 277}}],
#     'render': {'index': 4},
#     'format': {'name': 'QUESTION3', 'value': 'QUESTION3'},
#     'validate': {'regExp': ''}},
#    {'cellId': 5,
#     'rois': [{'annotationId': 'lJajZC-En',
#       'annotationTags': 'QUESTION4_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 191, 'left': 215, 'bottom': 211, 'right': 239}},
#      {'annotationId': 'a27bXhfIq',
#       'annotationTags': 'QUESTION4_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 190, 'left': 254, 'bottom': 211, 'right': 277}}],
#     'render': {'index': 5},
#     'format': {'name': 'QUESTION4', 'value': 'QUESTION4'},
#     'validate': {'regExp': ''}},
#    {'cellId': 6,
#     'rois': [{'annotationId': 'dwrADIlko',
#       'annotationTags': 'QUESTION5_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 221, 'left': 217, 'bottom': 241, 'right': 240}},
#      {'annotationId': '5G1m9rB0M',
#       'annotationTags': 'QUESTION5_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 221, 'left': 254, 'bottom': 240, 'right': 277}}],
#     'render': {'index': 6},
#     'format': {'name': 'QUESTION5', 'value': 'QUESTION5'},
#     'validate': {'regExp': ''}},
#    {'cellId': 7,
#     'rois': [{'annotationId': 'n4Q67gnZH',
#       'annotationTags': 'QUESTION6_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 253, 'left': 216, 'bottom': 272, 'right': 239}},
#      {'annotationId': 'IK_dnNCHL',
#       'annotationTags': 'QUESTION6_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 252, 'left': 255, 'bottom': 272, 'right': 277}}],
#     'render': {'index': 7},
#     'format': {'name': 'QUESTION6', 'value': 'QUESTION6'},
#     'validate': {'regExp': ''}},
#    {'cellId': 8,
#     'rois': [{'annotationId': 'zF7l1F1E6',
#       'annotationTags': 'QUESTION7_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 284, 'left': 217, 'bottom': 304, 'right': 240}},
#      {'annotationId': 'yqb811NKt',
#       'annotationTags': 'QUESTION7_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 282, 'left': 255, 'bottom': 303, 'right': 277}}],
#     'render': {'index': 8},
#     'format': {'name': 'QUESTION7', 'value': 'QUESTION7'},
#     'validate': {'regExp': ''}},
#    {'cellId': 9,
#     'rois': [{'annotationId': '-m8mtkweq',
#       'annotationTags': 'QUESTION8_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 315, 'left': 216, 'bottom': 333, 'right': 238}},
#      {'annotationId': 'mhXVeEpNP',
#       'annotationTags': 'QUESTION8_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 314, 'left': 254, 'bottom': 334, 'right': 276}}],
#     'render': {'index': 9},
#     'format': {'name': 'QUESTION8', 'value': 'QUESTION8'},
#     'validate': {'regExp': ''}},
#    {'cellId': 10,
#     'rois': [{'annotationId': 'obB0ldNIa',
#       'annotationTags': 'QUESTION9_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 346, 'left': 217, 'bottom': 364, 'right': 240}},
#      {'annotationId': 'rXbrEobnu',
#       'annotationTags': 'QUESTION9_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 346, 'left': 254, 'bottom': 365, 'right': 277}}],
#     'render': {'index': 10},
#     'format': {'name': 'QUESTION9', 'value': 'QUESTION9'},
#     'validate': {'regExp': ''}},
#    {'cellId': 11,
#     'rois': [{'annotationId': 'Ifp71Rcwk',
#       'annotationTags': 'QUESTION10_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 378, 'left': 217, 'bottom': 396, 'right': 239}},
#      {'annotationId': '0Ef9J59as',
#       'annotationTags': 'QUESTION10_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 378, 'left': 254, 'bottom': 396, 'right': 277}}],
#     'render': {'index': 11},
#     'format': {'name': 'QUESTION10', 'value': 'QUESTION10'},
#     'validate': {'regExp': ''}},
#    {'cellId': 12,
#     'rois': [{'annotationId': 'jrwUFusmU',
#       'annotationTags': 'QUESTION11_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 96, 'left': 512, 'bottom': 115, 'right': 534}},
#      {'annotationId': 'CWIYnEzlF',
#       'annotationTags': 'QUESTION11_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 97, 'left': 550, 'bottom': 115, 'right': 571}}],
#     'render': {'index': 12},
#     'format': {'name': 'QUESTION11', 'value': 'QUESTION11'},
#     'validate': {'regExp': ''}},
#    {'cellId': 13,
#     'rois': [{'annotationId': 'zk0eRRqMi',
#       'annotationTags': 'QUESTION12_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 129, 'left': 512, 'bottom': 148, 'right': 534}},
#      {'annotationId': 'D_jFs5_Zc',
#       'annotationTags': 'QUESTION12_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 128, 'left': 551, 'bottom': 147, 'right': 572}}],
#     'render': {'index': 13},
#     'format': {'name': 'QUESTION12', 'value': 'QUESTION12'},
#     'validate': {'regExp': ''}},
#    {'cellId': 14,
#     'rois': [{'annotationId': 'd-bW8vYQG',
#       'annotationTags': 'QUESTION13_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 160, 'left': 512, 'bottom': 178, 'right': 534}},
#      {'annotationId': '1ZoWIQLxG',
#       'annotationTags': 'QUESTION13_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 160, 'left': 550, 'bottom': 177, 'right': 572}}],
#     'render': {'index': 14},
#     'format': {'name': 'QUESTION13', 'value': 'QUESTION13'},
#     'validate': {'regExp': ''}},
#    {'cellId': 15,
#     'rois': [{'annotationId': 'VqzZ0uw_h',
#       'annotationTags': 'QUESTION14_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 191, 'left': 511, 'bottom': 210, 'right': 533}},
#      {'annotationId': 'aQ6stvzCG',
#       'annotationTags': 'QUESTION14_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 190, 'left': 549, 'bottom': 210, 'right': 570}}],
#     'render': {'index': 15},
#     'format': {'name': 'QUESTION14', 'value': 'QUESTION14'},
#     'validate': {'regExp': ''}},
#    {'cellId': 16,
#     'rois': [{'annotationId': 'S3MWGUi8W',
#       'annotationTags': 'QUESTION15_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 222, 'left': 511, 'bottom': 240, 'right': 532}},
#      {'annotationId': 'IxTpX_Nwm',
#       'annotationTags': 'QUESTION15_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 222, 'left': 549, 'bottom': 239, 'right': 570}}],
#     'render': {'index': 16},
#     'format': {'name': 'QUESTION15', 'value': 'QUESTION15'},
#     'validate': {'regExp': ''}},
#    {'cellId': 17,
#     'rois': [{'annotationId': 'oVk3gXqe7',
#       'annotationTags': 'QUESTION16_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 253, 'left': 511, 'bottom': 272, 'right': 532}},
#      {'annotationId': 'zxLlGErzP',
#       'annotationTags': 'QUESTION16_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 253, 'left': 549, 'bottom': 272, 'right': 570}}],
#     'render': {'index': 17},
#     'format': {'name': 'QUESTION16', 'value': 'QUESTION16'},
#     'validate': {'regExp': ''}},
#    {'cellId': 18,
#     'rois': [{'annotationId': 'vvri1ICpi',
#       'annotationTags': 'QUESTION17_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 284, 'left': 512, 'bottom': 302, 'right': 535}},
#      {'annotationId': 'XRYDpDPhu',
#       'annotationTags': 'QUESTION17_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 284, 'left': 550, 'bottom': 303, 'right': 571}}],
#     'render': {'index': 18},
#     'format': {'name': 'QUESTION17', 'value': 'QUESTION17'},
#     'validate': {'regExp': ''}},
#    {'cellId': 19,
#     'rois': [{'annotationId': 'LVFeB7Esk',
#       'annotationTags': 'QUESTION18_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 315, 'left': 512, 'bottom': 333, 'right': 534}},
#      {'annotationId': 'kmFd_TUYR',
#       'annotationTags': 'QUESTION18_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 315, 'left': 550, 'bottom': 334, 'right': 570}}],
#     'render': {'index': 19},
#     'format': {'name': 'QUESTION18', 'value': 'QUESTION18'},
#     'validate': {'regExp': ''}},
#    {'cellId': 20,
#     'rois': [{'annotationId': 'E-P0HcZDx',
#       'annotationTags': 'QUESTION19_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 346, 'left': 512, 'bottom': 365, 'right': 534}},
#      {'annotationId': 'bH-bcnmQt',
#       'annotationTags': 'QUESTION19_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 347, 'left': 551, 'bottom': 365, 'right': 570}}],
#     'render': {'index': 20},
#     'format': {'name': 'QUESTION19', 'value': 'QUESTION19'},
#     'validate': {'regExp': ''}},
#    {'cellId': 21,
#     'rois': [{'annotationId': 'mbxoMePCZ',
#       'annotationTags': 'QUESTION20_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 378, 'left': 512, 'bottom': 396, 'right': 534}},
#      {'annotationId': 'uK2ozwlw5',
#       'annotationTags': 'QUESTION20_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 377, 'left': 551, 'bottom': 395, 'right': 571}}],
#     'render': {'index': 21},
#     'format': {'name': 'QUESTION20', 'value': 'QUESTION20'},
#     'validate': {'regExp': ''}},
#    {'cellId': 22,
#     'rois': [{'annotationId': 'T2kCVI_K3',
#       'annotationTags': 'MAX_MARKS_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 430, 'left': 133, 'bottom': 449, 'right': 156}},
#      {'annotationId': '8htMWqCEw',
#       'annotationTags': 'MAX_MARKS_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 431, 'left': 159, 'bottom': 450, 'right': 181}},
#      {'annotationId': 'WGj6_lo-N',
#       'annotationTags': 'MAX_MARKS_3',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 3,
#       'index': 2,
#       'rect': {'top': 431, 'left': 185, 'bottom': 451, 'right': 207}}],
#     'render': {'index': 22},
#     'format': {'name': 'MAXMARKS', 'value': 'MAXMARKS'},
#     'validate': {'regExp': ''}},
#    {'cellId': 23,
#     'rois': [{'annotationId': 'RXj9Bn8hV',
#       'annotationTags': 'MARKS_OBTAINED_1',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 1,
#       'index': 0,
#       'rect': {'top': 430, 'left': 333, 'bottom': 449, 'right': 354}},
#      {'annotationId': '8dMmpKvYj',
#       'annotationTags': 'MARKS_OBTAINED_2',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 2,
#       'index': 1,
#       'rect': {'top': 430, 'left': 358, 'bottom': 448, 'right': 380}},
#      {'annotationId': 'AgmM8n0lW',
#       'annotationTags': 'MARKS_OBTAINED_3',
#       'extractionMethod': 'NUMERIC_CLASSIFICATION',
#       'roiId': 3,
#       'index': 2,
#       'rect': {'top': 430, 'left': 384, 'bottom': 450, 'right': 405}}],
#     'render': {'index': 23},
#     'format': {'name': 'MARKSOBTAINED', 'value': 'MARKSOBTAINED'},
#     'validate': {'regExp': ''}}]}}
