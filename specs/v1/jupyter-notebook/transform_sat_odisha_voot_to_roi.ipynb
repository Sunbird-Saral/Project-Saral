# %%
# Dileep Gadiraju - Odisha ROI Transformation from VoTT Raw format
# Takes filename of VoTT raw format file and generates ROI configuration
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(uuid.uuid4()),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""

              cells_data.append({
                          "cellId": str(uuid.uuid4()),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "Odisha SAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("sat_odisha_vottraw.json")

# %%
tagGroups = ["STUDENTID_", "QUESTION1_", "QUESTION2_","QUESTION3_","QUESTION4_","QUESTION5_","QUESTION6_","QUESTION7_","QUESTION8_","QUESTION9_","QUESTION10_","QUESTION11_","QUESTION12_","QUESTION13_","QUESTION14_","QUESTION15_","QUESTION16_","QUESTION17_","QUESTION18_","QUESTION19_","QUESTION20_","MAX_MARKS_","MARKS_OBTAINED_"]
formatLookup = {
    'QUESTION1_':'QUESTION 1',
    'QUESTION2_':'QUESTION 2',
    'QUESTION3_':'QUESTION 3',
    'QUESTION4_':'QUESTION 4',
    'QUESTION5_':'QUESTION 5',
    'QUESTION6_':'QUESTION 6',
    'QUESTION7_':'QUESTION 7',
    'QUESTION8_':'QUESTION 8',
    'QUESTION9_':'QUESTION 9',
    'QUESTION10_':'QUESTION 10',
    'QUESTION11_':'QUESTION 11',
    'QUESTION12_':'QUESTION 12',
    'QUESTION13_':'QUESTION 13',
    'QUESTION14_':'QUESTION 14',
    'QUESTION15_':'QUESTION 15',
    'QUESTION16_':'QUESTION 16',
    'QUESTION17_':'QUESTION 17',
    'QUESTION18_':'QUESTION 18',
    'QUESTION19_':'QUESTION 19',
    'QUESTION20_':'QUESTION 20',
    'STUDENTID_': 'STUDENTID',
    'MAX_MARKS_': 'MAX MARKS',
    'MARKS_OBTAINED_': 'MARKS OBTAINED'
    
}

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "Odisha SAT Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "440e3781-a147-4daf-8993-1a10e3f01cb7",
#                 "rois": [
#                     {
#                         "annotationTags": "STUDENTID_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "91a92f47-5da9-4b5f-ba0f-32ac71e6bace",
#                         "index": 0,
#                         "rect": {
#                             "top": 30,
#                             "left": 192,
#                             "bottom": 50,
#                             "right": 210
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7ef8234d-6431-4ca2-a3dc-a05d1ff62ddd",
#                         "index": 1,
#                         "rect": {
#                             "top": 29,
#                             "left": 215,
#                             "bottom": 51,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4cac716f-15a7-4e2d-903d-73a46faf3bcb",
#                         "index": 2,
#                         "rect": {
#                             "top": 30,
#                             "left": 242,
#                             "bottom": 50,
#                             "right": 265
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "39e9d37c-fc3d-46e7-9499-503be96728c2",
#                         "index": 3,
#                         "rect": {
#                             "top": 30,
#                             "left": 269,
#                             "bottom": 49,
#                             "right": 291
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "791167ae-d5fe-464e-8fd9-f6cde8097ea6",
#                         "index": 4,
#                         "rect": {
#                             "top": 31,
#                             "left": 294,
#                             "bottom": 50,
#                             "right": 315
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8e0f68d3-45f2-4028-8bb2-b3994f435b64",
#                         "index": 5,
#                         "rect": {
#                             "top": 31,
#                             "left": 319,
#                             "bottom": 49,
#                             "right": 340
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a6d07d69-f336-4502-b2b9-64b2277728be",
#                         "index": 6,
#                         "rect": {
#                             "top": 31,
#                             "left": 344,
#                             "bottom": 50,
#                             "right": 367
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1fdc820c-fba1-445d-8898-406a220e50b6",
#                         "index": 7,
#                         "rect": {
#                             "top": 31,
#                             "left": 371,
#                             "bottom": 50,
#                             "right": 392
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1f2f7bb9-8a7e-4c76-974d-5b56f96ebff0",
#                         "index": 8,
#                         "rect": {
#                             "top": 31,
#                             "left": 395,
#                             "bottom": 50,
#                             "right": 417
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b62d7822-df79-4c44-a18f-2bed8159957b",
#                         "index": 9,
#                         "rect": {
#                             "top": 31,
#                             "left": 421,
#                             "bottom": 50,
#                             "right": 442
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3acc395f-6e52-4a69-b97d-3651af3abfe9",
#                         "index": 10,
#                         "rect": {
#                             "top": 31,
#                             "left": 446,
#                             "bottom": 50,
#                             "right": 468
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4a801266-03f4-4a9e-bf73-25ca7f479927",
#                         "index": 11,
#                         "rect": {
#                             "top": 30,
#                             "left": 472,
#                             "bottom": 48,
#                             "right": 494
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_13",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1bfd4aaa-c1cf-4b73-824f-a1f9f1557e5c",
#                         "index": 12,
#                         "rect": {
#                             "top": 30,
#                             "left": 498,
#                             "bottom": 51,
#                             "right": 519
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_14",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d1e9f129-cdb3-4e84-94a0-120aee96c6bb",
#                         "index": 13,
#                         "rect": {
#                             "top": 31,
#                             "left": 522,
#                             "bottom": 51,
#                             "right": 544
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_15",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c81ff3c0-3817-40c7-bc65-5534ca8cd043",
#                         "index": 14,
#                         "rect": {
#                             "top": 31,
#                             "left": 548,
#                             "bottom": 51,
#                             "right": 570
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_16",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "dc9c0f1c-fb7e-49e5-a9b8-599d290ce6f9",
#                         "index": 15,
#                         "rect": {
#                             "top": 30,
#                             "left": 573,
#                             "bottom": 50,
#                             "right": 596
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "STUDENTID",
#                     "value": "STUDENTID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "167f4526-96bb-4ce1-8546-245eddd34fe5",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e3eadfd7-1016-4bf4-9a5d-04c17773dcdd",
#                         "index": 0,
#                         "rect": {
#                             "top": 96,
#                             "left": 215,
#                             "bottom": 115,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "258e6251-1443-4ec0-afa0-4d5b1fc2115b",
#                         "index": 1,
#                         "rect": {
#                             "top": 97,
#                             "left": 252,
#                             "bottom": 117,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "QUESTION1",
#                     "value": "QUESTION 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "66f31a81-aa92-42e4-a03a-3a46d6b948dd",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ca60bce7-2ec2-47a6-b393-f00fb5ff9269",
#                         "index": 0,
#                         "rect": {
#                             "top": 128,
#                             "left": 216,
#                             "bottom": 147,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e481cdef-21f7-48e0-88a6-f59917e27c8c",
#                         "index": 1,
#                         "rect": {
#                             "top": 128,
#                             "left": 253,
#                             "bottom": 148,
#                             "right": 275
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "QUESTION2",
#                     "value": "QUESTION 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7bbba037-1135-4f3c-ba0f-fadc32d31aba",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION3_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7da02812-f9c2-43ff-a794-88d9f023b546",
#                         "index": 0,
#                         "rect": {
#                             "top": 158,
#                             "left": 216,
#                             "bottom": 179,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "955b47e7-5f30-418b-8b55-16e773851e3d",
#                         "index": 1,
#                         "rect": {
#                             "top": 159,
#                             "left": 254,
#                             "bottom": 179,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "QUESTION3",
#                     "value": "QUESTION 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3839ec6b-9786-47ae-8342-ae1e5eeef9e9",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION4_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f7391347-dc67-422c-88a7-d10d6af09a72",
#                         "index": 0,
#                         "rect": {
#                             "top": 191,
#                             "left": 215,
#                             "bottom": 211,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "841af30c-4d96-4f97-8033-19db38b4de27",
#                         "index": 1,
#                         "rect": {
#                             "top": 190,
#                             "left": 254,
#                             "bottom": 211,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "QUESTION4",
#                     "value": "QUESTION 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14937cb2-3696-463d-b141-65d123f17e4b",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION5_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "cd06753c-8336-46a3-bf1c-886efaa00ac2",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 217,
#                             "bottom": 241,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6aa66b11-789f-4aed-87e6-fe6215042894",
#                         "index": 1,
#                         "rect": {
#                             "top": 221,
#                             "left": 254,
#                             "bottom": 240,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "QUESTION5",
#                     "value": "QUESTION 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "86cdc7da-4e48-4782-af8a-c6e565287d8c",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION6_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7187b209-669b-404e-a2d7-cc7dc532ace3",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 216,
#                             "bottom": 272,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION6_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f15587f6-504c-40f6-ac80-beca0f8fe3be",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 255,
#                             "bottom": 272,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "QUESTION6",
#                     "value": "QUESTION 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "bbaf4f19-922e-441f-8c34-8e4275c8accf",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION7_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4c12eab7-c06b-495b-9b66-f3f884790082",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 217,
#                             "bottom": 304,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION7_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "52ec570e-5dbf-4613-89b2-4ecff0a7235c",
#                         "index": 1,
#                         "rect": {
#                             "top": 282,
#                             "left": 255,
#                             "bottom": 303,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "QUESTION7",
#                     "value": "QUESTION 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b1d9fe97-3685-4c4f-a7d0-a65046a35bf7",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION8_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4a59cbfa-e4e7-4e13-be4a-7ca6c23c3f2f",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 216,
#                             "bottom": 333,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION8_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "de5a0b46-7ac8-45dd-b580-c92d910a05ef",
#                         "index": 1,
#                         "rect": {
#                             "top": 314,
#                             "left": 254,
#                             "bottom": 334,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "QUESTION8",
#                     "value": "QUESTION 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4b263781-aed8-46f1-8247-93c2d153142f",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION9_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d494f0b5-17d4-415b-b717-c15e5d0cc294",
#                         "index": 0,
#                         "rect": {
#                             "top": 346,
#                             "left": 217,
#                             "bottom": 364,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION9_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "77c46855-7a3a-46f1-99da-8b2089d4ead3",
#                         "index": 1,
#                         "rect": {
#                             "top": 346,
#                             "left": 254,
#                             "bottom": 365,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "QUESTION9",
#                     "value": "QUESTION 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9274ee8e-ab02-4933-a715-0d5a449896f1",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION10_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e4176cc5-e796-4fdf-a8d0-44ddbd74296b",
#                         "index": 0,
#                         "rect": {
#                             "top": 378,
#                             "left": 217,
#                             "bottom": 396,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION10_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7785df5a-d9d6-4fab-b509-dc006deb8d15",
#                         "index": 1,
#                         "rect": {
#                             "top": 378,
#                             "left": 254,
#                             "bottom": 396,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "QUESTION10",
#                     "value": "QUESTION 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4abe93e3-9f86-495c-b6a3-c33941bd315a",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION11_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6c741dc8-4662-4b09-a9ef-0d8cba6b620a",
#                         "index": 0,
#                         "rect": {
#                             "top": 96,
#                             "left": 512,
#                             "bottom": 115,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION11_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c06a8fcc-b947-43e4-9004-a229f6ca5e93",
#                         "index": 1,
#                         "rect": {
#                             "top": 97,
#                             "left": 550,
#                             "bottom": 115,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "QUESTION11",
#                     "value": "QUESTION 11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c6c953bb-1965-4d8b-bd8b-bf47b0925126",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION12_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8a413219-4acf-47dc-a667-5866b6b5482b",
#                         "index": 0,
#                         "rect": {
#                             "top": 129,
#                             "left": 512,
#                             "bottom": 148,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION12_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d6290020-df49-4921-be67-17344a1dec7a",
#                         "index": 1,
#                         "rect": {
#                             "top": 128,
#                             "left": 551,
#                             "bottom": 147,
#                             "right": 572
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "QUESTION12",
#                     "value": "QUESTION 12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4b841cbe-32ae-4a69-b337-cb42f66c175c",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION13_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e136dc57-bba0-4f60-b3f3-b20bd997c328",
#                         "index": 0,
#                         "rect": {
#                             "top": 160,
#                             "left": 512,
#                             "bottom": 178,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION13_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f0d0b200-115d-4e4e-8bda-cfc1722b3a7a",
#                         "index": 1,
#                         "rect": {
#                             "top": 160,
#                             "left": 550,
#                             "bottom": 177,
#                             "right": 572
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "QUESTION13",
#                     "value": "QUESTION 13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "828d9a62-0c3e-4d03-8d85-1fc6c1bf3a3d",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION14_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e2d0ca3c-3d19-4648-b73f-7f62d9b4722d",
#                         "index": 0,
#                         "rect": {
#                             "top": 191,
#                             "left": 511,
#                             "bottom": 210,
#                             "right": 533
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION14_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1c086758-71ec-4e42-86b2-5f761845f35f",
#                         "index": 1,
#                         "rect": {
#                             "top": 190,
#                             "left": 549,
#                             "bottom": 210,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "QUESTION14",
#                     "value": "QUESTION 14"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "34d5d7e3-18c1-4643-b0e4-2018f9a737a2",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION15_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e18ce1a6-02a3-4135-ad46-2667000e96eb",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 511,
#                             "bottom": 240,
#                             "right": 532
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION15_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e22c899c-92e1-40dd-9508-a97f327563e6",
#                         "index": 1,
#                         "rect": {
#                             "top": 222,
#                             "left": 549,
#                             "bottom": 239,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "QUESTION15",
#                     "value": "QUESTION 15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dfd76fce-7a63-412b-9c70-df2ed50694a2",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION16_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "cdc8dd77-0cf9-404a-870e-8753d3b70d02",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 511,
#                             "bottom": 272,
#                             "right": 532
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION16_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b876f93b-db6e-4bfa-94dc-55c468365671",
#                         "index": 1,
#                         "rect": {
#                             "top": 253,
#                             "left": 549,
#                             "bottom": 272,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "QUESTION16",
#                     "value": "QUESTION 16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "e3a24ce0-4aa2-42c9-b390-f7047b896d16",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION17_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "59cc8495-887b-43ed-b6ce-42ac2734b8c8",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 512,
#                             "bottom": 302,
#                             "right": 535
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION17_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "380ae431-42b3-41fe-856d-b0d3dc633847",
#                         "index": 1,
#                         "rect": {
#                             "top": 284,
#                             "left": 550,
#                             "bottom": 303,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "QUESTION17",
#                     "value": "QUESTION 17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "09821434-0845-4f45-8b07-5045dd18b3a2",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION18_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5a448443-e4aa-4b01-9d1c-096dc0f5d7e5",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 512,
#                             "bottom": 333,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION18_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "88ca3f9d-ddbf-48e2-bd67-5da3c1c574e6",
#                         "index": 1,
#                         "rect": {
#                             "top": 315,
#                             "left": 550,
#                             "bottom": 334,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "QUESTION18",
#                     "value": "QUESTION 18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c35af1d0-fbb6-4fc8-b317-1b7392d973cb",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION19_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9b4d8f94-0c53-41fe-93b4-021c5e31a185",
#                         "index": 0,
#                         "rect": {
#                             "top": 346,
#                             "left": 512,
#                             "bottom": 365,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION19_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "df46ae48-a908-40a7-b335-b4f0878c2401",
#                         "index": 1,
#                         "rect": {
#                             "top": 347,
#                             "left": 551,
#                             "bottom": 365,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "QUESTION19",
#                     "value": "QUESTION 19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f924a07e-26a0-474f-806b-44ad5f85ba21",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION20_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ebe69d99-5f87-41a9-8c32-eaf253ae84bf",
#                         "index": 0,
#                         "rect": {
#                             "top": 378,
#                             "left": 512,
#                             "bottom": 396,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION20_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "239641b6-8002-42b6-b359-4877feec3c70",
#                         "index": 1,
#                         "rect": {
#                             "top": 377,
#                             "left": 551,
#                             "bottom": 395,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "QUESTION20",
#                     "value": "QUESTION 20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a6eaaf36-299e-4b1b-8692-6b78c12857ad",
#                 "rois": [
#                     {
#                         "annotationTags": "MAX_MARKS_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "dac0bc61-1921-425d-ac26-0116046dbe90",
#                         "index": 0,
#                         "rect": {
#                             "top": 430,
#                             "left": 133,
#                             "bottom": 449,
#                             "right": 156
#                         }
#                     },
#                     {
#                         "annotationTags": "MAX_MARKS_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "615436ca-a89f-48ff-a781-977a51d2d750",
#                         "index": 1,
#                         "rect": {
#                             "top": 431,
#                             "left": 159,
#                             "bottom": 450,
#                             "right": 181
#                         }
#                     },
#                     {
#                         "annotationTags": "MAX_MARKS_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "bcde51d6-e45e-4d2e-83ff-f7851290d57f",
#                         "index": 2,
#                         "rect": {
#                             "top": 431,
#                             "left": 185,
#                             "bottom": 451,
#                             "right": 207
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "MAX_MARKS",
#                     "value": "MAX MARKS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9e947daa-30b1-4956-b8b2-501f6c736337",
#                 "rois": [
#                     {
#                         "annotationTags": "MARKS_OBTAINED_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8b01c128-c0c2-4ba7-8c2b-f4f195b859ad",
#                         "index": 0,
#                         "rect": {
#                             "top": 430,
#                             "left": 333,
#                             "bottom": 449,
#                             "right": 354
#                         }
#                     },
#                     {
#                         "annotationTags": "MARKS_OBTAINED_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e630340c-b883-4ffe-8fc7-278f46644570",
#                         "index": 1,
#                         "rect": {
#                             "top": 430,
#                             "left": 358,
#                             "bottom": 448,
#                             "right": 380
#                         }
#                     },
#                     {
#                         "annotationTags": "MARKS_OBTAINED_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "bac411e4-6ce8-4cb7-8439-3826687d444e",
#                         "index": 2,
#                         "rect": {
#                             "top": 430,
#                             "left": 384,
#                             "bottom": 450,
#                             "right": 405
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "MARKS_OBTAINED",
#                     "value": "MARKS OBTAINED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
