# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
    
            rois.append({

                "annotationTags": str(region['tags'][0]),
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
            
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName = ""

              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "Gujrat 5Q MultiChoice Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("gujrat_5q_multichoice_vottraw.json")

# %%
tagGroups = ["ROLLNUMBER", "QUESTION1","QUESTION2","QUESTION3","QUESTION4","QUESTION5"]

formatLookup = {
    'ROLLNUMBER': 'ROLLNUMBER',
    'QUESTION1':'QUESTION 1',
    'QUESTION2':'QUESTION 2',
    'QUESTION3':'QUESTION 3',
    'QUESTION4':'QUESTION 4',
    'QUESTION5':'QUESTION 5',
}

formatNameLookup = {
    'ROLLNUMBER': 'ROLLNUMBER',
    'QUESTION1':'QUESTION1',
    'QUESTION2':'QUESTION2',
    'QUESTION3':'QUESTION3',
    'QUESTION4':'QUESTION4',
    'QUESTION5':'QUESTION5',

}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "Gujrat 5Q MultiChoice Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 33,
#                             "left": 220,
#                             "bottom": 63,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 32,
#                             "left": 245,
#                             "bottom": 64,
#                             "right": 269
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 32,
#                             "left": 271,
#                             "bottom": 63,
#                             "right": 293
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 33,
#                             "left": 294,
#                             "bottom": 63,
#                             "right": 316
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 33,
#                             "left": 317,
#                             "bottom": 63,
#                             "right": 342
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 34,
#                             "left": 343,
#                             "bottom": 63,
#                             "right": 365
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 33,
#                             "left": 367,
#                             "bottom": 64,
#                             "right": 391
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER",
#                     "value": "ROLLNUMBER"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION1_0",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 0,
#                         "rect": {
#                             "top": 130,
#                             "left": 221,
#                             "bottom": 159,
#                             "right": 244
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 1,
#                         "rect": {
#                             "top": 131,
#                             "left": 246,
#                             "bottom": 160,
#                             "right": 268
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 2,
#                         "rect": {
#                             "top": 131,
#                             "left": 271,
#                             "bottom": 160,
#                             "right": 293
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 3,
#                         "rect": {
#                             "top": 131,
#                             "left": 294,
#                             "bottom": 158,
#                             "right": 316
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 4,
#                         "rect": {
#                             "top": 132,
#                             "left": 320,
#                             "bottom": 159,
#                             "right": 340
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 5,
#                         "rect": {
#                             "top": 131,
#                             "left": 344,
#                             "bottom": 157,
#                             "right": 365
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "QUESTION1",
#                     "value": "QUESTION 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION2_0",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "14",
#                         "index": 0,
#                         "rect": {
#                             "top": 179,
#                             "left": 222,
#                             "bottom": 205,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "15",
#                         "index": 1,
#                         "rect": {
#                             "top": 179,
#                             "left": 246,
#                             "bottom": 206,
#                             "right": 267
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "16",
#                         "index": 2,
#                         "rect": {
#                             "top": 179,
#                             "left": 271,
#                             "bottom": 206,
#                             "right": 290
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "17",
#                         "index": 3,
#                         "rect": {
#                             "top": 179,
#                             "left": 294,
#                             "bottom": 207,
#                             "right": 316
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "18",
#                         "index": 4,
#                         "rect": {
#                             "top": 180,
#                             "left": 319,
#                             "bottom": 206,
#                             "right": 340
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "19",
#                         "index": 5,
#                         "rect": {
#                             "top": 179,
#                             "left": 344,
#                             "bottom": 206,
#                             "right": 364
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "QUESTION2",
#                     "value": "QUESTION 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION3_0",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "20",
#                         "index": 0,
#                         "rect": {
#                             "top": 228,
#                             "left": 222,
#                             "bottom": 253,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "21",
#                         "index": 1,
#                         "rect": {
#                             "top": 227,
#                             "left": 246,
#                             "bottom": 253,
#                             "right": 267
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "22",
#                         "index": 2,
#                         "rect": {
#                             "top": 228,
#                             "left": 271,
#                             "bottom": 254,
#                             "right": 292
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "23",
#                         "index": 3,
#                         "rect": {
#                             "top": 227,
#                             "left": 296,
#                             "bottom": 255,
#                             "right": 317
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "24",
#                         "index": 4,
#                         "rect": {
#                             "top": 228,
#                             "left": 320,
#                             "bottom": 255,
#                             "right": 340
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "25",
#                         "index": 5,
#                         "rect": {
#                             "top": 228,
#                             "left": 345,
#                             "bottom": 255,
#                             "right": 365
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "QUESTION3",
#                     "value": "QUESTION 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION4_0",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "26",
#                         "index": 0,
#                         "rect": {
#                             "top": 275,
#                             "left": 222,
#                             "bottom": 301,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "27",
#                         "index": 1,
#                         "rect": {
#                             "top": 275,
#                             "left": 247,
#                             "bottom": 301,
#                             "right": 267
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "28",
#                         "index": 2,
#                         "rect": {
#                             "top": 275,
#                             "left": 271,
#                             "bottom": 301,
#                             "right": 292
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "29",
#                         "index": 3,
#                         "rect": {
#                             "top": 275,
#                             "left": 295,
#                             "bottom": 301,
#                             "right": 317
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "30",
#                         "index": 4,
#                         "rect": {
#                             "top": 275,
#                             "left": 320,
#                             "bottom": 302,
#                             "right": 342
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "31",
#                         "index": 5,
#                         "rect": {
#                             "top": 276,
#                             "left": 345,
#                             "bottom": 302,
#                             "right": 365
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "QUESTION4",
#                     "value": "QUESTION 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION5_0",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "32",
#                         "index": 0,
#                         "rect": {
#                             "top": 323,
#                             "left": 222,
#                             "bottom": 348,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "33",
#                         "index": 1,
#                         "rect": {
#                             "top": 323,
#                             "left": 246,
#                             "bottom": 349,
#                             "right": 267
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "34",
#                         "index": 2,
#                         "rect": {
#                             "top": 323,
#                             "left": 271,
#                             "bottom": 349,
#                             "right": 292
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "35",
#                         "index": 3,
#                         "rect": {
#                             "top": 322,
#                             "left": 295,
#                             "bottom": 349,
#                             "right": 315
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "36",
#                         "index": 4,
#                         "rect": {
#                             "top": 323,
#                             "left": 320,
#                             "bottom": 349,
#                             "right": 341
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "37",
#                         "index": 5,
#                         "rect": {
#                             "top": 323,
#                             "left": 344,
#                             "bottom": 349,
#                             "right": 365
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "QUESTION5",
#                     "value": "QUESTION 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
