# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
                
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = str(tagGroup)

    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": str(tagGroup),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "beneficiary growth monitoring Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("Beneficiary_growth_monitoring_vottraw.json")

# %%
tagGroups = ['CHILDID', 'AIM0_HEIGHTINCM','AIM0_HEIGHTINMM','AIM0_WEIGHTINKG','AIM0_WEIGHTINMG','AIM0_DOM', 'AIM0_STUNTED', 'AIM0_WASTED', 'AIM0_UNDERWEIGHT', 'AIM0_EDEMA', 'AIM0_ELIGIBLE_SUPPLIMNTRY', 'AIM0_ELIGIBLE_REFRAL', 'AIM0_REASON_REFRAL', 'AIM0_PARENTS_STATUS', 'AIM1_HEIGHTINCM','AIM1_HEIGHTINMM', 'AIM1_WEIGHTINKG','AIM1_WEIGHTINMG','AIM1_DOM', 'AIM1_STUNTED', 'AIM1_WASTED', 'AIM1_UNDERWEIGHT', 'AIM1_EDEMA', 'AIM1_ELIGIBLE_SUPPLIMNTRY', 'AIM1_ELIGIBLE_REFRAL', 'AIM1_REASON_REFRAL', 'AIM1_PARENTS_STATUS', 'AIM2_HEIGHTINCM','AIM2_HEIGHTINMM','AIM2_WEIGHTINKG','AIM2_WEIGHTINMG', 'AIM2_DOM', 'AIM2_STUNTED', 'AIM2_WASTED', 'AIM2_UNDERWEIGHT', 'AIM2_EDEMA', 'AIM2_ELIGIBLE_SUPPLIMNTRY', 'AIM2_ELIGIBLE_REFRAL', 'AIM2_REASON_REFRAL', 'AIM2_PARENTS_STATUS', 'AIM3_HEIGHTINCM','AIM3_HEIGHTINMM','AIM3_WEIGHTINKG','AIM3_WEIGHTINMG','AIM3_DOM', 'AIM3_STUNTED', 'AIM3_WASTED', 'AIM3_UNDERWEIGHT', 'AIM3_EDEMA', 'AIM3_ELIGIBLE_SUPPLIMNTRY', 'AIM3_ELIGIBLE_REFRAL', 'AIM3_REASON_REFRAL', 'AIM3_PARENTS_STATUS', 'AIM4_HEIGHTINCM','AIM4_HEIGHTINMM', 'AIM4_WEIGHTINKG','AIM4_WEIGHTINMG','AIM4_DOM', 'AIM4_STUNTED', 'AIM4_WASTED', 'AIM4_UNDERWEIGHT', 'AIM4_EDEMA', 'AIM4_ELIGIBLE_SUPPLIMNTRY', 'AIM4_ELIGIBLE_REFRAL', 'AIM4_REASON_REFRAL', 'AIM4_PARENTS_STATUS', 'AIM5_HEIGHTINCM','AIM5_HEIGHTINMM','AIM5_WEIGHTINKG','AIM5_WEIGHTINMG','AIM5_DOM', 'AIM5_STUNTED', 'AIM5_WASTED', 'AIM5_UNDERWEIGHT', 'AIM5_EDEMA', 'AIM5_ELIGIBLE_SUPPLIMNTRY', 'AIM5_ELIGIBLE_REFRAL', 'AIM5_REASON_REFRAL', 'AIM5_PARENTS_STATUS', 'AIM6_HEIGHTINCM','AIM6_HEIGHTINMM', 'AIM6_WEIGHTINKG','AIM6_WEIGHTINMG','AIM6_DOM', 'AIM6_STUNTED', 'AIM6_WASTED', 'AIM6_UNDERWEIGHT', 'AIM6_EDEMA', 'AIM6_ELIGIBLE_SUPPLIMNTRY', 'AIM6_ELIGIBLE_REFRAL', 'AIM6_REASON_REFRAL', 'AIM6_PARENTS_STATUS']
formatLookup = {
    'CHILDID' : 'CHILDID',
    'AIM0_HEIGHTINCM' : 'AIM0 HEIGHTINCM',
    'AIM0_HEIGHTINMM': 'AIM0 HEIGHTINMM',
    'AIM0_WEIGHTINKG' : 'AIM0 WEIGHTINKG',
    'AIM0_WEIGHTINMG': 'AIM0 WEIGHTINMG',
    'AIM0_DOM' : 'AIM0 DOM',
    'AIM0_STUNTED' : 'AIM0 STUNTED',
    'AIM0_WASTED' : 'AIM0 WASTED',
    'AIM0_UNDERWEIGHT' : 'AIM0 UNDERWEIGHT',
    'AIM0_EDEMA' : 'AIM0 EDEMA',
    'AIM0_ELIGIBLE_SUPPLIMNTRY' : 'AIM0 ELIGIBLE SUPPLIMNTRY',
    'AIM0_ELIGIBLE_REFRAL' : 'AIM0 ELIGIBLE REFRAL',
    'AIM0_REASON_REFRAL' : 'AIM0 REASON REFRAL',
    'AIM0_PARENTS_STATUS' : 'AIM0 PARENTS STATUS',
    'AIM1_HEIGHTINCM' : 'AIM1 HEIGHTINCM',
    'AIM1_HEIGHTINMM': 'AIM1 HEIGHTINMM',
    'AIM1_WEIGHTINKG' : 'AIM1 WEIGHTINKG',
    'AIM1_WEIGHTINMG': 'AIM1 WEIGHTINMG',
    'AIM1_DOM' : 'AIM1 DOM',
    'AIM1_STUNTED' : 'AIM1 STUNTED',
    'AIM1_WASTED' : 'AIM1 WASTED',
    'AIM1_UNDERWEIGHT' : 'AIM1 UNDERWEIGHT',
    'AIM1_EDEMA' : 'AIM1 EDEMA',
    'AIM1_ELIGIBLE_SUPPLIMNTRY' : 'AIM1 ELIGIBLE SUPPLIMNTRY',
    'AIM1_ELIGIBLE_REFRAL' : 'AIM1 ELIGIBLE REFRAL',
    'AIM1_REASON_REFRAL' : 'AIM1 REASON REFRAL',
    'AIM1_PARENTS_STATUS' : 'AIM1 PARENTS STATUS',
    'AIM2_HEIGHTINCM' : 'AIM2 HEIGHTINCM',
    'AIM2_HEIGHTINMM': 'AIM2 HEIGHTINMM',
    'AIM2_WEIGHTINKG' : 'AIM2 WEIGHTINKG',
    'AIM2_WEIGHTINMG': 'AIM2 WEIGHTINMG',
    'AIM2_DOM' : 'AIM2 DOM',
    'AIM2_STUNTED' : 'AIM2 STUNTED',
    'AIM2_WASTED' : 'AIM2 WASTED',
    'AIM2_UNDERWEIGHT' : 'AIM2 UNDERWEIGHT',
    'AIM2_EDEMA' : 'AIM2 EDEMA',
    'AIM2_ELIGIBLE_SUPPLIMNTRY' : 'AIM2 ELIGIBLE SUPPLIMNTRY',
    'AIM2_ELIGIBLE_REFRAL' : 'AIM2 ELIGIBLE REFRAL',
    'AIM2_REASON_REFRAL' : 'AIM2 REASON REFRAL',
    'AIM2_PARENTS_STATUS' : 'AIM2 PARENTS STATUS',
    'AIM3_HEIGHTINCM' : 'AIM3 HEIGHTINCM',
    'AIM3_HEIGHTINMM': 'AIM3 HEIGHTINMM',
    'AIM3_WEIGHTINKG' : 'AIM3 WEIGHTINKG',
    'AIM3_WEIGHTINMG': 'AIM3 WEIGHTINMG',
    'AIM3_DOM' : 'AIM3 DOM',
    'AIM3_STUNTED' : 'AIM3 STUNTED',
    'AIM3_WASTED' : 'AIM3 WASTED',
    'AIM3_UNDERWEIGHT' : 'AIM3 UNDERWEIGHT',
    'AIM3_EDEMA' : 'AIM3 EDEMA',
    'AIM3_ELIGIBLE_SUPPLIMNTRY' : 'AIM3 ELIGIBLE SUPPLIMNTRY',
    'AIM3_ELIGIBLE_REFRAL' : 'AIM3 ELIGIBLE REFRAL',
    'AIM3_REASON_REFRAL' : 'AIM3 REASON REFRAL',
    'AIM3_PARENTS_STATUS' : 'AIM3 PARENTS STATUS',
    'AIM4_HEIGHTINCM' : 'AIM4 HEIGHTINCM',
    'AIM4_HEIGHTINMM': 'AIM4 HEIGHTINMM',
    'AIM4_WEIGHTINKG' : 'AIM4 WEIGHTINKG',
    'AIM4_WEIGHTINMG': 'AIM4 WEIGHTINMG',
    'AIM4_DOM' : 'AIM4 DOM',
    'AIM4_STUNTED' : 'AIM4 STUNTED',
    'AIM4_WASTED' : 'AIM4 WASTED',
    'AIM4_UNDERWEIGHT' : 'AIM4 UNDERWEIGHT',
    'AIM4_EDEMA' : 'AIM4 EDEMA',
    'AIM4_ELIGIBLE_SUPPLIMNTRY' : 'AIM4 ELIGIBLE SUPPLIMNTRY',
    'AIM4_ELIGIBLE_REFRAL' : 'AIM4 ELIGIBLE REFRAL',
    'AIM4_REASON_REFRAL' : 'AIM4 REASON REFRAL',
    'AIM4_PARENTS_STATUS' : 'AIM4 PARENTS STATUS',
    'AIM5_HEIGHTINCM' : 'AIM5 HEIGHTINCM',
    'AIM5_HEIGHTINMM': 'AIM5 HEIGHTINMM',
    'AIM5_WEIGHTINKG' : 'AIM5 WEIGHTINKG',
    'AIM5_WEIGHTINMG': 'AIM5 WEIGHTINMG',
    'AIM5_DOM' : 'AIM5 DOM',
    'AIM5_STUNTED' : 'AIM5 STUNTED',
    'AIM5_WASTED' : 'AIM5 WASTED',
    'AIM5_UNDERWEIGHT' : 'AIM5 UNDERWEIGHT',
    'AIM5_EDEMA' : 'AIM5 EDEMA',
    'AIM5_ELIGIBLE_SUPPLIMNTRY' : 'AIM5 ELIGIBLE SUPPLIMNTRY',
    'AIM5_ELIGIBLE_REFRAL' : 'AIM5 ELIGIBLE REFRAL',
    'AIM5_REASON_REFRAL' : 'AIM5 REASON REFRAL',
    'AIM5_PARENTS_STATUS' : 'AIM5 PARENTS STATUS',
    'AIM6_HEIGHTINCM' : 'AIM6 HEIGHTINCM',
    'AIM6_HEIGHTINMM': 'AIM6 HEIGHTINMM',
    'AIM6_WEIGHTINKG' : 'AIM6 WEIGHTINKG',
    'AIM6_WEIGHTINMG': 'AIM6 WEIGHTINMG',
    'AIM6_DOM' : 'AIM6 DOM',
    'AIM6_STUNTED' : 'AIM6 STUNTED',
    'AIM6_WASTED' : 'AIM6 WASTED',
    'AIM6_UNDERWEIGHT' : 'AIM6 UNDERWEIGHT',
    'AIM6_EDEMA' : 'AIM6 EDEMA',
    'AIM6_ELIGIBLE_SUPPLIMNTRY' : 'AIM6 ELIGIBLE SUPPLIMNTRY',
    'AIM6_ELIGIBLE_REFRAL' : 'AIM6 ELIGIBLE REFRAL',
    'AIM6_REASON_REFRAL' : 'AIM6 REASON REFRAL',
    'AIM6_PARENTS_STATUS' : 'AIM6 PARENTS STATUS'
      
}

formatAnnotationTagLookup = {
    'CHILDIDTEN' : 'CHILDID10'
}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "beneficiary growth monitoring Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 22,
#                             "left": 270,
#                             "bottom": 55,
#                             "right": 292
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 22,
#                             "left": 294,
#                             "bottom": 55,
#                             "right": 315
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 22,
#                             "left": 317,
#                             "bottom": 55,
#                             "right": 339
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 22,
#                             "left": 341,
#                             "bottom": 53,
#                             "right": 363
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 22,
#                             "left": 364,
#                             "bottom": 54,
#                             "right": 387
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 22,
#                             "left": 388,
#                             "bottom": 55,
#                             "right": 410
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 22,
#                             "left": 413,
#                             "bottom": 53,
#                             "right": 435
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 7,
#                         "rect": {
#                             "top": 22,
#                             "left": 436,
#                             "bottom": 53,
#                             "right": 459
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 8,
#                         "rect": {
#                             "top": 22,
#                             "left": 460,
#                             "bottom": 55,
#                             "right": 481
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 9,
#                         "rect": {
#                             "top": 23,
#                             "left": 483,
#                             "bottom": 56,
#                             "right": 505
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "CHILDID",
#                     "value": "CHILDID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_HEIGHTINCM1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 80,
#                             "bottom": 253,
#                             "right": 101
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHTINCM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 1,
#                         "rect": {
#                             "top": 222,
#                             "left": 104,
#                             "bottom": 254,
#                             "right": 125
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHTINCM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 2,
#                         "rect": {
#                             "top": 221,
#                             "left": 127,
#                             "bottom": 254,
#                             "right": 149
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "AIM0_HEIGHTINCM",
#                     "value": "AIM0 HEIGHTINCM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_HEIGHTINMM2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "14",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 150,
#                             "bottom": 254,
#                             "right": 173
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "AIM0_HEIGHTINMM",
#                     "value": "AIM0 HEIGHTINMM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_WEIGHTINKG1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "15",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 175,
#                             "bottom": 253,
#                             "right": 197
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHTINKG1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "16",
#                         "index": 1,
#                         "rect": {
#                             "top": 222,
#                             "left": 199,
#                             "bottom": 255,
#                             "right": 221
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "AIM0_WEIGHTINKG",
#                     "value": "AIM0 WEIGHTINKG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_WEIGHTINMG2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "17",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 222,
#                             "bottom": 254,
#                             "right": 244
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHTINMG2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "18",
#                         "index": 1,
#                         "rect": {
#                             "top": 222,
#                             "left": 247,
#                             "bottom": 254,
#                             "right": 268
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHTINMG2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "19",
#                         "index": 2,
#                         "rect": {
#                             "top": 222,
#                             "left": 269,
#                             "bottom": 254,
#                             "right": 291
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "AIM0_WEIGHTINMG",
#                     "value": "AIM0 WEIGHTINMG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_DOM1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "20",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 292,
#                             "bottom": 254,
#                             "right": 315
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "21",
#                         "index": 1,
#                         "rect": {
#                             "top": 223,
#                             "left": 317,
#                             "bottom": 253,
#                             "right": 339
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "22",
#                         "index": 2,
#                         "rect": {
#                             "top": 222,
#                             "left": 341,
#                             "bottom": 253,
#                             "right": 362
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "23",
#                         "index": 3,
#                         "rect": {
#                             "top": 223,
#                             "left": 364,
#                             "bottom": 255,
#                             "right": 387
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "24",
#                         "index": 4,
#                         "rect": {
#                             "top": 222,
#                             "left": 388,
#                             "bottom": 254,
#                             "right": 409
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "25",
#                         "index": 5,
#                         "rect": {
#                             "top": 221,
#                             "left": 412,
#                             "bottom": 254,
#                             "right": 434
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "AIM0_DOM",
#                     "value": "AIM0 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_STUNTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "26",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 436,
#                             "bottom": 252,
#                             "right": 457
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "AIM0_STUNTED",
#                     "value": "AIM0 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_WASTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "27",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 459,
#                             "bottom": 254,
#                             "right": 480
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "AIM0_WASTED",
#                     "value": "AIM0 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_UNDERWEIGHT1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "28",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 483,
#                             "bottom": 254,
#                             "right": 504
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "AIM0_UNDERWEIGHT",
#                     "value": "AIM0 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_EDEMA1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "29",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 506,
#                             "bottom": 253,
#                             "right": 528
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "AIM0_EDEMA",
#                     "value": "AIM0 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_ELIGIBLE_SUPPLIMNTRY1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "30",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 529,
#                             "bottom": 254,
#                             "right": 552
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "AIM0_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM0 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_ELIGIBLE_REFRAL1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "31",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 553,
#                             "bottom": 254,
#                             "right": 576
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "AIM0_ELIGIBLE_REFRAL",
#                     "value": "AIM0 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_REASON_REFRAL1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "32",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 578,
#                             "bottom": 255,
#                             "right": 600
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "AIM0_REASON_REFRAL",
#                     "value": "AIM0 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_PARENTS_STATUS1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "33",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 601,
#                             "bottom": 254,
#                             "right": 623
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "AIM0_PARENTS_STATUS",
#                     "value": "AIM0 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "15",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_HEIGHTINCM1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "34",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 81,
#                             "bottom": 286,
#                             "right": 99
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_HEIGHTINCM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "35",
#                         "index": 1,
#                         "rect": {
#                             "top": 258,
#                             "left": 105,
#                             "bottom": 285,
#                             "right": 123
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_HEIGHTINCM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "36",
#                         "index": 2,
#                         "rect": {
#                             "top": 257,
#                             "left": 129,
#                             "bottom": 285,
#                             "right": 148
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "AIM1_HEIGHTINCM",
#                     "value": "AIM1 HEIGHTINCM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "16",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_HEIGHTINMM2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "37",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 152,
#                             "bottom": 284,
#                             "right": 169
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "AIM1_HEIGHTINMM",
#                     "value": "AIM1 HEIGHTINMM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "17",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_WEIGHTINKG1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "38",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 176,
#                             "bottom": 285,
#                             "right": 193
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHTINKG1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "39",
#                         "index": 1,
#                         "rect": {
#                             "top": 258,
#                             "left": 201,
#                             "bottom": 284,
#                             "right": 218
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "AIM1_WEIGHTINKG",
#                     "value": "AIM1 WEIGHTINKG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_WEIGHTINMG2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "40",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 224,
#                             "bottom": 285,
#                             "right": 241
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHTINMG2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "41",
#                         "index": 1,
#                         "rect": {
#                             "top": 258,
#                             "left": 247,
#                             "bottom": 284,
#                             "right": 264
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHTINMG2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "42",
#                         "index": 2,
#                         "rect": {
#                             "top": 258,
#                             "left": 271,
#                             "bottom": 285,
#                             "right": 289
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "AIM1_WEIGHTINMG",
#                     "value": "AIM1 WEIGHTINMG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "19",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_DOM1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "43",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 293,
#                             "bottom": 285,
#                             "right": 311
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "44",
#                         "index": 1,
#                         "rect": {
#                             "top": 258,
#                             "left": 319,
#                             "bottom": 285,
#                             "right": 336
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "45",
#                         "index": 2,
#                         "rect": {
#                             "top": 258,
#                             "left": 342,
#                             "bottom": 285,
#                             "right": 360
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "46",
#                         "index": 3,
#                         "rect": {
#                             "top": 259,
#                             "left": 367,
#                             "bottom": 285,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "47",
#                         "index": 4,
#                         "rect": {
#                             "top": 259,
#                             "left": 389,
#                             "bottom": 283,
#                             "right": 406
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "48",
#                         "index": 5,
#                         "rect": {
#                             "top": 258,
#                             "left": 414,
#                             "bottom": 284,
#                             "right": 430
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "AIM1_DOM",
#                     "value": "AIM1 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "20",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_STUNTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "49",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 437,
#                             "bottom": 282,
#                             "right": 453
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "AIM1_STUNTED",
#                     "value": "AIM1 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "21",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_WASTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "50",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 462,
#                             "bottom": 284,
#                             "right": 477
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "AIM1_WASTED",
#                     "value": "AIM1 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "22",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_UNDERWEIGHT1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "51",
#                         "index": 0,
#                         "rect": {
#                             "top": 259,
#                             "left": 485,
#                             "bottom": 284,
#                             "right": 502
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "AIM1_UNDERWEIGHT",
#                     "value": "AIM1 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "23",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_EDEMA1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "52",
#                         "index": 0,
#                         "rect": {
#                             "top": 259,
#                             "left": 508,
#                             "bottom": 285,
#                             "right": 525
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "AIM1_EDEMA",
#                     "value": "AIM1 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "24",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_ELIGIBLE_SUPPLIMNTRY1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "53",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 531,
#                             "bottom": 285,
#                             "right": 548
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "AIM1_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM1 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "25",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_ELIGIBLE_REFRAL1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "54",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 555,
#                             "bottom": 285,
#                             "right": 574
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "AIM1_ELIGIBLE_REFRAL",
#                     "value": "AIM1 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "26",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_REASON_REFRAL1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "55",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 579,
#                             "bottom": 286,
#                             "right": 597
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "AIM1_REASON_REFRAL",
#                     "value": "AIM1 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "27",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_PARENTS_STATUS1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "56",
#                         "index": 0,
#                         "rect": {
#                             "top": 257,
#                             "left": 603,
#                             "bottom": 285,
#                             "right": 622
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "AIM1_PARENTS_STATUS",
#                     "value": "AIM1 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "28",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_HEIGHTINCM1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "57",
#                         "index": 0,
#                         "rect": {
#                             "top": 292,
#                             "left": 81,
#                             "bottom": 319,
#                             "right": 99
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_HEIGHTINCM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "58",
#                         "index": 1,
#                         "rect": {
#                             "top": 291,
#                             "left": 105,
#                             "bottom": 319,
#                             "right": 123
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_HEIGHTINCM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "59",
#                         "index": 2,
#                         "rect": {
#                             "top": 292,
#                             "left": 129,
#                             "bottom": 319,
#                             "right": 147
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 28
#                 },
#                 "format": {
#                     "name": "AIM2_HEIGHTINCM",
#                     "value": "AIM2 HEIGHTINCM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "29",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_HEIGHTINMM2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "60",
#                         "index": 0,
#                         "rect": {
#                             "top": 291,
#                             "left": 152,
#                             "bottom": 318,
#                             "right": 170
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 29
#                 },
#                 "format": {
#                     "name": "AIM2_HEIGHTINMM",
#                     "value": "AIM2 HEIGHTINMM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "30",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_WEIGHTINKG1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "61",
#                         "index": 0,
#                         "rect": {
#                             "top": 292,
#                             "left": 176,
#                             "bottom": 319,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHTINKG1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "62",
#                         "index": 1,
#                         "rect": {
#                             "top": 291,
#                             "left": 200,
#                             "bottom": 319,
#                             "right": 219
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 30
#                 },
#                 "format": {
#                     "name": "AIM2_WEIGHTINKG",
#                     "value": "AIM2 WEIGHTINKG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "31",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_WEIGHTINMG2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "63",
#                         "index": 0,
#                         "rect": {
#                             "top": 292,
#                             "left": 224,
#                             "bottom": 319,
#                             "right": 242
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHTINMG2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "64",
#                         "index": 1,
#                         "rect": {
#                             "top": 291,
#                             "left": 248,
#                             "bottom": 319,
#                             "right": 265
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHTINMG2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "65",
#                         "index": 2,
#                         "rect": {
#                             "top": 291,
#                             "left": 272,
#                             "bottom": 319,
#                             "right": 289
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 31
#                 },
#                 "format": {
#                     "name": "AIM2_WEIGHTINMG",
#                     "value": "AIM2 WEIGHTINMG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "32",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_DOM2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "66",
#                         "index": 0,
#                         "rect": {
#                             "top": 291,
#                             "left": 296,
#                             "bottom": 319,
#                             "right": 313
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "67",
#                         "index": 1,
#                         "rect": {
#                             "top": 291,
#                             "left": 319,
#                             "bottom": 319,
#                             "right": 336
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "68",
#                         "index": 2,
#                         "rect": {
#                             "top": 292,
#                             "left": 342,
#                             "bottom": 319,
#                             "right": 359
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM2_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "69",
#                         "index": 3,
#                         "rect": {
#                             "top": 292,
#                             "left": 366,
#                             "bottom": 319,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM2_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "70",
#                         "index": 4,
#                         "rect": {
#                             "top": 292,
#                             "left": 390,
#                             "bottom": 319,
#                             "right": 407
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM2_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "71",
#                         "index": 5,
#                         "rect": {
#                             "top": 292,
#                             "left": 414,
#                             "bottom": 319,
#                             "right": 431
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 32
#                 },
#                 "format": {
#                     "name": "AIM2_DOM",
#                     "value": "AIM2 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "33",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_STUNTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "72",
#                         "index": 0,
#                         "rect": {
#                             "top": 292,
#                             "left": 437,
#                             "bottom": 319,
#                             "right": 454
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 33
#                 },
#                 "format": {
#                     "name": "AIM2_STUNTED",
#                     "value": "AIM2 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "34",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_WASTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "73",
# ...
#                             "top": 427,
#                             "left": 81,
#                             "bottom": 455,
#                             "right": 100
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_HEIGHTINCM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "150",
#                         "index": 1,
#                         "rect": {
#                             "top": 427,
#                             "left": 106,
#                             "bottom": 455,
#                             "right": 123
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_HEIGHTINCM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "151",
#                         "index": 2,
#                         "rect": {
#                             "top": 427,
#                             "left": 129,
#                             "bottom": 454,
#                             "right": 147
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 80
#                 },
#                 "format": {
#                     "name": "AIM6_HEIGHTINCM",
#                     "value": "AIM6 HEIGHTINCM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "81",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_HEIGHTINMM2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "152",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 153,
#                             "bottom": 454,
#                             "right": 171
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 81
#                 },
#                 "format": {
#                     "name": "AIM6_HEIGHTINMM",
#                     "value": "AIM6 HEIGHTINMM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "82",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_WEIGHTINKG1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "153",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 177,
#                             "bottom": 454,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHTINKG1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "154",
#                         "index": 1,
#                         "rect": {
#                             "top": 428,
#                             "left": 201,
#                             "bottom": 454,
#                             "right": 218
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 82
#                 },
#                 "format": {
#                     "name": "AIM6_WEIGHTINKG",
#                     "value": "AIM6 WEIGHTINKG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "83",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_WEIGHTINMG2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "155",
#                         "index": 0,
#                         "rect": {
#                             "top": 425,
#                             "left": 225,
#                             "bottom": 453,
#                             "right": 242
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHTINMG2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "156",
#                         "index": 1,
#                         "rect": {
#                             "top": 427,
#                             "left": 249,
#                             "bottom": 454,
#                             "right": 265
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHTINMG2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "157",
#                         "index": 2,
#                         "rect": {
#                             "top": 429,
#                             "left": 273,
#                             "bottom": 455,
#                             "right": 289
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 83
#                 },
#                 "format": {
#                     "name": "AIM6_WEIGHTINMG",
#                     "value": "AIM6 WEIGHTINMG"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "84",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_DOM1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "158",
#                         "index": 0,
#                         "rect": {
#                             "top": 429,
#                             "left": 296,
#                             "bottom": 455,
#                             "right": 314
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "159",
#                         "index": 1,
#                         "rect": {
#                             "top": 428,
#                             "left": 319,
#                             "bottom": 455,
#                             "right": 338
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "160",
#                         "index": 2,
#                         "rect": {
#                             "top": 429,
#                             "left": 342,
#                             "bottom": 455,
#                             "right": 361
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "161",
#                         "index": 3,
#                         "rect": {
#                             "top": 428,
#                             "left": 367,
#                             "bottom": 454,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "162",
#                         "index": 4,
#                         "rect": {
#                             "top": 429,
#                             "left": 390,
#                             "bottom": 454,
#                             "right": 407
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "163",
#                         "index": 5,
#                         "rect": {
#                             "top": 427,
#                             "left": 414,
#                             "bottom": 453,
#                             "right": 431
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 84
#                 },
#                 "format": {
#                     "name": "AIM6_DOM",
#                     "value": "AIM6 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "85",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_STUNTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "164",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 438,
#                             "bottom": 454,
#                             "right": 454
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 85
#                 },
#                 "format": {
#                     "name": "AIM6_STUNTED",
#                     "value": "AIM6 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "86",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_WASTED1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "165",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 463,
#                             "bottom": 454,
#                             "right": 479
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 86
#                 },
#                 "format": {
#                     "name": "AIM6_WASTED",
#                     "value": "AIM6 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "87",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_UNDERWEIGHT1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "166",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 485,
#                             "bottom": 454,
#                             "right": 502
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 87
#                 },
#                 "format": {
#                     "name": "AIM6_UNDERWEIGHT",
#                     "value": "AIM6 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "88",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_EDEMA1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "167",
#                         "index": 0,
#                         "rect": {
#                             "top": 426,
#                             "left": 509,
#                             "bottom": 454,
#                             "right": 525
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 88
#                 },
#                 "format": {
#                     "name": "AIM6_EDEMA",
#                     "value": "AIM6 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "89",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_ELIGIBLE_SUPPLIMNTRY1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "168",
#                         "index": 0,
#                         "rect": {
#                             "top": 426,
#                             "left": 533,
#                             "bottom": 454,
#                             "right": 550
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 89
#                 },
#                 "format": {
#                     "name": "AIM6_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM6 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "90",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_ELIGIBLE_REFRAL1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "169",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 556,
#                             "bottom": 454,
#                             "right": 574
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 90
#                 },
#                 "format": {
#                     "name": "AIM6_ELIGIBLE_REFRAL",
#                     "value": "AIM6 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "91",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_REASON_REFRAL1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "170",
#                         "index": 0,
#                         "rect": {
#                             "top": 427,
#                             "left": 581,
#                             "bottom": 453,
#                             "right": 597
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 91
#                 },
#                 "format": {
#                     "name": "AIM6_REASON_REFRAL",
#                     "value": "AIM6 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "92",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_PARENTS_STATUS1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "171",
#                         "index": 0,
#                         "rect": {
#                             "top": 428,
#                             "left": 604,
#                             "bottom": 454,
#                             "right": 621
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 92
#                 },
#                 "format": {
#                     "name": "AIM6_PARENTS_STATUS",
#                     "value": "AIM6 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
