# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
                
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": "NUMERIC CLASSIFICATION",
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = str(tagGroup)

    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": str(tagGroup),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "beneficiary growth monitoring Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("Beneficiary_growth_vottraw.json")

# %%
tagGroups = ['CHILDID', 'AIM0_HEIGHT', 'AIM0_WEIGHT', 'AIM0_DOM', 'AIM0_STUNTED', 'AIM0_WASTED', 'AIM0_UNDERWEIGHT', 'AIM0_EDEMA', 'AIM0_ELIGIBLE_SUPPLIMNTRY', 'AIM0_ELIGIBLE_REFRAL', 'AIM0_REASON_REFRAL', 'AIM0_PARENTS_STATUS', 'AIM1_HEIGHT', 'AIM1_WEIGHT', 'AIM1_DOM', 'AIM1_STUNTED', 'AIM1_WASTED', 'AIM1_UNDERWEIGHT', 'AIM1_EDEMA', 'AIM1_ELIGIBLE_SUPPLIMNTRY', 'AIM1_ELIGIBLE_REFRAL', 'AIM1_REASON_REFRAL', 'AIM1_PARENTS_STATUS', 'AIM2_HEIGHT', 'AIM2_WEIGHT', 'AIM2_DOM', 'AIM2_STUNTED', 'AIM2_WASTED', 'AIM2_UNDERWEIGHT', 'AIM2_EDEMA', 'AIM2_ELIGIBLE_SUPPLIMNTRY', 'AIM2_ELIGIBLE_REFRAL', 'AIM2_REASON_REFRAL', 'AIM2_PARENTS_STATUS', 'AIM3_HEIGHT', 'AIM3_WEIGHT', 'AIM3_DOM', 'AIM3_STUNTED', 'AIM3_WASTED', 'AIM3_UNDERWEIGHT', 'AIM3_EDEMA', 'AIM3_ELIGIBLE_SUPPLIMNTRY', 'AIM3_ELIGIBLE_REFRAL', 'AIM3_REASON_REFRAL', 'AIM3_PARENTS_STATUS', 'AIM4_HEIGHT', 'AIM4_WEIGHT', 'AIM4_DOM', 'AIM4_STUNTED', 'AIM4_WASTED', 'AIM4_UNDERWEIGHT', 'AIM4_EDEMA', 'AIM4_ELIGIBLE_SUPPLIMNTRY', 'AIM4_ELIGIBLE_REFRAL', 'AIM4_REASON_REFRAL', 'AIM4_PARENTS_STATUS', 'AIM5_HEIGHT', 'AIM5_WEIGHT', 'AIM5_DOM', 'AIM5_STUNTED', 'AIM5_WASTED', 'AIM5_UNDERWEIGHT', 'AIM5_EDEMA', 'AIM5_ELIGIBLE_SUPPLIMNTRY', 'AIM5_ELIGIBLE_REFRAL', 'AIM5_REASON_REFRAL', 'AIM5_PARENTS_STATUS', 'AIM6_HEIGHT', 'AIM6_WEIGHT', 'AIM6_DOM', 'AIM6_STUNTED', 'AIM6_WASTED', 'AIM6_UNDERWEIGHT', 'AIM6_EDEMA', 'AIM6_ELIGIBLE_SUPPLIMNTRY', 'AIM6_ELIGIBLE_REFRAL', 'AIM6_REASON_REFRAL', 'AIM6_PARENTS_STATUS']
formatLookup = {
    'CHILDID' : 'CHILDID',
    'AIM0_HEIGHT' : 'AIM0 HEIGHT',
    'AIM0_WEIGHT' : 'AIM0 WEIGHT',
    'AIM0_DOM' : 'AIM0 DOM',
    'AIM0_STUNTED' : 'AIM0 STUNTED',
    'AIM0_WASTED' : 'AIM0 WASTED',
    'AIM0_UNDERWEIGHT' : 'AIM0 UNDERWEIGHT',
    'AIM0_EDEMA' : 'AIM0 EDEMA',
    'AIM0_ELIGIBLE_SUPPLIMNTRY' : 'AIM0 ELIGIBLE SUPPLIMNTRY',
    'AIM0_ELIGIBLE_REFRAL' : 'AIM0 ELIGIBLE REFRAL',
    'AIM0_REASON_REFRAL' : 'AIM0 REASON REFRAL',
    'AIM0_PARENTS_STATUS' : 'AIM0 PARENTS STATUS',
    'AIM1_HEIGHT' : 'AIM1 HEIGHT',
    'AIM1_WEIGHT' : 'AIM1 WEIGHT',
    'AIM1_DOM' : 'AIM1 DOM',
    'AIM1_STUNTED' : 'AIM1 STUNTED',
    'AIM1_WASTED' : 'AIM1 WASTED',
    'AIM1_UNDERWEIGHT' : 'AIM1 UNDERWEIGHT',
    'AIM1_EDEMA' : 'AIM1 EDEMA',
    'AIM1_ELIGIBLE_SUPPLIMNTRY' : 'AIM1 ELIGIBLE SUPPLIMNTRY',
    'AIM1_ELIGIBLE_REFRAL' : 'AIM1 ELIGIBLE REFRAL',
    'AIM1_REASON_REFRAL' : 'AIM1 REASON REFRAL',
    'AIM1_PARENTS_STATUS' : 'AIM1 PARENTS STATUS',
    'AIM2_HEIGHT' : 'AIM2 HEIGHT',
    'AIM2_WEIGHT' : 'AIM2 WEIGHT',
    'AIM2_DOM' : 'AIM2 DOM',
    'AIM2_STUNTED' : 'AIM2 STUNTED',
    'AIM2_WASTED' : 'AIM2 WASTED',
    'AIM2_UNDERWEIGHT' : 'AIM2 UNDERWEIGHT',
    'AIM2_EDEMA' : 'AIM2 EDEMA',
    'AIM2_ELIGIBLE_SUPPLIMNTRY' : 'AIM2 ELIGIBLE SUPPLIMNTRY',
    'AIM2_ELIGIBLE_REFRAL' : 'AIM2 ELIGIBLE REFRAL',
    'AIM2_REASON_REFRAL' : 'AIM2 REASON REFRAL',
    'AIM2_PARENTS_STATUS' : 'AIM2 PARENTS STATUS',
    'AIM3_HEIGHT' : 'AIM3 HEIGHT',
    'AIM3_WEIGHT' : 'AIM3 WEIGHT',
    'AIM3_DOM' : 'AIM3 DOM',
    'AIM3_STUNTED' : 'AIM3 STUNTED',
    'AIM3_WASTED' : 'AIM3 WASTED',
    'AIM3_UNDERWEIGHT' : 'AIM3 UNDERWEIGHT',
    'AIM3_EDEMA' : 'AIM3 EDEMA',
    'AIM3_ELIGIBLE_SUPPLIMNTRY' : 'AIM3 ELIGIBLE SUPPLIMNTRY',
    'AIM3_ELIGIBLE_REFRAL' : 'AIM3 ELIGIBLE REFRAL',
    'AIM3_REASON_REFRAL' : 'AIM3 REASON REFRAL',
    'AIM3_PARENTS_STATUS' : 'AIM3 PARENTS STATUS',
    'AIM4_HEIGHT' : 'AIM4 HEIGHT',
    'AIM4_WEIGHT' : 'AIM4 WEIGHT',
    'AIM4_DOM' : 'AIM4 DOM',
    'AIM4_STUNTED' : 'AIM4 STUNTED',
    'AIM4_WASTED' : 'AIM4 WASTED',
    'AIM4_UNDERWEIGHT' : 'AIM4 UNDERWEIGHT',
    'AIM4_EDEMA' : 'AIM4 EDEMA',
    'AIM4_ELIGIBLE_SUPPLIMNTRY' : 'AIM4 ELIGIBLE SUPPLIMNTRY',
    'AIM4_ELIGIBLE_REFRAL' : 'AIM4 ELIGIBLE REFRAL',
    'AIM4_REASON_REFRAL' : 'AIM4 REASON REFRAL',
    'AIM4_PARENTS_STATUS' : 'AIM4 PARENTS STATUS',
    'AIM5_HEIGHT' : 'AIM5 HEIGHT',
    'AIM5_WEIGHT' : 'AIM5 WEIGHT',
    'AIM5_DOM' : 'AIM5 DOM',
    'AIM5_STUNTED' : 'AIM5 STUNTED',
    'AIM5_WASTED' : 'AIM5 WASTED',
    'AIM5_UNDERWEIGHT' : 'AIM5 UNDERWEIGHT',
    'AIM5_EDEMA' : 'AIM5 EDEMA',
    'AIM5_ELIGIBLE_SUPPLIMNTRY' : 'AIM5 ELIGIBLE SUPPLIMNTRY',
    'AIM5_ELIGIBLE_REFRAL' : 'AIM5 ELIGIBLE REFRAL',
    'AIM5_REASON_REFRAL' : 'AIM5 REASON REFRAL',
    'AIM5_PARENTS_STATUS' : 'AIM5 PARENTS STATUS',
    'AIM6_HEIGHT' : 'AIM6 HEIGHT',
    'AIM6_WEIGHT' : 'AIM6 WEIGHT',
    'AIM6_DOM' : 'AIM6 DOM',
    'AIM6_STUNTED' : 'AIM6 STUNTED',
    'AIM6_WASTED' : 'AIM6 WASTED',
    'AIM6_UNDERWEIGHT' : 'AIM6 UNDERWEIGHT',
    'AIM6_EDEMA' : 'AIM6 EDEMA',
    'AIM6_ELIGIBLE_SUPPLIMNTRY' : 'AIM6 ELIGIBLE SUPPLIMNTRY',
    'AIM6_ELIGIBLE_REFRAL' : 'AIM6 ELIGIBLE REFRAL',
    'AIM6_REASON_REFRAL' : 'AIM6 REASON REFRAL',
    'AIM6_PARENTS_STATUS' : 'AIM6 PARENTS STATUS'
      
}

formatAnnotationTagLookup = {
    'CHILDID1_TEN' : 'CHILDID1_10',
    'CHILDID1_ELEVEN' : 'CHILDID1_11',
    'CHILDID1_TWELVE' : 'CHILDID1_12',
    'CHILDID1_THERTEEN' : 'CHILDID1_13',
    'CHILDID1_FOURTEEN' : 'CHILDID1_14',
    'CHILDID1_FIFTEEN' : 'CHILDID1_15',
    

}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "beneficiary growth monitoring Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDID1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 25,
#                             "left": 268,
#                             "bottom": 56,
#                             "right": 292
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 23,
#                             "left": 294,
#                             "bottom": 56,
#                             "right": 314
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 24,
#                             "left": 318,
#                             "bottom": 57,
#                             "right": 338
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 25,
#                             "left": 340,
#                             "bottom": 57,
#                             "right": 362
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 26,
#                             "left": 364,
#                             "bottom": 56,
#                             "right": 386
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_6",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 25,
#                             "left": 386,
#                             "bottom": 56,
#                             "right": 408
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_7",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 25,
#                             "left": 411,
#                             "bottom": 55,
#                             "right": 432
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_8",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 7,
#                         "rect": {
#                             "top": 25,
#                             "left": 433,
#                             "bottom": 57,
#                             "right": 454
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_9",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 8,
#                         "rect": {
#                             "top": 23,
#                             "left": 458,
#                             "bottom": 55,
#                             "right": 480
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_10",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 9,
#                         "rect": {
#                             "top": 23,
#                             "left": 482,
#                             "bottom": 55,
#                             "right": 502
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_11",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 10,
#                         "rect": {
#                             "top": 22,
#                             "left": 506,
#                             "bottom": 54,
#                             "right": 527
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_12",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 11,
#                         "rect": {
#                             "top": 21,
#                             "left": 529,
#                             "bottom": 54,
#                             "right": 552
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_13",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 12,
#                         "rect": {
#                             "top": 21,
#                             "left": 553,
#                             "bottom": 55,
#                             "right": 574
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_14",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "14",
#                         "index": 13,
#                         "rect": {
#                             "top": 20,
#                             "left": 577,
#                             "bottom": 54,
#                             "right": 600
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_15",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "15",
#                         "index": 14,
#                         "rect": {
#                             "top": 20,
#                             "left": 602,
#                             "bottom": 54,
#                             "right": 624
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "CHILDID",
#                     "value": "CHILDID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "16",
#                         "index": 0,
#                         "rect": {
#                             "top": 215,
#                             "left": 42,
#                             "bottom": 249,
#                             "right": 66
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "17",
#                         "index": 1,
#                         "rect": {
#                             "top": 217,
#                             "left": 68,
#                             "bottom": 249,
#                             "right": 92
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "18",
#                         "index": 2,
#                         "rect": {
#                             "top": 216,
#                             "left": 94,
#                             "bottom": 249,
#                             "right": 117
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "AIM0_HEIGHT",
#                     "value": "AIM0 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "AIM0_WEIGHT",
#                     "value": "AIM0 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "AIM0_DOM",
#                     "value": "AIM0 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "AIM0_STUNTED",
#                     "value": "AIM0 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "AIM0_WASTED",
#                     "value": "AIM0 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7",
#                 "rois": [],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "AIM0_UNDERWEIGHT",
#                     "value": "AIM0 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "AIM0_EDEMA",
#                     "value": "AIM0 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "AIM0_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM0 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "AIM0_ELIGIBLE_REFRAL",
#                     "value": "AIM0 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "AIM0_REASON_REFRAL",
#                     "value": "AIM0 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "AIM0_PARENTS_STATUS",
#                     "value": "AIM0 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "AIM1_HEIGHT",
#                     "value": "AIM1 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14",
#                 "rois": [],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "AIM1_WEIGHT",
#                     "value": "AIM1 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "15",
#                 "rois": [],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "AIM1_DOM",
#                     "value": "AIM1 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "16",
#                 "rois": [],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "AIM1_STUNTED",
#                     "value": "AIM1 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "17",
#                 "rois": [],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "AIM1_WASTED",
#                     "value": "AIM1 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18",
#                 "rois": [],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "AIM1_UNDERWEIGHT",
#                     "value": "AIM1 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "19",
#                 "rois": [],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "AIM1_EDEMA",
#                     "value": "AIM1 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "20",
#                 "rois": [],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "AIM1_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM1 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "21",
#                 "rois": [],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "AIM1_ELIGIBLE_REFRAL",
#                     "value": "AIM1 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "22",
#                 "rois": [],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "AIM1_REASON_REFRAL",
#                     "value": "AIM1 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "23",
#                 "rois": [],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "AIM1_PARENTS_STATUS",
#                     "value": "AIM1 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "24",
#                 "rois": [],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "AIM2_HEIGHT",
#                     "value": "AIM2 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "25",
#                 "rois": [],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "AIM2_WEIGHT",
#                     "value": "AIM2 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "26",
#                 "rois": [],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "AIM2_DOM",
#                     "value": "AIM2 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "27",
#                 "rois": [],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "AIM2_STUNTED",
#                     "value": "AIM2 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "28",
#                 "rois": [],
#                 "render": {
#                     "index": 28
#                 },
#                 "format": {
#                     "name": "AIM2_WASTED",
#                     "value": "AIM2 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "29",
#                 "rois": [],
#                 "render": {
#                     "index": 29
#                 },
#                 "format": {
#                     "name": "AIM2_UNDERWEIGHT",
#                     "value": "AIM2 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "30",
#                 "rois": [],
#                 "render": {
#                     "index": 30
#                 },
#                 "format": {
#                     "name": "AIM2_EDEMA",
#                     "value": "AIM2 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "31",
#                 "rois": [],
#                 "render": {
#                     "index": 31
#                 },
#                 "format": {
#                     "name": "AIM2_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM2 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "32",
#                 "rois": [],
#                 "render": {
#                     "index": 32
#                 },
#                 "format": {
#                     "name": "AIM2_ELIGIBLE_REFRAL",
#                     "value": "AIM2 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "33",
#                 "rois": [],
#                 "render": {
#                     "index": 33
#                 },
#                 "format": {
#                     "name": "AIM2_REASON_REFRAL",
#                     "value": "AIM2 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "34",
#                 "rois": [],
#                 "render": {
#                     "index": 34
#                 },
#                 "format": {
#                     "name": "AIM2_PARENTS_STATUS",
#                     "value": "AIM2 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "35",
#                 "rois": [],
#                 "render": {
#                     "index": 35
#                 },
#                 "format": {
#                     "name": "AIM3_HEIGHT",
#                     "value": "AIM3 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "36",
#                 "rois": [],
#                 "render": {
#                     "index": 36
#                 },
#                 "format": {
#                     "name": "AIM3_WEIGHT",
#                     "value": "AIM3 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "37",
#                 "rois": [],
#                 "render": {
#                     "index": 37
#                 },
#                 "format": {
#                     "name": "AIM3_DOM",
#                     "value": "AIM3 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "38",
#                 "rois": [],
#                 "render": {
#                     "index": 38
#                 },
#                 "format": {
#                     "name": "AIM3_STUNTED",
#                     "value": "AIM3 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "39",
#                 "rois": [],
#                 "render": {
#                     "index": 39
#                 },
#                 "format": {
#                     "name": "AIM3_WASTED",
#                     "value": "AIM3 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "40",
#                 "rois": [],
#                 "render": {
#                     "index": 40
#                 },
#                 "format": {
#                     "name": "AIM3_UNDERWEIGHT",
#                     "value": "AIM3 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "41",
#                 "rois": [],
#                 "render": {
#                     "index": 41
#                 },
#                 "format": {
#                     "name": "AIM3_EDEMA",
#                     "value": "AIM3 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "42",
#                 "rois": [],
#                 "render": {
#                     "index": 42
#                 },
#                 "format": {
#                     "name": "AIM3_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM3 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "43",
#                 "rois": [],
#                 "render": {
#                     "index": 43
#                 },
#                 "format": {
#                     "name": "AIM3_ELIGIBLE_REFRAL",
#                     "value": "AIM3 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "44",
#                 "rois": [],
#                 "render": {
#                     "index": 44
#                 },
#                 "format": {
#                     "name": "AIM3_REASON_REFRAL",
#                     "value": "AIM3 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "45",
#                 "rois": [],
#                 "render": {
#                     "index": 45
#                 },
#                 "format": {
#                     "name": "AIM3_PARENTS_STATUS",
#                     "value": "AIM3 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "46",
#                 "rois": [],
#                 "render": {
#                     "index": 46
#                 },
#                 "format": {
#                     "name": "AIM4_HEIGHT",
#                     "value": "AIM4 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "47",
#                 "rois": [],
#                 "render": {
#                     "index": 47
#                 },
#                 "format": {
#                     "name": "AIM4_WEIGHT",
#                     "value": "AIM4 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "48",
#                 "rois": [],
#                 "render": {
#                     "index": 48
#                 },
#                 "format": {
#                     "name": "AIM4_DOM",
#                     "value": "AIM4 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "49",
#                 "rois": [],
#                 "render": {
#                     "index": 49
#                 },
#                 "format": {
#                     "name": "AIM4_STUNTED",
#                     "value": "AIM4 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "50",
#                 "rois": [],
#                 "render": {
#                     "index": 50
#                 },
#                 "format": {
#                     "name": "AIM4_WASTED",
#                     "value": "AIM4 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "51",
#                 "rois": [],
#                 "render": {
#                     "index": 51
#                 },
#                 "format": {
#                     "name": "AIM4_UNDERWEIGHT",
#                     "value": "AIM4 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "52",
#                 "rois": [],
#                 "render": {
#                     "index": 52
#                 },
#                 "format": {
#                     "name": "AIM4_EDEMA",
#                     "value": "AIM4 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "53",
#                 "rois": [],
#                 "render": {
#                     "index": 53
#                 },
#                 "format": {
#                     "name": "AIM4_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM4 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "54",
#                 "rois": [],
#                 "render": {
#                     "index": 54
#                 },
#                 "format": {
#                     "name": "AIM4_ELIGIBLE_REFRAL",
#                     "value": "AIM4 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "55",
#                 "rois": [],
#                 "render": {
#                     "index": 55
#                 },
#                 "format": {
#                     "name": "AIM4_REASON_REFRAL",
#                     "value": "AIM4 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "56",
#                 "rois": [],
#                 "render": {
#                     "index": 56
#                 },
#                 "format": {
#                     "name": "AIM4_PARENTS_STATUS",
#                     "value": "AIM4 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "57",
#                 "rois": [],
#                 "render": {
#                     "index": 57
#                 },
#                 "format": {
#                     "name": "AIM5_HEIGHT",
#                     "value": "AIM5 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "58",
#                 "rois": [],
#                 "render": {
#                     "index": 58
#                 },
#                 "format": {
#                     "name": "AIM5_WEIGHT",
#                     "value": "AIM5 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "59",
#                 "rois": [],
#                 "render": {
#                     "index": 59
#                 },
#                 "format": {
#                     "name": "AIM5_DOM",
#                     "value": "AIM5 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "60",
#                 "rois": [],
#                 "render": {
#                     "index": 60
#                 },
#                 "format": {
#                     "name": "AIM5_STUNTED",
#                     "value": "AIM5 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "61",
#                 "rois": [],
#                 "render": {
#                     "index": 61
#                 },
#                 "format": {
#                     "name": "AIM5_WASTED",
#                     "value": "AIM5 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "62",
#                 "rois": [],
#                 "render": {
#                     "index": 62
#                 },
#                 "format": {
#                     "name": "AIM5_UNDERWEIGHT",
#                     "value": "AIM5 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "63",
#                 "rois": [],
#                 "render": {
#                     "index": 63
#                 },
#                 "format": {
#                     "name": "AIM5_EDEMA",
#                     "value": "AIM5 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "64",
#                 "rois": [],
#                 "render": {
#                     "index": 64
#                 },
#                 "format": {
#                     "name": "AIM5_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM5 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "65",
#                 "rois": [],
#                 "render": {
#                     "index": 65
#                 },
#                 "format": {
#                     "name": "AIM5_ELIGIBLE_REFRAL",
#                     "value": "AIM5 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "66",
#                 "rois": [],
#                 "render": {
#                     "index": 66
#                 },
#                 "format": {
#                     "name": "AIM5_REASON_REFRAL",
#                     "value": "AIM5 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "67",
#                 "rois": [],
#                 "render": {
#                     "index": 67
#                 },
#                 "format": {
#                     "name": "AIM5_PARENTS_STATUS",
#                     "value": "AIM5 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "68",
#                 "rois": [],
#                 "render": {
#                     "index": 68
#                 },
#                 "format": {
#                     "name": "AIM6_HEIGHT",
#                     "value": "AIM6 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "69",
#                 "rois": [],
#                 "render": {
#                     "index": 69
#                 },
#                 "format": {
#                     "name": "AIM6_WEIGHT",
#                     "value": "AIM6 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "70",
#                 "rois": [],
#                 "render": {
#                     "index": 70
#                 },
#                 "format": {
#                     "name": "AIM6_DOM",
#                     "value": "AIM6 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "71",
#                 "rois": [],
#                 "render": {
#                     "index": 71
#                 },
#                 "format": {
#                     "name": "AIM6_STUNTED",
#                     "value": "AIM6 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "72",
#                 "rois": [],
#                 "render": {
#                     "index": 72
#                 },
#                 "format": {
#                     "name": "AIM6_WASTED",
#                     "value": "AIM6 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "73",
#                 "rois": [],
#                 "render": {
#                     "index": 73
#                 },
#                 "format": {
#                     "name": "AIM6_UNDERWEIGHT",
#                     "value": "AIM6 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "74",
#                 "rois": [],
#                 "render": {
#                     "index": 74
#                 },
#                 "format": {
#                     "name": "AIM6_EDEMA",
#                     "value": "AIM6 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "75",
#                 "rois": [],
#                 "render": {
#                     "index": 75
#                 },
#                 "format": {
#                     "name": "AIM6_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM6 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "76",
#                 "rois": [],
#                 "render": {
#                     "index": 76
#                 },
#                 "format": {
#                     "name": "AIM6_ELIGIBLE_REFRAL",
#                     "value": "AIM6 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "77",
#                 "rois": [],
#                 "render": {
#                     "index": 77
#                 },
#                 "format": {
#                     "name": "AIM6_REASON_REFRAL",
#                     "value": "AIM6 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "78",
#                 "rois": [],
#                 "render": {
#                     "index": 78
#                 },
#                 "format": {
#                     "name": "AIM6_PARENTS_STATUS",
#                     "value": "AIM6 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
