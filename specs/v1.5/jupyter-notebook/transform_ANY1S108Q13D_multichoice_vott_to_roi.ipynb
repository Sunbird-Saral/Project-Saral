# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                extractionValue = "CELL_OMR"
                
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
                    
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "ANY1S108Q13DOMR Exam Sheet Form",
            "threshold": {
                    "minWidth": 0,
                    "minHeight": 0,
                    "detectionRadius": 12
            },
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("ANY_1S108Q_13D_multichoice_vottraw.json")

# %%
tagGroups = ['ROLLNUMBERID1','QUESTION1','QUESTION2','QUESTION3','QUESTION4','QUESTION5','QUESTION6','QUESTION7','QUESTION8','QUESTION9','QUESTIONTEN','QUESTIONELE','QUESTIONTWL','QUESTIONTHRTN','QUESTIONFORTN','QUESTIONFIFTN','QUESTIONSIXTN','QUESTIONSVTN','QUESTIONEGTN','QUESTIONNINTN','QUESTIONTWTY','QUESTIONTWNTYONE','QUESTIONTWNTYTWO','QUESTIONTWNTYTHREE','QUESTIONTWNTYFOUR','QUESTIONTWNTYFIVE','QUESTIONTWNTYSIX','QUESTIONTWNTYSVN','QUESTIONTWNTYEGTH','QUESTIONTWNTYNINE','QUESTIONTRTY','QUESTIONTHRTYONE','QUESTIONTHRTYTWO','QUESTIONTHRTYTHREE','QUESTIONTHRTYFOUR','QUESTIONTHRTYFIVE','QUESTIONTHRTYSIX','QUESTIONTHRTYSVN','QUESTIONTHRTYEGTH','QUESTIONTHRTYNINE','QUESTIONFORTY','QUESTIONFRTYONE','QUESTIONFRTYTWO','QUESTIONFRTYTHREE','QUESTIONFRTYFOUR','QUESTIONFRTYFIVE','QUESTIONFRTYSIX','QUESTIONFRTYSVN','QUESTIONFRTYEGTH','QUESTIONFRTYNINE','QUESTIONFIFTY','QUESTIONFFTYONE','QUESTIONFFTYTWO','QUESTIONFFTYTHREE','QUESTIONFFTYFOUR','QUESTIONFFTYFIVE','QUESTIONFFTYSIX','QUESTIONFFTYSVN','QUESTIONFFTYEGTH','QUESTIONFFTYNINE','QUESTIONSIXTY','QUESTIONSXTYONE','QUESTIONSXTYTWO','QUESTIONSXTYTHREE','QUESTIONSXTYFOUR','QUESTIONSXTYFIVE','QUESTIONSXTYSIX','QUESTIONSXTYSVN','QUESTIONSXTYEGTH','QUESTIONSXTYNINE','QUESTIONSNTY','QUESTIONSVNTYONE','QUESTIONSVNTYTWO','QUESTIONSVNTYTHREE','QUESTIONSVNTYFOUR','QUESTIONSVNTYFIVE','QUESTIONSVNTYSIX','QUESTIONSVNTYSVN','QUESTIONSVNTYEGTH','QUESTIONSVNTYNINE','QUESTIONEGHTY','QUESTIONEGTYONE','QUESTIONEGTYTWO','QUESTIONEGTYTHREE','QUESTIONEGTYFOUR','QUESTIONEGTYFIVE','QUESTIONEGTYSIX','QUESTIONEGTYSVN','QUESTIONEGTYEGTH','QUESTIONEGTYNINE','QUESTIONNINTY','QUESTIONNNTYONE','QUESTIONNNTYTWO','QUESTIONNNTYTHREE','QUESTIONNNTYFOUR','QUESTIONNNTYFIVE','QUESTIONNNTYSIX','QUESTIONNNTYSVN','QUESTIONNNTYEGTH','QUESTIONNNTYNINE','QUESTONHUND','QUESTONHNDONE','QUESTONHNDTWO','QUESTONHNDTHREEA','QUESTONHNDTHREEB','QUESTONHNDTHREEC','QUESTONHNDTHREED','QUESTONHNDFOUR','QUESTONHNDFIVE']

formatLookup = {
    'ROLLNUMBERID1' : 'ROLLNUMBERID1',
    'QUESTION1': 'QUESTION 1',
    'QUESTION2': 'QUESTION 2',
    'QUESTION3': 'QUESTION 3',
    'QUESTION4': 'QUESTION 4',
    'QUESTION5': 'QUESTION 5',
    'QUESTION6': 'QUESTION 6',
    'QUESTION7': 'QUESTION 7',
    'QUESTION8': 'QUESTION 8',
    'QUESTION9': 'QUESTION 9',
    'QUESTIONTEN': 'QUESTION 10',
    'QUESTIONELE': 'QUESTION 11',
    'QUESTIONTWL': 'QUESTION 12',
    'QUESTIONTHRTN': 'QUESTION 13',
    'QUESTIONFORTN': 'QUESTION 14',
    'QUESTIONFIFTN': 'QUESTION 15',
    'QUESTIONSIXTN': 'QUESTION 16',
    'QUESTIONSVTN': 'QUESTION 17',
    'QUESTIONEGTN': 'QUESTION 18',
    'QUESTIONNINTN': 'QUESTION 19',
    'QUESTIONTWTY': 'QUESTION 20',
    'QUESTIONTWNTYONE': 'QUESTION 21',
    'QUESTIONTWNTYTWO': 'QUESTION 22',
    'QUESTIONTWNTYTHREE': 'QUESTION 23',
    'QUESTIONTWNTYFOUR': 'QUESTION 24',
    'QUESTIONTWNTYFIVE': 'QUESTION 25',
    'QUESTIONTWNTYSIX': 'QUESTION 26',
    'QUESTIONTWNTYSVN': 'QUESTION 27',
    'QUESTIONTWNTYEGTH': 'QUESTION 28',
    'QUESTIONTWNTYNINE': 'QUESTION 29',
    'QUESTIONTRTY': 'QUESTION 30',
    'QUESTIONTHRTYONE': 'QUESTION 31',
    'QUESTIONTHRTYTWO': 'QUESTION 32',
    'QUESTIONTHRTYTHREE': 'QUESTION 33',
    'QUESTIONTHRTYFOUR': 'QUESTION 34',
    'QUESTIONTHRTYFIVE': 'QUESTION 35',
    'QUESTIONTHRTYSIX': 'QUESTION 36',
    'QUESTIONTHRTYSVN': 'QUESTION 37',
    'QUESTIONTHRTYEGTH': 'QUESTION 38',
    'QUESTIONTHRTYNINE': 'QUESTION 39',
    'QUESTIONFORTY': 'QUESTION 40',
    'QUESTIONFRTYONE': 'QUESTION 41',
    'QUESTIONFRTYTWO': 'QUESTION 42',
    'QUESTIONFRTYTHREE': 'QUESTION 43',
    'QUESTIONFRTYFOUR': 'QUESTION 44',
    'QUESTIONFRTYFIVE': 'QUESTION 45',
    'QUESTIONFRTYSIX': 'QUESTION 46',
    'QUESTIONFRTYSVN': 'QUESTION 47',
    'QUESTIONFRTYEGTH': 'QUESTION 48',
    'QUESTIONFRTYNINE': 'QUESTION 49',
    'QUESTIONFIFTY': 'QUESTION 50',
    'QUESTIONFFTYONE': 'QUESTION 51',
    'QUESTIONFFTYTWO': 'QUESTION 52',
    'QUESTIONFFTYTHREE': 'QUESTION 53',
    'QUESTIONFFTYFOUR': 'QUESTION 54',
    'QUESTIONFFTYFIVE': 'Question 55',
    'QUESTIONFFTYSIX': 'Question 56',
    'QUESTIONFFTYSVN': 'Question 57',
    'QUESTIONFFTYEGTH': 'QUESTION 58',
    'QUESTIONFFTYNINE': 'QUESTION 59',
    'QUESTIONSIXTY': 'QUESTION 60',
    'QUESTIONSXTYONE': 'QUESTION 61',
    'QUESTIONSXTYTWO': 'QUESTION 62',
    'QUESTIONSXTYTHREE': 'QUESTION 63',
    'QUESTIONSXTYFOUR': 'QUESTION 64',
    'QUESTIONSXTYFIVE': 'QUESTION 65',
    'QUESTIONSXTYSIX': 'QUESTION 66',
    'QUESTIONSXTYSVN': 'QUESTION 67',
    'QUESTIONSXTYEGTH': 'QUESTION 68',
    'QUESTIONSXTYNINE': 'QUESTION 69',
    'QUESTIONSNTY': 'QUESTION 70',
    'QUESTIONSVNTYONE': 'QUESTION 71',
    'QUESTIONSVNTYTWO': 'QUESTION 72',
    'QUESTIONSVNTYTHREE': 'QUESTION 73',
    'QUESTIONSVNTYFOUR': 'QUESTION 74',
    'QUESTIONSVNTYFIVE': 'QUESTION 75',
    'QUESTIONSVNTYSIX': 'QUESTION 76',
    'QUESTIONSVNTYSVN': 'QUESTION 77',
    'QUESTIONSVNTYEGTH': 'QUESTION 78',
    'QUESTIONSVNTYNINE': 'QUESTION 79',
    'QUESTIONEGHTY': 'QUESTION 80',
    'QUESTIONEGTYONE': 'QUESTION 81',
    'QUESTIONEGTYTWO': 'QUESTION 82',
    'QUESTIONEGTYTHREE': 'QUESTION 83',
    'QUESTIONEGTYFOUR': 'QUESTION 84',
    'QUESTIONEGTYFIVE': 'QUESTION 85',
    'QUESTIONEGTYSIX': 'QUESTION 86',
    'QUESTIONEGTYSVN': 'QUESTION 87',
    'QUESTIONEGTYEGTH': 'QUESTION 88',
    'QUESTIONEGTYNINE': 'QUESTION 89',
    'QUESTIONNINTY': 'QUESTION 90',
    'QUESTIONNNTYONE': 'QUESTION 91',
    'QUESTIONNNTYTWO': 'QUESTION 92',
    'QUESTIONNNTYTHREE': 'QUESTION 93',
    'QUESTIONNNTYFOUR': 'QUESTION 94',
    'QUESTIONNNTYFIVE': 'QUESTION 95',
    'QUESTIONNNTYSIX': 'QUESTION 96',
    'QUESTIONNNTYSVN': 'QUESTION 97',
    'QUESTIONNNTYEGTH': 'QUESTION 98',
    'QUESTIONNNTYNINE': 'QUESTION 99',
    'QUESTONHUND': 'QUESTION 100',
    'QUESTONHNDONE': 'QUESTION 101',
    'QUESTONHNDTWO': 'QUESTION 102',
    'QUESTONHNDTHREEA': 'QUESTION 103A',
    'QUESTONHNDTHREEB': 'QUESTION 103B',
    'QUESTONHNDTHREEC': 'QUESTION 103C',
    'QUESTONHNDTHREED': 'QUESTION 103D',
    'QUESTONHNDFOUR': 'QUESTION 104',
    'QUESTONHNDFIVE': 'QUESTION 105'
    
    
}

formatNameLookup = {
    'ROLLNUMBERID1_TEN' : 'ROLLNUMBERID1_10',
    'ROLLNUMBERID1_ELE' : 'ROLLNUMBERID1_11',
    'ROLLNUMBERID1_TWL' : 'ROLLNUMBERID1_12',
    'ROLLNUMBERID1_THRTN' : 'ROLLNUMBERID1_13',

}

formatAnnotationTagLookup = {
    'ROLLNUMBERID1_TEN' : 'ROLLNUMBERID1_10',
    'ROLLNUMBERID1_ELE' : 'ROLLNUMBERID1_11',
    'ROLLNUMBERID1_TWL' : 'ROLLNUMBERID1_12',
    'ROLLNUMBERID1_THRTN' : 'ROLLNUMBERID1_13'

}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "ANY1S108Q13DOMR Exam Sheet Form",
#         "threshold": {
#             "minWidth": 0,
#             "minHeight": 0,
#             "detectionRadius": 12
#         },
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 111,
#                             "left": 72,
#                             "bottom": 132,
#                             "right": 92
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 110,
#                             "left": 94,
#                             "bottom": 131,
#                             "right": 111
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 111,
#                             "left": 113,
#                             "bottom": 132,
#                             "right": 131
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 112,
#                             "left": 134,
#                             "bottom": 132,
#                             "right": 152
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 112,
#                             "left": 156,
#                             "bottom": 133,
#                             "right": 175
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 113,
#                             "left": 178,
#                             "bottom": 132,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 112,
#                             "left": 197,
#                             "bottom": 132,
#                             "right": 216
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 7,
#                         "rect": {
#                             "top": 112,
#                             "left": 219,
#                             "bottom": 132,
#                             "right": 237
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 8,
#                         "rect": {
#                             "top": 112,
#                             "left": 241,
#                             "bottom": 132,
#                             "right": 259
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 9,
#                         "rect": {
#                             "top": 112,
#                             "left": 261,
#                             "bottom": 132,
#                             "right": 278
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 10,
#                         "rect": {
#                             "top": 112,
#                             "left": 281,
#                             "bottom": 132,
#                             "right": 299
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 11,
#                         "rect": {
#                             "top": 112,
#                             "left": 304,
#                             "bottom": 132,
#                             "right": 321
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_13",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 12,
#                         "rect": {
#                             "top": 112,
#                             "left": 324,
#                             "bottom": 131,
#                             "right": 343
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "ROLLNUMBERID1",
#                     "value": "ROLLNUMBERID1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION1_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "14",
#                         "index": 0,
#                         "rect": {
#                             "top": 188,
#                             "left": 38,
#                             "bottom": 201,
#                             "right": 49
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "15",
#                         "index": 1,
#                         "rect": {
#                             "top": 189,
#                             "left": 54,
#                             "bottom": 199,
#                             "right": 64
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "16",
#                         "index": 2,
#                         "rect": {
#                             "top": 188,
#                             "left": 67,
#                             "bottom": 199,
#                             "right": 77
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "17",
#                         "index": 3,
#                         "rect": {
#                             "top": 188,
#                             "left": 80,
#                             "bottom": 198,
#                             "right": 89
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "QUESTION1",
#                     "value": "QUESTION 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION2_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "18",
#                         "index": 0,
#                         "rect": {
#                             "top": 205,
#                             "left": 39,
#                             "bottom": 215,
#                             "right": 49
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "19",
#                         "index": 1,
#                         "rect": {
#                             "top": 202,
#                             "left": 54,
#                             "bottom": 212,
#                             "right": 64
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "20",
#                         "index": 2,
#                         "rect": {
#                             "top": 202,
#                             "left": 67,
#                             "bottom": 213,
#                             "right": 77
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "21",
#                         "index": 3,
#                         "rect": {
#                             "top": 201,
#                             "left": 80,
#                             "bottom": 212,
#                             "right": 89
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "QUESTION2",
#                     "value": "QUESTION 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION3_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "22",
#                         "index": 0,
#                         "rect": {
#                             "top": 216,
#                             "left": 38,
#                             "bottom": 226,
#                             "right": 48
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "23",
#                         "index": 1,
#                         "rect": {
#                             "top": 216,
#                             "left": 53,
#                             "bottom": 225,
#                             "right": 64
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "24",
#                         "index": 2,
#                         "rect": {
#                             "top": 216,
#                             "left": 67,
#                             "bottom": 226,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "25",
#                         "index": 3,
#                         "rect": {
#                             "top": 216,
#                             "left": 79,
#                             "bottom": 228,
#                             "right": 88
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "QUESTION3",
#                     "value": "QUESTION 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION4_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "26",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 40,
#                             "bottom": 240,
#                             "right": 50
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "27",
#                         "index": 1,
#                         "rect": {
#                             "top": 229,
#                             "left": 55,
#                             "bottom": 240,
#                             "right": 65
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "28",
#                         "index": 2,
#                         "rect": {
#                             "top": 231,
#                             "left": 68,
#                             "bottom": 241,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "29",
#                         "index": 3,
#                         "rect": {
#                             "top": 231,
#                             "left": 79,
#                             "bottom": 240,
#                             "right": 87
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "QUESTION4",
#                     "value": "QUESTION 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION5_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "30",
#                         "index": 0,
#                         "rect": {
#                             "top": 244,
#                             "left": 41,
#                             "bottom": 254,
#                             "right": 50
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "31",
#                         "index": 1,
#                         "rect": {
#                             "top": 244,
#                             "left": 54,
#                             "bottom": 254,
#                             "right": 63
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "32",
#                         "index": 2,
#                         "rect": {
#                             "top": 243,
#                             "left": 66,
#                             "bottom": 254,
#                             "right": 75
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "33",
#                         "index": 3,
#                         "rect": {
#                             "top": 244,
#                             "left": 78,
#                             "bottom": 255,
#                             "right": 87
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "QUESTION5",
#                     "value": "QUESTION 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION6_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "34",
#                         "index": 0,
#                         "rect": {
#                             "top": 272,
#                             "left": 41,
#                             "bottom": 283,
#                             "right": 51
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION6_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "35",
#                         "index": 1,
#                         "rect": {
#                             "top": 272,
#                             "left": 53,
#                             "bottom": 282,
#                             "right": 62
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION6_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "36",
#                         "index": 2,
#                         "rect": {
#                             "top": 272,
#                             "left": 66,
#                             "bottom": 281,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION6_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "37",
#                         "index": 3,
#                         "rect": {
#                             "top": 272,
#                             "left": 79,
#                             "bottom": 281,
#                             "right": 88
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "QUESTION6",
#                     "value": "QUESTION 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION7_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "38",
#                         "index": 0,
#                         "rect": {
#                             "top": 286,
#                             "left": 42,
#                             "bottom": 297,
#                             "right": 51
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION7_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "39",
#                         "index": 1,
#                         "rect": {
#                             "top": 285,
#                             "left": 54,
#                             "bottom": 296,
#                             "right": 64
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION7_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "40",
#                         "index": 2,
#                         "rect": {
#                             "top": 285,
#                             "left": 68,
#                             "bottom": 297,
#                             "right": 77
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION7_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "41",
#                         "index": 3,
#                         "rect": {
#                             "top": 286,
#                             "left": 80,
#                             "bottom": 297,
#                             "right": 88
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "QUESTION7",
#                     "value": "QUESTION 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION8_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "42",
#                         "index": 0,
#                         "rect": {
#                             "top": 300,
#                             "left": 42,
#                             "bottom": 311,
#                             "right": 50
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION8_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "43",
#                         "index": 1,
#                         "rect": {
#                             "top": 300,
#                             "left": 55,
#                             "bottom": 311,
#                             "right": 63
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION8_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "44",
#                         "index": 2,
#                         "rect": {
#                             "top": 301,
#                             "left": 68,
#                             "bottom": 312,
#                             "right": 77
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION8_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "45",
#                         "index": 3,
#                         "rect": {
#                             "top": 301,
#                             "left": 80,
#                             "bottom": 311,
#                             "right": 89
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "QUESTION8",
#                     "value": "QUESTION 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION9_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "46",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 42,
#                             "bottom": 326,
#                             "right": 52
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION9_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "47",
#                         "index": 1,
#                         "rect": {
#                             "top": 315,
#                             "left": 54,
#                             "bottom": 326,
#                             "right": 63
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION9_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "48",
#                         "index": 2,
#                         "rect": {
#                             "top": 315,
#                             "left": 68,
#                             "bottom": 326,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION9_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "49",
#                         "index": 3,
#                         "rect": {
#                             "top": 316,
#                             "left": 80,
#                             "bottom": 325,
#                             "right": 89
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "QUESTION9",
#                     "value": "QUESTION 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONTEN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "50",
#                         "index": 0,
#                         "rect": {
#                             "top": 328,
#                             "left": 42,
#                             "bottom": 338,
#                             "right": 51
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTEN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "51",
#                         "index": 1,
#                         "rect": {
#                             "top": 329,
#                             "left": 54,
#                             "bottom": 339,
#                             "right": 63
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTEN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "52",
#                         "index": 2,
#                         "rect": {
#                             "top": 329,
#                             "left": 66,
#                             "bottom": 339,
#                             "right": 77
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTEN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "53",
#                         "index": 3,
#                         "rect": {
#                             "top": 328,
#                             "left": 80,
#                             "bottom": 340,
#                             "right": 88
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "QUESTIONTEN",
#                     "value": "QUESTION 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONELE_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "54",
#                         "index": 0,
#                         "rect": {
#                             "top": 356,
#                             "left": 42,
#                             "bottom": 367,
#                             "right": 50
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONELE_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "55",
#                         "index": 1,
#                         "rect": {
#                             "top": 356,
#                             "left": 54,
#                             "bottom": 367,
#                             "right": 63
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONELE_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "56",
#                         "index": 2,
#                         "rect": {
#                             "top": 356,
#                             "left": 66,
#                             "bottom": 366,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONELE_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "57",
#                         "index": 3,
#                         "rect": {
#                             "top": 355,
#                             "left": 80,
#                             "bottom": 366,
#                             "right": 91
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "QUESTIONELE",
#                     "value": "QUESTION 11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONTWL_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "58",
#                         "index": 0,
#                         "rect": {
#                             "top": 371,
#                             "left": 42,
#                             "bottom": 382,
#                             "right": 52
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTWL_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "59",
#                         "index": 1,
#                         "rect": {
#                             "top": 370,
#                             "left": 56,
#                             "bottom": 381,
#                             "right": 65
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTWL_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "60",
#                         "index": 2,
#                         "rect": {
#                             "top": 369,
#                             "left": 67,
#                             "bottom": 380,
#                             "right": 79
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTWL_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "61",
#                         "index": 3,
#                         "rect": {
#                             "top": 370,
#                             "left": 80,
#                             "bottom": 381,
#                             "right": 90
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "QUESTIONTWL",
#                     "value": "QUESTION 12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONTHRTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "62",
#                         "index": 0,
#                         "rect": {
#                             "top": 384,
#                             "left": 40,
#                             "bottom": 394,
#                             "right": 50
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTHRTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "63",
#                         "index": 1,
#                         "rect": {
#                             "top": 384,
#                             "left": 54,
#                             "bottom": 394,
#                             "right": 64
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTHRTN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "64",
#                         "index": 2,
#                         "rect": {
#                             "top": 384,
#                             "left": 67,
#                             "bottom": 395,
#                             "right": 80
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONTHRTN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "65",
#                         "index": 3,
#                         "rect": {
#                             "top": 385,
#                             "left": 80,
#                             "bottom": 395,
#                             "right": 90
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "QUESTIONTHRTN",
#                     "value": "QUESTION 13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "15",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONFORTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "66",
#                         "index": 0,
#                         "rect": {
#                             "top": 397,
#                             "left": 41,
#                             "bottom": 410,
#                             "right": 51
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONFORTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "67",
#                         "index": 1,
#                         "rect": {
#                             "top": 397,
#                             "left": 53,
#                             "bottom": 408,
#                             "right": 65
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONFORTN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "68",
#                         "index": 2,
#                         "rect": {
#                             "top": 398,
#                             "left": 66,
#                             "bottom": 409,
#                             "right": 79
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONFORTN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "69",
#                         "index": 3,
#                         "rect": {
#                             "top": 398,
#                             "left": 81,
#                             "bottom": 410,
#                             "right": 91
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "QUESTIONFORTN",
#                     "value": "QUESTION 14"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "16",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONFIFTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "70",
#                         "index": 0,
#                         "rect": {
#                             "top": 413,
#                             "left": 41,
#                             "bottom": 424,
#                             "right": 52
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONFIFTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "71",
#                         "index": 1,
#                         "rect": {
#                             "top": 411,
#                             "left": 55,
#                             "bottom": 424,
#                             "right": 66
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONFIFTN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "72",
#                         "index": 2,
#                         "rect": {
#                             "top": 412,
#                             "left": 69,
#                             "bottom": 423,
#                             "right": 80
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONFIFTN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "73",
#                         "index": 3,
#                         "rect": {
#                             "top": 412,
#                             "left": 82,
#                             "bottom": 425,
#                             "right": 93
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "QUESTIONFIFTN",
#                     "value": "QUESTION 15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "17",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONSIXTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "74",
#                         "index": 0,
#                         "rect": {
#                             "top": 188,
#                             "left": 113,
#                             "bottom": 201,
#                             "right": 122
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONSIXTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "75",
#                         "index": 1,
#                         "rect": {
#                             "top": 189,
#                             "left": 125,
#                             "bottom": 200,
#                             "right": 136
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONSIXTN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "76",
#                         "index": 2,
#                         "rect": {
#                             "top": 188,
#                             "left": 138,
#                             "bottom": 200,
#                             "right": 148
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONSIXTN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "77",
#                         "index": 3,
#                         "rect": {
#                             "top": 188,
#                             "left": 151,
#                             "bottom": 201,
#                             "right": 160
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "QUESTIONSIXTN",
#                     "value": "QUESTION 16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONSVTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "78",
#                         "index": 0,
#                         "rect": {
#                             "top": 203,
#                             "left": 113,
#                             "bottom": 214,
#                             "right": 124
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONSVTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "79",
#                         "index": 1,
#                         "rect": {
#                             "top": 203,
#                             "left": 126,
#                             "bottom": 214,
#                             "right": 136
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONSVTN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "80",
#                         "index": 2,
#                         "rect": {
#                             "top": 203,
#                             "left": 138,
#                             "bottom": 213,
#                             "right": 150
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONSVTN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "81",
#                         "index": 3,
#                         "rect": {
#                             "top": 203,
#                             "left": 151,
#                             "bottom": 213,
#                             "right": 163
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "QUESTIONSVTN",
#                     "value": "QUESTION 17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "19",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONEGTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "82",
#                         "index": 0,
#                         "rect": {
#                             "top": 217,
#                             "left": 113,
#                             "bottom": 228,
#                             "right": 122
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONEGTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "83",
#                         "index": 1,
#                         "rect": {
#                             "top": 216,
#                             "left": 125,
#                             "bottom": 228,
#                             "right": 136
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONEGTN_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "84",
#                         "index": 2,
#                         "rect": {
#                             "top": 216,
#                             "left": 138,
#                             "bottom": 226,
#                             "right": 150
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONEGTN_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "85",
#                         "index": 3,
#                         "rect": {
#                             "top": 216,
#                             "left": 151,
#                             "bottom": 227,
#                             "right": 163
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "QUESTIONEGTN",
#                     "value": "QUESTION 18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "20",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTIONNINTN_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "86",
#                         "index": 0,
#                         "rect": {
#                             "top": 232,
#                             "left": 113,
#                             "bottom": 242,
#                             "right": 123
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONNINTN_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "87",
#                         "index": 1,
#                         "rect": {
#                             "top": 231,
#                             "left": 125,
#                             "bottom": 242,
#                             "right": 136
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTIONNINTN_3",
# ...
#                         "rect": {
#                             "top": 213,
#                             "left": 543,
#                             "bottom": 226,
#                             "right": 555
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDONE_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "415",
#                         "index": 1,
#                         "rect": {
#                             "top": 213,
#                             "left": 556,
#                             "bottom": 226,
#                             "right": 567
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDONE_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "416",
#                         "index": 2,
#                         "rect": {
#                             "top": 212,
#                             "left": 569,
#                             "bottom": 225,
#                             "right": 579
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDONE_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "417",
#                         "index": 3,
#                         "rect": {
#                             "top": 213,
#                             "left": 581,
#                             "bottom": 226,
#                             "right": 592
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 102
#                 },
#                 "format": {
#                     "name": "QUESTONHNDONE",
#                     "value": "QUESTION 101"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "103",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDTWO_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "418",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 542,
#                             "bottom": 242,
#                             "right": 555
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTWO_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "419",
#                         "index": 1,
#                         "rect": {
#                             "top": 228,
#                             "left": 557,
#                             "bottom": 242,
#                             "right": 569
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTWO_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "420",
#                         "index": 2,
#                         "rect": {
#                             "top": 228,
#                             "left": 571,
#                             "bottom": 241,
#                             "right": 582
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTWO_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "421",
#                         "index": 3,
#                         "rect": {
#                             "top": 227,
#                             "left": 584,
#                             "bottom": 241,
#                             "right": 594
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 103
#                 },
#                 "format": {
#                     "name": "QUESTONHNDTWO",
#                     "value": "QUESTION 102"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "104",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDTHREEA_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "422",
#                         "index": 0,
#                         "rect": {
#                             "top": 243,
#                             "left": 543,
#                             "bottom": 254,
#                             "right": 556
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREEA_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "423",
#                         "index": 1,
#                         "rect": {
#                             "top": 244,
#                             "left": 558,
#                             "bottom": 254,
#                             "right": 569
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREEA_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "424",
#                         "index": 2,
#                         "rect": {
#                             "top": 244,
#                             "left": 571,
#                             "bottom": 255,
#                             "right": 582
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 104
#                 },
#                 "format": {
#                     "name": "QUESTONHNDTHREEA",
#                     "value": "QUESTION 103A"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "105",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDTHREEB_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "425",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 543,
#                             "bottom": 268,
#                             "right": 556
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREEB_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "426",
#                         "index": 1,
#                         "rect": {
#                             "top": 257,
#                             "left": 559,
#                             "bottom": 270,
#                             "right": 569
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREEB_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "427",
#                         "index": 2,
#                         "rect": {
#                             "top": 258,
#                             "left": 571,
#                             "bottom": 269,
#                             "right": 580
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 105
#                 },
#                 "format": {
#                     "name": "QUESTONHNDTHREEB",
#                     "value": "QUESTION 103B"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "106",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDTHREEC_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "428",
#                         "index": 0,
#                         "rect": {
#                             "top": 271,
#                             "left": 543,
#                             "bottom": 281,
#                             "right": 556
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREEC_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "429",
#                         "index": 1,
#                         "rect": {
#                             "top": 272,
#                             "left": 558,
#                             "bottom": 282,
#                             "right": 569
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREEC_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "430",
#                         "index": 2,
#                         "rect": {
#                             "top": 272,
#                             "left": 571,
#                             "bottom": 281,
#                             "right": 581
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 106
#                 },
#                 "format": {
#                     "name": "QUESTONHNDTHREEC",
#                     "value": "QUESTION 103C"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "107",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDTHREED_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "431",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 543,
#                             "bottom": 294,
#                             "right": 554
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREED_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "432",
#                         "index": 1,
#                         "rect": {
#                             "top": 284,
#                             "left": 558,
#                             "bottom": 295,
#                             "right": 568
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDTHREED_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "433",
#                         "index": 2,
#                         "rect": {
#                             "top": 284,
#                             "left": 570,
#                             "bottom": 297,
#                             "right": 580
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 107
#                 },
#                 "format": {
#                     "name": "QUESTONHNDTHREED",
#                     "value": "QUESTION 103D"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "108",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDFOUR_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "434",
#                         "index": 0,
#                         "rect": {
#                             "top": 298,
#                             "left": 542,
#                             "bottom": 309,
#                             "right": 555
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDFOUR_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "435",
#                         "index": 1,
#                         "rect": {
#                             "top": 298,
#                             "left": 557,
#                             "bottom": 310,
#                             "right": 567
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDFOUR_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "436",
#                         "index": 2,
#                         "rect": {
#                             "top": 298,
#                             "left": 568,
#                             "bottom": 309,
#                             "right": 577
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDFOUR_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "437",
#                         "index": 3,
#                         "rect": {
#                             "top": 298,
#                             "left": 578,
#                             "bottom": 310,
#                             "right": 588
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 108
#                 },
#                 "format": {
#                     "name": "QUESTONHNDFOUR",
#                     "value": "QUESTION 104"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "109",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTONHNDFIVE_1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "438",
#                         "index": 0,
#                         "rect": {
#                             "top": 312,
#                             "left": 543,
#                             "bottom": 326,
#                             "right": 554
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDFIVE_2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "439",
#                         "index": 1,
#                         "rect": {
#                             "top": 313,
#                             "left": 557,
#                             "bottom": 326,
#                             "right": 566
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDFIVE_3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "440",
#                         "index": 2,
#                         "rect": {
#                             "top": 312,
#                             "left": 569,
#                             "bottom": 325,
#                             "right": 578
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTONHNDFIVE_4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "441",
#                         "index": 3,
#                         "rect": {
#                             "top": 312,
#                             "left": 580,
#                             "bottom": 326,
#                             "right": 589
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 109
#                 },
#                 "format": {
#                     "name": "QUESTONHNDFIVE",
#                     "value": "QUESTION 105"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
