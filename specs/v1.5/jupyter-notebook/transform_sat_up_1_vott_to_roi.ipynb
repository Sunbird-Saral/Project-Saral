# %%
# Dileep Gadiraju - UP ROI Transformation from VoTT Raw format
# Takes filename of VoTT raw format file and generates ROI configuration
# v1.5 saral ocr version

import uuid
import json

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    roiIndex = 1
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            
            if region['tags'][0].startswith('CELL_'):
              extraMethod=""
            else:
              extraMethod="NUMERIC_CLASSIFICATION"
            rois.append({
                 "annotationId": region['id'],
                "annotationTag": region['tags'][0],
                "extractionMethod": extraMethod,
                "langIsoCode": "eng",
                "roiId": roiIndex,
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex + 1
        
    return rois

def get_cells(regions,tagGroups,validationInfo,printLabels):
    
    cells_data = []
    renderIndex = 1
    cellIndex = 1
    for tagGroup in tagGroups: 
              try:
                  labelText = printLabels[str(tagGroup)]
              except KeyError as ke:
                  labelText = ""

              try:
                  validRegExp = validationInfo[str(tagGroup.rstrip('_'))]['regExp']
                  validName = validationInfo[str(tagGroup.rstrip('_'))]['name']
                  validErrorMsg = validationInfo[str(tagGroup.rstrip('_'))]['errorMessage']
                  validSource = validationInfo[str(tagGroup.rstrip('_'))]['source']
              except KeyError as ke:
                  validRegExp = ""
                  validName = ""
                  validErrorMsg = ""
                  validSource = ""
                  
              cells_data.append({
                          "cellId": cellIndex,
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex,
                              "text": labelText,
                              "langIsoCode": "eng",
                              "alignment": "center"
                          },
                          "format": {
                              "name": tagGroup.rstrip('_'),
                              "value": tagGroup.replace("_", " ")
                          },
                          "validate": {
                              "name": validName,
                              "regExp":  validRegExp,
                              "errorMessage": validErrorMsg,
                              "source": validSource
                          }
              })
              renderIndex = renderIndex +1
              cellIndex = cellIndex + 1
    return cells_data

def get_layout(cells,responseExcludeFields):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "UP SAT Exam Sheet Form",
            "type": "SAT_50_MARKSHEET",
            "tolerance": {
                "predictionMin": 0.95,
                "roiMinWidth": 15,
                "roiMinHeight": 15,
                "page": { # A4 sheet = 8.3 Inces x 11.7 Inches.
                    "width": 8.3,
                    "height": 11.7
                }
            },
            "excludeFieldsInResponse": responseExcludeFields,
            #"identifiers": [{"name":"teacherId","value":"2321121"}],
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

regions=get_annotation("sat_up_1_vottraw.json")
regions
# Out:
# [{'id': 'av3CIJxCK',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ROLLNUMBER_0'],
#   'boundingBox': {'height': 62.5789785438055,
#    'width': 125.84080323688592,
#    'left': 17.65527425062448,
#    'top': 23.7251280044742},
#   'points': [{'x': 17.65527425062448, 'y': 23.7251280044742},
#    {'x': 143.4960774875104, 'y': 23.7251280044742},
#    {'x': 143.4960774875104, 'y': 86.30410654827969},
#    {'x': 17.65527425062448, 'y': 86.30410654827969}]},
#  {'id': 'w2YWhWjDD',
#   'type': 'RECTANGLE',
#   'tags': ['ROLLNUMBER_1'],
#   'boundingBox': {'height': 34.17052883948391,
#    'width': 25.479125468359697,
#    'left': 155.46748152581182,
#    'top': 39.3683586162944},
#   'points': [{'x': 155.46748152581182, 'y': 39.3683586162944},
#    {'x': 180.9466069941715, 'y': 39.3683586162944},
#    {'x': 180.9466069941715, 'y': 73.53888745577831},
#    {'x': 155.46748152581182, 'y': 73.53888745577831}]},
#  {'id': 'd8IE27EHC',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ROLLNUMBER_1'],
#   'boundingBox': {'height': 61.04350201165372,
#    'width': 44.573012073272274,
#    'left': 145.74843229600333,
#    'top': 25.634407949500556},
#   'points': [{'x': 145.74843229600333, 'y': 25.634407949500556},
#    {'x': 190.32144436927558, 'y': 25.634407949500556},
#    {'x': 190.32144436927558, 'y': 86.67790996115428},
#    {'x': 145.74843229600333, 'y': 86.67790996115428}]},
#  {'id': 'EH5E9epOl',
#   'type': 'RECTANGLE',
#   'tags': ['ROLLNUMBER_2'],
#   'boundingBox': {'height': 33.71348458310213,
#    'width': 25.14060548501249,
#    'left': 202.87429746044958,
#    'top': 40.488346281908996},
#   'points': [{'x': 202.87429746044958, 'y': 40.488346281908996},
#    {'x': 228.01490294546207, 'y': 40.488346281908996},
#    {'x': 228.01490294546207, 'y': 74.20183086501112},
#    {'x': 202.87429746044958, 'y': 74.20183086501112}]},
#  {'id': 'bJ59kMV5v',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ROLLNUMBER_2'],
#   'boundingBox': {'height': 61.63755224230026,
#    'width': 45.557705818068335,
#    'left': 192.64379293297245,
#    'top': 26.10432852386238},
#   'points': [{'x': 192.64379293297245, 'y': 26.10432852386238},
#    {'x': 238.2014987510408, 'y': 26.10432852386238},
#    {'x': 238.2014987510408, 'y': 87.74188076616264},
#    {'x': 192.64379293297245, 'y': 87.74188076616264}]},
#  {'id': 'byVn93veE',
#   'type': 'RECTANGLE',
#   'tags': ['ROLLNUMBER_3'],
#   'boundingBox': {'height': 33.79249835252497,
#    'width': 24.983932660283095,
#    'left': 249.7255217006661,
#    'top': 40.39861850548002},
#   'points': [{'x': 249.7255217006661, 'y': 40.39861850548002},
#    {'x': 274.7094543609492, 'y': 40.39861850548002},
#    {'x': 274.7094543609492, 'y': 74.191116858005},
#    {'x': 249.7255217006661, 'y': 74.191116858005}]},
#  {'id': '-ao8WUT1W',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ROLLNUMBER_3'],
#   'boundingBox': {'height': 62.775626907602685,
#    'width': 45.20116699625315,
#    'left': 240.42747580141545,
#    'top': 26.304691835460606},
#   'points': [{'x': 240.42747580141545, 'y': 26.304691835460606},
#    {'x': 285.6286427976686, 'y': 26.304691835460606},
#    {'x': 285.6286427976686, 'y': 89.08031874306329},
#    {'x': 240.42747580141545, 'y': 89.08031874306329}]},
#  {'id': 'AWvrH-t0m',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ROLLNUMBER_4'],
#   'boundingBox': {'height': 60.73251942286349,
#    'width': 332.87807035803496,
#    'left': 287.4015143630308,
#    'top': 27.16981132075472},
#   'points': [{'x': 287.4015143630308, 'y': 27.16981132075472},
#    {'x': 620.2795847210657, 'y': 27.16981132075472},
#    {'x': 620.2795847210657, 'y': 87.90233074361821},
#    {'x': 287.4015143630308, 'y': 87.90233074361821}]},
#  {'id': 'fD8TBUoH9',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_LABEL_0'],
#   'boundingBox': {'height': 49.786836240982204,
#    'width': 125.12502601998334,
#    'left': 18.22218463780183,
#    'top': 88.72592735502225},
#   'points': [{'x': 18.22218463780183, 'y': 88.72592735502225},
#    {'x': 143.34721065778518, 'y': 88.72592735502225},
#    {'x': 143.34721065778518, 'y': 138.51276359600445},
#    {'x': 18.22218463780183, 'y': 138.51276359600445}]},
#  {'id': 'M1H9CEf0u',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_OBJECTIVE'],
#   'boundingBox': {'height': 50.66171051262481,
#    'width': 375.77910335137386,
#    'left': 145.80499323480433,
#    'top': 89.44927727871816},
#   'points': [{'x': 145.80499323480433, 'y': 89.44927727871816},
#    {'x': 521.5840965861781, 'y': 89.44927727871816},
#    {'x': 521.5840965861781, 'y': 140.11098779134295},
#    {'x': 145.80499323480433, 'y': 140.11098779134295}]},
#  {'id': 'K5uq0kiWV',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SUBJECTIVE'],
#   'boundingBox': {'height': 50.43466786036349,
#    'width': 94.42125052039967,
#    'left': 524.5287130516236,
#    'top': 90.22579078801333},
#   'points': [{'x': 524.5287130516236, 'y': 90.22579078801333},
#    {'x': 618.9499635720233, 'y': 90.22579078801333},
#    {'x': 618.9499635720233, 'y': 140.66045864837682},
#    {'x': 524.5287130516236, 'y': 140.66045864837682}]},
#  {'id': '1q6JlCHIL',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SUBJECT'],
#   'boundingBox': {'height': 50.3174153284545,
#    'width': 125.02185678601165,
#    'left': 18.66247528101582,
#    'top': 141.11191016058547},
#   'points': [{'x': 18.66247528101582, 'y': 141.11191016058547},
#    {'x': 143.68433206702747, 'y': 141.11191016058547},
#    {'x': 143.68433206702747, 'y': 191.42932548903997},
#    {'x': 18.66247528101582, 'y': 191.42932548903997}]},
#  {'id': 'pbe6YFBEA',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_1'],
#   'boundingBox': {'height': 50.18909899888768,
#    'width': 45.0329803288926,
#    'left': 145.9574052872606,
#    'top': 141.49054505005557},
#   'points': [{'x': 145.9574052872606, 'y': 141.49054505005557},
#    {'x': 190.9903856161532, 'y': 141.49054505005557},
#    {'x': 190.9903856161532, 'y': 191.67964404894326},
#    {'x': 145.9574052872606, 'y': 191.67964404894326}]},
#  {'id': 'Zw6kaLsgE',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_2'],
#   'boundingBox': {'height': 49.47408153267204,
#    'width': 44.73749089300583,
#    'left': 193.99972679017483,
#    'top': 142.30485549909824},
#   'points': [{'x': 193.99972679017483, 'y': 142.30485549909824},
#    {'x': 238.73721768318066, 'y': 142.30485549909824},
#    {'x': 238.73721768318066, 'y': 191.77893703177028},
#    {'x': 193.99972679017483, 'y': 191.77893703177028}]},
#  {'id': '3UwadIj-H',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_3'],
#   'boundingBox': {'height': 50.490416464345174,
#    'width': 44.86739565986677,
#    'left': 241.33036922356368,
#    'top': 142.39482714518593},
#   'points': [{'x': 241.33036922356368, 'y': 142.39482714518593},
#    {'x': 286.19776488343047, 'y': 142.39482714518593},
#    {'x': 286.19776488343047, 'y': 192.8852436095311},
#    {'x': 241.33036922356368, 'y': 192.8852436095311}]},
#  {'id': '2Ukgcz6aa',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_4'],
#   'boundingBox': {'height': 51.04613038464207,
#    'width': 44.07726634054954,
#    'left': 289.09674880308074,
#    'top': 142.90976605854607},
#   'points': [{'x': 289.09674880308074, 'y': 142.90976605854607},
#    {'x': 333.1740151436303, 'y': 142.90976605854607},
#    {'x': 333.1740151436303, 'y': 193.95589644318815},
#    {'x': 289.09674880308074, 'y': 193.95589644318815}]},
#  {'id': 'UK_e9ytac',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_5'],
#   'boundingBox': {'height': 49.189827058476695,
#    'width': 44.4573207223148,
#    'left': 335.49272090965854,
#    'top': 143.63844859877918},
#   'points': [{'x': 335.49272090965854, 'y': 143.63844859877918},
#    {'x': 379.95004163197336, 'y': 143.63844859877918},
#    {'x': 379.95004163197336, 'y': 192.8282756572559},
#    {'x': 335.49272090965854, 'y': 192.8282756572559}]},
#  {'id': 'hKMX7FV4d',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_6'],
#   'boundingBox': {'height': 49.655146625277474,
#    'width': 44.79388920691097,
#    'left': 382.5832964716902,
#    'top': 143.26539305285797},
#   'points': [{'x': 382.5832964716902, 'y': 143.26539305285797},
#    {'x': 427.37718567860117, 'y': 143.26539305285797},
#    {'x': 427.37718567860117, 'y': 192.92053967813544},
#    {'x': 382.5832964716902, 'y': 192.92053967813544}]},
#  {'id': 'YhmcZDYby',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_7'],
#   'boundingBox': {'height': 49.40148966426194,
#    'width': 44.95017173189009,
#    'left': 430.10830818068274,
#    'top': 143.80805181742508},
#   'points': [{'x': 430.10830818068274, 'y': 143.80805181742508},
#    {'x': 475.0584799125728, 'y': 143.80805181742508},
#    {'x': 475.0584799125728, 'y': 193.20954148168704},
#    {'x': 430.10830818068274, 'y': 193.20954148168704}]},
#  {'id': 'd1p7ohuqh',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_8'],
#   'boundingBox': {'height': 49.01502128711158,
#    'width': 44.47309533721904,
#    'left': 477.75837843463773,
#    'top': 143.30743618201998},
#   'points': [{'x': 477.75837843463773, 'y': 143.30743618201998},
#    {'x': 522.2314737718567, 'y': 143.30743618201998},
#    {'x': 522.2314737718567, 'y': 192.32245746913156},
#    {'x': 477.75837843463773, 'y': 192.32245746913156}]},
#  {'id': 'VnNBGqkVz',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_9'],
#   'boundingBox': {'height': 49.810215212264154,
#    'width': 44.99804850124896,
#    'left': 524.7946372814321,
#    'top': 143.64547204495005},
#   'points': [{'x': 524.7946372814321, 'y': 143.64547204495005},
#    {'x': 569.792685782681, 'y': 143.64547204495005},
#    {'x': 569.792685782681, 'y': 193.45568725721424},
#    {'x': 524.7946372814321, 'y': 193.45568725721424}]},
#  {'id': 'N_Z_qI16y',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_QUESTION_10'],
#   'boundingBox': {'height': 50.0775288741676,
#    'width': 47.02923345129059,
#    'left': 572.8447647793505,
#    'top': 142.8332885335738},
#   'points': [{'x': 572.8447647793505, 'y': 142.8332885335738},
#    {'x': 619.8739982306411, 'y': 142.8332885335738},
#    {'x': 619.8739982306411, 'y': 192.9108174077414},
#    {'x': 572.8447647793505, 'y': 192.9108174077414}]},
#  {'id': 'eTwo21vaW',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_LABEL_HINDI'],
#   'boundingBox': {'height': 50.38102857973244,
#    'width': 126.41153365438535,
#    'left': 17.708566429017484,
#    'top': 193.62342080847668},
#   'points': [{'x': 17.708566429017484, 'y': 193.62342080847668},
#    {'x': 144.12010008340283, 'y': 193.62342080847668},
#    {'x': 144.12010008340283, 'y': 244.0044493882091},
#    {'x': 17.708566429017484, 'y': 244.0044493882091}]},
#  {'id': 'cxfP8uVOx',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_1'],
#   'boundingBox': {'height': 35.32859318513626,
#    'width': 25.391276584653877,
#    'left': 155.55951574228524,
#    'top': 200.66695742665462},
#   'points': [{'x': 155.55951574228524, 'y': 200.66695742665462},
#    {'x': 180.9507923269391, 'y': 200.66695742665462},
#    {'x': 180.9507923269391, 'y': 235.99555061179086},
#    {'x': 155.55951574228524, 'y': 235.99555061179086}]},
#  {'id': 'w5PLd4uxy',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_1'],
#   'boundingBox': {'height': 49.31970853031146,
#    'width': 44.673490929941615,
#    'left': 146.59703398665553,
#    'top': 194.5754397246941},
#   'points': [{'x': 146.59703398665553, 'y': 194.5754397246941},
#    {'x': 191.27052491659717, 'y': 194.5754397246941},
#    {'x': 191.27052491659717, 'y': 243.89514825500555},
#    {'x': 146.59703398665553, 'y': 243.89514825500555}]},
#  {'id': 'Muatqaseb',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_2'],
#   'boundingBox': {'height': 34.5840321711624,
#    'width': 24.68440497289408,
#    'left': 203.65656276063385,
#    'top': 201.61128467394326},
#   'points': [{'x': 203.65656276063385, 'y': 201.61128467394326},
#    {'x': 228.34096773352792, 'y': 201.61128467394326},
#    {'x': 228.34096773352792, 'y': 236.19531684510568},
#    {'x': 203.65656276063385, 'y': 236.19531684510568}]},
#  {'id': 'LcCziZz7z',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_2'],
#   'boundingBox': {'height': 49.47948892867075,
#    'width': 44.79240512927439,
#    'left': 193.9569758653044,
#    'top': 194.50840560692436},
#   'points': [{'x': 193.9569758653044, 'y': 194.50840560692436},
#    {'x': 238.74938099457881, 'y': 194.50840560692436},
#    {'x': 238.74938099457881, 'y': 243.9878945355951},
#    {'x': 193.9569758653044, 'y': 243.9878945355951}]},
#  {'id': 'jZmW-nez7',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_3'],
#   'boundingBox': {'height': 35.55734670467186,
#    'width': 24.644788625938283,
#    'left': 251.08378075479564,
#    'top': 200.96730742491658},
#   'points': [{'x': 251.08378075479564, 'y': 200.96730742491658},
#    {'x': 275.7285693807339, 'y': 200.96730742491658},
#    {'x': 275.7285693807339, 'y': 236.5246541295884},
#    {'x': 251.08378075479564, 'y': 236.5246541295884}]},
#  {'id': 'xB0FKYneH',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_3'],
#   'boundingBox': {'height': 48.61260775862069,
#    'width': 45.03801996455379,
#    'left': 241.60084575688072,
#    'top': 195.43303323136814},
#   'points': [{'x': 241.60084575688072, 'y': 195.43303323136814},
#    {'x': 286.6388657214345, 'y': 195.43303323136814},
#    {'x': 286.6388657214345, 'y': 244.04564098998884},
#    {'x': 241.60084575688072, 'y': 244.04564098998884}]},
#  {'id': 'MMc9B9gLn',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_4'],
#   'boundingBox': {'height': 35.07621315350389,
#    'width': 23.8457829441201,
#    'left': 298.5621807235196,
#    'top': 202.14648220244715},
#   'points': [{'x': 298.5621807235196, 'y': 202.14648220244715},
#    {'x': 322.4079636676397, 'y': 202.14648220244715},
#    {'x': 322.4079636676397, 'y': 237.22269535595106},
#    {'x': 298.5621807235196, 'y': 237.22269535595106}]},
#  {'id': '4WhQGun-j',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_4'],
#   'boundingBox': {'height': 49.2916825987208,
#    'width': 43.70738636363636,
#    'left': 289.04608006672225,
#    'top': 195.41713014460512},
#   'points': [{'x': 289.04608006672225, 'y': 195.41713014460512},
#    {'x': 332.7534664303586, 'y': 195.41713014460512},
#    {'x': 332.7534664303586, 'y': 244.70881274332592},
#    {'x': 289.04608006672225, 'y': 244.70881274332592}]},
#  {'id': '5DFeVRjUq',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_5'],
#   'boundingBox': {'height': 34.96516854664905,
#    'width': 24.819804263969974,
#    'left': 345.08102455170973,
#    'top': 202.39592928775028},
#   'points': [{'x': 345.08102455170973, 'y': 202.39592928775028},
#    {'x': 369.90082881567974, 'y': 202.39592928775028},
#    {'x': 369.90082881567974, 'y': 237.36109783439932},
#    {'x': 345.08102455170973, 'y': 237.36109783439932}]},
#  {'id': '67a-WS1n2',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_5'],
#   'boundingBox': {'height': 49.88596270161287,
#    'width': 45.109042691826524,
#    'left': 335.5038378336113,
#    'top': 195.41713014460512},
#   'points': [{'x': 335.5038378336113, 'y': 195.41713014460512},
#    {'x': 380.61288052543784, 'y': 195.41713014460512},
#    {'x': 380.61288052543784, 'y': 245.303092846218},
#    {'x': 335.5038378336113, 'y': 245.303092846218}]},
#  {'id': 'CbMCC8zrn',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_6'],
#   'boundingBox': {'height': 33.42511101744994,
#    'width': 24.545617441618013,
#    'left': 392.8711100396163,
#    'top': 203.25257773394048},
#   'points': [{'x': 392.8711100396163, 'y': 203.25257773394048},
#    {'x': 417.4167274812343, 'y': 203.25257773394048},
#    {'x': 417.4167274812343, 'y': 236.67768875139043},
#    {'x': 392.8711100396163, 'y': 236.67768875139043}]},
#  {'id': 'V92FH7DLG',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_6'],
#   'boundingBox': {'height': 48.627207313681865,
#    'width': 45.452232329024184,
#    'left': 382.8777562030859,
#    'top': 195.95105672969967},
#   'points': [{'x': 382.8777562030859, 'y': 195.95105672969967},
#    {'x': 428.32998853211006, 'y': 195.95105672969967},
#    {'x': 428.32998853211006, 'y': 244.57826404338152},
#    {'x': 382.8777562030859, 'y': 244.57826404338152}]},
#  {'id': 'o9cBJO5Vr',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_7'],
#   'boundingBox': {'height': 34.68083569417408,
#    'width': 24.004639282735614,
#    'left': 440.35335435779814,
#    'top': 202.3552590986513},
#   'points': [{'x': 440.35335435779814, 'y': 202.3552590986513},
#    {'x': 464.3579936405338, 'y': 202.3552590986513},
#    {'x': 464.3579936405338, 'y': 237.03609479282537},
#    {'x': 440.35335435779814, 'y': 237.03609479282537}]},
#  {'id': 'kmlPn7qnk',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_7'],
#   'boundingBox': {'height': 48.92437995342046,
#    'width': 45.37114261884904,
#    'left': 429.69140950792325,
#    'top': 195.95105672969967},
#   'points': [{'x': 429.69140950792325, 'y': 195.95105672969967},
#    {'x': 475.0625521267723, 'y': 195.95105672969967},
#    {'x': 475.0625521267723, 'y': 244.87543668312014},
#    {'x': 429.69140950792325, 'y': 244.87543668312014}]},
#  {'id': '9dCFXBLiV',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_8'],
#   'boundingBox': {'height': 33.84452234253337,
#    'width': 24.027379587155963,
#    'left': 487.69124009591326,
#    'top': 202.60390777078698},
#   'points': [{'x': 487.69124009591326, 'y': 202.60390777078698},
#    {'x': 511.7186196830692, 'y': 202.60390777078698},
#    {'x': 511.7186196830692, 'y': 236.44843011332034},
#    {'x': 487.69124009591326, 'y': 236.44843011332034}]},
#  {'id': 'moxg21bL5',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_8'],
#   'boundingBox': {'height': 48.904501094966626,
#    'width': 43.80382089241034,
#    'left': 477.7865669307756,
#    'top': 195.95434814724695},
#   'points': [{'x': 477.7865669307756, 'y': 195.95434814724695},
#    {'x': 521.590387823186, 'y': 195.95434814724695},
#    {'x': 521.590387823186, 'y': 244.85884924221355},
#    {'x': 477.7865669307756, 'y': 244.85884924221355}]},
#  {'id': 'x2MPxcbEV',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_9'],
#   'boundingBox': {'height': 34.40026678948832,
#    'width': 23.730322143452877,
#    'left': 535.9062890950792,
#    'top': 202.7696681208287},
#   'points': [{'x': 535.9062890950792, 'y': 202.7696681208287},
#    {'x': 559.636611238532, 'y': 202.7696681208287},
#    {'x': 559.636611238532, 'y': 237.169934910317},
#    {'x': 535.9062890950792, 'y': 237.169934910317}]},
#  {'id': 'Dp8bE0gpW',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_9'],
#   'boundingBox': {'height': 48.487240597191324,
#    'width': 45.33413261050875,
#    'left': 525.0422226855712,
#    'top': 196.67158387791991},
#   'points': [{'x': 525.0422226855712, 'y': 196.67158387791991},
#    {'x': 570.3763552960801, 'y': 196.67158387791991},
#    {'x': 570.3763552960801, 'y': 245.15882447511123},
#    {'x': 525.0422226855712, 'y': 245.15882447511123}]},
#  {'id': 'W4jYa1vCS',
#   'type': 'RECTANGLE',
#   'tags': ['HINDI_QUESTION_TEN'],
#   'boundingBox': {'height': 35.8471380961485,
#    'width': 23.803104149291077,
#    'left': 583.6813229774812,
#    'top': 201.4947000573554},
#   'points': [{'x': 583.6813229774812, 'y': 201.4947000573554},
#    {'x': 607.4844271267723, 'y': 201.4947000573554},
#    {'x': 607.4844271267723, 'y': 237.3418381535039},
#    {'x': 583.6813229774812, 'y': 237.3418381535039}]},
#  {'id': 'kjSaABuNR',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_HINDI_QUESTION_TEN'],
#   'boundingBox': {'height': 49.78489011227753,
#    'width': 46.63489105504587,
#    'left': 573.2897857589658,
#    'top': 195.59814181555896},
#   'points': [{'x': 573.2897857589658, 'y': 195.59814181555896},
#    {'x': 619.9246768140116, 'y': 195.59814181555896},
#    {'x': 619.9246768140116, 'y': 245.38303192783647},
#    {'x': 573.2897857589658, 'y': 245.38303192783647}]},
#  {'id': 'ShKrIsoTX',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_LABEL_ENGLISH'],
#   'boundingBox': {'height': 50.215332574388206,
#    'width': 126.47140846538782,
#    'left': 17.381867702251874,
#    'top': 246.44260767171858},
#   'points': [{'x': 17.381867702251874, 'y': 246.44260767171858},
#    {'x': 143.8532761676397, 'y': 246.44260767171858},
#    {'x': 143.8532761676397, 'y': 296.65794024610676},
#    {'x': 17.381867702251874, 'y': 296.65794024610676}]},
#  {'id': 'eY_nH_Kqw',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_1'],
#   'boundingBox': {'height': 34.916041695634036,
#    'width': 25.261969610091743,
#    'left': 156.09515090700583,
#    'top': 253.81245003128475},
#   'points': [{'x': 156.09515090700583, 'y': 253.81245003128475},
#    {'x': 181.35712051709757, 'y': 253.81245003128475},
#    {'x': 181.35712051709757, 'y': 288.7284917269188},
#    {'x': 156.09515090700583, 'y': 288.7284917269188}]},
#  {'id': '0MZ3TWNbf',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_1'],
#   'boundingBox': {'height': 50.65217863598443,
#    'width': 45.88654608006672,
#    'left': 146.1921718619683,
#    'top': 246.97708825778642},
#   'points': [{'x': 146.1921718619683, 'y': 246.97708825778642},
#    {'x': 192.078717942035, 'y': 246.97708825778642},
#    {'x': 192.078717942035, 'y': 297.6292668937709},
#    {'x': 146.1921718619683, 'y': 297.6292668937709}]},
#  {'id': 'vhAHjFizv',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_2'],
#   'boundingBox': {'height': 34.40600232897664,
#    'width': 24.408100500417014,
#    'left': 204.12088198498748,
#    'top': 253.615127919911},
#   'points': [{'x': 204.12088198498748, 'y': 253.615127919911},
#    {'x': 228.5289824854045, 'y': 253.615127919911},
#    {'x': 228.5289824854045, 'y': 288.02113024888763},
#    {'x': 204.12088198498748, 'y': 288.02113024888763}]},
#  {'id': 'CGKXiax44',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_2'],
#   'boundingBox': {'height': 49.6048235018075,
#    'width': 44.609016628440365,
#    'left': 194.52359388031692,
#    'top': 247.20800889877643},
#   'points': [{'x': 194.52359388031692, 'y': 247.20800889877643},
#    {'x': 239.1326105087573, 'y': 247.20800889877643},
#    {'x': 239.1326105087573, 'y': 296.81283240058394},
#    {'x': 194.52359388031692, 'y': 296.81283240058394}]},
#  {'id': '5LDSXmWs9',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_3'],
#   'boundingBox': {'height': 35.41539210233593,
#    'width': 25.6100135529608,
#    'left': 251.12131203085903,
#    'top': 254.05907822928253},
#   'points': [{'x': 251.12131203085903, 'y': 254.05907822928253},
#    {'x': 276.73132558381985, 'y': 254.05907822928253},
#    {'x': 276.73132558381985, 'y': 289.4744703316185},
#    {'x': 251.12131203085903, 'y': 289.4744703316185}]},
#  {'id': 'vaqJ-Hc_j',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_3'],
#   'boundingBox': {'height': 49.32192453420467,
#    'width': 44.327532057964966,
#    'left': 241.9251720183486,
#    'top': 247.18487121106784},
#   'points': [{'x': 241.9251720183486, 'y': 247.18487121106784},
#    {'x': 286.2527040763136, 'y': 247.18487121106784},
#    {'x': 286.2527040763136, 'y': 296.50679574527254},
#    {'x': 241.9251720183486, 'y': 296.50679574527254}]},
#  {'id': 'so9WEurw4',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_4'],
#   'boundingBox': {'height': 35.629855655589544,
#    'width': 24.208976230191826,
#    'left': 298.58003414303585,
#    'top': 253.9997023602614},
#   'points': [{'x': 298.58003414303585, 'y': 253.9997023602614},
#    {'x': 322.78901037322765, 'y': 253.9997023602614},
#    {'x': 322.78901037322765, 'y': 289.62955801585093},
#    {'x': 298.58003414303585, 'y': 289.62955801585093}]},
#  {'id': 'H8H3drmx9',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_4'],
#   'boundingBox': {'height': 49.78738311665742,
#    'width': 44.92236368849041,
#    'left': 288.7648235508758,
#    'top': 247.60972478100663},
#   'points': [{'x': 288.7648235508758, 'y': 247.60972478100663},
#    {'x': 333.6871872393662, 'y': 247.60972478100663},
#    {'x': 333.6871872393662, 'y': 297.39710789766406},
#    {'x': 288.7648235508758, 'y': 297.39710789766406}]},
#  {'id': 'M5mw0hg4g',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_5'],
#   'boundingBox': {'height': 34.333688907814235,
#    'width': 24.819087520850708,
#    'left': 345.74994135738115,
#    'top': 255.18904468506673},
#   'points': [{'x': 345.74994135738115, 'y': 255.18904468506673},
#    {'x': 370.56902887823185, 'y': 255.18904468506673},
#    {'x': 370.56902887823185, 'y': 289.52273359288097},
#    {'x': 345.74994135738115, 'y': 289.52273359288097}]},
#  {'id': 'YyncvWCrW',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_5'],
#   'boundingBox': {'height': 48.97635828003334,
#    'width': 43.69875286697248,
#    'left': 336.2802335279399,
#    'top': 248.25497297344268},
#   'points': [{'x': 336.2802335279399, 'y': 248.25497297344268},
#    {'x': 379.9789863949124, 'y': 248.25497297344268},
#    {'x': 379.9789863949124, 'y': 297.231331253476},
#    {'x': 336.2802335279399, 'y': 297.231331253476}]},
#  {'id': 'tn9rjjvxZ',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_6'],
#   'boundingBox': {'height': 34.48395352474972,
#    'width': 24.02744474562135,
#    'left': 393.2923920975813,
#    'top': 254.79110904477196},
#   'points': [{'x': 393.2923920975813, 'y': 254.79110904477196},
#    {'x': 417.31983684320267, 'y': 254.79110904477196},
#    {'x': 417.31983684320267, 'y': 289.2750625695217},
#    {'x': 393.2923920975813, 'y': 289.2750625695217}]},
#  {'id': 'uKGx4ceBx',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_6'],
#   'boundingBox': {'height': 49.641517919215794,
#    'width': 45.18149890533778,
#    'left': 382.9190666701418,
#    'top': 247.84801037611234},
#   'points': [{'x': 382.9190666701418, 'y': 247.84801037611234},
#    {'x': 428.10056557547955, 'y': 247.84801037611234},
#    {'x': 428.10056557547955, 'y': 297.4895282953281},
#    {'x': 382.9190666701418, 'y': 297.4895282953281}]},
#  {'id': '62iFMSzw5',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_7'],
#   'boundingBox': {'height': 34.07503562986652,
#    'width': 24.26325323185988,
#    'left': 440.637771059216,
#    'top': 254.67102118673526},
#   'points': [{'x': 440.637771059216, 'y': 254.67102118673526},
#    {'x': 464.9010242910759, 'y': 254.67102118673526},
#    {'x': 464.9010242910759, 'y': 288.74605681660177},
#    {'x': 440.637771059216, 'y': 288.74605681660177}]},
#  {'id': 'pe3du1SnC',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_7'],
#   'boundingBox': {'height': 50.149015399054534,
#    'width': 45.71622185154295,
#    'left': 430.2251876563803,
#    'top': 247.81095748748606},
#   'points': [{'x': 430.2251876563803, 'y': 247.81095748748606},
#    {'x': 475.94140950792325, 'y': 247.81095748748606},
#    {'x': 475.94140950792325, 'y': 297.9599728865406},
#    {'x': 430.2251876563803, 'y': 297.9599728865406}]},
#  {'id': 'wpSshya3P',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_8'],
#   'boundingBox': {'height': 35.510712858036705,
#    'width': 24.630486342785655,
#    'left': 488.27154138865717,
#    'top': 254.67281354282537},
#   'points': [{'x': 488.27154138865717, 'y': 254.67281354282537},
#    {'x': 512.9020277314429, 'y': 254.67281354282537},
#    {'x': 512.9020277314429, 'y': 290.18352640086204},
#    {'x': 488.27154138865717, 'y': 290.18352640086204}]},
#  {'id': 'Sx37oYT5x',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_8'],
#   'boundingBox': {'height': 49.09524037124583,
#    'width': 44.58930619266055,
#    'left': 478.18344714345284,
#    'top': 248.03614258898776},
#   'points': [{'x': 478.18344714345284, 'y': 248.03614258898776},
#    {'x': 522.7727533361134, 'y': 248.03614258898776},
#    {'x': 522.7727533361134, 'y': 297.13138296023357},
#    {'x': 478.18344714345284, 'y': 297.13138296023357}]},
#  {'id': '0_AbVIp4_',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_9'],
#   'boundingBox': {'height': 36.12092863598443,
#    'width': 24.886103002502082,
#    'left': 535.7595522310259,
#    'top': 254.98305408787542},
#   'points': [{'x': 535.7595522310259, 'y': 254.98305408787542},
#    {'x': 560.6456552335279, 'y': 254.98305408787542},
#    {'x': 560.6456552335279, 'y': 291.1039827238598},
#    {'x': 535.7595522310259, 'y': 291.1039827238598}]},
#  {'id': 'lRiwE-1Vr',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_9'],
#   'boundingBox': {'height': 49.986139112903224,
#    'width': 44.882388969974976,
#    'left': 526.1197482276897,
#    'top': 248.23238928670744},
#   'points': [{'x': 526.1197482276897, 'y': 248.23238928670744},
#    {'x': 571.0021371976648, 'y': 248.23238928670744},
#    {'x': 571.0021371976648, 'y': 298.21852839961065},
#    {'x': 526.1197482276897, 'y': 298.21852839961065}]},
#  {'id': '33rLNckDL',
#   'type': 'RECTANGLE',
#   'tags': ['ENGLISH_QUESTION_TEN'],
#   'boundingBox': {'height': 35.39101605951057,
#    'width': 24.827199749791493,
#    'left': 583.3858293369474,
#    'top': 254.35748922413794},
#   'points': [{'x': 583.3858293369474, 'y': 254.35748922413794},
#    {'x': 608.213029086739, 'y': 254.35748922413794},
#    {'x': 608.213029086739, 'y': 289.7485052836485},
#    {'x': 583.3858293369474, 'y': 289.7485052836485}]},
#  {'id': 'aPJLYc-Sv',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_ENGLISH_QUESTION_TEN'],
#   'boundingBox': {'height': 49.31931747080089,
#    'width': 45.757402001668055,
#    'left': 573.2979957256047,
#    'top': 248.43574023220245},
#   'points': [{'x': 573.2979957256047, 'y': 248.43574023220245},
#    {'x': 619.0553977272727, 'y': 248.43574023220245},
#    {'x': 619.0553977272727, 'y': 297.75505770300333},
#    {'x': 573.2979957256047, 'y': 297.75505770300333}]},
#  {'id': 'qLmGD_N8N',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_LABEL_MATHS'],
#   'boundingBox': {'height': 48.23784239432697,
#    'width': 126.2472959236864,
#    'left': 17.87280415971643,
#    'top': 300.60066740823135},
#   'points': [{'x': 17.87280415971643, 'y': 300.60066740823135},
#    {'x': 144.12010008340283, 'y': 300.60066740823135},
#    {'x': 144.12010008340283, 'y': 348.83850980255835},
#    {'x': 17.87280415971643, 'y': 348.83850980255835}]},
#  {'id': 'bJz0So938',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_1'],
#   'boundingBox': {'height': 35.025310240545046,
#    'width': 23.729800875729772,
#    'left': 156.75054733110926,
#    'top': 306.528380057703},
#   'points': [{'x': 156.75054733110926, 'y': 306.528380057703},
#    {'x': 180.48034820683904, 'y': 306.528380057703},
#    {'x': 180.48034820683904, 'y': 341.55369029824806},
#    {'x': 156.75054733110926, 'y': 341.55369029824806}]},
#  {'id': 'eWnIsBE5w',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_1'],
#   'boundingBox': {'height': 48.96703802836485,
#    'width': 44.38278643661384,
#    'left': 146.81006958924104,
#    'top': 300.0688916504449},
#   'points': [{'x': 146.81006958924104, 'y': 300.0688916504449},
#    {'x': 191.19285602585487, 'y': 300.0688916504449},
#    {'x': 191.19285602585487, 'y': 349.0359296788098},
#    {'x': 146.81006958924104, 'y': 349.0359296788098}]},
#  {'id': 'JGceL6wb8',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_2'],
#   'boundingBox': {'height': 34.70535838431591,
#    'width': 24.589371351125937,
#    'left': 204.06263031693078,
#    'top': 306.3533483384316},
#   'points': [{'x': 204.06263031693078, 'y': 306.3533483384316},
#    {'x': 228.6520016680567, 'y': 306.3533483384316},
#    {'x': 228.6520016680567, 'y': 341.0587067227475},
#    {'x': 204.06263031693078, 'y': 341.0587067227475}]},
#  {'id': 'umy0kYu2X',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_2'],
#   'boundingBox': {'height': 49.15363859149054,
#    'width': 45.68058017097581,
#    'left': 194.0217759591326,
#    'top': 299.977253371802},
#   'points': [{'x': 194.0217759591326, 'y': 299.977253371802},
#    {'x': 239.70235613010843, 'y': 299.977253371802},
#    {'x': 239.70235613010843, 'y': 349.1308919632925},
#    {'x': 194.0217759591326, 'y': 349.1308919632925}]},
#  {'id': 'YvPdBPLYt',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_3'],
#   'boundingBox': {'height': 35.6357541365406,
#    'width': 24.73731364678899,
#    'left': 251.6908947560467,
#    'top': 306.0474746245829},
#   'points': [{'x': 251.6908947560467, 'y': 306.0474746245829},
#    {'x': 276.4282084028357, 'y': 306.0474746245829},
#    {'x': 276.4282084028357, 'y': 341.6832287611235},
#    {'x': 251.6908947560467, 'y': 341.6832287611235}]},
#  {'id': 'uQOVx2Vog',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_3'],
#   'boundingBox': {'height': 50.02540800542269,
#    'width': 43.95997315471226,
#    'left': 241.98547617806506,
#    'top': 299.40777295953836},
#   'points': [{'x': 241.98547617806506, 'y': 299.40777295953836},
#    {'x': 285.9454493327773, 'y': 299.40777295953836},
#    {'x': 285.9454493327773, 'y': 349.4331809649611},
#    {'x': 241.98547617806506, 'y': 349.4331809649611}]},
#  {'id': 'LVQHYsc6g',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_4'],
#   'boundingBox': {'height': 34.0693000903782,
#    'width': 24.597516159299417,
#    'left': 299.0258157839866,
#    'top': 306.91360626390434},
#   'points': [{'x': 299.0258157839866, 'y': 306.91360626390434},
#    {'x': 323.6233319432861, 'y': 306.91360626390434},
#    {'x': 323.6233319432861, 'y': 340.98290635428253},
#    {'x': 299.0258157839866, 'y': 340.98290635428253}]},
#  {'id': 'ecje8WnjV',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_4'],
#   'boundingBox': {'height': 49.90453802836485,
#    'width': 45.089234518348626,
#    'left': 288.848877971226,
#    'top': 299.9140972608454},
#   'points': [{'x': 288.848877971226, 'y': 299.9140972608454},
#    {'x': 333.9381124895746, 'y': 299.9140972608454},
#    {'x': 333.9381124895746, 'y': 349.81863528921025},
#    {'x': 288.848877971226, 'y': 349.81863528921025}]},
#  {'id': 'nJNRKSFCA',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_5'],
#   'boundingBox': {'height': 34.69082400583982,
#    'width': 24.268107537531275,
#    'left': 345.9759434945788,
#    'top': 306.4036646621246},
#   'points': [{'x': 345.9759434945788, 'y': 306.4036646621246},
#    {'x': 370.24405103211006, 'y': 306.4036646621246},
#    {'x': 370.24405103211006, 'y': 341.0944886679644},
#    {'x': 345.9759434945788, 'y': 341.0944886679644}]},
#  {'id': '0US8xV-id',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_5'],
#   'boundingBox': {'height': 50.39121158926585,
#    'width': 44.914512093411176,
#    'left': 336.2802335279399,
#    'top': 300.0063873053393},
#   'points': [{'x': 336.2802335279399, 'y': 300.0063873053393},
#    {'x': 381.1947456213511, 'y': 300.0063873053393},
#    {'x': 381.1947456213511, 'y': 350.3975988946051},
#    {'x': 336.2802335279399, 'y': 350.3975988946051}]},
#  {'id': 'YS_hFUgEO',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_6'],
#   'boundingBox': {'height': 34.697406840934434,
#    'width': 24.333135685988324,
#    'left': 393.19305801709754,
#    'top': 307.0156076195772},
#   'points': [{'x': 393.19305801709754, 'y': 307.0156076195772},
#    {'x': 417.5261937030859, 'y': 307.0156076195772},
#    {'x': 417.5261937030859, 'y': 341.71301446051166},
#    {'x': 393.19305801709754, 'y': 341.71301446051166}]},
#  {'id': 'Pi4mmlEA3',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_6'],
#   'boundingBox': {'height': 49.08885306590656,
#    'width': 44.21467759591326,
#    'left': 384.135835852794,
#    'top': 300.8109270717464},
#   'points': [{'x': 384.135835852794, 'y': 300.8109270717464},
#    {'x': 428.35051344870726, 'y': 300.8109270717464},
#    {'x': 428.35051344870726, 'y': 349.89978013765295},
#    {'x': 384.135835852794, 'y': 349.89978013765295}]},
#  {'id': 'Nds6EzgPE',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_7'],
#   'boundingBox': {'height': 34.97092038028365,
#    'width': 24.649577773144287,
#    'left': 441.0679472477064,
#    'top': 306.9157245029199},
#   'points': [{'x': 441.0679472477064, 'y': 306.9157245029199},
#    {'x': 465.7175250208507, 'y': 306.9157245029199},
#    {'x': 465.7175250208507, 'y': 341.88664488320353},
#    {'x': 441.0679472477064, 'y': 341.88664488320353}]},
#  {'id': '2930Zj0lQ',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_7'],
#   'boundingBox': {'height': 49.87097208704115,
#    'width': 44.672904503753124,
#    'left': 431.22009226438695,
#    'top': 300.2554270369855},
#   'points': [{'x': 431.22009226438695, 'y': 300.2554270369855},
#    {'x': 475.8929967681401, 'y': 300.2554270369855},
#    {'x': 475.8929967681401, 'y': 350.1263991240267},
#    {'x': 431.22009226438695, 'y': 350.1263991240267}]},
#  {'id': 'B-5TCF5mo',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_8'],
#   'boundingBox': {'height': 35.11574275236374,
#    'width': 24.61380577564637,
#    'left': 488.4182130942452,
#    'top': 306.8205992769744},
#   'points': [{'x': 488.4182130942452, 'y': 306.8205992769744},
#    {'x': 513.0320188698915, 'y': 306.8205992769744},
#    {'x': 513.0320188698915, 'y': 341.93634202933816},
#    {'x': 488.4182130942452, 'y': 341.93634202933816}]},
#  {'id': 'AMGsKFWHB',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_8'],
#   'boundingBox': {'height': 49.300970262096776,
#    'width': 45.62923530025021,
#    'left': 478.2313386155129,
#    'top': 300.5386518875139},
#   'points': [{'x': 478.2313386155129, 'y': 300.5386518875139},
#    {'x': 523.8605739157631, 'y': 300.5386518875139},
#    {'x': 523.8605739157631, 'y': 349.83962214961065},
#    {'x': 478.2313386155129, 'y': 349.83962214961065}]},
#  {'id': 'ZRQKebuLb',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_9'],
#   'boundingBox': {'height': 35.086869525166854,
#    'width': 24.61022206005004,
#    'left': 536.1601464762301,
#    'top': 307.25588110052837},
#   'points': [{'x': 536.1601464762301, 'y': 307.25588110052837},
#    {'x': 560.7703685362802, 'y': 307.25588110052837},
#    {'x': 560.7703685362802, 'y': 342.3427506256952},
#    {'x': 536.1601464762301, 'y': 342.3427506256952}]},
#  {'id': '7bCxmmVEw',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_9'],
#   'boundingBox': {'height': 49.69486495411568,
#    'width': 44.554772206005005,
#    'left': 526.7141889074228,
#    'top': 300.6447267797553},
#   'points': [{'x': 526.7141889074228, 'y': 300.6447267797553},
#    {'x': 571.2689611134278, 'y': 300.6447267797553},
#    {'x': 571.2689611134278, 'y': 350.339591733871},
#    {'x': 526.7141889074228, 'y': 350.339591733871}]},
#  {'id': '0M673nBF5',
#   'type': 'RECTANGLE',
#   'tags': ['MATHS_QUESTION_TEN'],
#   'boundingBox': {'height': 33.56072719688543,
#    'width': 24.74470913261051,
#    'left': 584.1795246038365,
#    'top': 307.9186292060623},
#   'points': [{'x': 584.1795246038365, 'y': 307.9186292060623},
#    {'x': 608.924233736447, 'y': 307.9186292060623},
#    {'x': 608.924233736447, 'y': 341.4793564029477},
#    {'x': 584.1795246038365, 'y': 341.4793564029477}]},
#  {'id': '-D3Btu836',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_MATHS_QUESTION_TEN'],
#   'boundingBox': {'height': 50.43080636471079,
#    'width': 45.43108840700584,
#    'left': 573.7515638031692,
#    'top': 300.4013248227197},
#   'points': [{'x': 573.7515638031692, 'y': 300.4013248227197},
#    {'x': 619.1826522101751, 'y': 300.4013248227197},
#    {'x': 619.1826522101751, 'y': 350.8321311874305},
#    {'x': 573.7515638031692, 'y': 350.8321311874305}]},
#  {'id': 'VAl4ni4V_',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_LABEL_EVS'],
#   'boundingBox': {'height': 50.03309884246385,
#    'width': 125.79292965492077,
#    'left': 18.153295063594662,
#    'top': 352.45411568409344},
#   'points': [{'x': 18.153295063594662, 'y': 352.45411568409344},
#    {'x': 143.94622471851542, 'y': 352.45411568409344},
#    {'x': 143.94622471851542, 'y': 402.4872145265573},
#    {'x': 18.153295063594662, 'y': 402.4872145265573}]},
#  {'id': 'mHvpxIcJH',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_1'],
#   'boundingBox': {'height': 36.13927584468854,
#    'width': 24.729364314011676,
#    'left': 156.50724562135113,
#    'top': 358.89766841629586},
#   'points': [{'x': 156.50724562135113, 'y': 358.89766841629586},
#    {'x': 181.2366099353628, 'y': 358.89766841629586},
#    {'x': 181.2366099353628, 'y': 395.0369442609844},
#    {'x': 156.50724562135113, 'y': 395.0369442609844}]},
#  {'id': '85qRzzhgi',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_1'],
#   'boundingBox': {'height': 50.77546014669077,
#    'width': 44.579858215179314,
#    'left': 146.44342290450373,
#    'top': 352.25229638834816},
#   'points': [{'x': 146.44342290450373, 'y': 352.25229638834816},
#    {'x': 191.02328111968305, 'y': 352.25229638834816},
#    {'x': 191.02328111968305, 'y': 403.0277565350389},
#    {'x': 146.44342290450373, 'y': 403.0277565350389}]},
#  {'id': 'hrE8jiSGi',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_2'],
#   'boundingBox': {'height': 35.46326430408787,
#    'width': 24.823648613427856,
#    'left': 204.0978158882402,
#    'top': 359.36472382508344},
#   'points': [{'x': 204.0978158882402, 'y': 359.36472382508344},
#    {'x': 228.92146450166805, 'y': 359.36472382508344},
#    {'x': 228.92146450166805, 'y': 394.8279881291713},
#    {'x': 204.0978158882402, 'y': 394.8279881291713}]},
#  {'id': 'NeWQwHGR8',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_2'],
#   'boundingBox': {'height': 50.56904590169633,
#    'width': 45.56463068181818,
#    'left': 193.80649238949124,
#    'top': 351.8133646760289},
#   'points': [{'x': 193.80649238949124, 'y': 351.8133646760289},
#    {'x': 239.37112307130943, 'y': 351.8133646760289},
#    {'x': 239.37112307130943, 'y': 402.38241057772524},
#    {'x': 193.80649238949124, 'y': 402.38241057772524}]},
#  {'id': 'wo3-YSl2H',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_3'],
#   'boundingBox': {'height': 35.1849928740267,
#    'width': 24.57575323185988,
#    'left': 251.70575088615513,
#    'top': 358.899819243604},
#   'points': [{'x': 251.70575088615513, 'y': 358.899819243604},
#    {'x': 276.281504118015, 'y': 358.899819243604},
#    {'x': 276.281504118015, 'y': 394.0848121176307},
#    {'x': 251.70575088615513, 'y': 394.0848121176307}]},
#  {'id': 'oQnmC-D4j',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_3'],
#   'boundingBox': {'height': 49.746810692436036,
#    'width': 45.15862828398665,
#    'left': 241.86460722477062,
#    'top': 352.4517041504449},
#   'points': [{'x': 241.86460722477062, 'y': 352.4517041504449},
#    {'x': 287.0232355087573, 'y': 352.4517041504449},
#    {'x': 287.0232355087573, 'y': 402.19851484288097},
#    {'x': 241.86460722477062, 'y': 402.19851484288097}]},
#  {'id': 'VT5TrWozx',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_4'],
#   'boundingBox': {'height': 34.57891580923248,
#    'width': 24.547604774812342,
#    'left': 299.20731468932445,
#    'top': 358.9670163028365},
#   'points': [{'x': 299.20731468932445, 'y': 358.9670163028365},
#    {'x': 323.7549194641368, 'y': 358.9670163028365},
#    {'x': 323.7549194641368, 'y': 393.54593211206895},
#    {'x': 299.20731468932445, 'y': 393.54593211206895}]},
#  {'id': 'nJ-f3iW45',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_4'],
#   'boundingBox': {'height': 49.00004996871524,
#    'width': 43.694484987489574,
#    'left': 289.9532488010842,
#    'top': 352.0749509003059},
#   'points': [{'x': 289.9532488010842, 'y': 352.0749509003059},
#    {'x': 333.6477337885738, 'y': 352.0749509003059},
#    {'x': 333.6477337885738, 'y': 401.07500086902115},
#    {'x': 289.9532488010842, 'y': 401.07500086902115}]},
#  {'id': 'ZGKpO8ex-',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_5'],
#   'boundingBox': {'height': 34.7951065419911,
#    'width': 24.70343124478732,
#    'left': 346.4782501042535,
#    'top': 359.2489702099555},
#   'points': [{'x': 346.4782501042535, 'y': 359.2489702099555},
#    {'x': 371.18168134904084, 'y': 359.2489702099555},
#    {'x': 371.18168134904084, 'y': 394.0440767519466},
#    {'x': 346.4782501042535, 'y': 394.0440767519466}]},
#  {'id': '9bQwRKN1e',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_5'],
#   'boundingBox': {'height': 47.67152304644049,
#    'width': 45.91466195788156,
#    'left': 335.66588693703085,
#    'top': 353.29411151279197},
#   'points': [{'x': 335.66588693703085, 'y': 353.29411151279197},
#    {'x': 381.5805488949124, 'y': 353.29411151279197},
#    {'x': 381.5805488949124, 'y': 400.96563455923246},
#    {'x': 335.66588693703085, 'y': 400.96563455923246}]},
#  {'id': '_BJEejm-x',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_6'],
#   'boundingBox': {'height': 34.23677132577864,
#    'width': 24.596603940783986,
#    'left': 393.9108762510425,
#    'top': 360.01127554922135},
#   'points': [{'x': 393.9108762510425, 'y': 360.01127554922135},
#    {'x': 418.5074801918265, 'y': 360.01127554922135},
#    {'x': 418.5074801918265, 'y': 394.248046875},
#    {'x': 393.9108762510425, 'y': 394.248046875}]},
#  {'id': 'C6_XG8xvL',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_6'],
#   'boundingBox': {'height': 49.37318591838154,
#    'width': 42.96223415346122,
#    'left': 384.34913208924104,
#    'top': 352.84087354004447},
#   'points': [{'x': 384.34913208924104, 'y': 352.84087354004447},
#    {'x': 427.31136624270226, 'y': 352.84087354004447},
#    {'x': 427.31136624270226, 'y': 402.214059458426},
#    {'x': 384.34913208924104, 'y': 402.214059458426}]},
#  {'id': 'b9E4575ov',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_7'],
#   'boundingBox': {'height': 35.11072415531146,
#    'width': 23.720809007506254,
#    'left': 441.7734831109258,
#    'top': 359.2702829532814},
#   'points': [{'x': 441.7734831109258, 'y': 359.2702829532814},
#    {'x': 465.494292118432, 'y': 359.2702829532814},
#    {'x': 465.494292118432, 'y': 394.3810071085929},
#    {'x': 441.7734831109258, 'y': 394.3810071085929}]},
#  {'id': 'znv-qVw9G',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_7'],
#   'boundingBox': {'height': 49.69959025653504,
#    'width': 45.628453398665556,
#    'left': 430.8268609257715,
#    'top': 352.707163775723},
#   'points': [{'x': 430.8268609257715, 'y': 352.707163775723},
#    {'x': 476.45531432443704, 'y': 352.707163775723},
#    {'x': 476.45531432443704, 'y': 402.40675403225805},
#    {'x': 430.8268609257715, 'y': 402.40675403225805}]},
#  {'id': 'bDEcnxJf8',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_8'],
#   'boundingBox': {'height': 35.34571833286986,
#    'width': 24.34144339032527,
#    'left': 489.1751589866555,
#    'top': 359.86306399471636},
#   'points': [{'x': 489.1751589866555, 'y': 359.86306399471636},
#    {'x': 513.5166023769808, 'y': 359.86306399471636},
#    {'x': 513.5166023769808, 'y': 395.2087823275862},
#    {'x': 489.1751589866555, 'y': 395.2087823275862}]},
#  {'id': 'uxBQph9LJ',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_8'],
#   'boundingBox': {'height': 48.03977075222469,
#    'width': 44.080288261050875,
#    'left': 479.0222972268557,
#    'top': 353.4593993325918},
#   'points': [{'x': 479.0222972268557, 'y': 353.4593993325918},
#    {'x': 523.1025854879066, 'y': 353.4593993325918},
#    {'x': 523.1025854879066, 'y': 401.49917008481646},
#    {'x': 479.0222972268557, 'y': 401.49917008481646}]},
#  {'id': 'HwHMoHP8f',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_9'],
#   'boundingBox': {'height': 34.83424508134038,
#    'width': 24.266576313594662,
#    'left': 536.0388214136781,
#    'top': 360.00244412194104},
#   'points': [{'x': 536.0388214136781, 'y': 360.00244412194104},
#    {'x': 560.3053977272727, 'y': 360.00244412194104},
#    {'x': 560.3053977272727, 'y': 394.8366892032814},
#    {'x': 536.0388214136781, 'y': 394.8366892032814}]},
#  {'id': '1vFGeHsd7',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_9'],
#   'boundingBox': {'height': 49.335253145856505,
#    'width': 44.684372393661384,
#    'left': 526.3817504170141,
#    'top': 353.2824123157675},
#   'points': [{'x': 526.3817504170141, 'y': 353.2824123157675},
#    {'x': 571.0661228106756, 'y': 353.2824123157675},
#    {'x': 571.0661228106756, 'y': 402.61766546162403},
#    {'x': 526.3817504170141, 'y': 402.61766546162403}]},
#  {'id': '3m3rRH0lN',
#   'type': 'RECTANGLE',
#   'tags': ['EVS_QUESTION_TEN'],
#   'boundingBox': {'height': 35.46864137235818,
#    'width': 23.599223311092576,
#    'left': 584.8892306088406,
#    'top': 359.9548326265295},
#   'points': [{'x': 584.8892306088406, 'y': 359.9548326265295},
#    {'x': 608.4884539199332, 'y': 359.9548326265295},
#    {'x': 608.4884539199332, 'y': 395.42347399888763},
#    {'x': 584.8892306088406, 'y': 395.42347399888763}]},
#  {'id': 'YmffrzMoS',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_EVS_QUESTION_TEN'],
#   'boundingBox': {'height': 49.59025653503893,
#    'width': 46.460722477064216,
#    'left': 573.7879222268557,
#    'top': 353.4838405520022},
#   'points': [{'x': 573.7879222268557, 'y': 353.4838405520022},
#    {'x': 620.2486447039199, 'y': 353.4838405520022},
#    {'x': 620.2486447039199, 'y': 403.07409708704114},
#    {'x': 573.7879222268557, 'y': 403.07409708704114}]},
#  {'id': 'uYBC8WQ0S',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_LABEL_SCIENCE'],
#   'boundingBox': {'height': 50.972326021968854,
#    'width': 125.08876211947455,
#    'left': 17.85750820996664,
#    'top': 405.50111017449944},
#   'points': [{'x': 17.85750820996664, 'y': 405.50111017449944},
#    {'x': 142.9462703294412, 'y': 405.50111017449944},
#    {'x': 142.9462703294412, 'y': 456.4734361964683},
#    {'x': 17.85750820996664, 'y': 456.4734361964683}]},
#  {'id': 'D7EhDm4uy',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_1'],
#   'boundingBox': {'height': 35.73114006882647,
#    'width': 24.536397518765636,
#    'left': 156.33258835487905,
#    'top': 412.39161133898773},
#   'points': [{'x': 156.33258835487905, 'y': 412.39161133898773},
#    {'x': 180.8689858736447, 'y': 412.39161133898773},
#    {'x': 180.8689858736447, 'y': 448.12275140781423},
#    {'x': 156.33258835487905, 'y': 448.12275140781423}]},
#  {'id': 'mxD6kv4HW',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_1'],
#   'boundingBox': {'height': 50.898872010567295,
#    'width': 45.113082516680564,
#    'left': 145.96682130942452,
#    'top': 405.5586285108454},
#   'points': [{'x': 145.96682130942452, 'y': 405.5586285108454},
#    {'x': 191.07990382610507, 'y': 405.5586285108454},
#    {'x': 191.07990382610507, 'y': 456.45750052141267},
#    {'x': 145.96682130942452, 'y': 456.45750052141267}]},
#  {'id': 't5zTgSdc2',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_2'],
#   'boundingBox': {'height': 34.96000330228031,
#    'width': 24.427517723102586,
#    'left': 204.23569120100083,
#    'top': 412.49217880978864},
#   'points': [{'x': 204.23569120100083, 'y': 412.49217880978864},
#    {'x': 228.6632089241034, 'y': 412.49217880978864},
#    {'x': 228.6632089241034, 'y': 447.45218211206895},
#    {'x': 204.23569120100083, 'y': 447.45218211206895}]},
#  {'id': 'ObL69DUMI',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_2'],
#   'boundingBox': {'height': 50.76281588918243,
#    'width': 46.08664772727273,
#    'left': 193.88777757506256,
#    'top': 405.393959868604},
#   'points': [{'x': 193.88777757506256, 'y': 405.393959868604},
#    {'x': 239.97442530233528, 'y': 405.393959868604},
#    {'x': 239.97442530233528, 'y': 456.1567757577864},
#    {'x': 193.88777757506256, 'y': 456.1567757577864}]},
#  {'id': 'OrRvGhzLV',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_3'],
#   'boundingBox': {'height': 35.926180999721915,
#    'width': 24.428853471643034,
#    'left': 252.19251720183485,
#    'top': 411.95870846078975},
#   'points': [{'x': 252.19251720183485, 'y': 411.95870846078975},
#    {'x': 276.6213706734779, 'y': 411.95870846078975},
#    {'x': 276.6213706734779, 'y': 447.88488946051166},
#    {'x': 252.19251720183485, 'y': 447.88488946051166}]},
#  {'id': '34FhZfXNN',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_3'],
#   'boundingBox': {'height': 50.347608453837594,
#    'width': 44.05034794620517,
#    'left': 242.42109309841533,
#    'top': 405.66180304505},
#   'points': [{'x': 242.42109309841533, 'y': 405.66180304505},
#    {'x': 286.4714410446205, 'y': 405.66180304505},
#    {'x': 286.4714410446205, 'y': 456.00941149888763},
#    {'x': 242.42109309841533, 'y': 456.00941149888763}]},
#  {'id': '-x_u3fFhV',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_4'],
#   'boundingBox': {'height': 34.87032032119021,
#    'width': 23.55012640742285,
#    'left': 299.90705144912425,
#    'top': 411.58293285942716},
#   'points': [{'x': 299.90705144912425, 'y': 411.58293285942716},
#    {'x': 323.4571778565471, 'y': 411.58293285942716},
#    {'x': 323.4571778565471, 'y': 446.45325318061737},
#    {'x': 299.90705144912425, 'y': 446.45325318061737}]},
#  {'id': 'J_-DQIpGa',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_4'],
#   'boundingBox': {'height': 50.32903312708565,
#    'width': 44.83136989157631,
#    'left': 289.3605022414512,
#    'top': 405.2830619090656},
#   'points': [{'x': 289.3605022414512, 'y': 405.2830619090656},
#    {'x': 334.1918721330275, 'y': 405.2830619090656},
#    {'x': 334.1918721330275, 'y': 455.6120950361513},
#    {'x': 289.3605022414512, 'y': 455.6120950361513}]},
#  {'id': 'LVHw1QHMH',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_5'],
#   'boundingBox': {'height': 35.585731107480534,
#    'width': 23.61906406380317,
#    'left': 347.23320866346955,
#    'top': 411.92263322093993},
#   'points': [{'x': 347.23320866346955, 'y': 411.92263322093993},
#    {'x': 370.8522727272727, 'y': 411.92263322093993},
#    {'x': 370.8522727272727, 'y': 447.50836432842044},
#    {'x': 347.23320866346955, 'y': 447.50836432842044}]},
#  {'id': 'JfjpePMxn',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_5'],
#   'boundingBox': {'height': 50.01768458008899,
#    'width': 44.01095965387823,
#    'left': 337.5963693703086,
#    'top': 404.94557755144604},
#   'points': [{'x': 337.5963693703086, 'y': 404.94557755144604},
#    {'x': 381.6073290241868, 'y': 404.94557755144604},
#    {'x': 381.6073290241868, 'y': 454.96326213153503},
#    {'x': 337.5963693703086, 'y': 454.96326213153503}]},
#  {'id': 'JXXYfHtGc',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_6'],
#   'boundingBox': {'height': 35.132167251807566,
#    'width': 24.943703085904918,
#    'left': 394.1060258548791,
#    'top': 412.02570999026693},
#   'points': [{'x': 394.1060258548791, 'y': 412.02570999026693},
#    {'x': 419.04972894078395, 'y': 412.02570999026693},
#    {'x': 419.04972894078395, 'y': 447.1578772420745},
#    {'x': 394.1060258548791, 'y': 447.1578772420745}]},
#  {'id': 'pFvAySJke',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_6'],
#   'boundingBox': {'height': 50.774906145717466,
#    'width': 44.0469922852377,
#    'left': 384.52408256880733,
#    'top': 405.2548404477197},
#   'points': [{'x': 384.52408256880733, 'y': 405.2548404477197},
#    {'x': 428.57107485404504, 'y': 405.2548404477197},
#    {'x': 428.57107485404504, 'y': 456.02974659343715},
#    {'x': 384.52408256880733, 'y': 456.02974659343715}]},
#  {'id': 'j6qSm7bRU',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_7'],
#   'boundingBox': {'height': 35.51853404824805,
#    'width': 24.440614574645537,
#    'left': 441.30799103419514,
#    'top': 412.0769713744438},
#   'points': [{'x': 441.30799103419514, 'y': 412.0769713744438},
#    {'x': 465.7486056088407, 'y': 412.0769713744438},
#    {'x': 465.7486056088407, 'y': 447.5955054226919},
#    {'x': 441.30799103419514, 'y': 447.5955054226919}]},
#  {'id': '0_vpmBTT9',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_7'],
#   'boundingBox': {'height': 50.948764686457174,
#    'width': 44.91405598415346,
#    'left': 431.54666649291073,
#    'top': 405.3805660803671},
#   'points': [{'x': 431.54666649291073, 'y': 405.3805660803671},
#    {'x': 476.4607224770642, 'y': 405.3805660803671},
#    {'x': 476.4607224770642, 'y': 456.3293307668242},
#    {'x': 431.54666649291073, 'y': 456.3293307668242}]},
#  {'id': '6TPxclnwr',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_8'],
#   'boundingBox': {'height': 34.6719227961624,
#    'width': 24.77103315262719,
#    'left': 488.5605191826522,
#    'top': 412.71628849763624},
#   'points': [{'x': 488.5605191826522, 'y': 412.71628849763624},
#    {'x': 513.3315523352794, 'y': 412.71628849763624},
#    {'x': 513.3315523352794, 'y': 447.38821129379863},
#    {'x': 488.5605191826522, 'y': 447.38821129379863}]},
#  {'id': 'WBo-Yl8C8',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_8'],
#   'boundingBox': {'height': 49.43454967324805,
#    'width': 45.788612906588824,
#    'left': 479.3988479983319,
#    'top': 405.57045806104003},
#   'points': [{'x': 479.3988479983319, 'y': 405.57045806104003},
#    {'x': 525.1874609049207, 'y': 405.57045806104003},
#    {'x': 525.1874609049207, 'y': 455.0050077342881},
#    {'x': 479.3988479983319, 'y': 455.0050077342881}]},
#  {'id': 'Li5u6VAyY',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_9'],
#   'boundingBox': {'height': 35.71429192157953,
#    'width': 24.90323967889908,
#    'left': 537.3319563177648,
#    'top': 412.02320069174084},
#   'points': [{'x': 537.3319563177648, 'y': 412.02320069174084},
#    {'x': 562.2351959966638, 'y': 412.02320069174084},
#    {'x': 562.2351959966638, 'y': 447.73749261332034},
#    {'x': 537.3319563177648, 'y': 447.73749261332034}]},
#  {'id': '5Xp5ec-Fc',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_9'],
#   'boundingBox': {'height': 50.70933850111235,
#    'width': 44.29576730608841,
#    'left': 527.372810675563,
#    'top': 405.2174942644605},
#   'points': [{'x': 527.372810675563, 'y': 405.2174942644605},
#    {'x': 571.6685779816513, 'y': 405.2174942644605},
#    {'x': 571.6685779816513, 'y': 455.92683276557284},
#    {'x': 527.372810675563, 'y': 455.92683276557284}]},
#  {'id': 'eZpuYFTx-',
#   'type': 'RECTANGLE',
#   'tags': ['SCIENCE_QUESTION_TEN'],
#   'boundingBox': {'height': 34.9289792477753,
#    'width': 24.66176240617181,
#    'left': 584.4626381359466,
#    'top': 412.9871949735817},
#   'points': [{'x': 584.4626381359466, 'y': 412.9871949735817},
#    {'x': 609.1244005421185, 'y': 412.9871949735817},
#    {'x': 609.1244005421185, 'y': 447.91617422135704},
#    {'x': 584.4626381359466, 'y': 447.91617422135704}]},
#  {'id': 'DH_pfxrzf',
#   'type': 'RECTANGLE',
#   'tags': ['CELL_SCIENCE_QUESTION_TEN'],
#   'boundingBox': {'height': 51.388804400723025,
#    'width': 46.17363427856547,
#    'left': 574.4033439324437,
#    'top': 405.8999582869855},
#   'points': [{'x': 574.4033439324437, 'y': 405.8999582869855},
#    {'x': 620.5769782110092, 'y': 405.8999582869855},
#    {'x': 620.5769782110092, 'y': 457.2887626877086},
#    {'x': 574.4033439324437, 'y': 457.2887626877086}]}]

# %%
## Inject validations during scanning as these can be exam/school specific.
## Below keys can be stored in backend in School and Exam entities so that these can be linked during scan time.

validationInfo = {
    'ROLLNUMBER': { 'name': 'Between 2 to 3 Digits' , 'regExp': '^[1-9][0-9]{1,3}$' , 'errorMessage': 'Should be 2 to 3 Digits', 'source': 'BACKEND_SCHOOL' },
    'HINDI_QUESTION_1': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION 1 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_2': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION2 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_3': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION3 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_4': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'HINDI QUESTION4 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_5': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'HINDI QUESTION5 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_6': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION6 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_7': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION7 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_8': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION8 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_9': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION9 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'HINDI_QUESTION_TEN': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'HINDI QUESTION10 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    
    'ENGLISH_QUESTION_1': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION 1 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_2': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION2 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_3': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION3 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_4': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'ENGLISH QUESTION4 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_5': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'ENGLISH QUESTION5 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_6': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION6 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_7': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION7 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_8': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION8 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_9': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION9 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'ENGLISH_QUESTION_TEN': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'ENGLISH QUESTION10 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },

    'MATHS_QUESTION_1': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION 1 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_2': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION2 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_3': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION3 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_4': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'MATHS QUESTION4 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_5': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'MATHS QUESTION5 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_6': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION6 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_7': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION7 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_8': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION8 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_9': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION9 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'MATHS_QUESTION_TEN': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'MATHS QUESTION10 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },

    'EVS_QUESTION_1': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION 1 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_2': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION2 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_3': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION3 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_4': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'EVS QUESTION4 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_5': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'EVS QUESTION5 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_6': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION6 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_7': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION7 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_8': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION8 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_9': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION9 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'EVS_QUESTION_TEN': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'EVS QUESTION10 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    
    'SCIENCE_QUESTION_1': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION 1 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_2': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION2 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_3': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION3 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_4': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'SCIENCE QUESTION4 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_5': { 'name': 'Between 0 to 10 Marks' , 'regExp': '[0-10]' , 'errorMessage': 'SCIENCE QUESTION5 should range from 0 to 10 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_6': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION6 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_7': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION7 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_8': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION8 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_9': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION9 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' },
    'SCIENCE_QUESTION_TEN': { 'name': 'Between 0 to 5 Marks' , 'regExp': '[0-5]' , 'errorMessage': 'SCIENCE QUESTION10 should range from 0 to 5 Marks', 'source': 'BACKEND_EXAM' }

}

responseExcludeFields= ['rois','validate','render']

# %%
## Print Labels for rendering
printLabels={
    'CELL_ROLLNUMBER_0':'ROLL NUMBER',
    'CELL_ROLLNUMBER_4': '',
    'CELL_LABEL_0':'',
    'CELL_OBJECTIVE':'OBJECTIVE',
    'CELL_SUBJECTIVE':'SUBJECTIVE',
    'CELL_SUBJECT':'SUBJECT',
    'CELL_QUESTION_1':'1',
    'CELL_QUESTION_2':'2',
    'CELL_QUESTION_3':'3',
    'CELL_QUESTION_4':'4',
    'CELL_QUESTION_5':'5',
    'CELL_QUESTION_6':'6',
    'CELL_QUESTION_7':'7',
    'CELL_QUESTION_8':'8',
    'CELL_QUESTION_9':'9',
    'CELL_QUESTION_10':'10'
}

## Groups to construct cell and rois
tagGroups = ["CELL_ROLLNUMBER_0","CELL_ROLLNUMBER_1","CELL_ROLLNUMBER_2","CELL_ROLLNUMBER_3",
             "ROLLNUMBER","CELL_ROLLNUMBER_4",
             "CELL_LABEL_0","CELL_OBJECTIVE","CELL_SUBJECTIVE","CELL_SUBJECT",
             "CELL_QUESTION_1","CELL_QUESTION_2","CELL_QUESTION_3","CELL_QUESTION_4","CELL_QUESTION_5","CELL_QUESTION_6","CELL_QUESTION_7","CELL_QUESTION_8","CELL_QUESTION_9","CELL_QUESTION_10",
             "HINDI_QUESTION_1","HINDI_QUESTION_2","HINDI_QUESTION_3","HINDI_QUESTION_4","HINDI_QUESTION_5","HINDI_QUESTION_6","HINDI_QUESTION_7","HINDI_QUESTION_8","HINDI_QUESTION_9","HINDI_QUESTION_TEN",
            "ENGLISH_QUESTION_1","ENGLISH_QUESTION_2","ENGLISH_QUESTION_3","ENGLISH_QUESTION_4","ENGLISH_QUESTION_5","ENGLISH_QUESTION_6","ENGLISH_QUESTION_7","ENGLISH_QUESTION_8","ENGLISH_QUESTION_9","ENGLISH_QUESTION_TEN",
            "MATHS_QUESTION_1","MATHS_QUESTION_2","MATHS_QUESTION_3","MATHS_QUESTION_4","MATHS_QUESTION_5","MATHS_QUESTION_6","MATHS_QUESTION_7","MATHS_QUESTION_8","MATHS_QUESTION_9","MATHS_QUESTION_TEN",
            "EVS_QUESTION_1","EVS_QUESTION_2","EVS_QUESTION_3","EVS_QUESTION_4","EVS_QUESTION_5","EVS_QUESTION_6","EVS_QUESTION_7","EVS_QUESTION_8","EVS_QUESTION_9","EVS_QUESTION_TEN",
            "SCIENCE_QUESTION_1","SCIENCE_QUESTION_2","SCIENCE_QUESTION_3","SCIENCE_QUESTION_4","SCIENCE_QUESTION_5","SCIENCE_QUESTION_6","SCIENCE_QUESTION_7","SCIENCE_QUESTION_8","SCIENCE_QUESTION_9","SCIENCE_QUESTION_TEN"]


## tags at cell level


cells=get_cells(regions,tagGroups,validationInfo,printLabels)
cells
pp_json(get_layout(cells,responseExcludeFields))
# Out:
# {
#     "layout": {
#         "cells": [
#             {
#                 "cellId": 1,
#                 "format": {
#                     "name": "CELL_ROLLNUMBER_0",
#                     "value": "CELL ROLLNUMBER 0"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 1,
#                     "langIsoCode": "eng",
#                     "text": "ROLL NUMBER"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "av3CIJxCK",
#                         "annotationTag": "CELL_ROLLNUMBER_0",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 85,
#                             "left": 17,
#                             "right": 142,
#                             "top": 23
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 2,
#                 "format": {
#                     "name": "CELL_ROLLNUMBER_1",
#                     "value": "CELL ROLLNUMBER 1"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 2,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "d8IE27EHC",
#                         "annotationTag": "CELL_ROLLNUMBER_1",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 86,
#                             "left": 145,
#                             "right": 189,
#                             "top": 25
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 3,
#                 "format": {
#                     "name": "CELL_ROLLNUMBER_2",
#                     "value": "CELL ROLLNUMBER 2"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 3,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "bJ59kMV5v",
#                         "annotationTag": "CELL_ROLLNUMBER_2",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 87,
#                             "left": 192,
#                             "right": 237,
#                             "top": 26
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 4,
#                 "format": {
#                     "name": "CELL_ROLLNUMBER_3",
#                     "value": "CELL ROLLNUMBER 3"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 4,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "-ao8WUT1W",
#                         "annotationTag": "CELL_ROLLNUMBER_3",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 88,
#                             "left": 240,
#                             "right": 285,
#                             "top": 26
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 5,
#                 "format": {
#                     "name": "ROLLNUMBER",
#                     "value": "ROLLNUMBER"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 5,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "w2YWhWjDD",
#                         "annotationTag": "ROLLNUMBER_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 73,
#                             "left": 155,
#                             "right": 180,
#                             "top": 39
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "EH5E9epOl",
#                         "annotationTag": "ROLLNUMBER_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 73,
#                             "left": 202,
#                             "right": 227,
#                             "top": 40
#                         },
#                         "roiId": 2
#                     },
#                     {
#                         "annotationId": "byVn93veE",
#                         "annotationTag": "ROLLNUMBER_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 2,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 73,
#                             "left": 249,
#                             "right": 273,
#                             "top": 40
#                         },
#                         "roiId": 3
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "Should be 2 to 3 Digits",
#                     "name": "Between 2 to 3 Digits",
#                     "regExp": "^[1-9][0-9]{1,3}$",
#                     "source": "BACKEND_SCHOOL"
#                 }
#             },
#             {
#                 "cellId": 6,
#                 "format": {
#                     "name": "CELL_ROLLNUMBER_4",
#                     "value": "CELL ROLLNUMBER 4"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 6,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "AWvrH-t0m",
#                         "annotationTag": "CELL_ROLLNUMBER_4",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 87,
#                             "left": 287,
#                             "right": 619,
#                             "top": 27
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 7,
#                 "format": {
#                     "name": "CELL_LABEL_0",
#                     "value": "CELL LABEL 0"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 7,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "fD8TBUoH9",
#                         "annotationTag": "CELL_LABEL_0",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 137,
#                             "left": 18,
#                             "right": 143,
#                             "top": 88
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 8,
#                 "format": {
#                     "name": "CELL_OBJECTIVE",
#                     "value": "CELL OBJECTIVE"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 8,
#                     "langIsoCode": "eng",
#                     "text": "OBJECTIVE"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "M1H9CEf0u",
#                         "annotationTag": "CELL_OBJECTIVE",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 139,
#                             "left": 145,
#                             "right": 520,
#                             "top": 89
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 9,
#                 "format": {
#                     "name": "CELL_SUBJECTIVE",
#                     "value": "CELL SUBJECTIVE"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 9,
#                     "langIsoCode": "eng",
#                     "text": "SUBJECTIVE"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "K5uq0kiWV",
#                         "annotationTag": "CELL_SUBJECTIVE",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 140,
#                             "left": 524,
#                             "right": 618,
#                             "top": 90
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 10,
#                 "format": {
#                     "name": "CELL_SUBJECT",
#                     "value": "CELL SUBJECT"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 10,
#                     "langIsoCode": "eng",
#                     "text": "SUBJECT"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "K5uq0kiWV",
#                         "annotationTag": "CELL_SUBJECTIVE",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 140,
#                             "left": 524,
#                             "right": 618,
#                             "top": 90
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "1q6JlCHIL",
#                         "annotationTag": "CELL_SUBJECT",
#                         "extractionMethod": "",
#                         "index": 1,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 191,
#                             "left": 18,
#                             "right": 143,
#                             "top": 141
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 11,
#                 "format": {
#                     "name": "CELL_QUESTION_1",
#                     "value": "CELL QUESTION 1"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 11,
#                     "langIsoCode": "eng",
#                     "text": "1"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "pbe6YFBEA",
#                         "annotationTag": "CELL_QUESTION_1",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 191,
#                             "left": 145,
#                             "right": 190,
#                             "top": 141
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "N_Z_qI16y",
#                         "annotationTag": "CELL_QUESTION_10",
#                         "extractionMethod": "",
#                         "index": 1,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 572,
#                             "right": 619,
#                             "top": 142
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 12,
#                 "format": {
#                     "name": "CELL_QUESTION_2",
#                     "value": "CELL QUESTION 2"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 12,
#                     "langIsoCode": "eng",
#                     "text": "2"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "Zw6kaLsgE",
#                         "annotationTag": "CELL_QUESTION_2",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 191,
#                             "left": 193,
#                             "right": 237,
#                             "top": 142
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 13,
#                 "format": {
#                     "name": "CELL_QUESTION_3",
#                     "value": "CELL QUESTION 3"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 13,
#                     "langIsoCode": "eng",
#                     "text": "3"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "3UwadIj-H",
#                         "annotationTag": "CELL_QUESTION_3",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 241,
#                             "right": 285,
#                             "top": 142
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 14,
#                 "format": {
#                     "name": "CELL_QUESTION_4",
#                     "value": "CELL QUESTION 4"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 14,
#                     "langIsoCode": "eng",
#                     "text": "4"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "2Ukgcz6aa",
#                         "annotationTag": "CELL_QUESTION_4",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 193,
#                             "left": 289,
#                             "right": 333,
#                             "top": 142
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 15,
#                 "format": {
#                     "name": "CELL_QUESTION_5",
#                     "value": "CELL QUESTION 5"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 15,
#                     "langIsoCode": "eng",
#                     "text": "5"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "UK_e9ytac",
#                         "annotationTag": "CELL_QUESTION_5",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 335,
#                             "right": 379,
#                             "top": 143
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 16,
#                 "format": {
#                     "name": "CELL_QUESTION_6",
#                     "value": "CELL QUESTION 6"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 16,
#                     "langIsoCode": "eng",
#                     "text": "6"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "hKMX7FV4d",
#                         "annotationTag": "CELL_QUESTION_6",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 382,
#                             "right": 426,
#                             "top": 143
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 17,
#                 "format": {
#                     "name": "CELL_QUESTION_7",
#                     "value": "CELL QUESTION 7"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 17,
#                     "langIsoCode": "eng",
#                     "text": "7"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "YhmcZDYby",
#                         "annotationTag": "CELL_QUESTION_7",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 430,
#                             "right": 474,
#                             "top": 143
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 18,
#                 "format": {
#                     "name": "CELL_QUESTION_8",
#                     "value": "CELL QUESTION 8"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 18,
#                     "langIsoCode": "eng",
#                     "text": "8"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "d1p7ohuqh",
#                         "annotationTag": "CELL_QUESTION_8",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 477,
#                             "right": 521,
#                             "top": 143
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 19,
#                 "format": {
#                     "name": "CELL_QUESTION_9",
#                     "value": "CELL QUESTION 9"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 19,
#                     "langIsoCode": "eng",
#                     "text": "9"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "VnNBGqkVz",
#                         "annotationTag": "CELL_QUESTION_9",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 524,
#                             "right": 568,
#                             "top": 143
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 20,
#                 "format": {
#                     "name": "CELL_QUESTION_10",
#                     "value": "CELL QUESTION 10"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 20,
#                     "langIsoCode": "eng",
#                     "text": "10"
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "N_Z_qI16y",
#                         "annotationTag": "CELL_QUESTION_10",
#                         "extractionMethod": "",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 192,
#                             "left": 572,
#                             "right": 619,
#                             "top": 142
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "",
#                     "name": "",
#                     "regExp": "",
#                     "source": ""
#                 }
#             },
#             {
#                 "cellId": 21,
#                 "format": {
#                     "name": "HINDI_QUESTION_1",
#                     "value": "HINDI QUESTION 1"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 21,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "cxfP8uVOx",
#                         "annotationTag": "HINDI_QUESTION_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 235,
#                             "left": 155,
#                             "right": 180,
#                             "top": 200
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION 1 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 22,
#                 "format": {
#                     "name": "HINDI_QUESTION_2",
#                     "value": "HINDI QUESTION 2"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 22,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "Muatqaseb",
#                         "annotationTag": "HINDI_QUESTION_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 235,
#                             "left": 203,
#                             "right": 227,
#                             "top": 201
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION2 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 23,
#                 "format": {
#                     "name": "HINDI_QUESTION_3",
#                     "value": "HINDI QUESTION 3"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 23,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "jZmW-nez7",
#                         "annotationTag": "HINDI_QUESTION_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 235,
#                             "left": 251,
#                             "right": 275,
#                             "top": 200
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION3 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 24,
#                 "format": {
#                     "name": "HINDI_QUESTION_4",
#                     "value": "HINDI QUESTION 4"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 24,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "MMc9B9gLn",
#                         "annotationTag": "HINDI_QUESTION_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 237,
#                             "left": 298,
#                             "right": 321,
#                             "top": 202
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION4 should range from 0 to 10 Marks",
#                     "name": "Between 0 to 10 Marks",
#                     "regExp": "[0-10]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 25,
#                 "format": {
#                     "name": "HINDI_QUESTION_5",
#                     "value": "HINDI QUESTION 5"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 25,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "5DFeVRjUq",
#                         "annotationTag": "HINDI_QUESTION_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 236,
#                             "left": 345,
#                             "right": 369,
#                             "top": 202
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION5 should range from 0 to 10 Marks",
#                     "name": "Between 0 to 10 Marks",
#                     "regExp": "[0-10]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 26,
#                 "format": {
#                     "name": "HINDI_QUESTION_6",
#                     "value": "HINDI QUESTION 6"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 26,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "CbMCC8zrn",
#                         "annotationTag": "HINDI_QUESTION_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 236,
#                             "left": 392,
#                             "right": 416,
#                             "top": 203
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION6 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 27,
#                 "format": {
#                     "name": "HINDI_QUESTION_7",
#                     "value": "HINDI QUESTION 7"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 27,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "o9cBJO5Vr",
#                         "annotationTag": "HINDI_QUESTION_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 236,
#                             "left": 440,
#                             "right": 464,
#                             "top": 202
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION7 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 28,
#                 "format": {
#                     "name": "HINDI_QUESTION_8",
#                     "value": "HINDI QUESTION 8"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 28,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "9dCFXBLiV",
#                         "annotationTag": "HINDI_QUESTION_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 235,
#                             "left": 487,
#                             "right": 511,
#                             "top": 202
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION8 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 29,
#                 "format": {
#                     "name": "HINDI_QUESTION_9",
#                     "value": "HINDI QUESTION 9"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 29,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "x2MPxcbEV",
#                         "annotationTag": "HINDI_QUESTION_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 236,
#                             "left": 535,
#                             "right": 558,
#                             "top": 202
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION9 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 30,
#                 "format": {
#                     "name": "HINDI_QUESTION_TEN",
#                     "value": "HINDI QUESTION TEN"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 30,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "W4jYa1vCS",
#                         "annotationTag": "HINDI_QUESTION_TEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 236,
#                             "left": 583,
#                             "right": 606,
#                             "top": 201
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "HINDI QUESTION10 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 31,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_1",
#                     "value": "ENGLISH QUESTION 1"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 31,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "eY_nH_Kqw",
#                         "annotationTag": "ENGLISH_QUESTION_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 287,
#                             "left": 156,
#                             "right": 181,
#                             "top": 253
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION 1 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 32,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_2",
#                     "value": "ENGLISH QUESTION 2"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 32,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "vhAHjFizv",
#                         "annotationTag": "ENGLISH_QUESTION_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 287,
#                             "left": 204,
#                             "right": 228,
#                             "top": 253
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION2 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 33,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_3",
#                     "value": "ENGLISH QUESTION 3"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 33,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "5LDSXmWs9",
#                         "annotationTag": "ENGLISH_QUESTION_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 289,
#                             "left": 251,
#                             "right": 276,
#                             "top": 254
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION3 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 34,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_4",
#                     "value": "ENGLISH QUESTION 4"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 34,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "so9WEurw4",
#                         "annotationTag": "ENGLISH_QUESTION_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 288,
#                             "left": 298,
#                             "right": 322,
#                             "top": 253
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION4 should range from 0 to 10 Marks",
#                     "name": "Between 0 to 10 Marks",
#                     "regExp": "[0-10]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 35,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_5",
#                     "value": "ENGLISH QUESTION 5"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 35,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "M5mw0hg4g",
#                         "annotationTag": "ENGLISH_QUESTION_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 289,
#                             "left": 345,
#                             "right": 369,
#                             "top": 255
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION5 should range from 0 to 10 Marks",
#                     "name": "Between 0 to 10 Marks",
#                     "regExp": "[0-10]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 36,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_6",
#                     "value": "ENGLISH QUESTION 6"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 36,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "tn9rjjvxZ",
#                         "annotationTag": "ENGLISH_QUESTION_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 288,
#                             "left": 393,
#                             "right": 417,
#                             "top": 254
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION6 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 37,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_7",
#                     "value": "ENGLISH QUESTION 7"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 37,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "62iFMSzw5",
#                         "annotationTag": "ENGLISH_QUESTION_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 288,
#                             "left": 440,
#                             "right": 464,
#                             "top": 254
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "ENGLISH QUESTION7 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 38,
#                 "format": {
#                     "name": "ENGLISH_QUESTION_8",
#                     "value": "ENGLISH QUESTION 8"
#                 },
# ...
#                         "annotationTag": "EVS_QUESTION_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 394,
#                             "left": 536,
#                             "right": 560,
#                             "top": 360
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "EVS QUESTION9 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 60,
#                 "format": {
#                     "name": "EVS_QUESTION_TEN",
#                     "value": "EVS QUESTION TEN"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 60,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "3m3rRH0lN",
#                         "annotationTag": "EVS_QUESTION_TEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 394,
#                             "left": 584,
#                             "right": 607,
#                             "top": 359
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "EVS QUESTION10 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 61,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_1",
#                     "value": "SCIENCE QUESTION 1"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 61,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "D7EhDm4uy",
#                         "annotationTag": "SCIENCE_QUESTION_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 447,
#                             "left": 156,
#                             "right": 180,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION 1 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 62,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_2",
#                     "value": "SCIENCE QUESTION 2"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 62,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "t5zTgSdc2",
#                         "annotationTag": "SCIENCE_QUESTION_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 446,
#                             "left": 204,
#                             "right": 228,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION2 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 63,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_3",
#                     "value": "SCIENCE QUESTION 3"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 63,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "OrRvGhzLV",
#                         "annotationTag": "SCIENCE_QUESTION_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 446,
#                             "left": 252,
#                             "right": 276,
#                             "top": 411
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION3 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 64,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_4",
#                     "value": "SCIENCE QUESTION 4"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 64,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "-x_u3fFhV",
#                         "annotationTag": "SCIENCE_QUESTION_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 445,
#                             "left": 299,
#                             "right": 322,
#                             "top": 411
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION4 should range from 0 to 10 Marks",
#                     "name": "Between 0 to 10 Marks",
#                     "regExp": "[0-10]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 65,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_5",
#                     "value": "SCIENCE QUESTION 5"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 65,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "LVHw1QHMH",
#                         "annotationTag": "SCIENCE_QUESTION_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 446,
#                             "left": 347,
#                             "right": 370,
#                             "top": 411
#                         },
#                         "roiId": 1
#                     },
#                     {
#                         "annotationId": "JfjpePMxn",
#                         "annotationTag": "SCIENCE_QUESTION_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 1,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 454,
#                             "left": 337,
#                             "right": 381,
#                             "top": 404
#                         },
#                         "roiId": 2
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION5 should range from 0 to 10 Marks",
#                     "name": "Between 0 to 10 Marks",
#                     "regExp": "[0-10]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 66,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_6",
#                     "value": "SCIENCE QUESTION 6"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 66,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "JXXYfHtGc",
#                         "annotationTag": "SCIENCE_QUESTION_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 447,
#                             "left": 394,
#                             "right": 418,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION6 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 67,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_7",
#                     "value": "SCIENCE QUESTION 7"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 67,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "j6qSm7bRU",
#                         "annotationTag": "SCIENCE_QUESTION_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 447,
#                             "left": 441,
#                             "right": 465,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION7 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 68,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_8",
#                     "value": "SCIENCE QUESTION 8"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 68,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "6TPxclnwr",
#                         "annotationTag": "SCIENCE_QUESTION_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 446,
#                             "left": 488,
#                             "right": 512,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION8 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 69,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_9",
#                     "value": "SCIENCE QUESTION 9"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 69,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "Li5u6VAyY",
#                         "annotationTag": "SCIENCE_QUESTION_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 447,
#                             "left": 537,
#                             "right": 561,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION9 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             },
#             {
#                 "cellId": 70,
#                 "format": {
#                     "name": "SCIENCE_QUESTION_TEN",
#                     "value": "SCIENCE QUESTION TEN"
#                 },
#                 "render": {
#                     "alignment": "center",
#                     "index": 70,
#                     "langIsoCode": "eng",
#                     "text": ""
#                 },
#                 "rois": [
#                     {
#                         "annotationId": "eZpuYFTx-",
#                         "annotationTag": "SCIENCE_QUESTION_TEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "index": 0,
#                         "langIsoCode": "eng",
#                         "rect": {
#                             "bottom": 446,
#                             "left": 584,
#                             "right": 608,
#                             "top": 412
#                         },
#                         "roiId": 1
#                     }
#                 ],
#                 "validate": {
#                     "errorMessage": "SCIENCE QUESTION10 should range from 0 to 5 Marks",
#                     "name": "Between 0 to 5 Marks",
#                     "regExp": "[0-5]",
#                     "source": "BACKEND_EXAM"
#                 }
#             }
#         ],
#         "excludeFieldsInResponse": [
#             "rois",
#             "validate",
#             "render"
#         ],
#         "name": "UP SAT Exam Sheet Form",
#         "tolerance": {
#             "predictionMin": 0.95,
#             "roiMinHeight": 15,
#             "roiMinWidth": 15
#         },
#         "type": "SAT_50_MARKSHEET",
#         "version": "1.0"
#     }
# }
