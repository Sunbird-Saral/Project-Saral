# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatNameLookup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                 extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                 extractionValue = "CELL_OMR"
                    
                                            
            try:
                 annotationTagsValue = formatNameLookup[region['tags'][0]]
            except KeyError as ke:
                 annotationTagsValue =  region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
                    
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatNameLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "HINDI8S13_9DQOMR Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("HINDI8S13Q_9D_vottraw.json")

# %%
tagGroups = ["ROLLNUMBERID1", "ROLLNUMBER1_Q1","ROLLNUMBER1_Q2","ROLLNUMBER1_Q3","ROLLNUMBER1_Q4","ROLLNUMBER1_Q5","ROLLNUMBER1_Q6","ROLLNUMBER1_Q7","ROLLNUMBER1_Q8","ROLLNUMBER1_Q9","ROLLNUMBER1_QTEN","ROLLNUMBER1_QELEVEN","ROLLNUMBER1_QTWL","ROLLNUMBER1_QTHRTN", "ROLLNUMBERID2","ROLLNUMBER2_Q1","ROLLNUMBER2_Q2","ROLLNUMBER2_Q3","ROLLNUMBER2_Q4","ROLLNUMBER2_Q5","ROLLNUMBER2_Q6","ROLLNUMBER2_Q7","ROLLNUMBER2_Q8","ROLLNUMBER2_Q9","ROLLNUMBER2_QTEN","ROLLNUMBER2_QELEVEN","ROLLNUMBER2_QTWL","ROLLNUMBER2_QTHRTN","ROLLNUMBERID3", "ROLLNUMBER3_Q1","ROLLNUMBER3_Q2","ROLLNUMBER3_Q3","ROLLNUMBER3_Q4","ROLLNUMBER3_Q5","ROLLNUMBER3_Q6","ROLLNUMBER3_Q7","ROLLNUMBER3_Q8","ROLLNUMBER3_Q9","ROLLNUMBER3_QTEN","ROLLNUMBER3_QELEVEN","ROLLNUMBER3_QTWL","ROLLNUMBER3_QTHRTN","ROLLNUMBERID4", "ROLLNUMBER4_Q1","ROLLNUMBER4_Q2","ROLLNUMBER4_Q3","ROLLNUMBER4_Q4","ROLLNUMBER4_Q5","ROLLNUMBER4_Q6","ROLLNUMBER4_Q7","ROLLNUMBER4_Q8","ROLLNUMBER4_Q9","ROLLNUMBER4_QTEN","ROLLNUMBER4_QELEVEN","ROLLNUMBER4_QTWL","ROLLNUMBER4_QTHRTN", "ROLLNUMBERID5","ROLLNUMBER5_Q1","ROLLNUMBER5_Q2","ROLLNUMBER5_Q3","ROLLNUMBER5_Q4","ROLLNUMBER5_Q5","ROLLNUMBER5_Q6","ROLLNUMBER5_Q7","ROLLNUMBER5_Q8","ROLLNUMBER5_Q9","ROLLNUMBER5_QTEN","ROLLNUMBER5_QELEVEN","ROLLNUMBER5_QTWL","ROLLNUMBER5_QTHRTN","ROLLNUMBERID6", "ROLLNUMBER6_Q1","ROLLNUMBER6_Q2","ROLLNUMBER6_Q3","ROLLNUMBER6_Q4","ROLLNUMBER6_Q5","ROLLNUMBER6_Q6","ROLLNUMBER6_Q7","ROLLNUMBER6_Q8","ROLLNUMBER6_Q9","ROLLNUMBER6_QTEN","ROLLNUMBER6_QELEVEN","ROLLNUMBER6_QTWL","ROLLNUMBER6_QTHRTN","ROLLNUMBERID7", "ROLLNUMBER7_Q1","ROLLNUMBER7_Q2","ROLLNUMBER7_Q3","ROLLNUMBER7_Q4","ROLLNUMBER7_Q5","ROLLNUMBER7_Q6","ROLLNUMBER7_Q7","ROLLNUMBER7_Q8","ROLLNUMBER7_Q9","ROLLNUMBER7_QTEN","ROLLNUMBER7_QELEVEN","ROLLNUMBER7_QTWL","ROLLNUMBER7_QTHRTN","ROLLNUMBERID8","ROLLNUMBER8_Q1","ROLLNUMBER8_Q2","ROLLNUMBER8_Q3","ROLLNUMBER8_Q4","ROLLNUMBER8_Q5","ROLLNUMBER8_Q6","ROLLNUMBER8_Q7","ROLLNUMBER8_Q8","ROLLNUMBER8_Q9","ROLLNUMBER8_QTEN","ROLLNUMBER8_QELEVEN","ROLLNUMBER8_QTWL","ROLLNUMBER8_QTHRTN"]


formatLookup= {
    
    'ROLLNUMBERID1': 'ROLLNUMBERID1',
    'ROLLNUMBER1_Q1': 'छात्र आईडी1 Q1',
    'ROLLNUMBER1_Q2': 'छात्र आईडी1 Q2',
    'ROLLNUMBER1_Q3': 'छात्र आईडी1 Q3',
    'ROLLNUMBER1_Q4': 'छात्र आईडी1 Q4',
    'ROLLNUMBER1_Q5': 'छात्र आईडी1 Q5',
    'ROLLNUMBER1_Q6': 'छात्र आईडी1 Q6',
    'ROLLNUMBER1_Q7': 'छात्र आईडी1 Q7',
    'ROLLNUMBER1_Q8': 'छात्र आईडी1 Q8',
    'ROLLNUMBER1_Q9': 'छात्र आईडी1 Q9',
    'ROLLNUMBER1_QTEN': 'छात्र आईडी1 Q10',
    'ROLLNUMBER1_QELEVEN': 'छात्र आईडी1 Q11',
    'ROLLNUMBER1_QTWL': 'छात्र आईडी1 Q12',
    'ROLLNUMBER1_QTHRTN': 'छात्र आईडी1 Q13',
    'ROLLNUMBERID2': 'छात्र आईडी2',
    'ROLLNUMBER2_Q1': 'छात्र आईडी2 Q1',
    'ROLLNUMBER2_Q2': 'छात्र आईडी2 Q2',
    'ROLLNUMBER2_Q3': 'छात्र आईडी2 Q3',
    'ROLLNUMBER2_Q4': 'छात्र आईडी2 Q4',
    'ROLLNUMBER2_Q5': 'छात्र आईडी2 Q5',
    'ROLLNUMBER2_Q6': 'छात्र आईडी2 Q6',
    'ROLLNUMBER2_Q7': 'छात्र आईडी2 Q7',
    'ROLLNUMBER2_Q8': 'छात्र आईडी2 Q8',
    'ROLLNUMBER2_Q9': 'छात्र आईडी2 Q9',
    'ROLLNUMBER2_QTEN': 'छात्र आईडी2 Q10',
    'ROLLNUMBER2_QELEVEN': 'छात्र आईडी2 Q11',
    'ROLLNUMBER2_QTWL': 'छात्र आईडी2 Q12',
    'ROLLNUMBER2_QTHRTN': 'छात्र आईडी2 Q13',
    'ROLLNUMBERID3': 'छात्र आईडी3',
    'ROLLNUMBER3_Q1': 'छात्र आईडी3 Q1',
    'ROLLNUMBER3_Q2': 'छात्र आईडी3 Q2',
    'ROLLNUMBER3_Q3': 'छात्र आईडी3 Q3',
    'ROLLNUMBER3_Q4': 'छात्र आईडी3 Q4',
    'ROLLNUMBER3_Q5': 'छात्र आईडी3 Q5',
    'ROLLNUMBER3_Q6': 'छात्र आईडी3 Q6',
    'ROLLNUMBER3_Q7': 'छात्र आईडी3 Q7',
    'ROLLNUMBER3_Q8': 'छात्र आईडी3 Q8',
    'ROLLNUMBER3_Q9': 'छात्र आईडी3 Q9',
    'ROLLNUMBER3_QTEN': 'छात्र आईडी3 Q10',
    'ROLLNUMBER3_QELEVEN': 'छात्र आईडी3 Q11',
    'ROLLNUMBER3_QTWL': 'छात्र आईडी3 Q12',
    'ROLLNUMBER3_QTHRTN': 'छात्र आईडी3 Q13',
    'ROLLNUMBERID4': 'छात्र आईडी4',
    'ROLLNUMBER4_Q1': 'छात्र आईडी4 Q1',
    'ROLLNUMBER4_Q2': 'छात्र आईडी4 Q2',
    'ROLLNUMBER4_Q3': 'छात्र आईडी4 Q3',
    'ROLLNUMBER4_Q4': 'छात्र आईडी4 Q4',
    'ROLLNUMBER4_Q5': 'छात्र आईडी4 Q5',
    'ROLLNUMBER4_Q6': 'छात्र आईडी4 Q6',
    'ROLLNUMBER4_Q7': 'छात्र आईडी4 Q7',
    'ROLLNUMBER4_Q8': 'छात्र आईडी4 Q8',
    'ROLLNUMBER4_Q9': 'छात्र आईडी4 Q9',
    'ROLLNUMBER4_QTEN': 'छात्र आईडी4 Q10',
    'ROLLNUMBER4_QELEVEN': 'छात्र आईडी4 Q11',
    'ROLLNUMBER4_QTWL': 'छात्र आईडी4 Q12',
    'ROLLNUMBER4_QTHRTN': 'छात्र आईडी4 Q13',
    'ROLLNUMBERID5': 'छात्र आईडी5',
    'ROLLNUMBER5_Q1': 'छात्र आईडी5 Q1',
    'ROLLNUMBER5_Q2': 'छात्र आईडी5 Q2',
    'ROLLNUMBER5_Q3': 'छात्र आईडी5 Q3',
    'ROLLNUMBER5_Q4': 'छात्र आईडी5 Q4',
    'ROLLNUMBER5_Q5': 'छात्र आईडी5 Q5',
    'ROLLNUMBER5_Q6': 'छात्र आईडी5 Q6',
    'ROLLNUMBER5_Q7': 'छात्र आईडी5 Q7',
    'ROLLNUMBER5_Q8': 'छात्र आईडी5 Q8',
    'ROLLNUMBER5_Q9': 'छात्र आईडी5 Q9',
    'ROLLNUMBER5_QTEN': 'छात्र आईडी5 Q10',
    'ROLLNUMBER5_QELEVEN': 'छात्र आईडी5 Q11',
    'ROLLNUMBER5_QTWL': 'छात्र आईडी5 Q12',
    'ROLLNUMBER5_QTHRTN': 'छात्र आईडी5 Q13',
    'ROLLNUMBERID6': 'छात्र आईडी6',
    'ROLLNUMBER6_Q1': 'छात्र आईडी6 Q1',
    'ROLLNUMBER6_Q2': 'छात्र आईडी6 Q2',
    'ROLLNUMBER6_Q3': 'छात्र आईडी6 Q3',
    'ROLLNUMBER6_Q4': 'छात्र आईडी6 Q4',
    'ROLLNUMBER6_Q5': 'छात्र आईडी6 Q5',
    'ROLLNUMBER6_Q6': 'छात्र आईडी6 Q6',
    'ROLLNUMBER6_Q7': 'छात्र आईडी6 Q7',
    'ROLLNUMBER6_Q8': 'छात्र आईडी6 Q8',
    'ROLLNUMBER6_Q9': 'छात्र आईडी6 Q9',
    'ROLLNUMBER6_QTEN': 'छात्र आईडी6 Q10',
    'ROLLNUMBER6_QELEVEN': 'छात्र आईडी6 Q11',
    'ROLLNUMBER6_QTWL': 'छात्र आईडी6 Q12',
    'ROLLNUMBER6_QTHRTN': 'छात्र आईडी6 Q13',
    'ROLLNUMBERID7': 'छात्र आईडी7',
    'ROLLNUMBER7_Q1': 'छात्र आईडी7 Q1',
    'ROLLNUMBER7_Q2': 'छात्र आईडी7 Q2',
    'ROLLNUMBER7_Q3': 'छात्र आईडी7 Q3',
    'ROLLNUMBER7_Q4': 'छात्र आईडी7 Q4',
    'ROLLNUMBER7_Q5': 'छात्र आईडी7 Q5',
    'ROLLNUMBER7_Q6': 'छात्र आईडी7 Q6',
    'ROLLNUMBER7_Q7': 'छात्र आईडी7 Q7',
    'ROLLNUMBER7_Q8': 'छात्र आईडी7 Q8',
    'ROLLNUMBER7_Q9': 'छात्र आईडी7 Q9',
    'ROLLNUMBER7_QTEN': 'छात्र आईडी7 Q10',
    'ROLLNUMBER7_QELEVEN': 'छात्र आईडी7 Q11',
    'ROLLNUMBER7_QTWL': 'छात्र आईडी7 Q12',
    'ROLLNUMBER7_QTHRTN': 'छात्र आईडी7 Q13',
    'ROLLNUMBERID8': 'छात्र आईडी8',
    'ROLLNUMBER8_Q1': 'छात्र आईडी8 Q1',
    'ROLLNUMBER8_Q2': 'छात्र आईडी8 Q2',
    'ROLLNUMBER8_Q3': 'छात्र आईडी8 Q3',
    'ROLLNUMBER8_Q4': 'छात्र आईडी8 Q4',
    'ROLLNUMBER8_Q5': 'छात्र आईडी8 Q5',
    'ROLLNUMBER8_Q6': 'छात्र आईडी8 Q6',
    'ROLLNUMBER8_Q7': 'छात्र आईडी8 Q7',
    'ROLLNUMBER8_Q8': 'छात्र आईडी8 Q8',
    'ROLLNUMBER8_Q9': 'छात्र आईडी8 Q9',
    'ROLLNUMBER8_QTEN': 'छात्र आईडी8 Q10',
    'ROLLNUMBER8_QELEVEN': 'छात्र आईडी8 Q11',
    'ROLLNUMBER8_QTWL': 'छात्र आईडी8 Q12',
    'ROLLNUMBER8_QTHRTN': 'छात्र आईडी8 Q13'
}

formatNameLookup= {
'ROLLNUMBER1_Q1': 'ROLLNUMBER1_Q1',
'ROLLNUMBER1_Q2': 'ROLLNUMBER1_Q2',
'ROLLNUMBER1_Q3': 'ROLLNUMBER1_Q3',
'ROLLNUMBER1_Q4': 'ROLLNUMBER1_Q4',
'ROLLNUMBER1_Q5': 'ROLLNUMBER1_Q5',
'ROLLNUMBER1_Q6': 'ROLLNUMBER1_Q6',
'ROLLNUMBER1_Q7': 'ROLLNUMBER1_Q7',
'ROLLNUMBER1_Q8': 'ROLLNUMBER1_Q8',
'ROLLNUMBER1_Q9': 'ROLLNUMBER1_Q9',
'ROLLNUMBER1_QTEN': 'ROLLNUMBER1_Q10',
'ROLLNUMBER1_QELEVEN': 'ROLLNUMBER1_Q11',
'ROLLNUMBER1_QTWL': 'ROLLNUMBER1_Q12', 
'ROLLNUMBER1_QTHRTN': 'ROLLNUMBER1_Q13',
'ROLLNUMBER2_Q1': 'ROLLNUMBER2_Q1',
'ROLLNUMBER2_Q2': 'ROLLNUMBER2_Q2',
'ROLLNUMBER2_Q3': 'ROLLNUMBER2_Q3',
'ROLLNUMBER2_Q4': 'ROLLNUMBER2_Q4',
'ROLLNUMBER2_Q5': 'ROLLNUMBER2_Q5',
'ROLLNUMBER2_Q6': 'ROLLNUMBER2_Q6',
'ROLLNUMBER2_Q7': 'ROLLNUMBER2_Q7',
'ROLLNUMBER2_Q8': 'ROLLNUMBER2_Q8',
'ROLLNUMBER2_Q9': 'ROLLNUMBER2_Q9',
'ROLLNUMBER2_QTEN': 'ROLLNUMBER2_Q10',
'ROLLNUMBER2_QELEVEN': 'ROLLNUMBER2_Q11',
'ROLLNUMBER2_QTWL': 'ROLLNUMBER2_Q12',
'ROLLNUMBER2_QTHRTN': 'ROLLNUMBER2_Q13',
'ROLLNUMBER3_Q1': 'ROLLNUMBER3_Q1',
'ROLLNUMBER3_Q2': 'ROLLNUMBER3_Q2',
'ROLLNUMBER3_Q3': 'ROLLNUMBER3_Q3',
'ROLLNUMBER3_Q4': 'ROLLNUMBER3_Q4',
'ROLLNUMBER3_Q5': 'ROLLNUMBER3_Q5',
'ROLLNUMBER3_Q6': 'ROLLNUMBER3_Q6',
'ROLLNUMBER3_Q7': 'ROLLNUMBER3_Q7',
'ROLLNUMBER3_Q8': 'ROLLNUMBER3_Q8',
'ROLLNUMBER3_Q9': 'ROLLNUMBER3_Q9',
'ROLLNUMBER3_QTEN': 'ROLLNUMBER3_Q10',
'ROLLNUMBER3_QELEVEN': 'ROLLNUMBER3_Q11',
'ROLLNUMBER3_QTWL': 'ROLLNUMBER3_Q12',
'ROLLNUMBER3_QTHRTN': 'ROLLNUMBER3',
'ROLLNUMBER4_Q1': 'ROLLNUMBER4_Q1',
'ROLLNUMBER4_Q2': 'ROLLNUMBER4_Q2',
'ROLLNUMBER4_Q3': 'ROLLNUMBER4_Q3',
'ROLLNUMBER4_Q4': 'ROLLNUMBER4_Q4',
'ROLLNUMBER4_Q5': 'ROLLNUMBER4_Q5',
'ROLLNUMBER4_Q6': 'ROLLNUMBER4_Q6',
'ROLLNUMBER4_Q7': 'ROLLNUMBER4_Q7',
'ROLLNUMBER4_Q8': 'ROLLNUMBER4_Q8',
'ROLLNUMBER4_Q9': 'ROLLNUMBER4_Q9',
'ROLLNUMBER4_QTEN': 'ROLLNUMBER4_Q10',
'ROLLNUMBER4_QELEVN': 'ROLLNUMBER4_Q11',
'ROLLNUMBER4_QTWL': 'ROLLNUMBER4_Q12',
'ROLLNUMBER4_QTHRTN': 'ROLLNUMBER4_Q13',
'ROLLNUMBER5_Q1': 'ROLLNUMBER5_Q1',
'ROLLNUMBER5_Q2': 'ROLLNUMBER5_Q2',
'ROLLNUMBER5_Q3': 'ROLLNUMBER5_Q3',
'ROLLNUMBER5_Q4': 'ROLLNUMBER5_Q4',
'ROLLNUMBER5_Q5': 'ROLLNUMBER5_Q5',
'ROLLNUMBER5_Q6': 'ROLLNUMBER5_Q6',
'ROLLNUMBER5_Q7': 'ROLLNUMBER5_Q7',
'ROLLNUMBER5_Q8': 'ROLLNUMBER5_Q8',
'ROLLNUMBER5_Q9': 'ROLLNUMBER5_Q9',
'ROLLNUMBER5_QTEN': 'ROLLNUMBER5_Q10',
'ROLLNUMBER5_QELEVEN': 'ROLLNUMBER5_Q11',
'ROLLNUMBER5_QTWL': 'ROLLNUMBER5_Q12',
'ROLLNUMBER5_QTHRTN': 'ROLLNUMBER5_Q13',
'ROLLNUMBER6_Q1': 'ROLLNUMBER6_Q1',
'ROLLNUMBER6_Q2': 'ROLLNUMBER6_Q2',
'ROLLNUMBER6_Q3': 'ROLLNUMBER6_Q3',
'ROLLNUMBER6_Q4': 'ROLLNUMBER6_Q4',
'ROLLNUMBER6_Q5': 'ROLLNUMBER6_Q5',
'ROLLNUMBER6_Q6': 'ROLLNUMBER6_Q6',
'ROLLNUMBER6_Q7': 'ROLLNUMBER6_Q7',
'ROLLNUMBER6_Q8': 'ROLLNUMBER6_Q8',
'ROLLNUMBER6_Q9': 'ROLLNUMBER6_Q9',
'ROLLNUMBER6_QTEN': 'ROLLNUMBER6_Q10',
'ROLLNUMBER6_QELEVEN': 'ROLLNUMBER6_Q11',
'ROLLNUMBER6_QTWL': 'ROLLNUMBER6_Q12',
'ROLLNUMBER6_QTHRTN': 'ROLLNUMBER6_Q13_3',
'ROLLNUMBER7_Q1': 'ROLLNUMBER7_Q1',
'ROLLNUMBER7_Q2': 'ROLLNUMBER7_Q2',
'ROLLNUMBER7_Q3': 'ROLLNUMBER7_Q3',
'ROLLNUMBER7_Q4': 'ROLLNUMBER7_Q4',
'ROLLNUMBER7_Q5': 'ROLLNUMBER7_Q5',
'ROLLNUMBER7_Q6': 'ROLLNUMBER7_Q6',
'ROLLNUMBER7_Q7': 'ROLLNUMBER7_Q7',
'ROLLNUMBER7_Q8': 'ROLLNUMBER7_Q8',
'ROLLNUMBER7_Q9': 'ROLLNUMBER7_Q9',
'ROLLNUMBER7_QTEN': 'ROLLNUMBER7_Q10',
'ROLLNUMBER7_QELEVEN': 'ROLLNUMBER7_Q11',
'ROLLNUMBER7_QTWL': 'ROLLNUMBER7_Q12',
'ROLLNUMBER7_QTHRTN': 'ROLLNUMBER7_Q13',
'ROLLNUMBER8_Q1': 'ROLLNUMBER8_Q1',
'ROLLNUMBER8_Q2': 'ROLLNUMBER8_Q2',
'ROLLNUMBER8_Q3': 'ROLLNUMBER8_Q3',
'ROLLNUMBER8_Q4': 'ROLLNUMBER8_Q4',
'ROLLNUMBER8_Q5': 'ROLLNUMBER8_Q5',
'ROLLNUMBER8_Q6': 'ROLLNUMBER8_Q6',
'ROLLNUMBER8_Q7': 'ROLLNUMBER8_Q7',
'ROLLNUMBER8_Q8': 'ROLLNUMBER8_Q8',
'ROLLNUMBER8_Q9': 'ROLLNUMBER8_Q9',
'ROLLNUMBER8_QTEN': 'ROLLNUMBER8_Q10', 
'ROLLNUMBER8_QELEVEN': 'ROLLNUMBER8_Q11',  
'ROLLNUMBER8_QTWL': 'ROLLNUMBER8_Q12',
'ROLLNUMBER8_QTHRTN': 'ROLLNUMBER8_Q13'
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "HINDI8S13_9DQOMR Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 150,
#                             "left": 54,
#                             "bottom": 179,
#                             "right": 70
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
