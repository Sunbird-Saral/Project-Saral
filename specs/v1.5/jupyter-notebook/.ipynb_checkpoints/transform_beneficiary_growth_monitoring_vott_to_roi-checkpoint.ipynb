# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
                
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": "NUMERIC CLASSIFICATION",
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = str(tagGroup)

    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": str(tagGroup),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "beneficiary growth monitoring Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("Beneficiary_growth_vottraw.json")

# %%
tagGroups = ['CHILDID', 'AIM0_HEIGHT', 'AIM0_WEIGHT', 'AIM0_DOM', 'AIM0_STUNTED', 'AIM0_WASTED', 'AIM0_UNDERWEIGHT', 'AIM0_EDEMA', 'AIM0_ELIGIBLE_SUPPLIMNTRY', 'AIM0_ELIGIBLE_REFRAL', 'AIM0_REASON_REFRAL', 'AIM0_PARENTS_STATUS', 'AIM1_HEIGHT', 'AIM1_WEIGHT', 'AIM1_DOM', 'AIM1_STUNTED', 'AIM1_WASTED', 'AIM1_UNDERWEIGHT', 'AIM1_EDEMA', 'AIM1_ELIGIBLE_SUPPLIMNTRY', 'AIM1_ELIGIBLE_REFRAL', 'AIM1_REASON_REFRAL', 'AIM1_PARENTS_STATUS', 'AIM2_HEIGHT', 'AIM2_WEIGHT', 'AIM2_DOM', 'AIM2_STUNTED', 'AIM2_WASTED', 'AIM2_UNDERWEIGHT', 'AIM2_EDEMA', 'AIM2_ELIGIBLE_SUPPLIMNTRY', 'AIM2_ELIGIBLE_REFRAL', 'AIM2_REASON_REFRAL', 'AIM2_PARENTS_STATUS', 'AIM3_HEIGHT', 'AIM3_WEIGHT', 'AIM3_DOM', 'AIM3_STUNTED', 'AIM3_WASTED', 'AIM3_UNDERWEIGHT', 'AIM3_EDEMA', 'AIM3_ELIGIBLE_SUPPLIMNTRY', 'AIM3_ELIGIBLE_REFRAL', 'AIM3_REASON_REFRAL', 'AIM3_PARENTS_STATUS', 'AIM4_HEIGHT', 'AIM4_WEIGHT', 'AIM4_DOM', 'AIM4_STUNTED', 'AIM4_WASTED', 'AIM4_UNDERWEIGHT', 'AIM4_EDEMA', 'AIM4_ELIGIBLE_SUPPLIMNTRY', 'AIM4_ELIGIBLE_REFRAL', 'AIM4_REASON_REFRAL', 'AIM4_PARENTS_STATUS', 'AIM5_HEIGHT', 'AIM5_WEIGHT', 'AIM5_DOM', 'AIM5_STUNTED', 'AIM5_WASTED', 'AIM5_UNDERWEIGHT', 'AIM5_EDEMA', 'AIM5_ELIGIBLE_SUPPLIMNTRY', 'AIM5_ELIGIBLE_REFRAL', 'AIM5_REASON_REFRAL', 'AIM5_PARENTS_STATUS', 'AIM6_HEIGHT', 'AIM6_WEIGHT', 'AIM6_DOM', 'AIM6_STUNTED', 'AIM6_WASTED', 'AIM6_UNDERWEIGHT', 'AIM6_EDEMA', 'AIM6_ELIGIBLE_SUPPLIMNTRY', 'AIM6_ELIGIBLE_REFRAL', 'AIM6_REASON_REFRAL', 'AIM6_PARENTS_STATUS']
formatLookup = {
    'CHILDID' : 'CHILDID',
    'AIM0_HEIGHT' : 'AIM0 HEIGHT',
    'AIM0_WEIGHT' : 'AIM0 WEIGHT',
    'AIM0_DOM' : 'AIM0 DOM',
    'AIM0_STUNTED' : 'AIM0 STUNTED',
    'AIM0_WASTED' : 'AIM0 WASTED',
    'AIM0_UNDERWEIGHT' : 'AIM0 UNDERWEIGHT',
    'AIM0_EDEMA' : 'AIM0 EDEMA',
    'AIM0_ELIGIBLE_SUPPLIMNTRY' : 'AIM0 ELIGIBLE SUPPLIMNTRY',
    'AIM0_ELIGIBLE_REFRAL' : 'AIM0 ELIGIBLE REFRAL',
    'AIM0_REASON_REFRAL' : 'AIM0 REASON REFRAL',
    'AIM0_PARENTS_STATUS' : 'AIM0 PARENTS STATUS',
    'AIM1_HEIGHT' : 'AIM1 HEIGHT',
    'AIM1_WEIGHT' : 'AIM1 WEIGHT',
    'AIM1_DOM' : 'AIM1 DOM',
    'AIM1_STUNTED' : 'AIM1 STUNTED',
    'AIM1_WASTED' : 'AIM1 WASTED',
    'AIM1_UNDERWEIGHT' : 'AIM1 UNDERWEIGHT',
    'AIM1_EDEMA' : 'AIM1 EDEMA',
    'AIM1_ELIGIBLE_SUPPLIMNTRY' : 'AIM1 ELIGIBLE SUPPLIMNTRY',
    'AIM1_ELIGIBLE_REFRAL' : 'AIM1 ELIGIBLE REFRAL',
    'AIM1_REASON_REFRAL' : 'AIM1 REASON REFRAL',
    'AIM1_PARENTS_STATUS' : 'AIM1 PARENTS STATUS',
    'AIM2_HEIGHT' : 'AIM2 HEIGHT',
    'AIM2_WEIGHT' : 'AIM2 WEIGHT',
    'AIM2_DOM' : 'AIM2 DOM',
    'AIM2_STUNTED' : 'AIM2 STUNTED',
    'AIM2_WASTED' : 'AIM2 WASTED',
    'AIM2_UNDERWEIGHT' : 'AIM2 UNDERWEIGHT',
    'AIM2_EDEMA' : 'AIM2 EDEMA',
    'AIM2_ELIGIBLE_SUPPLIMNTRY' : 'AIM2 ELIGIBLE SUPPLIMNTRY',
    'AIM2_ELIGIBLE_REFRAL' : 'AIM2 ELIGIBLE REFRAL',
    'AIM2_REASON_REFRAL' : 'AIM2 REASON REFRAL',
    'AIM2_PARENTS_STATUS' : 'AIM2 PARENTS STATUS',
    'AIM3_HEIGHT' : 'AIM3 HEIGHT',
    'AIM3_WEIGHT' : 'AIM3 WEIGHT',
    'AIM3_DOM' : 'AIM3 DOM',
    'AIM3_STUNTED' : 'AIM3 STUNTED',
    'AIM3_WASTED' : 'AIM3 WASTED',
    'AIM3_UNDERWEIGHT' : 'AIM3 UNDERWEIGHT',
    'AIM3_EDEMA' : 'AIM3 EDEMA',
    'AIM3_ELIGIBLE_SUPPLIMNTRY' : 'AIM3 ELIGIBLE SUPPLIMNTRY',
    'AIM3_ELIGIBLE_REFRAL' : 'AIM3 ELIGIBLE REFRAL',
    'AIM3_REASON_REFRAL' : 'AIM3 REASON REFRAL',
    'AIM3_PARENTS_STATUS' : 'AIM3 PARENTS STATUS',
    'AIM4_HEIGHT' : 'AIM4 HEIGHT',
    'AIM4_WEIGHT' : 'AIM4 WEIGHT',
    'AIM4_DOM' : 'AIM4 DOM',
    'AIM4_STUNTED' : 'AIM4 STUNTED',
    'AIM4_WASTED' : 'AIM4 WASTED',
    'AIM4_UNDERWEIGHT' : 'AIM4 UNDERWEIGHT',
    'AIM4_EDEMA' : 'AIM4 EDEMA',
    'AIM4_ELIGIBLE_SUPPLIMNTRY' : 'AIM4 ELIGIBLE SUPPLIMNTRY',
    'AIM4_ELIGIBLE_REFRAL' : 'AIM4 ELIGIBLE REFRAL',
    'AIM4_REASON_REFRAL' : 'AIM4 REASON REFRAL',
    'AIM4_PARENTS_STATUS' : 'AIM4 PARENTS STATUS',
    'AIM5_HEIGHT' : 'AIM5 HEIGHT',
    'AIM5_WEIGHT' : 'AIM5 WEIGHT',
    'AIM5_DOM' : 'AIM5 DOM',
    'AIM5_STUNTED' : 'AIM5 STUNTED',
    'AIM5_WASTED' : 'AIM5 WASTED',
    'AIM5_UNDERWEIGHT' : 'AIM5 UNDERWEIGHT',
    'AIM5_EDEMA' : 'AIM5 EDEMA',
    'AIM5_ELIGIBLE_SUPPLIMNTRY' : 'AIM5 ELIGIBLE SUPPLIMNTRY',
    'AIM5_ELIGIBLE_REFRAL' : 'AIM5 ELIGIBLE REFRAL',
    'AIM5_REASON_REFRAL' : 'AIM5 REASON REFRAL',
    'AIM5_PARENTS_STATUS' : 'AIM5 PARENTS STATUS',
    'AIM6_HEIGHT' : 'AIM6 HEIGHT',
    'AIM6_WEIGHT' : 'AIM6 WEIGHT',
    'AIM6_DOM' : 'AIM6 DOM',
    'AIM6_STUNTED' : 'AIM6 STUNTED',
    'AIM6_WASTED' : 'AIM6 WASTED',
    'AIM6_UNDERWEIGHT' : 'AIM6 UNDERWEIGHT',
    'AIM6_EDEMA' : 'AIM6 EDEMA',
    'AIM6_ELIGIBLE_SUPPLIMNTRY' : 'AIM6 ELIGIBLE SUPPLIMNTRY',
    'AIM6_ELIGIBLE_REFRAL' : 'AIM6 ELIGIBLE REFRAL',
    'AIM6_REASON_REFRAL' : 'AIM6 REASON REFRAL',
    'AIM6_PARENTS_STATUS' : 'AIM6 PARENTS STATUS'
      
}

formatAnnotationTagLookup = {
    'CHILDID1_TEN' : 'CHILDID1_10',
    'CHILDID1_ELEVEN' : 'CHILDID1_11',
    'CHILDID1_TWELVE' : 'CHILDID1_12',
    'CHILDID1_THERTEEN' : 'CHILDID1_13',
    'CHILDID1_FOURTEEN' : 'CHILDID1_14',
    'CHILDID1_FIFTEEN' : 'CHILDID1_15',
    

}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "beneficiary growth monitoring Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDID1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 25,
#                             "left": 269,
#                             "bottom": 55,
#                             "right": 293
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 26,
#                             "left": 293,
#                             "bottom": 56,
#                             "right": 316
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 25,
#                             "left": 317,
#                             "bottom": 56,
#                             "right": 338
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 27,
#                             "left": 341,
#                             "bottom": 56,
#                             "right": 361
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 28,
#                             "left": 363,
#                             "bottom": 55,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_6",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 25,
#                             "left": 386,
#                             "bottom": 55,
#                             "right": 408
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_7",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 26,
#                             "left": 410,
#                             "bottom": 54,
#                             "right": 431
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_8",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 7,
#                         "rect": {
#                             "top": 26,
#                             "left": 432,
#                             "bottom": 55,
#                             "right": 455
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_9",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 8,
#                         "rect": {
#                             "top": 25,
#                             "left": 456,
#                             "bottom": 54,
#                             "right": 479
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_10",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 9,
#                         "rect": {
#                             "top": 25,
#                             "left": 480,
#                             "bottom": 53,
#                             "right": 503
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_11",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 10,
#                         "rect": {
#                             "top": 24,
#                             "left": 506,
#                             "bottom": 55,
#                             "right": 529
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_12",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 11,
#                         "rect": {
#                             "top": 21,
#                             "left": 529,
#                             "bottom": 51,
#                             "right": 554
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_13",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 12,
#                         "rect": {
#                             "top": 22,
#                             "left": 553,
#                             "bottom": 52,
#                             "right": 575
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_14",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "14",
#                         "index": 13,
#                         "rect": {
#                             "top": 21,
#                             "left": 578,
#                             "bottom": 51,
#                             "right": 600
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID1_15",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "15",
#                         "index": 14,
#                         "rect": {
#                             "top": 21,
#                             "left": 601,
#                             "bottom": 51,
#                             "right": 624
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "CHILDID",
#                     "value": "CHILDID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "16",
#                         "index": 0,
#                         "rect": {
#                             "top": 218,
#                             "left": 42,
#                             "bottom": 249,
#                             "right": 66
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "17",
#                         "index": 1,
#                         "rect": {
#                             "top": 218,
#                             "left": 68,
#                             "bottom": 249,
#                             "right": 91
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "18",
#                         "index": 2,
#                         "rect": {
#                             "top": 216,
#                             "left": 94,
#                             "bottom": 248,
#                             "right": 116
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_HEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "19",
#                         "index": 3,
#                         "rect": {
#                             "top": 217,
#                             "left": 119,
#                             "bottom": 248,
#                             "right": 142
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "AIM0_HEIGHT",
#                     "value": "AIM0 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_WEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "20",
#                         "index": 0,
#                         "rect": {
#                             "top": 217,
#                             "left": 144,
#                             "bottom": 248,
#                             "right": 168
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "21",
#                         "index": 1,
#                         "rect": {
#                             "top": 217,
#                             "left": 170,
#                             "bottom": 248,
#                             "right": 194
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "22",
#                         "index": 2,
#                         "rect": {
#                             "top": 218,
#                             "left": 195,
#                             "bottom": 248,
#                             "right": 217
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "23",
#                         "index": 3,
#                         "rect": {
#                             "top": 217,
#                             "left": 221,
#                             "bottom": 249,
#                             "right": 245
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_WEIGHT1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "24",
#                         "index": 4,
#                         "rect": {
#                             "top": 217,
#                             "left": 246,
#                             "bottom": 247,
#                             "right": 271
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "AIM0_WEIGHT",
#                     "value": "AIM0 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_DOM1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "25",
#                         "index": 0,
#                         "rect": {
#                             "top": 218,
#                             "left": 271,
#                             "bottom": 251,
#                             "right": 296
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "26",
#                         "index": 1,
#                         "rect": {
#                             "top": 217,
#                             "left": 296,
#                             "bottom": 248,
#                             "right": 319
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "27",
#                         "index": 2,
#                         "rect": {
#                             "top": 218,
#                             "left": 321,
#                             "bottom": 248,
#                             "right": 344
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "28",
#                         "index": 3,
#                         "rect": {
#                             "top": 217,
#                             "left": 347,
#                             "bottom": 250,
#                             "right": 369
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "29",
#                         "index": 4,
#                         "rect": {
#                             "top": 217,
#                             "left": 371,
#                             "bottom": 247,
#                             "right": 393
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM0_DOM1_6",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "30",
#                         "index": 5,
#                         "rect": {
#                             "top": 217,
#                             "left": 395,
#                             "bottom": 248,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "AIM0_DOM",
#                     "value": "AIM0 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_STUNTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "31",
#                         "index": 0,
#                         "rect": {
#                             "top": 216,
#                             "left": 421,
#                             "bottom": 249,
#                             "right": 444
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "AIM0_STUNTED",
#                     "value": "AIM0 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_WASTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "32",
#                         "index": 0,
#                         "rect": {
#                             "top": 216,
#                             "left": 446,
#                             "bottom": 248,
#                             "right": 468
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "AIM0_WASTED",
#                     "value": "AIM0 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_UNDERWEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "33",
#                         "index": 0,
#                         "rect": {
#                             "top": 218,
#                             "left": 471,
#                             "bottom": 248,
#                             "right": 494
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "AIM0_UNDERWEIGHT",
#                     "value": "AIM0 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_EDEMA1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "34",
#                         "index": 0,
#                         "rect": {
#                             "top": 217,
#                             "left": 495,
#                             "bottom": 248,
#                             "right": 520
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "AIM0_EDEMA",
#                     "value": "AIM0 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_ELIGIBLE_SUPPLIMNTRY1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "35",
#                         "index": 0,
#                         "rect": {
#                             "top": 217,
#                             "left": 522,
#                             "bottom": 249,
#                             "right": 545
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "AIM0_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM0 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_ELIGIBLE_REFRAL1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "36",
#                         "index": 0,
#                         "rect": {
#                             "top": 216,
#                             "left": 547,
#                             "bottom": 248,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "AIM0_ELIGIBLE_REFRAL",
#                     "value": "AIM0 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_REASON_REFRAL1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "37",
#                         "index": 0,
#                         "rect": {
#                             "top": 216,
#                             "left": 575,
#                             "bottom": 247,
#                             "right": 597
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "AIM0_REASON_REFRAL",
#                     "value": "AIM0 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM0_PARENTS_STATUS1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "38",
#                         "index": 0,
#                         "rect": {
#                             "top": 216,
#                             "left": 599,
#                             "bottom": 248,
#                             "right": 623
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "AIM0_PARENTS_STATUS",
#                     "value": "AIM0 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_HEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "39",
#                         "index": 0,
#                         "rect": {
#                             "top": 251,
#                             "left": 42,
#                             "bottom": 282,
#                             "right": 66
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_HEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "40",
#                         "index": 1,
#                         "rect": {
#                             "top": 251,
#                             "left": 68,
#                             "bottom": 281,
#                             "right": 92
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_HEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "41",
#                         "index": 2,
#                         "rect": {
#                             "top": 250,
#                             "left": 94,
#                             "bottom": 282,
#                             "right": 118
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_HEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "42",
#                         "index": 3,
#                         "rect": {
#                             "top": 250,
#                             "left": 119,
#                             "bottom": 284,
#                             "right": 144
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "AIM1_HEIGHT",
#                     "value": "AIM1 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_WEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "43",
#                         "index": 0,
#                         "rect": {
#                             "top": 251,
#                             "left": 145,
#                             "bottom": 283,
#                             "right": 168
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "44",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 169,
#                             "bottom": 282,
#                             "right": 194
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "45",
#                         "index": 2,
#                         "rect": {
#                             "top": 251,
#                             "left": 195,
#                             "bottom": 283,
#                             "right": 219
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "46",
#                         "index": 3,
#                         "rect": {
#                             "top": 250,
#                             "left": 221,
#                             "bottom": 283,
#                             "right": 246
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_WEIGHT1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "47",
#                         "index": 4,
#                         "rect": {
#                             "top": 250,
#                             "left": 246,
#                             "bottom": 283,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "AIM1_WEIGHT",
#                     "value": "AIM1 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "15",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_DOM1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "48",
#                         "index": 0,
#                         "rect": {
#                             "top": 251,
#                             "left": 270,
#                             "bottom": 282,
#                             "right": 294
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "49",
#                         "index": 1,
#                         "rect": {
#                             "top": 251,
#                             "left": 297,
#                             "bottom": 282,
#                             "right": 320
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "50",
#                         "index": 2,
#                         "rect": {
#                             "top": 251,
#                             "left": 322,
#                             "bottom": 283,
#                             "right": 345
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "51",
#                         "index": 3,
#                         "rect": {
#                             "top": 251,
#                             "left": 347,
#                             "bottom": 282,
#                             "right": 367
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "52",
#                         "index": 4,
#                         "rect": {
#                             "top": 251,
#                             "left": 372,
#                             "bottom": 283,
#                             "right": 393
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM1_DOM1_6",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "53",
#                         "index": 5,
#                         "rect": {
#                             "top": 250,
#                             "left": 397,
#                             "bottom": 283,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "AIM1_DOM",
#                     "value": "AIM1 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "16",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_STUNTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "54",
#                         "index": 0,
#                         "rect": {
#                             "top": 251,
#                             "left": 421,
#                             "bottom": 282,
#                             "right": 443
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "AIM1_STUNTED",
#                     "value": "AIM1 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "17",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_WASTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "55",
#                         "index": 0,
#                         "rect": {
#                             "top": 250,
#                             "left": 445,
#                             "bottom": 283,
#                             "right": 469
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "AIM1_WASTED",
#                     "value": "AIM1 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_UNDERWEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "56",
#                         "index": 0,
#                         "rect": {
#                             "top": 249,
#                             "left": 471,
#                             "bottom": 280,
#                             "right": 495
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "AIM1_UNDERWEIGHT",
#                     "value": "AIM1 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "19",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_EDEMA1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "57",
#                         "index": 0,
#                         "rect": {
#                             "top": 249,
#                             "left": 494,
#                             "bottom": 283,
#                             "right": 518
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "AIM1_EDEMA",
#                     "value": "AIM1 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "20",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_ELIGIBLE_SUPPLIMNTRY1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "58",
#                         "index": 0,
#                         "rect": {
#                             "top": 251,
#                             "left": 521,
#                             "bottom": 282,
#                             "right": 545
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "AIM1_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM1 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "21",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_ELIGIBLE_REFRAL1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "59",
#                         "index": 0,
#                         "rect": {
#                             "top": 250,
#                             "left": 547,
#                             "bottom": 281,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "AIM1_ELIGIBLE_REFRAL",
#                     "value": "AIM1 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "22",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_REASON_REFRAL1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "60",
#                         "index": 0,
#                         "rect": {
#                             "top": 249,
#                             "left": 572,
#                             "bottom": 282,
#                             "right": 597
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "AIM1_REASON_REFRAL",
#                     "value": "AIM1 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "23",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM1_PARENTS_STATUS1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "61",
#                         "index": 0,
#                         "rect": {
#                             "top": 250,
#                             "left": 600,
#                             "bottom": 283,
#                             "right": 623
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "AIM1_PARENTS_STATUS",
#                     "value": "AIM1 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "24",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_HEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "62",
#                         "index": 0,
#                         "rect": {
#                             "top": 287,
#                             "left": 68,
#                             "bottom": 317,
#                             "right": 94
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_HEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "63",
#                         "index": 1,
#                         "rect": {
#                             "top": 286,
#                             "left": 94,
#                             "bottom": 316,
#                             "right": 117
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_HEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "64",
#                         "index": 2,
#                         "rect": {
#                             "top": 286,
#                             "left": 120,
#                             "bottom": 317,
#                             "right": 141
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_HEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "65",
#                         "index": 3,
#                         "rect": {
#                             "top": 285,
#                             "left": 41,
#                             "bottom": 319,
#                             "right": 67
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "AIM2_HEIGHT",
#                     "value": "AIM2 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "25",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_WEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "66",
#                         "index": 0,
#                         "rect": {
#                             "top": 285,
#                             "left": 146,
#                             "bottom": 317,
#                             "right": 168
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "67",
#                         "index": 1,
#                         "rect": {
#                             "top": 286,
#                             "left": 171,
#                             "bottom": 316,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "68",
#                         "index": 2,
#                         "rect": {
#                             "top": 284,
#                             "left": 198,
#                             "bottom": 317,
#                             "right": 220
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "69",
#                         "index": 3,
#                         "rect": {
#                             "top": 284,
#                             "left": 222,
#                             "bottom": 316,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_WEIGHT1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "70",
#                         "index": 4,
#                         "rect": {
#                             "top": 285,
#                             "left": 245,
#                             "bottom": 314,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "AIM2_WEIGHT",
#                     "value": "AIM2 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "26",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_DOM1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "71",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 271,
#                             "bottom": 316,
#                             "right": 294
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "72",
#                         "index": 1,
#                         "rect": {
#                             "top": 284,
#                             "left": 295,
#                             "bottom": 315,
#                             "right": 319
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "73",
#                         "index": 2,
#                         "rect": {
#                             "top": 285,
#                             "left": 322,
#                             "bottom": 316,
#                             "right": 343
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "74",
#                         "index": 3,
#                         "rect": {
#                             "top": 284,
#                             "left": 346,
#                             "bottom": 316,
#                             "right": 369
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "75",
#                         "index": 4,
#                         "rect": {
#                             "top": 284,
#                             "left": 371,
#                             "bottom": 318,
#                             "right": 395
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM2_DOM1_6",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "76",
#                         "index": 5,
#                         "rect": {
#                             "top": 285,
#                             "left": 397,
#                             "bottom": 315,
#                             "right": 420
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "AIM2_DOM",
#                     "value": "AIM2 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "27",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_STUNTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "77",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 420,
#                             "bottom": 318,
#                             "right": 444
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "AIM2_STUNTED",
#                     "value": "AIM2 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "28",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM2_WASTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "78",
#                         "index": 0,
#                         "rect": {
#                             "top": 285,
#                             "left": 446,
#                             "bottom": 316,
# ...
#                             "top": 388,
#                             "left": 601,
#                             "bottom": 422,
#                             "right": 622
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 67
#                 },
#                 "format": {
#                     "name": "AIM5_PARENTS_STATUS",
#                     "value": "AIM5 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "68",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_HEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "154",
#                         "index": 0,
#                         "rect": {
#                             "top": 423,
#                             "left": 39,
#                             "bottom": 455,
#                             "right": 65
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_HEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "155",
#                         "index": 1,
#                         "rect": {
#                             "top": 424,
#                             "left": 67,
#                             "bottom": 456,
#                             "right": 89
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_HEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "156",
#                         "index": 2,
#                         "rect": {
#                             "top": 424,
#                             "left": 90,
#                             "bottom": 456,
#                             "right": 116
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_HEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "157",
#                         "index": 3,
#                         "rect": {
#                             "top": 424,
#                             "left": 119,
#                             "bottom": 456,
#                             "right": 140
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 68
#                 },
#                 "format": {
#                     "name": "AIM6_HEIGHT",
#                     "value": "AIM6 HEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "69",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_WEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "158",
#                         "index": 0,
#                         "rect": {
#                             "top": 423,
#                             "left": 142,
#                             "bottom": 455,
#                             "right": 167
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHT1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "159",
#                         "index": 1,
#                         "rect": {
#                             "top": 425,
#                             "left": 170,
#                             "bottom": 456,
#                             "right": 194
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHT1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "160",
#                         "index": 2,
#                         "rect": {
#                             "top": 423,
#                             "left": 196,
#                             "bottom": 455,
#                             "right": 217
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHT1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "161",
#                         "index": 3,
#                         "rect": {
#                             "top": 422,
#                             "left": 221,
#                             "bottom": 456,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_WEIGHT1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "162",
#                         "index": 4,
#                         "rect": {
#                             "top": 423,
#                             "left": 245,
#                             "bottom": 454,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 69
#                 },
#                 "format": {
#                     "name": "AIM6_WEIGHT",
#                     "value": "AIM6 WEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "70",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_DOM1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "163",
#                         "index": 0,
#                         "rect": {
#                             "top": 421,
#                             "left": 270,
#                             "bottom": 452,
#                             "right": 295
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_2",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "164",
#                         "index": 1,
#                         "rect": {
#                             "top": 421,
#                             "left": 295,
#                             "bottom": 453,
#                             "right": 320
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_3",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "165",
#                         "index": 2,
#                         "rect": {
#                             "top": 421,
#                             "left": 320,
#                             "bottom": 454,
#                             "right": 343
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_4",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "166",
#                         "index": 3,
#                         "rect": {
#                             "top": 420,
#                             "left": 347,
#                             "bottom": 454,
#                             "right": 368
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_5",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "167",
#                         "index": 4,
#                         "rect": {
#                             "top": 420,
#                             "left": 370,
#                             "bottom": 451,
#                             "right": 393
#                         }
#                     },
#                     {
#                         "annotationTags": "AIM6_DOM1_6",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "168",
#                         "index": 5,
#                         "rect": {
#                             "top": 420,
#                             "left": 397,
#                             "bottom": 451,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 70
#                 },
#                 "format": {
#                     "name": "AIM6_DOM",
#                     "value": "AIM6 DOM"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "71",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_STUNTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "169",
#                         "index": 0,
#                         "rect": {
#                             "top": 419,
#                             "left": 421,
#                             "bottom": 454,
#                             "right": 444
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 71
#                 },
#                 "format": {
#                     "name": "AIM6_STUNTED",
#                     "value": "AIM6 STUNTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "72",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_WASTED1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "170",
#                         "index": 0,
#                         "rect": {
#                             "top": 420,
#                             "left": 447,
#                             "bottom": 454,
#                             "right": 468
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 72
#                 },
#                 "format": {
#                     "name": "AIM6_WASTED",
#                     "value": "AIM6 WASTED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "73",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_UNDERWEIGHT1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "171",
#                         "index": 0,
#                         "rect": {
#                             "top": 420,
#                             "left": 471,
#                             "bottom": 454,
#                             "right": 494
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 73
#                 },
#                 "format": {
#                     "name": "AIM6_UNDERWEIGHT",
#                     "value": "AIM6 UNDERWEIGHT"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "74",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_EDEMA1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "172",
#                         "index": 0,
#                         "rect": {
#                             "top": 420,
#                             "left": 496,
#                             "bottom": 456,
#                             "right": 521
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 74
#                 },
#                 "format": {
#                     "name": "AIM6_EDEMA",
#                     "value": "AIM6 EDEMA"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "75",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_ELIGIBLE_SUPPLIMNTRY1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "173",
#                         "index": 0,
#                         "rect": {
#                             "top": 422,
#                             "left": 521,
#                             "bottom": 456,
#                             "right": 544
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 75
#                 },
#                 "format": {
#                     "name": "AIM6_ELIGIBLE_SUPPLIMNTRY",
#                     "value": "AIM6 ELIGIBLE SUPPLIMNTRY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "76",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_ELIGIBLE_REFRAL1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "174",
#                         "index": 0,
#                         "rect": {
#                             "top": 422,
#                             "left": 546,
#                             "bottom": 455,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 76
#                 },
#                 "format": {
#                     "name": "AIM6_ELIGIBLE_REFRAL",
#                     "value": "AIM6 ELIGIBLE REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "77",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_REASON_REFRAL1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "175",
#                         "index": 0,
#                         "rect": {
#                             "top": 422,
#                             "left": 573,
#                             "bottom": 456,
#                             "right": 598
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 77
#                 },
#                 "format": {
#                     "name": "AIM6_REASON_REFRAL",
#                     "value": "AIM6 REASON REFRAL"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "78",
#                 "rois": [
#                     {
#                         "annotationTags": "AIM6_PARENTS_STATUS1_1",
#                         "extractionMethod": "NUMERIC CLASSIFICATION",
#                         "roiId": "176",
#                         "index": 0,
#                         "rect": {
#                             "top": 424,
#                             "left": 599,
#                             "bottom": 457,
#                             "right": 624
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 78
#                 },
#                 "format": {
#                     "name": "AIM6_PARENTS_STATUS",
#                     "value": "AIM6 PARENTS STATUS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
