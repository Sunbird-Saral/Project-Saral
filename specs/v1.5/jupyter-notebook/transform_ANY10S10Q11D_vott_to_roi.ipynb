# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                extractionValue = "CELL_OMR"
                
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
                    
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "ANY10S10Q11DOMR Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("ANY_10S10Q11D_attendance_vottraw.json")

# %%
tagGroups = ['ROLLNUMBERID1', 'ROLLNUMBER1_Q1', 'ROLLNUMBER1_Q2', 'ROLLNUMBER1_Q3', 'ROLLNUMBER1_Q4', 'ROLLNUMBER1_Q5', 'ROLLNUMBER1_Q6', 'ROLLNUMBER1_Q7', 'ROLLNUMBER1_Q8', 'ROLLNUMBER1_Q9', 'ROLLNUMBER1_QTEN', 'ROLLNUMBERID2', 'ROLLNUMBER2_Q1', 'ROLLNUMBER2_Q2', 'ROLLNUMBER2_Q3', 'ROLLNUMBER2_Q4', 'ROLLNUMBER2_Q5', 'ROLLNUMBER2_Q6', 'ROLLNUMBER2_Q7', 'ROLLNUMBER2_Q8', 'ROLLNUMBER2_Q9', 'ROLLNUMBER2_QTEN', 'ROLLNUMBERID3', 'ROLLNUMBER3_Q1', 'ROLLNUMBER3_Q2', 'ROLLNUMBER3_Q3', 'ROLLNUMBER3_Q4', 'ROLLNUMBER3_Q5', 'ROLLNUMBER3_Q6', 'ROLLNUMBER3_Q7', 'ROLLNUMBER3_Q8', 'ROLLNUMBER3_Q9', 'ROLLNUMBER3_QTEN', 'ROLLNUMBERID4', 'ROLLNUMBER4_Q1', 'ROLLNUMBER4_Q2', 'ROLLNUMBER4_Q3', 'ROLLNUMBER4_Q4', 'ROLLNUMBER4_Q5', 'ROLLNUMBER4_Q6', 'ROLLNUMBER4_Q7', 'ROLLNUMBER4_Q8', 'ROLLNUMBER4_Q9', 'ROLLNUMBER4_QTEN', 'ROLLNUMBERID5', 'ROLLNUMBER5_Q1', 'ROLLNUMBER5_Q2', 'ROLLNUMBER5_Q3', 'ROLLNUMBER5_Q4', 'ROLLNUMBER5_Q5', 'ROLLNUMBER5_Q6', 'ROLLNUMBER5_Q7', 'ROLLNUMBER5_Q8', 'ROLLNUMBER5_Q9', 'ROLLNUMBER5_QTEN', 'ROLLNUMBERID6', 'ROLLNUMBER6_Q1', 'ROLLNUMBER6_Q2', 'ROLLNUMBER6_Q3', 'ROLLNUMBER6_Q4', 'ROLLNUMBER6_Q5', 'ROLLNUMBER6_Q6', 'ROLLNUMBER6_Q7', 'ROLLNUMBER6_Q8', 'ROLLNUMBER6_Q9', 'ROLLNUMBER6_QTEN', 'ROLLNUMBERID7', 'ROLLNUMBER7_Q1', 'ROLLNUMBER7_Q2', 'ROLLNUMBER7_Q3', 'ROLLNUMBER7_Q4', 'ROLLNUMBER7_Q5', 'ROLLNUMBER7_Q6', 'ROLLNUMBER7_Q7', 'ROLLNUMBER7_Q8', 'ROLLNUMBER7_Q9', 'ROLLNUMBER7_QTEN', 'ROLLNUMBERID8', 'ROLLNUMBER8_Q1', 'ROLLNUMBER8_Q2', 'ROLLNUMBER8_Q3', 'ROLLNUMBER8_Q4', 'ROLLNUMBER8_Q5', 'ROLLNUMBER8_Q6','ROLLNUMBER8_Q7','ROLLNUMBER8_Q8', 'ROLLNUMBER8_Q9', 'ROLLNUMBER8_QTEN', 'ROLLNUMBERID9', 'ROLLNUMBER9_Q1', 'ROLLNUMBER9_Q2', 'ROLLNUMBER9_Q3', 'ROLLNUMBER9_Q4', 'ROLLNUMBER9_Q5', 'ROLLNUMBER9_Q6', 'ROLLNUMBER9_Q7', 'ROLLNUMBER9_Q8', 'ROLLNUMBER9_Q9', 'ROLLNUMBER9_QTEN', 'ROLLNUMBERIDTEN', 'ROLLNUMBERTEN_Q1', 'ROLLNUMBERTEN_Q2', 'ROLLNUMBERTEN_Q3', 'ROLLNUMBERTEN_Q4', 'ROLLNUMBERTEN_Q5', 'ROLLNUMBERTEN_Q6', 'ROLLNUMBERTEN_Q7', 'ROLLNUMBERTEN_Q8', 'ROLLNUMBERTEN_Q9', 'ROLLNUMBERTEN_QTEN']


formatLookup = {
    'ROLLNUMBERID1' : 'ROLLNUMBERID1',
    'ROLLNUMBER1_Q1' : 'ROLLNUMBER1 Q1',
    'ROLLNUMBER1_Q2' : 'ROLLNUMBER1 Q2',
    'ROLLNUMBER1_Q3' : 'ROLLNUMBER1 Q3',
    'ROLLNUMBER1_Q4' : 'ROLLNUMBER1 Q4',
    'ROLLNUMBER1_Q5' : 'ROLLNUMBER1 Q5',
    'ROLLNUMBER1_Q6' : 'ROLLNUMBER1 Q6',
    'ROLLNUMBER1_Q7' : 'ROLLNUMBER1 Q7',
    'ROLLNUMBER1_Q8' : 'ROLLNUMBER1 Q8',
    'ROLLNUMBER1_Q9' : 'ROLLNUMBER1 Q9',
    'ROLLNUMBER1_QTEN' : 'ROLLNUMBER1 Q10',    
    'ROLLNUMBERID2' : 'ROLLNUMBERID2',
    'ROLLNUMBER2_Q1' : 'ROLLNUMBER2 Q1',
    'ROLLNUMBER2_Q2' : 'ROLLNUMBER2 Q2',
    'ROLLNUMBER2_Q3' : 'ROLLNUMBER2 Q3',
    'ROLLNUMBER2_Q4' : 'ROLLNUMBER2 Q4',
    'ROLLNUMBER2_Q5' : 'ROLLNUMBER2 Q5',
    'ROLLNUMBER2_Q6' : 'ROLLNUMBER2 Q6',
    'ROLLNUMBER2_Q7' : 'ROLLNUMBER2 Q7',
    'ROLLNUMBER2_Q8' : 'ROLLNUMBER2 Q8',
    'ROLLNUMBER2_Q9' : 'ROLLNUMBER2 Q9',
    'ROLLNUMBER2_QTEN' : 'ROLLNUMBER2 Q10',    
    'ROLLNUMBERID3' : 'ROLLNUMBERID3',
    'ROLLNUMBER3_Q1' : 'ROLLNUMBER3 Q1',
    'ROLLNUMBER3_Q2' : 'ROLLNUMBER3 Q2',
    'ROLLNUMBER3_Q3' : 'ROLLNUMBER3 Q3',
    'ROLLNUMBER3_Q4' : 'ROLLNUMBER3 Q4',
    'ROLLNUMBER3_Q5' : 'ROLLNUMBER3 Q5',
    'ROLLNUMBER3_Q6' : 'ROLLNUMBER3 Q6',
    'ROLLNUMBER3_Q7' : 'ROLLNUMBER3 Q7',
    'ROLLNUMBER3_Q8' : 'ROLLNUMBER3 Q8',
    'ROLLNUMBER3_Q9' : 'ROLLNUMBER3 Q9',
    'ROLLNUMBER3_QTEN' : 'ROLLNUMBER3 Q10',    
    'ROLLNUMBERID4' : 'ROLLNUMBERID4',
    'ROLLNUMBER4_Q1' : 'ROLLNUMBER4 Q1',
    'ROLLNUMBER4_Q2' : 'ROLLNUMBER4 Q2',
    'ROLLNUMBER4_Q3' : 'ROLLNUMBER4 Q3',
    'ROLLNUMBER4_Q4' : 'ROLLNUMBER4 Q4',
    'ROLLNUMBER4_Q5' : 'ROLLNUMBER4 Q5',
    'ROLLNUMBER4_Q6' : 'ROLLNUMBER4 Q6',
    'ROLLNUMBER4_Q7' : 'ROLLNUMBER4 Q7',
    'ROLLNUMBER4_Q8' : 'ROLLNUMBER4 Q8',
    'ROLLNUMBER4_Q9' : 'ROLLNUMBER4 Q9',
    'ROLLNUMBER4_QTEN' : 'ROLLNUMBER4 Q10',    
    'ROLLNUMBERID5' : 'ROLLNUMBERID5',
    'ROLLNUMBER5_Q1' : 'ROLLNUMBER5 Q1',
    'ROLLNUMBER5_Q2' : 'ROLLNUMBER5 Q2',
    'ROLLNUMBER5_Q3' : 'ROLLNUMBER5 Q3',
    'ROLLNUMBER5_Q4' : 'ROLLNUMBER5 Q4',
    'ROLLNUMBER5_Q5' : 'ROLLNUMBER5 Q5',
    'ROLLNUMBER5_Q6' : 'ROLLNUMBER5 Q6',
    'ROLLNUMBER5_Q7' : 'ROLLNUMBER5 Q7',
    'ROLLNUMBER5_Q8' : 'ROLLNUMBER5 Q8',
    'ROLLNUMBER5_Q9' : 'ROLLNUMBER5 Q9',
    'ROLLNUMBER5_QTEN' : 'ROLLNUMBER5 Q10',    
    'ROLLNUMBERID6' : 'ROLLNUMBERID6',
    'ROLLNUMBER6_Q1' : 'ROLLNUMBER6 Q1',
    'ROLLNUMBER6_Q2' : 'ROLLNUMBER6 Q2',
    'ROLLNUMBER6_Q3' : 'ROLLNUMBER6 Q3',
    'ROLLNUMBER6_Q4' : 'ROLLNUMBER6 Q4',
    'ROLLNUMBER6_Q5' : 'ROLLNUMBER6 Q5',
    'ROLLNUMBER6_Q6' : 'ROLLNUMBER6 Q6',
    'ROLLNUMBER6_Q7' : 'ROLLNUMBER6 Q7',
    'ROLLNUMBER6_Q8' : 'ROLLNUMBER6 Q8',
    'ROLLNUMBER6_Q9' : 'ROLLNUMBER6 Q9',
    'ROLLNUMBER6_QTEN' : 'ROLLNUMBER6 Q10',    
    'ROLLNUMBERID7' : 'ROLLNUMBERID7',
    'ROLLNUMBER7_Q1' : 'ROLLNUMBER7 Q1',
    'ROLLNUMBER7_Q2' : 'ROLLNUMBER7 Q2',
    'ROLLNUMBER7_Q3' : 'ROLLNUMBER7 Q3',
    'ROLLNUMBER7_Q4' : 'ROLLNUMBER7 Q4',
    'ROLLNUMBER7_Q5' : 'ROLLNUMBER7 Q5',
    'ROLLNUMBER7_Q6' : 'ROLLNUMBER7 Q6',
    'ROLLNUMBER7_Q7' : 'ROLLNUMBER7 Q7',
    'ROLLNUMBER7_Q8' : 'ROLLNUMBER7 Q8',
    'ROLLNUMBER7_Q9' : 'ROLLNUMBER7 Q9',
    'ROLLNUMBER7_QTEN' : 'ROLLNUMBER7 Q10',    
    'ROLLNUMBERID8' : 'ROLLNUMBERID8',
    'ROLLNUMBER8_Q1' : 'ROLLNUMBER8 Q1',
    'ROLLNUMBER8_Q2' : 'ROLLNUMBER8 Q2',
    'ROLLNUMBER8_Q3' : 'ROLLNUMBER8 Q3',
    'ROLLNUMBER8_Q4' : 'ROLLNUMBER8 Q4',
    'ROLLNUMBER8_Q5' : 'ROLLNUMBER8 Q5',
    'ROLLNUMBER8_Q6' : 'ROLLNUMBER8 Q6',
    'ROLLNUMBER8_Q7' : 'ROLLNUMBER8 Q7',
    'ROLLNUMBER8_Q8' : 'ROLLNUMBER8 Q8',
    'ROLLNUMBER8_Q9' : 'ROLLNUMBER8 Q9',
    'ROLLNUMBER8_QTEN' : 'ROLLNUMBER8 Q10',
    'ROLLNUMBERID9' : 'ROLLNUMBERID9',
    'ROLLNUMBER9_Q1' : 'ROLLNUMBER9 Q1',
    'ROLLNUMBER9_Q2' : 'ROLLNUMBER9 Q2',
    'ROLLNUMBER9_Q3' : 'ROLLNUMBER9 Q3',
    'ROLLNUMBER9_Q4' : 'ROLLNUMBER9 Q4',
    'ROLLNUMBER9_Q5' : 'ROLLNUMBER9 Q5',
    'ROLLNUMBER9_Q6' : 'ROLLNUMBER9 Q6',
    'ROLLNUMBER9_Q7' : 'ROLLNUMBER9 Q7',
    'ROLLNUMBER9_Q8' : 'ROLLNUMBER9 Q8',
    'ROLLNUMBER9_Q9' : 'ROLLNUMBER9 Q9',
    'ROLLNUMBER9_QTEN' : 'ROLLNUMBER9 Q10',
    'ROLLNUMBERIDTEN' : 'ROLLNUMBERID10',
    'ROLLNUMBERTEN_Q1' : 'ROLLNUMBER10 Q1',
    'ROLLNUMBERTEN_Q2' : 'ROLLNUMBER10 Q2',
    'ROLLNUMBERTEN_Q3' : 'ROLLNUMBER10 Q3',
    'ROLLNUMBERTEN_Q4' : 'ROLLNUMBER10 Q4',
    'ROLLNUMBERTEN_Q5' : 'ROLLNUMBER10 Q5',
    'ROLLNUMBERTEN_Q6' : 'ROLLNUMBER10 Q6',
    'ROLLNUMBERTEN_Q7' : 'ROLLNUMBER10 Q7',
    'ROLLNUMBERTEN_Q8' : 'ROLLNUMBER10 Q8',
    'ROLLNUMBERTEN_Q9' : 'ROLLNUMBER10 Q9',
    'ROLLNUMBERTEN_QTEN' : 'ROLLNUMBER10 Q10',
    
}

formatNameLookup = {
    'ROLLNUMBERID1_TEN' : 'ROLLNUMBERID1_10',
    'ROLLNUMBERID1_ELE' : 'ROLLNUMBERID1_11',
    'ROLLNUMBER1_Q1' : 'ROLLNUMBER1_Q1',
    'ROLLNUMBER1_Q2' : 'ROLLNUMBER1_Q2',
    'ROLLNUMBER1_Q3' : 'ROLLNUMBER1_Q3',
    'ROLLNUMBER1_Q4' : 'ROLLNUMBER1_Q4',
    'ROLLNUMBER1_Q5' : 'ROLLNUMBER1_Q5',
    'ROLLNUMBER1_Q6' : 'ROLLNUMBER1_Q6',
    'ROLLNUMBER1_Q7' : 'ROLLNUMBER1_Q7',
    'ROLLNUMBER1_Q8' : 'ROLLNUMBER1_Q8',
    'ROLLNUMBER1_Q9' : 'ROLLNUMBER1_Q9',
    'ROLLNUMBER1_QTEN' : 'ROLLNUMBER1_Q10',    
    'ROLLNUMBERID2_TEN' : 'ROLLNUMBERID2_10',
    'ROLLNUMBERID2_ELE' : 'ROLLNUMBERID2_11',
    'ROLLNUMBER2_Q1' : 'ROLLNUMBER2_Q1',
    'ROLLNUMBER2_Q2' : 'ROLLNUMBER2_Q2',
    'ROLLNUMBER2_Q3' : 'ROLLNUMBER2_Q3',
    'ROLLNUMBER2_Q4' : 'ROLLNUMBER2_Q4',
    'ROLLNUMBER2_Q5' : 'ROLLNUMBER2_Q5',
    'ROLLNUMBER2_Q6' : 'ROLLNUMBER2_Q6',
    'ROLLNUMBER2_Q7' : 'ROLLNUMBER2_Q7',
    'ROLLNUMBER2_Q8' : 'ROLLNUMBER2_Q8',
    'ROLLNUMBER2_Q9' : 'ROLLNUMBER2_Q9',
    'ROLLNUMBER2_QTEN' : 'ROLLNUMBER2_Q10', 
    'ROLLNUMBERID3_TEN' : 'ROLLNUMBERID3_10',
    'ROLLNUMBERID3_ELE' : 'ROLLNUMBERID3_11',
    'ROLLNUMBER3_Q1' : 'ROLLNUMBER3_Q1',
    'ROLLNUMBER3_Q2' : 'ROLLNUMBER3_Q2',
    'ROLLNUMBER3_Q3' : 'ROLLNUMBER3_Q3',
    'ROLLNUMBER3_Q4' : 'ROLLNUMBER3_Q4',
    'ROLLNUMBER3_Q5' : 'ROLLNUMBER3_Q5',
    'ROLLNUMBER3_Q6' : 'ROLLNUMBER3_Q6',
    'ROLLNUMBER3_Q7' : 'ROLLNUMBER3_Q7',
    'ROLLNUMBER3_Q8' : 'ROLLNUMBER3_Q8',
    'ROLLNUMBER3_Q9' : 'ROLLNUMBER3_Q9',
    'ROLLNUMBER3_QTEN' : 'ROLLNUMBER3_Q10',   
    'ROLLNUMBERID4_TEN' : 'ROLLNUMBERID4_10',
    'ROLLNUMBERID4_ELE' : 'ROLLNUMBERID4_11',
    'ROLLNUMBER4_Q1' : 'ROLLNUMBER4_Q1',
    'ROLLNUMBER4_Q2' : 'ROLLNUMBER4_Q2',
    'ROLLNUMBER4_Q3' : 'ROLLNUMBER4_Q3',
    'ROLLNUMBER4_Q4' : 'ROLLNUMBER4_Q4',
    'ROLLNUMBER4_Q5' : 'ROLLNUMBER4_Q5',
    'ROLLNUMBER4_Q6' : 'ROLLNUMBER4_Q6',
    'ROLLNUMBER4_Q7' : 'ROLLNUMBER4_Q7',
    'ROLLNUMBER4_Q8' : 'ROLLNUMBER4_Q8',
    'ROLLNUMBER4_Q9' : 'ROLLNUMBER4_Q9',
    'ROLLNUMBER4_QTEN' : 'ROLLNUMBER4_Q10',
    'ROLLNUMBERID5_TEN' : 'ROLLNUMBERID5_10',
    'ROLLNUMBERID5_ELE' : 'ROLLNUMBERID5_11',
    'ROLLNUMBER5_Q1' : 'ROLLNUMBER5_Q1',
    'ROLLNUMBER5_Q2' : 'ROLLNUMBER5_Q2',
    'ROLLNUMBER5_Q3' : 'ROLLNUMBER5_Q3',
    'ROLLNUMBER5_Q4' : 'ROLLNUMBER5_Q4',
    'ROLLNUMBER5_Q5' : 'ROLLNUMBER5_Q5',
    'ROLLNUMBER5_Q6' : 'ROLLNUMBER5_Q6',
    'ROLLNUMBER5_Q7' : 'ROLLNUMBER5_Q7',
    'ROLLNUMBER5_Q8' : 'ROLLNUMBER5_Q8',
    'ROLLNUMBER5_Q9' : 'ROLLNUMBER5_Q9',
    'ROLLNUMBER5_QTEN' : 'ROLLNUMBER5_Q10',
    'ROLLNUMBER6_Q1' : 'ROLLNUMBER6_Q1',
    'ROLLNUMBER6_Q2' : 'ROLLNUMBER6_Q2',
    'ROLLNUMBER6_Q3' : 'ROLLNUMBER6_Q3',
    'ROLLNUMBER6_Q4' : 'ROLLNUMBER6_Q4',
    'ROLLNUMBER6_Q5' : 'ROLLNUMBER6_Q5',
    'ROLLNUMBER6_Q6' : 'ROLLNUMBER6_Q6',
    'ROLLNUMBER6_Q7' : 'ROLLNUMBER6_Q7',
    'ROLLNUMBER6_Q8' : 'ROLLNUMBER6_Q8',
    'ROLLNUMBER6_Q9' : 'ROLLNUMBER6_Q9',
    'ROLLNUMBER6_QTEN' : 'ROLLNUMBER6_Q10',
    'ROLLNUMBER7_Q1' : 'ROLLNUMBER7_Q1',
    'ROLLNUMBER7_Q2' : 'ROLLNUMBER7_Q2',
    'ROLLNUMBER7_Q3' : 'ROLLNUMBER7_Q3',
    'ROLLNUMBER7_Q4' : 'ROLLNUMBER7_Q4',
    'ROLLNUMBER7_Q5' : 'ROLLNUMBER7_Q5',
    'ROLLNUMBER7_Q6' : 'ROLLNUMBER7_Q6',
    'ROLLNUMBER7_Q7' : 'ROLLNUMBER7_Q7',
    'ROLLNUMBER7_Q8' : 'ROLLNUMBER7_Q8',
    'ROLLNUMBER7_Q9' : 'ROLLNUMBER7_Q9',
    'ROLLNUMBER7_QTEN' : 'ROLLNUMBER7_Q10',
    'ROLLNUMBER8_Q1' : 'ROLLNUMBER8_Q1',
    'ROLLNUMBER8_Q2' : 'ROLLNUMBER8_Q2',
    'ROLLNUMBER8_Q3' : 'ROLLNUMBER8_Q3',
    'ROLLNUMBER8_Q4' : 'ROLLNUMBER8_Q4',
    'ROLLNUMBER8_Q5' : 'ROLLNUMBER8_Q5',
    'ROLLNUMBER8_Q6' : 'ROLLNUMBER8_Q6',
    'ROLLNUMBER8_Q7' : 'ROLLNUMBER8_Q7',
    'ROLLNUMBER8_Q8' : 'ROLLNUMBER8_Q8',
    'ROLLNUMBER8_Q9' : 'ROLLNUMBER8_Q9',
    'ROLLNUMBER8_QTEN' : 'ROLLNUMBER8_Q10',
    'ROLLNUMBER9_Q1' : 'ROLLNUMBER9_Q1',
    'ROLLNUMBER9_Q2' : 'ROLLNUMBER9_Q2',
    'ROLLNUMBER9_Q3' : 'ROLLNUMBER9_Q3',
    'ROLLNUMBER9_Q4' : 'ROLLNUMBER9_Q4',
    'ROLLNUMBER9_Q5' : 'ROLLNUMBER9_Q5',
    'ROLLNUMBER9_Q6' : 'ROLLNUMBER9_Q6',
    'ROLLNUMBER9_Q7' : 'ROLLNUMBER9_Q7',
    'ROLLNUMBER9_Q8' : 'ROLLNUMBER9_Q8',
    'ROLLNUMBER9_Q9' : 'ROLLNUMBER9_Q9',
    'ROLLNUMBER9_QTEN' : 'ROLLNUMBER9_Q10',
    'ROLLNUMBERIDTEN' : 'ROLLNUMBERID10',
    'ROLLNUMBERTEN_Q1' : 'ROLLNUMBER10_Q1',
    'ROLLNUMBERTEN_Q2' : 'ROLLNUMBER10_Q2',
    'ROLLNUMBERTEN_Q3' : 'ROLLNUMBER10_Q3',
    'ROLLNUMBERTEN_Q4' : 'ROLLNUMBER10_Q4',
    'ROLLNUMBERTEN_Q5' : 'ROLLNUMBER10_Q5',
    'ROLLNUMBERTEN_Q6' : 'ROLLNUMBER10_Q6',
    'ROLLNUMBERTEN_Q7' : 'ROLLNUMBER10_Q7',
    'ROLLNUMBERTEN_Q8' : 'ROLLNUMBER10_Q8',
    'ROLLNUMBERTEN_Q9' : 'ROLLNUMBER10_Q9',
    'ROLLNUMBERTEN_QTEN' : 'ROLLNUMBER10_Q10'
    
}

formatAnnotationTagLookup = {
    'ROLLNUMBERID1_TEN': 'ROLLNUMBERID1_10',
    'ROLLNUMBERID1_ELE': 'ROLLNUMBERID1_11',
    'ROLLNUMBERID2_TEN': 'ROLLNUMBERID2_10',
    'ROLLNUMBERID2_ELE': 'ROLLNUMBERID2_11',
    'ROLLNUMBERID3_TEN': 'ROLLNUMBERID3_10',
    'ROLLNUMBERID3_ELE': 'ROLLNUMBERID3_11',
    'ROLLNUMBERID4_TEN': 'ROLLNUMBERID4_10',
    'ROLLNUMBERID4_ELE': 'ROLLNUMBERID4_11',
    'ROLLNUMBERID5_TEN': 'ROLLNUMBERID5_10',
    'ROLLNUMBERID5_ELE': 'ROLLNUMBERID5_11',
    'ROLLNUMBERID6_TEN': 'ROLLNUMBERID6_10',
    'ROLLNUMBERID6_ELE': 'ROLLNUMBERID6_11',
    'ROLLNUMBERID7_TEN': 'ROLLNUMBERID7_10',
    'ROLLNUMBERID7_ELE': 'ROLLNUMBERID7_11',
    'ROLLNUMBERID8_TEN': 'ROLLNUMBERID8_10',
    'ROLLNUMBERID8_ELE': 'ROLLNUMBERID8_11',
    'ROLLNUMBERID9_TEN': 'ROLLNUMBERID9_10',
    'ROLLNUMBERID9_ELE': 'ROLLNUMBERID9_11',
    'ROLLNUMBERIDTEN_TEN': 'ROLLNUMBERID10_10',
    'ROLLNUMBERIDTEN_ELE': 'ROLLNUMBERID10_11',
    'ROLLNUMBER1_QTEN' : 'ROLLNUMBER1_Q10',
    'ROLLNUMBER2_QTEN' : 'ROLLNUMBER2_Q10',
    'ROLLNUMBER3_QTEN' : 'ROLLNUMBER3_Q10',
    'ROLLNUMBER4_QTEN' : 'ROLLNUMBER4_Q10',
    'ROLLNUMBER5_QTEN' : 'ROLLNUMBER5_Q10',
    'ROLLNUMBER6_QTEN' : 'ROLLNUMBER6_Q10',
    'ROLLNUMBER7_QTEN' : 'ROLLNUMBER7_Q10',
    'ROLLNUMBER8_QTEN' : 'ROLLNUMBER8_Q10',
    'ROLLNUMBER9_QTEN' : 'ROLLNUMBER9_Q10',
    'ROLLNUMBERIDTEN_3': 'ROLLNUMBERID10_3 ',
    'ROLLNUMBERIDTEN_4': 'ROLLNUMBERID10_4',
    'ROLLNUMBERIDTEN_5': 'ROLLNUMBERID10_5',
    'ROLLNUMBERIDTEN_6': 'ROLLNUMBERID10_6',
    'ROLLNUMBERIDTEN_7': 'ROLLNUMBERID10_7',
    'ROLLNUMBERTEN_Q1': 'ROLLNUMBER10_Q1',
    'ROLLNUMBERTEN_Q2': 'ROLLNUMBER10_Q2',
    'ROLLNUMBERTEN_Q3': 'ROLLNUMBER10_Q3',
    'ROLLNUMBERTEN_Q4': 'ROLLNUMBER10_Q4',
    'ROLLNUMBERTEN_Q5': 'ROLLNUMBER10_Q5',
    'ROLLNUMBERTEN_Q6': 'ROLLNUMBER10_Q6',
    'ROLLNUMBERTEN_Q7': 'ROLLNUMBER10_Q7',
    'ROLLNUMBERTEN_Q8': 'ROLLNUMBER10_Q8',
    'ROLLNUMBERTEN_Q9': 'ROLLNUMBER10_Q9',
    'ROLLNUMBERTEN_QTEN': 'ROLLNUMBER10_Q10',
    'ROLLNUMBERIDTEN_1': 'ROLLNUMBERID10_1',
    'ROLLNUMBERIDTEN_2': 'ROLLNUMBERID10_2',
    'ROLLNUMBERIDTEN_9': 'ROLLNUMBERID10_9',
    'ROLLNUMBERIDTEN_8': 'ROLLNUMBERID10_8'
}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "ANY10S10Q11DOMR Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 100,
#                             "left": 56,
#                             "bottom": 122,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
