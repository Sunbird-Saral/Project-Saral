# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatNameLookup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                 extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                 extractionValue = "CELL_OMR"
                    
            try:
                annotationTagsValue = formatNameLookup[region['tags'][0]]
            except KeyError as ke:
                 annotationTagsValue =  region['tags'][0]
    

            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue =  str(tagGroup)
                 
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
                    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatNameLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "HINDI3S30QOMR Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("HINDI3S30Q_vottraw.json")

# %%
tagGroups = []
for i in range(1,4):
  tagGroups.append("ROLLNUMBERID"+str(i))
  for j in ["ONE","TWO","THREE","FOUR","FIVE","SIX","SEVEN","EIGHT","NINE","TEN","ELEVEN","TWL","THRTN","FORTN","FIFT","SXTN","SVNTN","EGTN","NINT","TWENTY","TWENONE","TWENTWO","TWENTHREE","TWENFOUR","TWENFIVE","TWENSIX","TWENSEVEN","TWENEIGHT","TWENNINE","THIRTY"]:
    tagGroups.append("ROLLNUMBER"+str(i)+"_Q"+str(j))
    
formatLookup= { 
    'ROLLNUMBERID1': 'छात्र आईडी1',
    'ROLLNUMBER1_QONE': 'छात्र आईडी1 Q1 ',
    'ROLLNUMBER1_QTWO': 'छात्र आईडी1 Q2',
    'ROLLNUMBER1_QTHREE': 'छात्र आईडी1 Q3 ',
    'ROLLNUMBER1_QFOUR': 'छात्र आईडी1 Q4',
    'ROLLNUMBER1_QFIVE': 'छात्र आईडी1 Q5',
    'ROLLNUMBER1_QSIX': 'छात्र आईडी1 Q6',
    'ROLLNUMBER1_QSEVEN': 'छात्र आईडी1 Q7',
    'ROLLNUMBER1_QEIGHT': 'छात्र आईडी1 Q8',
    'ROLLNUMBER1_QNINE': 'छात्र आईडी1 Q9',
    'ROLLNUMBER1_QTEN': 'छात्र आईडी1 Q10',
    'ROLLNUMBER1_QELEVEN': 'छात्र आईडी1 Q11',
    'ROLLNUMBER1_QTWL': 'छात्र आईडी1 Q12',
    'ROLLNUMBER1_QTHRTN': 'छात्र आईडी1 Q13',
    'ROLLNUMBER1_QFORTN': 'छात्र आईडी1 Q14 ',
    'ROLLNUMBER1_QFIFT': 'छात्र आईडी1 Q15',
    'ROLLNUMBER1_QSXTN': 'छात्र आईडी1 Q16',
    'ROLLNUMBER1_QSVNTN': 'छात्र आईडी1 Q17',
    'ROLLNUMBER1_QEGTN': 'छात्र आईडी1 Q18',
    'ROLLNUMBER1_QNINT': 'छात्र आईडी1 Q19',
    'ROLLNUMBER1_QTWENTY': 'छात्र आईडी1 Q20',
    'ROLLNUMBER1_QTWENONE': 'छात्र आईडी1 Q21',
    'ROLLNUMBER1_QTWENTWO': 'छात्र आईडी1 Q22',
    'ROLLNUMBER1_QTWENTHREE': 'छात्र आईडी1 Q23',
    'ROLLNUMBER1_QTWENFOUR': 'छात्र आईडी1 Q24',
    'ROLLNUMBER1_QTWENFIVE': 'छात्र आईडी1 Q25',
    'ROLLNUMBER1_QTWENSIX':  'छात्र आईडी1 Q26',
    'ROLLNUMBER1_QTWENSEVEN': 'छात्र आईडी1 Q27',
    'ROLLNUMBER1_QTWENEIGHT': 'छात्र आईडी1 Q28',
    'ROLLNUMBER1_QTWENNINE': 'छात्र आईडी1 Q29',
    'ROLLNUMBER1_QTHIRTY': 'छात्र आईडी1 Q30',
    'ROLLNUMBERID2': 'छात्र आईडी2',
    'ROLLNUMBER2_QONE': 'छात्र आईडी2 Q1',
    'ROLLNUMBER2_QTWO': 'छात्र आईडी2 Q2',
    'ROLLNUMBER2_QTHREE': 'छात्र आईडी2 Q3',
    'ROLLNUMBER2_QFOUR': 'छात्र आईडी2 Q4',
    'ROLLNUMBER2_QFIVE': 'छात्र आईडी2 Q5',
    'ROLLNUMBER2_QSIX': 'छात्र आईडी2 Q6',
    'ROLLNUMBER2_QSEVEN': 'छात्र आईडी2 Q7',
    'ROLLNUMBER2_QEIGHT': 'छात्र आईडी2 Q8',
    'ROLLNUMBER2_QNINE': 'छात्र आईडी2 Q9',
    'ROLLNUMBER2_QTEN': 'छात्र आईडी2 Q10',
    'ROLLNUMBER2_QELEVEN': 'छात्र आईडी2 Q11',
    'ROLLNUMBER2_QTWL': 'छात्र आईडी2 Q12',
    'ROLLNUMBER2_QTHRTN': 'छात्र आईडी2 Q13',
    'ROLLNUMBER2_QFORTN': 'छात्र आईडी2 Q14 ',
    'ROLLNUMBER2_QFIFT': 'छात्र आईडी2 Q15',
    'ROLLNUMBER2_QSXTN': 'छात्र आईडी2 Q16',
    'ROLLNUMBER2_QSVNTN': 'छात्र आईडी2 Q17',
    'ROLLNUMBER2_QEGTN': 'छात्र आईडी2 Q18',
    'ROLLNUMBER2_QNINT': 'छात्र आईडी2 Q19',
    'ROLLNUMBER2_QTWENTY': 'छात्र आईडी2 Q20',
    'ROLLNUMBER2_QTWENONE': 'छात्र आईडी2 Q21',
    'ROLLNUMBER2_QTWENTWO': 'छात्र आईडी2 Q22',
    'ROLLNUMBER2_QTWENTHREE': 'छात्र आईडी2 Q23',
    'ROLLNUMBER2_QTWENFOUR': 'छात्र आईडी2 Q24',
    'ROLLNUMBER2_QTWENFIVE': 'छात्र आईडी2 Q25',
    'ROLLNUMBER2_QTWENSIX':  'छात्र आईडी2 Q26',
    'ROLLNUMBER2_QTWENSEVEN': 'छात्र आईडी2 Q27',
    'ROLLNUMBER2_QTWENEIGHT': 'छात्र आईडी2 Q28',
    'ROLLNUMBER2_QTWENNINE': 'छात्र आईडी2 Q29',
    'ROLLNUMBER2_QTHIRTY': 'छात्र आईडी2 Q30',
    'ROLLNUMBERID3': 'छात्र आईडी3',
    'ROLLNUMBER3_QONE': 'छात्र आईडी3 Q1',
    'ROLLNUMBER3_QTWO': 'छात्र आईडी3 Q2',
    'ROLLNUMBER3_QTHREE': 'छात्र आईडी3 Q3',
    'ROLLNUMBER3_QFOUR': 'छात्र आईडी3 Q4',
    'ROLLNUMBER3_QFIVE': 'छात्र आईडी3 Q5',
    'ROLLNUMBER3_QSIX': 'छात्र आईडी3 Q6',
    'ROLLNUMBER3_QSEVEN': 'छात्र आईडी3 Q7',
    'ROLLNUMBER3_QEIGHT': 'छात्र आईडी3 Q8',
    'ROLLNUMBER3_QNINE': 'छात्र आईडी3 Q9',
    'ROLLNUMBER3_QTEN': 'छात्र आईडी3 Q10',
    'ROLLNUMBER3_QELEVEN': 'छात्र आईडी3 Q11',
    'ROLLNUMBER3_QTWL': 'छात्र आईडी3 Q12',
    'ROLLNUMBER3_QTHRTN': 'छात्र आईडी3 Q13',
    'ROLLNUMBER3_QFORTN': 'छात्र आईडी3 Q14 ',
    'ROLLNUMBER3_QFIFT': 'छात्र आईडी3 Q15',
    'ROLLNUMBER3_QSXTN': 'छात्र आईडी3 Q16',
    'ROLLNUMBER3_QSVNTN': 'छात्र आईडी3 Q17',
    'ROLLNUMBER3_QEGTN': 'छात्र आईडी3 Q18',
    'ROLLNUMBER3_QNINT': 'छात्र आईडी3 Q19',
    'ROLLNUMBER3_QTWENTY': 'छात्र आईडी3 Q20',
    'ROLLNUMBER3_QTWENONE': 'छात्र आईडी3 Q21',
    'ROLLNUMBER3_QTWENTWO': 'छात्र आईडी3 Q22',
    'ROLLNUMBER3_QTWENTHREE': 'छात्र आईडी3 Q23',
    'ROLLNUMBER3_QTWENFOUR': 'छात्र आईडी3 Q24',
    'ROLLNUMBER3_QTWENFIVE': 'छात्र आईडी3 Q25',
    'ROLLNUMBER3_QTWENSIX':  'छात्र आईडी3 Q26',
    'ROLLNUMBER3_QTWENSEVEN': 'छात्र आईडी3 Q27',
    'ROLLNUMBER3_QTWENEIGHT': 'छात्र आईडी3 Q28',
    'ROLLNUMBER3_QTWENNINE': 'छात्र आईडी3 Q29',
    'ROLLNUMBER3_QTHIRTY': 'छात्र आईडी3 Q30'
}

formatNameLookup= { 
'ROLLNUMBER1_QONE': 'ROLLNUMBER1_Q1 ',
'ROLLNUMBER1_QTWO': 'ROLLNUMBER1_Q2',
'ROLLNUMBER1_QTHREE': 'ROLLNUMBER1_Q3 ',
'ROLLNUMBER1_QFOUR': 'ROLLNUMBER1_Q4',
'ROLLNUMBER1_QFIVE': 'ROLLNUMBER1_Q5',
'ROLLNUMBER1_QSIX': 'ROLLNUMBER1_Q6',
'ROLLNUMBER1_QSEVEN': 'ROLLNUMBER1_Q7',
'ROLLNUMBER1_QEIGHT': 'ROLLNUMBER1_Q8',
'ROLLNUMBER1_QNINE': 'ROLLNUMBER1_Q9',
'ROLLNUMBER1_QTEN': 'ROLLNUMBER1_Q10',
'ROLLNUMBER1_QELEVEN': 'ROLLNUMBER1_Q11',
'ROLLNUMBER1_QTWL': 'ROLLNUMBER1_Q12',
'ROLLNUMBER1_QTHRTN': 'ROLLNUMBER1_Q13',
'ROLLNUMBER1_QFORTN': 'ROLLNUMBER1_Q14 ',
'ROLLNUMBER1_QFIFT': 'ROLLNUMBER1_Q15',
'ROLLNUMBER1_QSXTN': 'ROLLNUMBER1_Q16',
'ROLLNUMBER1_QSVNTN': 'ROLLNUMBER1_Q17',
'ROLLNUMBER1_QEGTN': 'ROLLNUMBER1_Q18',
'ROLLNUMBER1_QNINT': 'ROLLNUMBER1_Q19',
'ROLLNUMBER1_QTWENTY': 'ROLLNUMBER1_Q20',
'ROLLNUMBER1_QTWENONE': 'ROLLNUMBER1_Q21',
'ROLLNUMBER1_QTWENTWO': 'ROLLNUMBER1_Q22',
'ROLLNUMBER1_QTWENTHREE': 'ROLLNUMBER1_Q23',
'ROLLNUMBER1_QTWENFOUR': 'ROLLNUMBER1_Q24',
'ROLLNUMBER1_QTWENFIVE': 'ROLLNUMBER1_Q25',
'ROLLNUMBER1_QTWENSIX':  'ROLLNUMBER1_Q26',
'ROLLNUMBER1_QTWENSEVEN': 'ROLLNUMBER1_Q27',
'ROLLNUMBER1_QTWENEIGHT': 'ROLLNUMBER1_Q28',
'ROLLNUMBER1_QTWENNINE': 'ROLLNUMBER1_Q29',
'ROLLNUMBER1_QTHIRTY': 'ROLLNUMBER1_Q30',
'ROLLNUMBER2_QONE': 'ROLLNUMBER2_Q1',
'ROLLNUMBER2_QTWO': 'ROLLNUMBER2_Q2',
'ROLLNUMBER2_QTHREE': 'ROLLNUMBER2_Q3',
'ROLLNUMBER2_QFOUR': 'ROLLNUMBER2_Q4',
'ROLLNUMBER2_QFIVE': 'ROLLNUMBER2_Q5',
'ROLLNUMBER2_QSIX': 'ROLLNUMBER2_Q6',
'ROLLNUMBER2_QSEVEN': 'ROLLNUMBER2_Q7',
'ROLLNUMBER2_QEIGHT': 'ROLLNUMBER2_Q8',
'ROLLNUMBER2_QNINE': 'ROLLNUMBER2_Q9',
'ROLLNUMBER2_QTEN': 'ROLLNUMBER2_Q10',
'ROLLNUMBER2_QELEVEN': 'ROLLNUMBER2_Q11',
'ROLLNUMBER2_QTWL': 'ROLLNUMBER2_Q12',
'ROLLNUMBER2_QTHRTN': 'ROLLNUMBER2_Q13',
'ROLLNUMBER2_QFORTN': 'ROLLNUMBER2_Q14 ',
'ROLLNUMBER2_QFIFT': 'ROLLNUMBER2_Q15',
'ROLLNUMBER2_QSXTN': 'ROLLNUMBER2_Q16',
'ROLLNUMBER2_QSVNTN': 'ROLLNUMBER2_Q17',
'ROLLNUMBER2_QEGTN': 'ROLLNUMBER2_Q18',
'ROLLNUMBER2_QNINT': 'ROLLNUMBER2_Q19',
'ROLLNUMBER2_QTWENTY': 'ROLLNUMBER2_Q20',
'ROLLNUMBER2_QTWENONE': 'ROLLNUMBER2_Q21',
'ROLLNUMBER2_QTWENTWO': 'ROLLNUMBER2_Q22',
'ROLLNUMBER2_QTWENTHREE': 'ROLLNUMBER2_Q23',
'ROLLNUMBER2_QTWENFOUR': 'ROLLNUMBER2_Q24',
'ROLLNUMBER2_QTWENFIVE': 'ROLLNUMBER2_Q25',
'ROLLNUMBER2_QTWENSIX':  'ROLLNUMBER2_Q26',
'ROLLNUMBER2_QTWENSEVEN': 'ROLLNUMBER2_Q27',
'ROLLNUMBER2_QTWENEIGHT': 'ROLLNUMBER2_Q28',
'ROLLNUMBER2_QTWENNINE': 'ROLLNUMBER2_Q29',
'ROLLNUMBER2_QTHIRTY': 'ROLLNUMBER2_Q30',
'ROLLNUMBER3_QONE': 'ROLLNUMBER3_Q1',
'ROLLNUMBER3_QTWO': 'ROLLNUMBER3_Q2',
'ROLLNUMBER3_QTHREE': 'ROLLNUMBER3_Q3',
'ROLLNUMBER3_QFOUR': 'ROLLNUMBER3_Q4',
'ROLLNUMBER3_QFIVE': 'ROLLNUMBER3_Q5',
'ROLLNUMBER3_QSIX': 'ROLLNUMBER3_Q6',
'ROLLNUMBER3_QSEVEN': 'ROLLNUMBER3_Q7',
'ROLLNUMBER3_QEIGHT': 'ROLLNUMBER3_Q8',
'ROLLNUMBER3_QNINE': 'ROLLNUMBER3_Q9',
'ROLLNUMBER3_QTEN': 'ROLLNUMBER3_Q10',
'ROLLNUMBER3_QELEVEN': 'ROLLNUMBER3_Q11',
'ROLLNUMBER3_QTWL': 'ROLLNUMBER3_Q12',
'ROLLNUMBER3_QTHRTN': 'ROLLNUMBER3_Q13',
'ROLLNUMBER3_QFORTN': 'ROLLNUMBER3_Q14 ',
'ROLLNUMBER3_QFIFT': 'ROLLNUMBER3_Q15',
'ROLLNUMBER3_QSXTN': 'ROLLNUMBER3_Q16',
'ROLLNUMBER3_QSVNTN': 'ROLLNUMBER3_Q17',
'ROLLNUMBER3_QEGTN': 'ROLLNUMBER3_Q18',
'ROLLNUMBER3_QNINT': 'ROLLNUMBER3_Q19',
'ROLLNUMBER3_QTWENTY': 'ROLLNUMBER3_Q20',
'ROLLNUMBER3_QTWENONE': 'ROLLNUMBER3_Q21',
'ROLLNUMBER3_QTWENTWO': 'ROLLNUMBER3_Q22',
'ROLLNUMBER3_QTWENTHREE': 'ROLLNUMBER3_Q23',
'ROLLNUMBER3_QTWENFOUR': 'ROLLNUMBER3_Q24',
'ROLLNUMBER3_QTWENFIVE': 'ROLLNUMBER3_Q25',
'ROLLNUMBER3_QTWENSIX':  'ROLLNUMBER3_Q26',
'ROLLNUMBER3_QTWENSEVEN': 'ROLLNUMBER3_Q27',
'ROLLNUMBER3_QTWENEIGHT': 'ROLLNUMBER3_Q28',
'ROLLNUMBER3_QTWENNINE': 'ROLLNUMBER3_Q29',
'ROLLNUMBER3_QTHIRTY': 'ROLLNUMBER3_Q30'
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "HINDI3S30QOMR Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 138,
#                             "left": 54,
#                             "bottom": 164,
#                             "right": 69
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 138,
#                             "left": 72,
#                             "bottom": 164,
#                             "right": 88
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 138,
#                             "left": 89,
#                             "bottom": 164,
#                             "right": 104
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 138,
#                             "left": 105,
#                             "bottom": 164,
#                             "right": 121
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 138,
#                             "left": 121,
#                             "bottom": 165,
#                             "right": 135
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 137,
#                             "left": 138,
#                             "bottom": 165,
#                             "right": 151
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 138,
#                             "left": 154,
#                             "bottom": 165,
#                             "right": 169
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "ROLLNUMBERID1",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q1 ",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "8",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 184,
#                             "bottom": 115,
#                             "right": 199
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q1 ",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q1 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "9",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 220,
#                             "bottom": 115,
#                             "right": 236
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q2",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q3 ",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "10",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 255,
#                             "bottom": 115,
#                             "right": 269
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q3 ",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q3 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "11",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 288,
#                             "bottom": 115,
#                             "right": 303
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q4",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q5",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "12",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 322,
#                             "bottom": 115,
#                             "right": 337
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q5",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q6",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "13",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 356,
#                             "bottom": 116,
#                             "right": 373
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q6",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q7",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "14",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 390,
#                             "bottom": 115,
#                             "right": 408
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q7",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q8",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "15",
#                         "index": 0,
#                         "rect": {
#                             "top": 102,
#                             "left": 426,
#                             "bottom": 115,
#                             "right": 440
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q8",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q9",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "16",
#                         "index": 0,
#                         "rect": {
#                             "top": 100,
#                             "left": 460,
#                             "bottom": 115,
#                             "right": 474
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q9",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q10",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "17",
#                         "index": 0,
#                         "rect": {
#                             "top": 102,
#                             "left": 495,
#                             "bottom": 116,
#                             "right": 509
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q10",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q11",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "18",
#                         "index": 0,
#                         "rect": {
#                             "top": 100,
#                             "left": 529,
#                             "bottom": 115,
#                             "right": 546
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q11",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q12",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "19",
#                         "index": 0,
#                         "rect": {
#                             "top": 100,
#                             "left": 563,
#                             "bottom": 114,
#                             "right": 578
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q12",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "14",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q13",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "20",
#                         "index": 0,
#                         "rect": {
#                             "top": 101,
#                             "left": 599,
#                             "bottom": 114,
#                             "right": 613
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q13",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "15",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q14 ",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "21",
#                         "index": 0,
#                         "rect": {
#                             "top": 143,
#                             "left": 182,
#                             "bottom": 157,
#                             "right": 198
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q14 ",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q14 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "16",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q15",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "22",
#                         "index": 0,
#                         "rect": {
#                             "top": 144,
#                             "left": 219,
#                             "bottom": 158,
#                             "right": 233
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q15",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "17",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q16",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "23",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 254,
#                             "bottom": 157,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q16",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "18",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q17",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "24",
#                         "index": 0,
#                         "rect": {
#                             "top": 144,
#                             "left": 287,
#                             "bottom": 159,
#                             "right": 304
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q17",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "19",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q18",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "25",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 321,
#                             "bottom": 158,
#                             "right": 336
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q18",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "20",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_QNINTN",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "26",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 358,
#                             "bottom": 159,
#                             "right": 371
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q19",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "21",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q20",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "27",
#                         "index": 0,
#                         "rect": {
#                             "top": 144,
#                             "left": 392,
#                             "bottom": 159,
#                             "right": 406
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q20",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "22",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q21",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "28",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 426,
#                             "bottom": 159,
#                             "right": 439
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q21",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q21"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "23",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q22",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "29",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 459,
#                             "bottom": 158,
#                             "right": 474
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q22",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q22"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "24",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q23",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "30",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 495,
#                             "bottom": 157,
#                             "right": 509
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q23",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q23"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "25",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q24",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "31",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 529,
#                             "bottom": 158,
#                             "right": 543
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q24",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q24"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "26",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q25",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "32",
#                         "index": 0,
#                         "rect": {
#                             "top": 145,
#                             "left": 565,
#                             "bottom": 158,
#                             "right": 579
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q25",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q25"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "27",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q26",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "33",
#                         "index": 0,
#                         "rect": {
#                             "top": 144,
#                             "left": 597,
#                             "bottom": 157,
#                             "right": 613
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q26",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q26"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "28",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q27",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "34",
#                         "index": 0,
#                         "rect": {
#                             "top": 187,
#                             "left": 183,
#                             "bottom": 201,
#                             "right": 198
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 28
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q27",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q27"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "29",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q28",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "35",
#                         "index": 0,
#                         "rect": {
#                             "top": 187,
#                             "left": 218,
#                             "bottom": 201,
#                             "right": 235
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 29
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q28",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q28"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "30",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q29",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "36",
#                         "index": 0,
#                         "rect": {
#                             "top": 189,
#                             "left": 251,
#                             "bottom": 202,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 30
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q29",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q29"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "31",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_Q30",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "37",
#                         "index": 0,
#                         "rect": {
#                             "top": 187,
#                             "left": 287,
#                             "bottom": 201,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 31
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER1_Q30",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09401 Q30"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "32",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "38",
#                         "index": 0,
#                         "rect": {
#                             "top": 256,
#                             "left": 55,
#                             "bottom": 283,
#                             "right": 71
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "39",
#                         "index": 1,
#                         "rect": {
#                             "top": 256,
#                             "left": 72,
#                             "bottom": 282,
#                             "right": 87
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "40",
#                         "index": 2,
#                         "rect": {
#                             "top": 257,
#                             "left": 89,
#                             "bottom": 281,
#                             "right": 102
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "41",
#                         "index": 3,
#                         "rect": {
#                             "top": 257,
#                             "left": 105,
#                             "bottom": 282,
#                             "right": 120
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "42",
#                         "index": 4,
#                         "rect": {
#                             "top": 256,
#                             "left": 121,
#                             "bottom": 283,
#                             "right": 136
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "43",
#                         "index": 5,
#                         "rect": {
#                             "top": 256,
#                             "left": 137,
#                             "bottom": 282,
#                             "right": 153
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID2_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "44",
#                         "index": 6,
#                         "rect": {
#                             "top": 256,
#                             "left": 154,
#                             "bottom": 284,
#                             "right": 170
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 32
#                 },
#                 "format": {
#                     "name": "ROLLNUMBERID2",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "33",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q1",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "45",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 184,
#                             "bottom": 243,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 33
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q1",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "34",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q2",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "46",
#                         "index": 0,
#                         "rect": {
#                             "top": 231,
#                             "left": 221,
#                             "bottom": 243,
#                             "right": 234
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 34
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q2",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "35",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q3",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "47",
#                         "index": 0,
#                         "rect": {
#                             "top": 230,
#                             "left": 254,
#                             "bottom": 243,
#                             "right": 266
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 35
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q3",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "36",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q4",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "48",
#                         "index": 0,
#                         "rect": {
#                             "top": 230,
#                             "left": 287,
#                             "bottom": 244,
#                             "right": 301
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 36
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q4",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "37",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q5",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "49",
#                         "index": 0,
#                         "rect": {
#                             "top": 230,
#                             "left": 321,
#                             "bottom": 243,
#                             "right": 335
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 37
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q5",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "38",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q6",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "50",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 356,
#                             "bottom": 244,
#                             "right": 372
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 38
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q6",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "39",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q7",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "51",
#                         "index": 0,
#                         "rect": {
#                             "top": 230,
#                             "left": 391,
#                             "bottom": 244,
#                             "right": 406
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 39
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q7",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "40",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q8",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "52",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 425,
#                             "bottom": 243,
#                             "right": 439
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 40
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q8",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "41",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q9",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "53",
#                         "index": 0,
#                         "rect": {
#                             "top": 228,
#                             "left": 459,
#                             "bottom": 243,
#                             "right": 476
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 41
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q9",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "42",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q10",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "54",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 491,
#                             "bottom": 243,
#                             "right": 510
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 42
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q10",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "43",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q11",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "55",
#                         "index": 0,
#                         "rect": {
#                             "top": 228,
#                             "left": 527,
#                             "bottom": 244,
#                             "right": 544
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 43
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q11",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "44",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q12",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "56",
#                         "index": 0,
#                         "rect": {
#                             "top": 229,
#                             "left": 565,
#                             "bottom": 244,
#                             "right": 579
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 44
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q12",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "45",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q13",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "57",
#                         "index": 0,
#                         "rect": {
#                             "top": 230,
#                             "left": 599,
#                             "bottom": 243,
#                             "right": 615
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 45
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q13",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "46",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q14 ",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "58",
#                         "index": 0,
#                         "rect": {
#                             "top": 272,
#                             "left": 185,
#                             "bottom": 287,
#                             "right": 199
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 46
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER2_Q14 ",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09402 Q14 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "47",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER2_Q15",
#                         "extractionMethod": "CELL_OMR",
# ...
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 76
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q13",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "77",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q14 ",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "95",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 185,
#                             "bottom": 413,
#                             "right": 200
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 77
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q14 ",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q14 "
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "78",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q15",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "96",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 220,
#                             "bottom": 413,
#                             "right": 234
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 78
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q15",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "79",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q16",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "97",
#                         "index": 0,
#                         "rect": {
#                             "top": 399,
#                             "left": 254,
#                             "bottom": 413,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 79
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q16",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "80",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q17",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "98",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 288,
#                             "bottom": 413,
#                             "right": 302
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 80
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q17",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "81",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q18",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "99",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 323,
#                             "bottom": 413,
#                             "right": 336
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 81
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q18",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "82",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q19",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "100",
#                         "index": 0,
#                         "rect": {
#                             "top": 399,
#                             "left": 356,
#                             "bottom": 413,
#                             "right": 371
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 82
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q19",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "83",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q20",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "101",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 391,
#                             "bottom": 412,
#                             "right": 405
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 83
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q20",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "84",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q21",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "102",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 426,
#                             "bottom": 413,
#                             "right": 439
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 84
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q21",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q21"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "85",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q22",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "103",
#                         "index": 0,
#                         "rect": {
#                             "top": 399,
#                             "left": 460,
#                             "bottom": 413,
#                             "right": 474
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 85
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q22",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q22"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "86",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q23",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "104",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 496,
#                             "bottom": 413,
#                             "right": 509
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 86
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q23",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q23"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "87",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q24",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "105",
#                         "index": 0,
#                         "rect": {
#                             "top": 400,
#                             "left": 530,
#                             "bottom": 414,
#                             "right": 543
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 87
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q24",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q24"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "88",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q25",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "106",
#                         "index": 0,
#                         "rect": {
#                             "top": 399,
#                             "left": 565,
#                             "bottom": 413,
#                             "right": 579
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 88
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q25",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q25"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "89",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q26",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "107",
#                         "index": 0,
#                         "rect": {
#                             "top": 399,
#                             "left": 599,
#                             "bottom": 413,
#                             "right": 613
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 89
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q26",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q26"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "90",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q27",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "108",
#                         "index": 0,
#                         "rect": {
#                             "top": 442,
#                             "left": 184,
#                             "bottom": 455,
#                             "right": 198
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 90
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q27",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q27"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "91",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q28",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "109",
#                         "index": 0,
#                         "rect": {
#                             "top": 442,
#                             "left": 219,
#                             "bottom": 455,
#                             "right": 234
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 91
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q28",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q28"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "92",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q29",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "110",
#                         "index": 0,
#                         "rect": {
#                             "top": 441,
#                             "left": 254,
#                             "bottom": 455,
#                             "right": 268
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 92
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q29",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q29"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "93",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER3_Q30",
#                         "extractionMethod": "CELL_OMR",
#                         "roiId": "111",
#                         "index": 0,
#                         "rect": {
#                             "top": 441,
#                             "left": 286,
#                             "bottom": 455,
#                             "right": 303
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 93
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER3_Q30",
#                     "value": "\u091b\u093e\u0924\u094d\u0930 \u0906\u0908\u0921\u09403 Q30"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
