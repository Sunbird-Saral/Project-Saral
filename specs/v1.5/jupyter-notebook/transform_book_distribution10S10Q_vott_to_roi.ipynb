# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatNameLookup,formatAnnotationNameLookup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBERID"):
                 extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                 extractionValue = "CELL_OMR"
                    
                                            
            try:
                 annotationTagsValue = formatAnnotationNameLookup[region['tags'][0]]
            except KeyError as ke:
                 annotationTagsValue =  region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationNameLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
                    
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName =   str(tagGroup)
    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatNameLookup,formatAnnotationNameLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "ANY10S10QOMR Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("ANY_10S_book_distribution_vottraw.json")

# %%
tagGroups = ["ROLLNUMBERID1", "ROLLNUMBER1_Q1","ROLLNUMBER1_Q2","ROLLNUMBER1_Q3","ROLLNUMBER1_Q4","ROLLNUMBER1_Q5","ROLLNUMBER1_Q6","ROLLNUMBER1_Q7","ROLLNUMBER1_Q8","ROLLNUMBER1_Q9","ROLLNUMBER1_QTEN", "ROLLNUMBERID2","ROLLNUMBER2_Q1","ROLLNUMBER2_Q2","ROLLNUMBER2_Q3","ROLLNUMBER2_Q4","ROLLNUMBER2_Q5","ROLLNUMBER2_Q6","ROLLNUMBER2_Q7","ROLLNUMBER2_Q8","ROLLNUMBER2_Q9","ROLLNUMBER2_QTEN","ROLLNUMBERID3", "ROLLNUMBER3_Q1","ROLLNUMBER3_Q2","ROLLNUMBER3_Q3","ROLLNUMBER3_Q4","ROLLNUMBER3_Q5","ROLLNUMBER3_Q6","ROLLNUMBER3_Q7","ROLLNUMBER3_Q8","ROLLNUMBER3_Q9","ROLLNUMBER3_QTEN","ROLLNUMBERID4", "ROLLNUMBER4_Q1","ROLLNUMBER4_Q2","ROLLNUMBER4_Q3","ROLLNUMBER4_Q4","ROLLNUMBER4_Q5","ROLLNUMBER4_Q6","ROLLNUMBER4_Q7","ROLLNUMBER4_Q8","ROLLNUMBER4_Q9","ROLLNUMBER4_QTEN", "ROLLNUMBERID5","ROLLNUMBER5_Q1","ROLLNUMBER5_Q2","ROLLNUMBER5_Q3","ROLLNUMBER5_Q4","ROLLNUMBER5_Q5","ROLLNUMBER5_Q6","ROLLNUMBER5_Q7","ROLLNUMBER5_Q8","ROLLNUMBER5_Q9","ROLLNUMBER5_QTEN","ROLLNUMBERID6", "ROLLNUMBER6_Q1","ROLLNUMBER6_Q2","ROLLNUMBER6_Q3","ROLLNUMBER6_Q4","ROLLNUMBER6_Q5","ROLLNUMBER6_Q6","ROLLNUMBER6_Q7","ROLLNUMBER6_Q8","ROLLNUMBER6_Q9","ROLLNUMBER6_QTEN","ROLLNUMBERID7", "ROLLNUMBER7_Q1","ROLLNUMBER7_Q2","ROLLNUMBER7_Q3","ROLLNUMBER7_Q4","ROLLNUMBER7_Q5","ROLLNUMBER7_Q6","ROLLNUMBER7_Q7","ROLLNUMBER7_Q8","ROLLNUMBER7_Q9","ROLLNUMBER7_QTEN","ROLLNUMBERID8","ROLLNUMBER8_Q1","ROLLNUMBER8_Q2","ROLLNUMBER8_Q3","ROLLNUMBER8_Q4","ROLLNUMBER8_Q5","ROLLNUMBER8_Q6","ROLLNUMBER8_Q7","ROLLNUMBER8_Q8","ROLLNUMBER8_Q9","ROLLNUMBER8_QTEN","ROLLNUMBERID9","ROLLNUMBER9_Q1","ROLLNUMBER9_Q2","ROLLNUMBER9_Q3","ROLLNUMBER9_Q4","ROLLNUMBER9_Q5","ROLLNUMBER9_Q6","ROLLNUMBER9_Q7","ROLLNUMBER9_Q8","ROLLNUMBER9_Q9","ROLLNUMBER9_QTEN","ROLLNUMBERIDTEN","ROLLNUMBERTEN_Q1","ROLLNUMBERTEN_Q2","ROLLNUMBERTEN_Q3","ROLLNUMBERTEN_Q4","ROLLNUMBERTEN_Q5","ROLLNUMBERTEN_Q6","ROLLNUMBERTEN_Q7","ROLLNUMBERTEN_Q8","ROLLNUMBERTEN_Q9","ROLLNUMBERTEN_QTEN"]


formatLookup= {
    'ROLLNUMBERID1': 'ROLLNUMBER1',
    'ROLLNUMBER1_Q1': 'Maths',
    'ROLLNUMBER1_Q2': 'Science',
    'ROLLNUMBER1_Q3': 'English',
    'ROLLNUMBER1_Q4': 'SST',
    'ROLLNUMBER1_Q5': '2nd Language',
    'ROLLNUMBER1_Q6': '3rd Language',
    'ROLLNUMBER1_Q7': 'Computers',
    'ROLLNUMBER1_Q8': 'General Knowledge',
    'ROLLNUMBER1_Q9': 'Notebook1',
    'ROLLNUMBER1_QTEN': 'Notebook2',
    'ROLLNUMBERID2': 'ROLLNUMBER2',
    'ROLLNUMBER2_Q1': 'Maths',
    'ROLLNUMBER2_Q2': 'Science',
    'ROLLNUMBER2_Q3': 'English',
    'ROLLNUMBER2_Q4': 'SST',
    'ROLLNUMBER2_Q5': '2nd Language',
    'ROLLNUMBER2_Q6': '3rd Language',
    'ROLLNUMBER2_Q7': 'Computer',
    'ROLLNUMBER2_Q8': 'General Knowledge',
    'ROLLNUMBER2_Q9': 'Notebook1',
    'ROLLNUMBER2_QTEN': 'Notebook2',
    'ROLLNUMBERID3': 'ROLLNUMBER3',
    'ROLLNUMBER3_Q1': 'Maths',
    'ROLLNUMBER3_Q2': 'Science',
    'ROLLNUMBER3_Q3': 'English',
    'ROLLNUMBER3_Q4': 'SST',
    'ROLLNUMBER3_Q5': '2nd Language',
    'ROLLNUMBER3_Q6': '3rdL Language',
    'ROLLNUMBER3_Q7': 'Computers',
    'ROLLNUMBER3_Q8': 'General Knowledge',
    'ROLLNUMBER3_Q9': 'Notebook1',
    'ROLLNUMBER3_QTEN': 'Notebook2',
    'ROLLNUMBERID4': 'ROLLNUMBER4',
    'ROLLNUMBER4_Q1': 'Maths',
    'ROLLNUMBER4_Q2': 'Science',
    'ROLLNUMBER4_Q3': 'English',
    'ROLLNUMBER4_Q4': 'SST',
    'ROLLNUMBER4_Q5': '2nd Language',
    'ROLLNUMBER4_Q6': '3rd Langauage',
    'ROLLNUMBER4_Q7': 'Computers',
    'ROLLNUMBER4_Q8': 'General Knowledge',
    'ROLLNUMBER4_Q9': 'Notebook1',
    'ROLLNUMBER4_QTEN': 'Notebook2',
    'ROLLNUMBERID5': 'ROLLNUMBER5',
    'ROLLNUMBER5_Q1': 'Maths',
    'ROLLNUMBER5_Q2': 'Science',
    'ROLLNUMBER5_Q3': 'English',
    'ROLLNUMBER5_Q4': 'SST',
    'ROLLNUMBER5_Q5': '2nd Language',
    'ROLLNUMBER5_Q6': '3rd Language',
    'ROLLNUMBER5_Q7': 'Computers',
    'ROLLNUMBER5_Q8': 'General Knowledge',
    'ROLLNUMBER5_Q9': 'Notebook1',
    'ROLLNUMBER5_QTEN': 'Notebook2',
    'ROLLNUMBERID6': 'ROLLNUMBER6',
    'ROLLNUMBER6_Q1': 'Maths',
    'ROLLNUMBER6_Q2': 'Science',
    'ROLLNUMBER6_Q3': 'English',
    'ROLLNUMBER6_Q4': 'SST',
    'ROLLNUMBER6_Q5': '2nd Language',
    'ROLLNUMBER6_Q6': '3rd Language',
    'ROLLNUMBER6_Q7': 'Computers',
    'ROLLNUMBER6_Q8': 'General Knowledge',
    'ROLLNUMBER6_Q9': 'Notebook1',
    'ROLLNUMBER6_QTEN': 'Notebook2',
    'ROLLNUMBERID7': 'ROLLNUMBER7',
    'ROLLNUMBER7_Q1': 'Maths',
    'ROLLNUMBER7_Q2': 'Science',
    'ROLLNUMBER7_Q3': 'English',
    'ROLLNUMBER7_Q4': 'SST',
    'ROLLNUMBER7_Q5': '2nd Language',
    'ROLLNUMBER7_Q6': '3rd Language',
    'ROLLNUMBER7_Q7': 'Computers',
    'ROLLNUMBER7_Q8': 'General Knowledge',
    'ROLLNUMBER7_Q9': 'Notebook1',
    'ROLLNUMBER7_QTEN': 'Notebook2',
    'ROLLNUMBERID8': 'ROLLNUMBER8',
    'ROLLNUMBER8_Q1': 'Maths',
    'ROLLNUMBER8_Q2': 'Science',
    'ROLLNUMBER8_Q3': 'English',
    'ROLLNUMBER8_Q4': 'SST',
    'ROLLNUMBER8_Q5': '2nd Language',
    'ROLLNUMBER8_Q6': '3rd Language',
    'ROLLNUMBER8_Q7': 'Computers',
    'ROLLNUMBER8_Q8': 'General Knowledge',
    'ROLLNUMBER8_Q9': 'Notebook1',
    'ROLLNUMBER8_QTEN': 'Notebook2',
    'ROLLNUMBERID9': 'ROLLNUMBER9',
    'ROLLNUMBER9_Q1': 'Maths',
    'ROLLNUMBER9_Q2': 'Science',
    'ROLLNUMBER9_Q3': 'English',
    'ROLLNUMBER9_Q4': 'SST',
    'ROLLNUMBER9_Q5': '2nd Language',
    'ROLLNUMBER9_Q6': '3rs Language',
    'ROLLNUMBER9_Q7': 'Computers',
    'ROLLNUMBER9_Q8': 'General Knowledge',
    'ROLLNUMBER9_Q9': 'Notebook1',
    'ROLLNUMBER9_QTEN': 'Notebook2',
    'ROLLNUMBERIDTEN': 'ROLLNUMBER10',
    'ROLLNUMBERTEN_Q1': 'Maths',
    'ROLLNUMBERTEN_Q2': 'Science',
    'ROLLNUMBERTEN_Q3': 'English',
    'ROLLNUMBERTEN_Q4': 'SST',
    'ROLLNUMBERTEN_Q5': '2nd Language',
    'ROLLNUMBERTEN_Q6': '3rd Language',
    'ROLLNUMBERTEN_Q7': 'Computers',
    'ROLLNUMBERTEN_Q8': 'General Knowledge',
    'ROLLNUMBERTEN_Q9': 'Notebook1',
    'ROLLNUMBERTEN_QTEN': 'Notebook2'
}

formatNameLookup= {
'ROLLNUMBER1_Q1': 'ROLLNUMBER1_MATHS',
'ROLLNUMBER1_Q2': 'ROLLNUMBER1_SCIENCE',
'ROLLNUMBER1_Q3': 'ROLLNUMBER1_ENGLISH',
'ROLLNUMBER1_Q4': 'ROLLNUMBER1_SST',
'ROLLNUMBER1_Q5': 'ROLLNUMBER1_2ndLanguage',
'ROLLNUMBER1_Q6': 'ROLLNUMBER1_3rdLanguage',
'ROLLNUMBER1_Q7': 'ROLLNUMBER1_Computers',
'ROLLNUMBER1_Q8': 'ROLLNUMBER1_General_Knowledge',
'ROLLNUMBER1_Q9': 'ROLLNUMBER1_Notebook1',
'ROLLNUMBER1_QTEN': 'ROLLNUMBER1_Notebook2',
'ROLLNUMBER2_Q1': 'ROLLNUMBER2_MATHS',
'ROLLNUMBER2_Q2': 'ROLLNUMBER2_SCIENCE',
'ROLLNUMBER2_Q3': 'ROLLNUMBER2_ENGLISH',
'ROLLNUMBER2_Q4': 'ROLLNUMBER2_SST',
'ROLLNUMBER2_Q5': 'ROLLNUMBER2_2ndLanguage',
'ROLLNUMBER2_Q6': 'ROLLNUMBER2_3rdLanguage',
'ROLLNUMBER2_Q7': 'ROLLNUMBER2_Computers',
'ROLLNUMBER2_Q8': 'ROLLNUMBER2_General_Knowledge',
'ROLLNUMBER2_Q9': 'ROLLNUMBER2_Notebook1',
'ROLLNUMBER2_QTEN': 'ROLLNUMBER2_Notebook2',
'ROLLNUMBER3_Q1': 'ROLLNUMBER3_MATHS',
'ROLLNUMBER3_Q2': 'ROLLNUMBER3_SCIENCE',
'ROLLNUMBER3_Q3': 'ROLLNUMBER3_ENGLISH',
'ROLLNUMBER3_Q4': 'ROLLNUMBER3_SST',
'ROLLNUMBER3_Q5': 'ROLLNUMBER3_2ndLanguage',
'ROLLNUMBER3_Q6': 'ROLLNUMBER3_3rdLanguage',
'ROLLNUMBER3_Q7': 'ROLLNUMBER3_Computers',
'ROLLNUMBER3_Q8': 'ROLLNUMBER3_General_Knowledge',
'ROLLNUMBER3_Q9': 'ROLLNUMBER3_Notebook1',
'ROLLNUMBER3_QTEN': 'ROLLNUMBER3_Notebook2',
'ROLLNUMBER4_Q1': 'ROLLNUMBER4_MATHS',
'ROLLNUMBER4_Q2': 'ROLLNUMBER4_SCIENCE',
'ROLLNUMBER4_Q3': 'ROLLNUMBER4_ENGLISH',
'ROLLNUMBER4_Q4': 'ROLLNUMBER4_SST',
'ROLLNUMBER4_Q5': 'ROLLNUMBER4_2ndLanguage',
'ROLLNUMBER4_Q6': 'ROLLNUMBER4_3rdLanguage',
'ROLLNUMBER4_Q7': 'ROLLNUMBER4_Computers',
'ROLLNUMBER4_Q8': 'ROLLNUMBER4_General_Knowledge',
'ROLLNUMBER4_Q9': 'ROLLNUMBER4_Notebook1',
'ROLLNUMBER4_QTEN': 'ROLLNUMBER4_Notebook2',
'ROLLNUMBER5_Q1': 'ROLLNUMBER5_MATHS',
'ROLLNUMBER5_Q2': 'ROLLNUMBER5_SCIENCE',
'ROLLNUMBER5_Q3': 'ROLLNUMBER5_ENGLISH',
'ROLLNUMBER5_Q4': 'ROLLNUMBER5_SST',
'ROLLNUMBER5_Q5': 'ROLLNUMBER5_2ndLanguage',
'ROLLNUMBER5_Q6': 'ROLLNUMBER5_3rdLanguage',
'ROLLNUMBER5_Q7': 'ROLLNUMBER5_Computers',
'ROLLNUMBER5_Q8': 'ROLLNUMBER5_General_Knowledge',
'ROLLNUMBER5_Q9': 'ROLLNUMBER5_Notebook1',
'ROLLNUMBER5_QTEN': 'ROLLNUMBER5_Notebook2',
'ROLLNUMBER6_Q1': 'ROLLNUMBER6_MATHS',
'ROLLNUMBER6_Q2': 'ROLLNUMBER6_SCIENCE',
'ROLLNUMBER6_Q3': 'ROLLNUMBER6_ENGLISH',
'ROLLNUMBER6_Q4': 'ROLLNUMBER6_SST',
'ROLLNUMBER6_Q5': 'ROLLNUMBER6_2ndLanguage',
'ROLLNUMBER6_Q6': 'ROLLNUMBER6_3rdLanguage',
'ROLLNUMBER6_Q7': 'ROLLNUMBER6_Computers',
'ROLLNUMBER6_Q8': 'ROLLNUMBER6_General_Knowledge',
'ROLLNUMBER6_Q9': 'ROLLNUMBER6_Notebook1',
'ROLLNUMBER6_QTEN': 'ROLLNUMBER6_Notebook2',
'ROLLNUMBER7_Q1': 'ROLLNUMBER7_MATHS',
'ROLLNUMBER7_Q2': 'ROLLNUMBER7_SCIENCE',
'ROLLNUMBER7_Q3': 'ROLLNUMBER7_ENGLISH',
'ROLLNUMBER7_Q4': 'ROLLNUMBER7_SST',
'ROLLNUMBER7_Q5': 'ROLLNUMBER7_2ndLanguage',
'ROLLNUMBER7_Q6': 'ROLLNUMBER7_3rdLanguage',
'ROLLNUMBER7_Q7': 'ROLLNUMBER7_Computers',
'ROLLNUMBER7_Q8': 'ROLLNUMBER7_General_Knowledge',
'ROLLNUMBER7_Q9': 'ROLLNUMBER7_Notebook1',
'ROLLNUMBER7_QTEN': 'ROLLNUMBER7_Notebook2',
'ROLLNUMBER8_Q1': 'ROLLNUMBER8_MATHS',
'ROLLNUMBER8_Q2': 'ROLLNUMBER8_SCIENCE',
'ROLLNUMBER8_Q3': 'ROLLNUMBER8_ENGLISH',
'ROLLNUMBER8_Q4': 'ROLLNUMBER8_SST',
'ROLLNUMBER8_Q5': 'ROLLNUMBER8_2ndLanguage',
'ROLLNUMBER8_Q6': 'ROLLNUMBER8_3rdLanguage',
'ROLLNUMBER8_Q7': 'ROLLNUMBER8_Computers',
'ROLLNUMBER8_Q8': 'ROLLNUMBER8_General_Knowledge',
'ROLLNUMBER8_Q9': 'ROLLNUMBER8_Notebook1',
'ROLLNUMBER8_QTEN': 'ROLLNUMBER8_Notebook2',
'ROLLNUMBER9_Q1': 'ROLLNUMBER9_MATHS',
'ROLLNUMBER9_Q2': 'ROLLNUMBER9_SCIENCE',
'ROLLNUMBER9_Q3': 'ROLLNUMBER9_ENGLISH',
'ROLLNUMBER9_Q4': 'ROLLNUMBER9_SST',
'ROLLNUMBER9_Q5': 'ROLLNUMBER9_2ndLanguage',
'ROLLNUMBER9_Q6': 'ROLLNUMBER9_3rdLanguage',
'ROLLNUMBER9_Q7': 'ROLLNUMBER9_Computers',
'ROLLNUMBER9_Q8': 'ROLLNUMBER9_General_Knowledge',
'ROLLNUMBER9_Q9': 'ROLLNUMBER9_Notebook1',
'ROLLNUMBER9_QTEN': 'ROLLNUMBER9_Notebook2',
'ROLLNUMBERIDTEN': 'ROLLNUMBERID10',  
'ROLLNUMBERTEN_Q1': 'ROLLNUMBER10_MATHS',
'ROLLNUMBERTEN_Q2': 'ROLLNUMBER10_SCIENCE',
'ROLLNUMBERTEN_Q3': 'ROLLNUMBER10_ENGLISH',
'ROLLNUMBERTEN_Q4': 'ROLLNUMBER10_SST',
'ROLLNUMBERTEN_Q5': 'ROLLNUMBE10_2ndLanguage',
'ROLLNUMBERTEN_Q6': 'ROLLNUMBER10_3rdLanguage',
'ROLLNUMBERTEN_Q7': 'ROLLNUMBER10_Computers',
'ROLLNUMBERTEN_Q8': 'ROLLNUMBER10_General_Knowledge',
'ROLLNUMBERTEN_Q9': 'ROLLNUMBER10_Notebook1',
'ROLLNUMBERTEN_QTEN': 'ROLLNUMBE10_Notebook2'
}
formatAnnotationNameLookup ={
'ROLLNUMBERTEN_1': 'ROLLNUMBERID10_1',
'ROLLNUMBERTEN_2': 'ROLLNUMBERID10_2',
'ROLLNUMBERTEN_3': 'ROLLNUMBERID10_3 ',
'ROLLNUMBERTEN_4': 'ROLLNUMBERID10_4',
'ROLLNUMBERTEN_5': 'ROLLNUMBERID10_5',
'ROLLNUMBERTEN_6': 'ROLLNUMBERID10_6',
'ROLLNUMBERTEN_7': 'ROLLNUMBERID10_7',
'ROLLNUMBERTEN_8': 'ROLLNUMBERID10_8',
'ROLLNUMBERTEN_7': 'ROLLNUMBERID10_9'
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationNameLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "ANY10S10QOMR Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBERID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 116,
#                             "left": 66,
#                             "bottom": 140,
#                             "right": 86
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
