# %%
# Dileep Gadiraju - Odisha ROI Transformation from VoTT Raw format
# Takes filename of VoTT raw format file and generates ROI configuration
# v1.5 saral ocr version

import json

def get_cells(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['layout']['cells']


get_cells("../samples/up_sat_v1.5_sample.json")
# Out:
# [{'cellId': 1,
#   'format': {'name': 'CELL_ROLLNUMBER_0', 'value': 'CELL ROLLNUMBER 0'},
#   'render': {'alignment': 'center', 'index': 1, 'text': 'ROLL NUMBER'},
#   'rois': [{'annotationId': 'av3CIJxCK',
#     'annotationTag': 'CELL_ROLLNUMBER_0',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 85, 'left': 17, 'right': 142, 'top': 23},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 2,
#   'format': {'name': 'CELL_ROLLNUMBER_1', 'value': 'CELL ROLLNUMBER 1'},
#   'render': {'alignment': 'center', 'index': 2, 'text': ''},
#   'rois': [{'annotationId': 'd8IE27EHC',
#     'annotationTag': 'CELL_ROLLNUMBER_1',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 86, 'left': 145, 'right': 189, 'top': 25},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 3,
#   'format': {'name': 'CELL_ROLLNUMBER_2', 'value': 'CELL ROLLNUMBER 2'},
#   'render': {'alignment': 'center', 'index': 3, 'text': ''},
#   'rois': [{'annotationId': 'bJ59kMV5v',
#     'annotationTag': 'CELL_ROLLNUMBER_2',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 87, 'left': 192, 'right': 237, 'top': 26},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 4,
#   'format': {'name': 'CELL_ROLLNUMBER_3', 'value': 'CELL ROLLNUMBER 3'},
#   'render': {'alignment': 'center', 'index': 4, 'text': ''},
#   'rois': [{'annotationId': '-ao8WUT1W',
#     'annotationTag': 'CELL_ROLLNUMBER_3',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 88, 'left': 240, 'right': 285, 'top': 26},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 5,
#   'format': {'name': 'ROLLNUMBER', 'value': 'ROLLNUMBER'},
#   'render': {'alignment': 'center', 'index': 5, 'text': ''},
#   'rois': [{'annotationId': 'w2YWhWjDD',
#     'annotationTag': 'ROLLNUMBER_1',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 73, 'left': 155, 'right': 180, 'top': 39},
#     'roiId': 1},
#    {'annotationId': 'EH5E9epOl',
#     'annotationTag': 'ROLLNUMBER_2',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 1,
#     'rect': {'bottom': 73, 'left': 202, 'right': 227, 'top': 40},
#     'roiId': 2},
#    {'annotationId': 'byVn93veE',
#     'annotationTag': 'ROLLNUMBER_3',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 2,
#     'rect': {'bottom': 73, 'left': 249, 'right': 273, 'top': 40},
#     'roiId': 3}],
#   'validate': {'errorMessage': 'Should be 2 to 3 Digits',
#    'name': 'Between 2 to 3 Digits',
#    'regExp': '^[1-9][0-9]{1,3}$',
#    'source': 'BACKEND_SCHOOL'}},
#  {'cellId': 6,
#   'format': {'name': 'CELL_ROLLNUMBER_4', 'value': 'CELL ROLLNUMBER 4'},
#   'render': {'alignment': 'center', 'index': 6, 'text': ''},
#   'rois': [{'annotationId': 'AWvrH-t0m',
#     'annotationTag': 'CELL_ROLLNUMBER_4',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 87, 'left': 287, 'right': 619, 'top': 27},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 7,
#   'format': {'name': 'CELL_LABEL_0', 'value': 'CELL LABEL 0'},
#   'render': {'alignment': 'center', 'index': 7, 'text': ''},
#   'rois': [{'annotationId': 'fD8TBUoH9',
#     'annotationTag': 'CELL_LABEL_0',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 137, 'left': 18, 'right': 143, 'top': 88},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 8,
#   'format': {'name': 'CELL_OBJECTIVE', 'value': 'CELL OBJECTIVE'},
#   'render': {'alignment': 'center', 'index': 8, 'text': 'OBJECTIVE'},
#   'rois': [{'annotationId': 'M1H9CEf0u',
#     'annotationTag': 'CELL_OBJECTIVE',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 139, 'left': 145, 'right': 520, 'top': 89},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 9,
#   'format': {'name': 'CELL_SUBJECTIVE', 'value': 'CELL SUBJECTIVE'},
#   'render': {'alignment': 'center', 'index': 9, 'text': 'SUBJECTIVE'},
#   'rois': [{'annotationId': 'K5uq0kiWV',
#     'annotationTag': 'CELL_SUBJECTIVE',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 140, 'left': 524, 'right': 618, 'top': 90},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 10,
#   'format': {'name': 'CELL_SUBJECT', 'value': 'CELL SUBJECT'},
#   'render': {'alignment': 'center', 'index': 10, 'text': 'SUBJECT'},
#   'rois': [{'annotationId': 'K5uq0kiWV',
#     'annotationTag': 'CELL_SUBJECTIVE',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 140, 'left': 524, 'right': 618, 'top': 90},
#     'roiId': 1},
#    {'annotationId': '1q6JlCHIL',
#     'annotationTag': 'CELL_SUBJECT',
#     'extractionMethod': '',
#     'index': 1,
#     'rect': {'bottom': 191, 'left': 18, 'right': 143, 'top': 141},
#     'roiId': 2}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 11,
#   'format': {'name': 'CELL_QUESTION_1', 'value': 'CELL QUESTION 1'},
#   'render': {'alignment': 'center', 'index': 11, 'text': '1'},
#   'rois': [{'annotationId': 'pbe6YFBEA',
#     'annotationTag': 'CELL_QUESTION_1',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 191, 'left': 145, 'right': 190, 'top': 141},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 12,
#   'format': {'name': 'CELL_QUESTION_2', 'value': 'CELL QUESTION 2'},
#   'render': {'alignment': 'center', 'index': 12, 'text': '2'},
#   'rois': [{'annotationId': 'Zw6kaLsgE',
#     'annotationTag': 'CELL_QUESTION_2',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 191, 'left': 193, 'right': 237, 'top': 142},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 13,
#   'format': {'name': 'CELL_QUESTION_3', 'value': 'CELL QUESTION 3'},
#   'render': {'alignment': 'center', 'index': 13, 'text': '3'},
#   'rois': [{'annotationId': '3UwadIj-H',
#     'annotationTag': 'CELL_QUESTION_3',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 241, 'right': 285, 'top': 142},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 14,
#   'format': {'name': 'CELL_QUESTION_4', 'value': 'CELL QUESTION 4'},
#   'render': {'alignment': 'center', 'index': 14, 'text': '4'},
#   'rois': [{'annotationId': '2Ukgcz6aa',
#     'annotationTag': 'CELL_QUESTION_4',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 193, 'left': 289, 'right': 333, 'top': 142},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 15,
#   'format': {'name': 'CELL_QUESTION_5', 'value': 'CELL QUESTION 5'},
#   'render': {'alignment': 'center', 'index': 15, 'text': '5'},
#   'rois': [{'annotationId': 'UK_e9ytac',
#     'annotationTag': 'CELL_QUESTION_5',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 335, 'right': 379, 'top': 143},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 16,
#   'format': {'name': 'CELL_QUESTION_6', 'value': 'CELL QUESTION 6'},
#   'render': {'alignment': 'center', 'index': 16, 'text': '6'},
#   'rois': [{'annotationId': 'hKMX7FV4d',
#     'annotationTag': 'CELL_QUESTION_6',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 382, 'right': 426, 'top': 143},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 17,
#   'format': {'name': 'CELL_QUESTION_7', 'value': 'CELL QUESTION 7'},
#   'render': {'alignment': 'center', 'index': 17, 'text': '7'},
#   'rois': [{'annotationId': 'YhmcZDYby',
#     'annotationTag': 'CELL_QUESTION_7',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 430, 'right': 474, 'top': 143},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 18,
#   'format': {'name': 'CELL_QUESTION_8', 'value': 'CELL QUESTION 8'},
#   'render': {'alignment': 'center', 'index': 18, 'text': '8'},
#   'rois': [{'annotationId': 'd1p7ohuqh',
#     'annotationTag': 'CELL_QUESTION_8',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 477, 'right': 521, 'top': 143},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 19,
#   'format': {'name': 'CELL_QUESTION_9', 'value': 'CELL QUESTION 9'},
#   'render': {'alignment': 'center', 'index': 19, 'text': '9'},
#   'rois': [{'annotationId': 'VnNBGqkVz',
#     'annotationTag': 'CELL_QUESTION_9',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 524, 'right': 568, 'top': 143},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 20,
#   'format': {'name': 'CELL_QUESTION_10', 'value': 'CELL QUESTION 10'},
#   'render': {'alignment': 'center', 'index': 20, 'text': '10'},
#   'rois': [{'annotationId': 'N_Z_qI16y',
#     'annotationTag': 'CELL_QUESTION_10',
#     'extractionMethod': '',
#     'index': 0,
#     'rect': {'bottom': 192, 'left': 572, 'right': 619, 'top': 142},
#     'roiId': 1}],
#   'validate': {'errorMessage': '', 'name': '', 'regExp': '', 'source': ''}},
#  {'cellId': 21,
#   'format': {'name': 'HINDI_QUESTION_1', 'value': 'HINDI QUESTION 1'},
#   'render': {'alignment': 'center', 'index': 21, 'text': ''},
#   'rois': [{'annotationId': 'cxfP8uVOx',
#     'annotationTag': 'HINDI_QUESTION_1',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 235, 'left': 155, 'right': 180, 'top': 200},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION 1 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 22,
#   'format': {'name': 'HINDI_QUESTION_2', 'value': 'HINDI QUESTION 2'},
#   'render': {'alignment': 'center', 'index': 22, 'text': ''},
#   'rois': [{'annotationId': 'Muatqaseb',
#     'annotationTag': 'HINDI_QUESTION_2',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 235, 'left': 203, 'right': 227, 'top': 201},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION2 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 23,
#   'format': {'name': 'HINDI_QUESTION_3', 'value': 'HINDI QUESTION 3'},
#   'render': {'alignment': 'center', 'index': 23, 'text': ''},
#   'rois': [{'annotationId': 'jZmW-nez7',
#     'annotationTag': 'HINDI_QUESTION_3',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 235, 'left': 251, 'right': 275, 'top': 200},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION3 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 24,
#   'format': {'name': 'HINDI_QUESTION_4', 'value': 'HINDI QUESTION 4'},
#   'render': {'alignment': 'center', 'index': 24, 'text': ''},
#   'rois': [{'annotationId': 'MMc9B9gLn',
#     'annotationTag': 'HINDI_QUESTION_4',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 237, 'left': 298, 'right': 321, 'top': 202},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION4 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 25,
#   'format': {'name': 'HINDI_QUESTION_5', 'value': 'HINDI QUESTION 5'},
#   'render': {'alignment': 'center', 'index': 25, 'text': ''},
#   'rois': [{'annotationId': '5DFeVRjUq',
#     'annotationTag': 'HINDI_QUESTION_5',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 236, 'left': 345, 'right': 369, 'top': 202},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION5 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 26,
#   'format': {'name': 'HINDI_QUESTION_6', 'value': 'HINDI QUESTION 6'},
#   'render': {'alignment': 'center', 'index': 26, 'text': ''},
#   'rois': [{'annotationId': 'CbMCC8zrn',
#     'annotationTag': 'HINDI_QUESTION_6',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 236, 'left': 392, 'right': 416, 'top': 203},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION6 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 27,
#   'format': {'name': 'HINDI_QUESTION_7', 'value': 'HINDI QUESTION 7'},
#   'render': {'alignment': 'center', 'index': 27, 'text': ''},
#   'rois': [{'annotationId': 'o9cBJO5Vr',
#     'annotationTag': 'HINDI_QUESTION_7',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 236, 'left': 440, 'right': 464, 'top': 202},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION7 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 28,
#   'format': {'name': 'HINDI_QUESTION_8', 'value': 'HINDI QUESTION 8'},
#   'render': {'alignment': 'center', 'index': 28, 'text': ''},
#   'rois': [{'annotationId': '9dCFXBLiV',
#     'annotationTag': 'HINDI_QUESTION_8',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 235, 'left': 487, 'right': 511, 'top': 202},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION8 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 29,
#   'format': {'name': 'HINDI_QUESTION_9', 'value': 'HINDI QUESTION 9'},
#   'render': {'alignment': 'center', 'index': 29, 'text': ''},
#   'rois': [{'annotationId': 'x2MPxcbEV',
#     'annotationTag': 'HINDI_QUESTION_9',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 236, 'left': 535, 'right': 558, 'top': 202},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION9 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 30,
#   'format': {'name': 'HINDI_QUESTION_TEN', 'value': 'HINDI QUESTION TEN'},
#   'render': {'alignment': 'center', 'index': 30, 'text': ''},
#   'rois': [{'annotationId': 'W4jYa1vCS',
#     'annotationTag': 'HINDI_QUESTION_TEN',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 236, 'left': 583, 'right': 606, 'top': 201},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'HINDI QUESTION10 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 31,
#   'format': {'name': 'ENGLISH_QUESTION_1', 'value': 'ENGLISH QUESTION 1'},
#   'render': {'alignment': 'center', 'index': 31, 'text': ''},
#   'rois': [{'annotationId': 'eY_nH_Kqw',
#     'annotationTag': 'ENGLISH_QUESTION_1',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 287, 'left': 156, 'right': 181, 'top': 253},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION 1 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 32,
#   'format': {'name': 'ENGLISH_QUESTION_2', 'value': 'ENGLISH QUESTION 2'},
#   'render': {'alignment': 'center', 'index': 32, 'text': ''},
#   'rois': [{'annotationId': 'vhAHjFizv',
#     'annotationTag': 'ENGLISH_QUESTION_2',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 287, 'left': 204, 'right': 228, 'top': 253},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION2 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 33,
#   'format': {'name': 'ENGLISH_QUESTION_3', 'value': 'ENGLISH QUESTION 3'},
#   'render': {'alignment': 'center', 'index': 33, 'text': ''},
#   'rois': [{'annotationId': '5LDSXmWs9',
#     'annotationTag': 'ENGLISH_QUESTION_3',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 289, 'left': 251, 'right': 276, 'top': 254},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION3 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 34,
#   'format': {'name': 'ENGLISH_QUESTION_4', 'value': 'ENGLISH QUESTION 4'},
#   'render': {'alignment': 'center', 'index': 34, 'text': ''},
#   'rois': [{'annotationId': 'so9WEurw4',
#     'annotationTag': 'ENGLISH_QUESTION_4',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 288, 'left': 298, 'right': 322, 'top': 253},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION4 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 35,
#   'format': {'name': 'ENGLISH_QUESTION_5', 'value': 'ENGLISH QUESTION 5'},
#   'render': {'alignment': 'center', 'index': 35, 'text': ''},
#   'rois': [{'annotationId': 'M5mw0hg4g',
#     'annotationTag': 'ENGLISH_QUESTION_5',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 289, 'left': 345, 'right': 369, 'top': 255},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION5 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 36,
#   'format': {'name': 'ENGLISH_QUESTION_6', 'value': 'ENGLISH QUESTION 6'},
#   'render': {'alignment': 'center', 'index': 36, 'text': ''},
#   'rois': [{'annotationId': 'tn9rjjvxZ',
#     'annotationTag': 'ENGLISH_QUESTION_6',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 288, 'left': 393, 'right': 417, 'top': 254},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION6 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 37,
#   'format': {'name': 'ENGLISH_QUESTION_7', 'value': 'ENGLISH QUESTION 7'},
#   'render': {'alignment': 'center', 'index': 37, 'text': ''},
#   'rois': [{'annotationId': '62iFMSzw5',
#     'annotationTag': 'ENGLISH_QUESTION_7',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 288, 'left': 440, 'right': 464, 'top': 254},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION7 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 38,
#   'format': {'name': 'ENGLISH_QUESTION_8', 'value': 'ENGLISH QUESTION 8'},
#   'render': {'alignment': 'center', 'index': 38, 'text': ''},
#   'rois': [{'annotationId': 'wpSshya3P',
#     'annotationTag': 'ENGLISH_QUESTION_8',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 289, 'left': 488, 'right': 512, 'top': 254},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION8 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 39,
#   'format': {'name': 'ENGLISH_QUESTION_9', 'value': 'ENGLISH QUESTION 9'},
#   'render': {'alignment': 'center', 'index': 39, 'text': ''},
#   'rois': [{'annotationId': '0_AbVIp4_',
#     'annotationTag': 'ENGLISH_QUESTION_9',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 290, 'left': 535, 'right': 559, 'top': 254},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION9 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 40,
#   'format': {'name': 'ENGLISH_QUESTION_TEN', 'value': 'ENGLISH QUESTION TEN'},
#   'render': {'alignment': 'center', 'index': 40, 'text': ''},
#   'rois': [{'annotationId': '33rLNckDL',
#     'annotationTag': 'ENGLISH_QUESTION_TEN',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 289, 'left': 583, 'right': 607, 'top': 254},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'ENGLISH QUESTION10 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 41,
#   'format': {'name': 'MATHS_QUESTION_1', 'value': 'MATHS QUESTION 1'},
#   'render': {'alignment': 'center', 'index': 41, 'text': ''},
#   'rois': [{'annotationId': 'bJz0So938',
#     'annotationTag': 'MATHS_QUESTION_1',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 341, 'left': 156, 'right': 179, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION 1 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 42,
#   'format': {'name': 'MATHS_QUESTION_2', 'value': 'MATHS QUESTION 2'},
#   'render': {'alignment': 'center', 'index': 42, 'text': ''},
#   'rois': [{'annotationId': 'JGceL6wb8',
#     'annotationTag': 'MATHS_QUESTION_2',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 340, 'left': 204, 'right': 228, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION2 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 43,
#   'format': {'name': 'MATHS_QUESTION_3', 'value': 'MATHS QUESTION 3'},
#   'render': {'alignment': 'center', 'index': 43, 'text': ''},
#   'rois': [{'annotationId': 'YvPdBPLYt',
#     'annotationTag': 'MATHS_QUESTION_3',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 341, 'left': 251, 'right': 275, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION3 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 44,
#   'format': {'name': 'MATHS_QUESTION_4', 'value': 'MATHS QUESTION 4'},
#   'render': {'alignment': 'center', 'index': 44, 'text': ''},
#   'rois': [{'annotationId': 'LVQHYsc6g',
#     'annotationTag': 'MATHS_QUESTION_4',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 340, 'left': 299, 'right': 323, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION4 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 45,
#   'format': {'name': 'MATHS_QUESTION_5', 'value': 'MATHS QUESTION 5'},
#   'render': {'alignment': 'center', 'index': 45, 'text': ''},
#   'rois': [{'annotationId': 'nJNRKSFCA',
#     'annotationTag': 'MATHS_QUESTION_5',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 340, 'left': 345, 'right': 369, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION5 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 46,
#   'format': {'name': 'MATHS_QUESTION_6', 'value': 'MATHS QUESTION 6'},
#   'render': {'alignment': 'center', 'index': 46, 'text': ''},
#   'rois': [{'annotationId': 'YS_hFUgEO',
#     'annotationTag': 'MATHS_QUESTION_6',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 341, 'left': 393, 'right': 417, 'top': 307},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION6 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 47,
#   'format': {'name': 'MATHS_QUESTION_7', 'value': 'MATHS QUESTION 7'},
#   'render': {'alignment': 'center', 'index': 47, 'text': ''},
#   'rois': [{'annotationId': 'Nds6EzgPE',
#     'annotationTag': 'MATHS_QUESTION_7',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 340, 'left': 441, 'right': 465, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION7 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 48,
#   'format': {'name': 'MATHS_QUESTION_8', 'value': 'MATHS QUESTION 8'},
#   'render': {'alignment': 'center', 'index': 48, 'text': ''},
#   'rois': [{'annotationId': 'B-5TCF5mo',
#     'annotationTag': 'MATHS_QUESTION_8',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 341, 'left': 488, 'right': 512, 'top': 306},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION8 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 49,
#   'format': {'name': 'MATHS_QUESTION_9', 'value': 'MATHS QUESTION 9'},
#   'render': {'alignment': 'center', 'index': 49, 'text': ''},
#   'rois': [{'annotationId': 'ZRQKebuLb',
#     'annotationTag': 'MATHS_QUESTION_9',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 342, 'left': 536, 'right': 560, 'top': 307},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION9 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 50,
#   'format': {'name': 'MATHS_QUESTION_TEN', 'value': 'MATHS QUESTION TEN'},
#   'render': {'alignment': 'center', 'index': 50, 'text': ''},
#   'rois': [{'annotationId': '0M673nBF5',
#     'annotationTag': 'MATHS_QUESTION_TEN',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 340, 'left': 584, 'right': 608, 'top': 307},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'MATHS QUESTION10 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 51,
#   'format': {'name': 'EVS_QUESTION_1', 'value': 'EVS QUESTION 1'},
#   'render': {'alignment': 'center', 'index': 51, 'text': ''},
#   'rois': [{'annotationId': 'mHvpxIcJH',
#     'annotationTag': 'EVS_QUESTION_1',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 156, 'right': 180, 'top': 358},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION 1 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 52,
#   'format': {'name': 'EVS_QUESTION_2', 'value': 'EVS QUESTION 2'},
#   'render': {'alignment': 'center', 'index': 52, 'text': ''},
#   'rois': [{'annotationId': 'hrE8jiSGi',
#     'annotationTag': 'EVS_QUESTION_2',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 204, 'right': 228, 'top': 359},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION2 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 53,
#   'format': {'name': 'EVS_QUESTION_3', 'value': 'EVS QUESTION 3'},
#   'render': {'alignment': 'center', 'index': 53, 'text': ''},
#   'rois': [{'annotationId': 'wo3-YSl2H',
#     'annotationTag': 'EVS_QUESTION_3',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 393, 'left': 251, 'right': 275, 'top': 358},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION3 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 54,
#   'format': {'name': 'EVS_QUESTION_4', 'value': 'EVS QUESTION 4'},
#   'render': {'alignment': 'center', 'index': 54, 'text': ''},
#   'rois': [{'annotationId': 'VT5TrWozx',
#     'annotationTag': 'EVS_QUESTION_4',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 392, 'left': 299, 'right': 323, 'top': 358},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION4 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 55,
#   'format': {'name': 'EVS_QUESTION_5', 'value': 'EVS QUESTION 5'},
#   'render': {'alignment': 'center', 'index': 55, 'text': ''},
#   'rois': [{'annotationId': 'ZGKpO8ex-',
#     'annotationTag': 'EVS_QUESTION_5',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 393, 'left': 346, 'right': 370, 'top': 359},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION5 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 56,
#   'format': {'name': 'EVS_QUESTION_6', 'value': 'EVS QUESTION 6'},
#   'render': {'alignment': 'center', 'index': 56, 'text': ''},
#   'rois': [{'annotationId': '_BJEejm-x',
#     'annotationTag': 'EVS_QUESTION_6',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 393, 'right': 417, 'top': 360},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION6 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 57,
#   'format': {'name': 'EVS_QUESTION_7', 'value': 'EVS QUESTION 7'},
#   'render': {'alignment': 'center', 'index': 57, 'text': ''},
#   'rois': [{'annotationId': 'b9E4575ov',
#     'annotationTag': 'EVS_QUESTION_7',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 441, 'right': 464, 'top': 359},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION7 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 58,
#   'format': {'name': 'EVS_QUESTION_8', 'value': 'EVS QUESTION 8'},
#   'render': {'alignment': 'center', 'index': 58, 'text': ''},
#   'rois': [{'annotationId': 'bDEcnxJf8',
#     'annotationTag': 'EVS_QUESTION_8',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 489, 'right': 513, 'top': 359},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION8 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 59,
#   'format': {'name': 'EVS_QUESTION_9', 'value': 'EVS QUESTION 9'},
#   'render': {'alignment': 'center', 'index': 59, 'text': ''},
#   'rois': [{'annotationId': 'HwHMoHP8f',
#     'annotationTag': 'EVS_QUESTION_9',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 536, 'right': 560, 'top': 360},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION9 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 60,
#   'format': {'name': 'EVS_QUESTION_TEN', 'value': 'EVS QUESTION TEN'},
#   'render': {'alignment': 'center', 'index': 60, 'text': ''},
#   'rois': [{'annotationId': '3m3rRH0lN',
#     'annotationTag': 'EVS_QUESTION_TEN',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 394, 'left': 584, 'right': 607, 'top': 359},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'EVS QUESTION10 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 61,
#   'format': {'name': 'SCIENCE_QUESTION_1', 'value': 'SCIENCE QUESTION 1'},
#   'render': {'alignment': 'center', 'index': 61, 'text': ''},
#   'rois': [{'annotationId': 'D7EhDm4uy',
#     'annotationTag': 'SCIENCE_QUESTION_1',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 447, 'left': 156, 'right': 180, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION 1 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 62,
#   'format': {'name': 'SCIENCE_QUESTION_2', 'value': 'SCIENCE QUESTION 2'},
#   'render': {'alignment': 'center', 'index': 62, 'text': ''},
#   'rois': [{'annotationId': 't5zTgSdc2',
#     'annotationTag': 'SCIENCE_QUESTION_2',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 446, 'left': 204, 'right': 228, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION2 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 63,
#   'format': {'name': 'SCIENCE_QUESTION_3', 'value': 'SCIENCE QUESTION 3'},
#   'render': {'alignment': 'center', 'index': 63, 'text': ''},
#   'rois': [{'annotationId': 'OrRvGhzLV',
#     'annotationTag': 'SCIENCE_QUESTION_3',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 446, 'left': 252, 'right': 276, 'top': 411},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION3 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 64,
#   'format': {'name': 'SCIENCE_QUESTION_4', 'value': 'SCIENCE QUESTION 4'},
#   'render': {'alignment': 'center', 'index': 64, 'text': ''},
#   'rois': [{'annotationId': '-x_u3fFhV',
#     'annotationTag': 'SCIENCE_QUESTION_4',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 445, 'left': 299, 'right': 322, 'top': 411},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION4 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 65,
#   'format': {'name': 'SCIENCE_QUESTION_5', 'value': 'SCIENCE QUESTION 5'},
#   'render': {'alignment': 'center', 'index': 65, 'text': ''},
#   'rois': [{'annotationId': 'LVHw1QHMH',
#     'annotationTag': 'SCIENCE_QUESTION_5',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 446, 'left': 347, 'right': 370, 'top': 411},
#     'roiId': 1},
#    {'annotationId': 'JfjpePMxn',
#     'annotationTag': 'SCIENCE_QUESTION_5',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 1,
#     'rect': {'bottom': 454, 'left': 337, 'right': 381, 'top': 404},
#     'roiId': 2}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION5 should range from 0 to 10 Marks',
#    'name': 'Between 0 to 10 Marks',
#    'regExp': '[0-10]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 66,
#   'format': {'name': 'SCIENCE_QUESTION_6', 'value': 'SCIENCE QUESTION 6'},
#   'render': {'alignment': 'center', 'index': 66, 'text': ''},
#   'rois': [{'annotationId': 'JXXYfHtGc',
#     'annotationTag': 'SCIENCE_QUESTION_6',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 447, 'left': 394, 'right': 418, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION6 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 67,
#   'format': {'name': 'SCIENCE_QUESTION_7', 'value': 'SCIENCE QUESTION 7'},
#   'render': {'alignment': 'center', 'index': 67, 'text': ''},
#   'rois': [{'annotationId': 'j6qSm7bRU',
#     'annotationTag': 'SCIENCE_QUESTION_7',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 447, 'left': 441, 'right': 465, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION7 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 68,
#   'format': {'name': 'SCIENCE_QUESTION_8', 'value': 'SCIENCE QUESTION 8'},
#   'render': {'alignment': 'center', 'index': 68, 'text': ''},
#   'rois': [{'annotationId': '6TPxclnwr',
#     'annotationTag': 'SCIENCE_QUESTION_8',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 446, 'left': 488, 'right': 512, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION8 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 69,
#   'format': {'name': 'SCIENCE_QUESTION_9', 'value': 'SCIENCE QUESTION 9'},
#   'render': {'alignment': 'center', 'index': 69, 'text': ''},
#   'rois': [{'annotationId': 'Li5u6VAyY',
#     'annotationTag': 'SCIENCE_QUESTION_9',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 447, 'left': 537, 'right': 561, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION9 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}},
#  {'cellId': 70,
#   'format': {'name': 'SCIENCE_QUESTION_TEN', 'value': 'SCIENCE QUESTION TEN'},
#   'render': {'alignment': 'center', 'index': 70, 'text': ''},
#   'rois': [{'annotationId': 'eZpuYFTx-',
#     'annotationTag': 'SCIENCE_QUESTION_TEN',
#     'extractionMethod': 'NUMERIC_CLASSIFICATION',
#     'index': 0,
#     'rect': {'bottom': 446, 'left': 584, 'right': 608, 'top': 412},
#     'roiId': 1}],
#   'validate': {'errorMessage': 'SCIENCE QUESTION10 should range from 0 to 5 Marks',
#    'name': 'Between 0 to 5 Marks',
#    'regExp': '[0-5]',
#    'source': 'BACKEND_EXAM'}}]
