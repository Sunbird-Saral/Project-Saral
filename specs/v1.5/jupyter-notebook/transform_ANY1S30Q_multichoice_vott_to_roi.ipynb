# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBER"):
                extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                extractionValue = "CELL_OMR"
            
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            rois.append({

                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
            
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName = ""

              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "ANY1S30QMULTICHOICE Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("ANY1S30Q_vottraw.json")

# %%
tagGroups = ["ROLLNUMBER", "QUESTION1","QUESTION2","QUESTION3","QUESTION4","QUESTION5","QUESTION6","QUESTION7","QUESTION8","QUESTION9","QUESTIONTEN","QUESTIONELE","QUESTIONTWL","QUESTIONTHRT","QUESTIONFORT","QUESTIONFIFT","QUESTIONSIXT","QUESTIONSVNT","QUESTIONEGTN","QUESTIONNINT","QUESTIONTWNTY","QUESTIONTWTYONE","QUESTIONTWTYTWO","QUESTIONTWTYTHREE","QUESTIONTWTYFOUR","QUESTIONTWTYFIVE","QUESTIONTWTYSIX","QUESTIONTWTYSVN","QUESTIONTWTYEGTN","QUESTIONTWTYNINT","QUESTIONTRTY"]

formatLookup = {
    'ROLLNUMBER': 'ROLLNUMBER',
    'QUESTION1':'QUESTION 1',
    'QUESTION2':'QUESTION 2',
    'QUESTION3':'QUESTION 3',
    'QUESTION4':'QUESTION 4',
    'QUESTION5':'QUESTION 5',
    'QUESTION6':'QUESTION 6',
    'QUESTION7':'QUESTION 7',
    'QUESTION8':'QUESTION 8',
    'QUESTION9':'QUESTION 9',
    'QUESTIONTEN': 'QUESTION 10',
    'QUESTIONELE': 'QUESTION 11',
    'QUESTIONTWL': 'QUESTION 12',
    'QUESTIONTHRT': 'QUESTION 13',
    'QUESTIONFORT': 'QUESTION 14',
    'QUESTIONFIFT': 'QUESTION 15',
    'QUESTIONSIXT': 'QUESTION 16',
    'QUESTIONSVNT': 'QUESTION 17',
    'QUESTIONEGTN': 'QUESTION 18',
    'QUESTIONNINT': 'QUESTION 19',
    'QUESTIONTWNTY': 'QUESTION 20',
    'QUESTIONTWTYONE': 'QUESTION 21',
    'QUESTIONTWTYTWO': 'QUESTION 22',
    'QUESTIONTWTYTHREE': 'QUESTION 23',
    'QUESTIONTWTYFOUR': 'QUESTION 24',
    'QUESTIONTWTYFIVE': 'QUESTION 25',
    'QUESTIONTWTYSIX': 'QUESTION 26',
    'QUESTIONTWTYSVN': 'QUESTION 27',
    'QUESTIONTWTYEGTN': 'QUESTION 28',
    'QUESTIONTWTYNINT': 'QUESTION 29',
    'QUESTIONTRTY': 'QUESTION 30'
}

formatNameLookup = {
    'ROLLNUMBER': 'ROLLNUMBER',
    'QUESTION1':'QUESTION1',
    'QUESTION2':'QUESTION2',
    'QUESTION3':'QUESTION3',
    'QUESTION4':'QUESTION4',
    'QUESTION5':'QUESTION5',
    'QUESTION6':'QUESTION6',
    'QUESTION7':'QUESTION7',
    'QUESTION8':'QUESTION8',
    'QUESTION9':'QUESTION9',
    'QUESTIONTEN': 'QUESTION10',
    'QUESTIONELE': 'QUESTION11',
    'QUESTIONTWL': 'QUESTION12',
    'QUESTIONTHRT': 'QUESTION13',
    'QUESTIONFORT': 'QUESTION14',
    'QUESTIONFIFT': 'QUESTION15',
    'QUESTIONSIXT': 'QUESTION16',
    'QUESTIONSVNT': 'QUESTION17',
    'QUESTIONEGTN': 'QUESTION18',
    'QUESTIONNINT': 'QUESTION19',
    'QUESTIONTWNTY': 'QUESTION20',
    'QUESTIONTWTYONE': 'QUESTION21',
    'QUESTIONTWTYTWO': 'QUESTION22',
    'QUESTIONTWTYTHREE': 'QUESTION23',
    'QUESTIONTWTYFOUR': 'QUESTION24',
    'QUESTIONTWTYFIVE': 'QUESTION25',
    'QUESTIONTWTYSIX': 'QUESTION26',
    'QUESTIONTWTYSVN': 'QUESTION27',
    'QUESTIONTWTYEGTN': 'QUESTION28',
    'QUESTIONTWTYNINT': 'QUESTION29',
    'QUESTIONTRTY': 'QUESTION 30'

}
formatAnnotationTagLookup = {
    'ROLLNUMBER1_TEN': 'ROLLNUMBER1_10',
    'ROLLNUMBER1_ELE': 'ROLLNUMBER1_11',
    'QUESTIONTEN_1': 'QUESTION10_1',
    'QUESTIONELE_1': 'QUESTION11_1',
    'QUESTIONTWL_1': 'QUESTION12_1',
    'QUESTIONTWL_2': 'QUESTION12_2',
    'QUESTIONTHRT_1': 'QUESTION13_1',
    'QUESTIONTHRT_2': 'QUESTION13_2',
    'QUESTIONTHRT_3': 'QUESTION13_3',
    'QUESTIONFORT_1': 'QUESTION14_1',
    'QUESTIONFORT_2': 'QUESTION14_2',
    'QUESTIONFORT_3': 'QUESTION14_3',
    'QUESTIONFORT_4': 'QUESTION14_4',
    'QUESTIONFORT_5': 'QUESTION14_5',
    'QUESTIONFIFT_1': 'QUESTION15_1',
    'QUESTIONFIFT_2': 'QUESTION15_2',
    'QUESTIONFIFT_3': 'QUESTION15_3',
    'QUESTIONFIFT_4': 'QUESTION15_4',
    'QUESTIONSIXT_1': 'QUESTION16_1',
    'QUESTIONSIXT_2': 'QUESTION16_2',
    'QUESTIONSIXT_3': 'QUESTION16_3',
    'QUESTIONSIXT_4': 'QUESTION16_4',
    'QUESTIONSIXT_5': 'QUESTION16_5',
    'QUESTIONSVNT_1': 'QUESTION17_1',
    'QUESTIONSVNT_2': 'QUESTION17_2',
    'QUESTIONEGTN_1': 'QUESTION18_1',
    'QUESTIONEGTN_2': 'QUESTION18_2',
    'QUESTIONNINT_1': 'QUESTION19_1',
    'QUESTIONTWNTY_1': 'QUESTION20_1',
    'QUESTIONTWNTY_2': 'QUESTION20_2',
    'QUESTIONTWNTY_3': 'QUESTION20_3',
    'QUESTIONTWNTY_4': 'QUESTION20_4',
    'QUESTIONTWNTY_5': 'QUESTION20_5',
    'QUESTIONTWTYONE_1': 'QUESTION21_1',
    'QUESTIONTWTYONE_2': 'QUESTION21_2',
    'QUESTIONTWTYONE_3': 'QUESTION21_3',
    'QUESTIONTWTYONE_4': 'QUESTION21_4',
    'QUESTIONTWTYTWO_1': 'QUESTION22_1',
    'QUESTIONTWTYTWO_2': 'QUESTION22_2',
    'QUESTIONTWTYTWO_3': 'QUESTION22_3',
    'QUESTIONTWTYTWO_4': 'QUESTION22_4',
    'QUESTIONTWTYTWO_5': 'QUESTION22_5',
    'QUESTIONTWTYTHREE_1': 'QUESTION23_1',
    'QUESTIONTWTYTHREE_2': 'QUESTION23_2',
    'QUESTIONTWTYTHREE_3': 'QUESTION23_3',
    'QUESTIONTWTYTHREE_4': 'QUESTION23_4',
    'QUESTIONTWTYTHREE_5': 'QUESTION23_5',
    'QUESTIONTWTYTHREE_6': 'QUESTION23_6',
    'QUESTIONTWTYFOUR_1': 'QUESTION24_1',
    'QUESTIONTWTYFOUR_2': 'QUESTION24_2',
    'QUESTIONTWTYFOUR_3': 'QUESTION24_3',
    'QUESTIONTWTYFIVE_1': 'QUESTION25_1',
    'QUESTIONTWTYFIVE_2': 'QUESTION25_2',
    'QUESTIONTWTYFIVE_3': 'QUESTION25_3',
    'QUESTIONTWTYFIVE_4': 'QUESTION25_4',
    'QUESTIONTWTYFIVE_5': 'QUESTION25_5',
    'QUESTIONTWTYFIVE_6': 'QUESTION25_6',
    'QUESTIONTWTYSIX_1': 'QUESTION26_1',
    'QUESTIONTWTYSIX_2': 'QUESTION26_2',
    'QUESTIONTWTYSIX_3': 'QUESTION26_3',
    'QUESTIONTWTYSIX_4': 'QUESTION26_4',
    'QUESTIONTWTYSIX_5': 'QUESTION26_5',
    'QUESTIONTWTYSIX_6': 'QUESTION26_6',
    'QUESTIONTWTYSVN_1': 'QUESTION27_1',
    'QUESTIONTWTYSVN_2': 'QUESTION27_2',
    'QUESTIONTWTYSVN_3': 'QUESTION27_3', 
    'QUESTIONTWTYEGTN_1': 'QUESTION28_1',
    'QUESTIONTWTYEGTN_2': 'QUESTION28_2',
    'QUESTIONTWTYEGTN_3': 'QUESTION28_3',
    'QUESTIONTWTYEGTN_4': 'QUESTION28_4',
    'QUESTIONTWTYEGTN_5': 'QUESTION28_5',
    'QUESTIONTWTYNINT_1': 'QUESTION29_1',
    'QUESTIONTWTYNINT_2': 'QUESTION29_2',
    'QUESTIONTRTY_1': 'QUESTION30_1',
    'QUESTIONTRTY_2': 'QUESTION30_2',
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "ANY1S30QMULTICHOICE Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 34,
#                             "left": 368,
#                             "bottom": 54,
#                             "right": 385
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
