# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if (region['tags'][0].find("NAME")) != -1:
                extractionValue = "BLOCK_ALPHANUMERIC_CLASSIFICATION"
            else:
                extractionValue = "NUMERIC_CLASSIFICATION"
           
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = str(tagGroup)

    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": str(tagGroup),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data


def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "BENEFICIARY DETAILS FROM",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("beneficiary_details_vottraw.json")

# %%
tagGroups = ['CHILDID', 'CHILDFIRSTNAME', 'CHILDLASTNAME', 'MOTHERFIRSTNAME', 'MOTHERLASTNAME', 'FATHERFIRSTNAME', 'FATHERLASTNAME', 'CHILDADHAARID', 'DOB', 'CASTE', 'RELIGION', 'GENDER', 'DISABILITY']

formatLookup = {
    'CHILDID': 'CHILDID',
    'CHILDFIRSTNAME': 'CHILD FIRST NAME',
    'CHILDLASTNAME': 'CHILD LAST NAME',
    'MOTHERFIRSTNAME': 'MOTHER FIRST NAME',
    'MOTHERLASTNAME': 'MOTHER LAST NAME',
    'FATHERFIRSTNAME': 'FATHER FIRST NAME',
    'FATHERLASTNAME': 'FATHER LAST NAME',
    'CHILDADHAARID': 'ADHAAR CARD ID',
    'DOB': 'DOB',
    'CASTE': 'CASTE',
    'RELIGION': 'RELIGION',
    'GENDER': 'GENDER',
    'DISABILITY': 'DISABILITY'

}

formatAnnotationTagLookup = {
    'CHILDIDTEN': 'CHILDID10',
    'CHILDIDELE': 'CHILDID11',
    'CHILDIDTWL': 'CHILDID12',
    'CHILDIDTHRTN': 'CHILDID13',
    'CHILDIDFORTN': 'CHILDID14',
    'CHILDIDFIFTN': 'CHILDID15',
    'CHILDIDSIXTN': 'CHILDID16',
    'CHILDIDSVNTN': 'CHILDID17',
    'CHILDIDEGTN': 'CHILDID18',
    'CHILDIDNITN': 'CHILDID19',
    'CHILDIDTWNTY': 'CHILDID20',
    'CHILDFIRSTNAMETEN': 'CHILDFIRSTNAME10',
    'CHILDFIRSTNAMEELE': 'CHILDFIRSTNAME11',
    'CHILDFIRSTNAMETWL': 'CHILDFIRSTNAME12',
    'CHILDFIRSTNAMETHRTN': 'CHILDFIRSTNAME13',
    'CHILDFIRSTNAMEFORTN': 'CHILDFIRSTNAME14',
    'CHILDFIRSTNAMEFIFTN': 'CHILDFIRSTNAME15',
    'CHILDFIRSTNAMESIXTN': 'CHILDFIRSTNAME16',
    'CHILDFIRSTNAMESVNTN': 'CHILDFIRSTNAME17',
    'CHILDFIRSTNAMEEGTN': 'CHILDFIRSTNAME18',
    'CHILDFIRSTNAMENITN': 'CHILDFIRSTNAME19',
    'CHILDFIRSTNAMETWNTY': 'CHILDFIRSTNAME20',
    'CHILDLASTNAMETEN': 'CHILDLASTNAME10',
    'CHILDLASTNAMEELE': 'CHILDLASTNAME11',
    'CHILDLASTNAMETWL': 'CHILDLASTNAME12',
    'CHILDLASTNAMETHRTN': 'CHILDLASTNAME13',
    'CHILDLASTNAMEFORTN': 'CHILDLASTNAME14',
    'CHILDLASTNAMEFIFTN': 'CHILDLASTNAME15',
    'CHILDLASTNAMESIXTN': 'CHILDLASTNAME16',
    'CHILDLASTNAMESVNTN': 'CHILDLASTNAME17',
    'CHILDLASTNAMEEGTN': 'CHILDLASTNAME18',
    'CHILDLASTNAMENITN': 'CHILDLASTNAME19',
    'CHILDLASTNAMETWNTY': 'CHILDLASTNAME20',
    'MOTHERFIRSTNAMETEN': 'MOTHERFIRSTNAME10',
    'MOTHERFIRSTNAMEELE': 'MOTHERFIRSTNAME11',
    'MOTHERFIRSTNAMETWL': 'MOTHERFIRSTNAME12',
    'MOTHERFIRSTNAMETHRTN': 'MOTHERFIRSTNAME13',
    'MOTHERFIRSTNAMEFORTN': 'MOTHERFIRSTNAME14',
    'MOTHERFIRSTNAMEFIFTN': 'MOTHERFIRSTNAME15',
    'MOTHERFIRSTNAMESIXTN': 'MOTHERFIRSTNAME16',
    'MOTHERFIRSTNAMESVNTN': 'MOTHERFIRSTNAME17',
    'MOTHERFIRSTNAMEEGTN': 'MOTHERFIRSTNAME18',
    'MOTHERFIRSTNAMENITN': 'MOTHERFIRSTNAME19',
    'MOTHERFIRSTNAMETWNTY': 'MOTHERFIRSTNAME20',
    'MOTHERLASTNAMETEN': 'MOTHERLASTNAME10',
    'MOTHERLASTNAMEELE': 'MOTHERLASTNAME11',
    'MOTHERLASTNAMETWL': 'MOTHERLASTNAME12',
    'MOTHERLASTNAMETHRTN': 'MOTHERLASTNAME13',
    'MOTHERLASTNAMEFORTN': 'MOTHERLASTNAME14',
    'MOTHERLASTNAMEFIFTN': 'MOTHERLASTNAME15',
    'MOTHERLASTNAMESIXTN': 'MOTHERLASTNAME16',
    'MOTHERLASTNAMESVNTN': 'MOTHERLASTNAME17',
    'MOTHERLASTNAMEEGTN': 'MOTHERLASTNAME18',
    'MOTHERLASTNAMENITN': 'MOTHERLASTNAME19',
    'MOTHERLASTNAMETWNTY': 'MOTHERLASTNAME20',
    'FATHERFIRSTNAMETEN': 'FATHERFIRSTNAME10',
    'FATHERFIRSTNAMEELE': 'FATHERFIRSTNAME11',
    'FATHERFIRSTNAMETWL': 'FATHERFIRSTNAME12',
    'FATHERFIRSTNAMETHRTN': 'FATHERFIRSTNAME13',
    'FATHERFIRSTNAMEFORTN': 'FATHERFIRSTNAME14',
    'FATHERFIRSTNAMEFIFTN': 'FATHERFIRSTNAME15',
    'FATHERFIRSTNAMESIXTN': 'FATHERFIRSTNAME16',
    'FATHERFIRSTNAMESVNTN': 'FATHERFIRSTNAME17',
    'FATHERFIRSTNAMEEGTN': 'FATHERFIRSTNAME18',
    'FATHERFIRSTNAMENITN': 'FATHERFIRSTNAME19',
    'FATHERFIRSTNAMETWNTY': 'FATHERFIRSTNAME20',
    'FATHERLASTNAMETEN': 'FATHERLASTNAME10',
    'FATHERLASTNAMEELE': 'FATHERLASTNAME11',
    'FATHERLASTNAMETWL': 'FATHERLASTNAME12',
    'FATHERLASTNAMETHRTN': 'FATHERLASTNAME13',
    'FATHERLASTNAMEFORTN': 'FATHERLASTNAME14',
    'FATHERLASTNAMEFIFTN': 'FATHERLASTNAME15',
    'FATHERLASTNAMESIXTN': 'FATHERLASTNAME16',
    'FATHERLASTNAMESVNTN': 'FATHERLASTNAME17',
    'FATHERLASTNAMEEGTN': 'FATHERLASTNAME18',
    'FATHERLASTNAMENITN': 'FATHERLASTNAME19',
    'FATHERLASTNAMETWNTY': 'FATHERLASTNAME20',
    'CHILDADHAARIDTEN': 'CHILDADHAARID10',
    'CHILDADHAARIDELE': 'CHILDADHAARID11',
    'CHILDADHAARIDTWL': 'CHILDADHAARID12'
}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "BENEFICIARY DETAILS FROM",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 22,
#                             "left": 148,
#                             "bottom": 55,
#                             "right": 171
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 22,
#                             "left": 172,
#                             "bottom": 54,
#                             "right": 194
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 22,
#                             "left": 195,
#                             "bottom": 55,
#                             "right": 218
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 23,
#                             "left": 220,
#                             "bottom": 54,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 22,
#                             "left": 243,
#                             "bottom": 55,
#                             "right": 267
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 23,
#                             "left": 267,
#                             "bottom": 55,
#                             "right": 290
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 23,
#                             "left": 292,
#                             "bottom": 56,
#                             "right": 313
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 7,
#                         "rect": {
#                             "top": 22,
#                             "left": 315,
#                             "bottom": 55,
#                             "right": 338
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 8,
#                         "rect": {
#                             "top": 22,
#                             "left": 339,
#                             "bottom": 54,
#                             "right": 361
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 9,
#                         "rect": {
#                             "top": 22,
#                             "left": 363,
#                             "bottom": 56,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 10,
#                         "rect": {
#                             "top": 23,
#                             "left": 387,
#                             "bottom": 55,
#                             "right": 409
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 11,
#                         "rect": {
#                             "top": 22,
#                             "left": 411,
#                             "bottom": 54,
#                             "right": 433
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID13",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 12,
#                         "rect": {
#                             "top": 22,
#                             "left": 433,
#                             "bottom": 55,
#                             "right": 456
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID14",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "14",
#                         "index": 13,
#                         "rect": {
#                             "top": 21,
#                             "left": 458,
#                             "bottom": 55,
#                             "right": 480
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID15",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "15",
#                         "index": 14,
#                         "rect": {
#                             "top": 22,
#                             "left": 483,
#                             "bottom": 55,
#                             "right": 505
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID16",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "16",
#                         "index": 15,
#                         "rect": {
#                             "top": 22,
#                             "left": 505,
#                             "bottom": 53,
#                             "right": 527
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID17",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "17",
#                         "index": 16,
#                         "rect": {
#                             "top": 23,
#                             "left": 530,
#                             "bottom": 55,
#                             "right": 553
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID18",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "18",
#                         "index": 17,
#                         "rect": {
#                             "top": 22,
#                             "left": 553,
#                             "bottom": 54,
#                             "right": 575
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID19",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "19",
#                         "index": 18,
#                         "rect": {
#                             "top": 22,
#                             "left": 577,
#                             "bottom": 55,
#                             "right": 599
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDID20",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "20",
#                         "index": 19,
#                         "rect": {
#                             "top": 22,
#                             "left": 600,
#                             "bottom": 55,
#                             "right": 623
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "CHILDID",
#                     "value": "CHILDID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDFIRSTNAME1",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "21",
#                         "index": 0,
#                         "rect": {
#                             "top": 56,
#                             "left": 147,
#                             "bottom": 86,
#                             "right": 171
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME2",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "22",
#                         "index": 1,
#                         "rect": {
#                             "top": 54,
#                             "left": 172,
#                             "bottom": 87,
#                             "right": 194
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME3",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "23",
#                         "index": 2,
#                         "rect": {
#                             "top": 55,
#                             "left": 195,
#                             "bottom": 88,
#                             "right": 219
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME4",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "24",
#                         "index": 3,
#                         "rect": {
#                             "top": 55,
#                             "left": 221,
#                             "bottom": 88,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME5",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "25",
#                         "index": 4,
#                         "rect": {
#                             "top": 55,
#                             "left": 245,
#                             "bottom": 88,
#                             "right": 267
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME6",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "26",
#                         "index": 5,
#                         "rect": {
#                             "top": 57,
#                             "left": 268,
#                             "bottom": 88,
#                             "right": 291
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME7",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "27",
#                         "index": 6,
#                         "rect": {
#                             "top": 57,
#                             "left": 291,
#                             "bottom": 89,
#                             "right": 313
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME8",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "28",
#                         "index": 7,
#                         "rect": {
#                             "top": 58,
#                             "left": 316,
#                             "bottom": 88,
#                             "right": 337
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME9",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "29",
#                         "index": 8,
#                         "rect": {
#                             "top": 57,
#                             "left": 339,
#                             "bottom": 88,
#                             "right": 361
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME10",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "30",
#                         "index": 9,
#                         "rect": {
#                             "top": 58,
#                             "left": 363,
#                             "bottom": 89,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME11",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "31",
#                         "index": 10,
#                         "rect": {
#                             "top": 57,
#                             "left": 386,
#                             "bottom": 88,
#                             "right": 409
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME12",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "32",
#                         "index": 11,
#                         "rect": {
#                             "top": 56,
#                             "left": 409,
#                             "bottom": 89,
#                             "right": 431
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME13",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "33",
#                         "index": 12,
#                         "rect": {
#                             "top": 56,
#                             "left": 434,
#                             "bottom": 89,
#                             "right": 456
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME14",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "34",
#                         "index": 13,
#                         "rect": {
#                             "top": 56,
#                             "left": 458,
#                             "bottom": 88,
#                             "right": 480
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME15",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "35",
#                         "index": 14,
#                         "rect": {
#                             "top": 56,
#                             "left": 482,
#                             "bottom": 89,
#                             "right": 504
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME16",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "36",
#                         "index": 15,
#                         "rect": {
#                             "top": 56,
#                             "left": 507,
#                             "bottom": 88,
#                             "right": 529
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME17",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "37",
#                         "index": 16,
#                         "rect": {
#                             "top": 56,
#                             "left": 529,
#                             "bottom": 88,
#                             "right": 552
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME18",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "38",
#                         "index": 17,
#                         "rect": {
#                             "top": 56,
#                             "left": 553,
#                             "bottom": 89,
#                             "right": 575
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME19",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "39",
#                         "index": 18,
#                         "rect": {
#                             "top": 55,
#                             "left": 577,
#                             "bottom": 88,
#                             "right": 598
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDFIRSTNAME20",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "40",
#                         "index": 19,
#                         "rect": {
#                             "top": 56,
#                             "left": 599,
#                             "bottom": 89,
#                             "right": 622
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "CHILDFIRSTNAME",
#                     "value": "CHILD FIRST NAME"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDLASTNAME1",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "41",
#                         "index": 0,
#                         "rect": {
#                             "top": 88,
#                             "left": 148,
#                             "bottom": 122,
#                             "right": 171
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME2",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "42",
#                         "index": 1,
#                         "rect": {
#                             "top": 88,
#                             "left": 172,
#                             "bottom": 122,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME3",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "43",
#                         "index": 2,
#                         "rect": {
#                             "top": 89,
#                             "left": 195,
#                             "bottom": 122,
#                             "right": 218
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME4",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "44",
#                         "index": 3,
#                         "rect": {
#                             "top": 90,
#                             "left": 220,
#                             "bottom": 123,
#                             "right": 242
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME5",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "45",
#                         "index": 4,
#                         "rect": {
#                             "top": 90,
#                             "left": 243,
#                             "bottom": 123,
#                             "right": 266
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME6",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "46",
#                         "index": 5,
#                         "rect": {
#                             "top": 90,
#                             "left": 266,
#                             "bottom": 123,
#                             "right": 289
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME7",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "47",
#                         "index": 6,
#                         "rect": {
#                             "top": 91,
#                             "left": 291,
#                             "bottom": 123,
#                             "right": 314
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME8",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "48",
#                         "index": 7,
#                         "rect": {
#                             "top": 90,
#                             "left": 316,
#                             "bottom": 122,
#                             "right": 337
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME9",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "49",
#                         "index": 8,
#                         "rect": {
#                             "top": 91,
#                             "left": 340,
#                             "bottom": 122,
#                             "right": 362
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME10",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "50",
#                         "index": 9,
#                         "rect": {
#                             "top": 90,
#                             "left": 362,
#                             "bottom": 123,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME11",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "51",
#                         "index": 10,
#                         "rect": {
#                             "top": 90,
#                             "left": 387,
#                             "bottom": 123,
#                             "right": 409
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME12",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "52",
#                         "index": 11,
#                         "rect": {
#                             "top": 89,
#                             "left": 411,
#                             "bottom": 123,
#                             "right": 433
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME13",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "53",
#                         "index": 12,
#                         "rect": {
#                             "top": 90,
#                             "left": 435,
#                             "bottom": 123,
#                             "right": 456
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME14",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "54",
#                         "index": 13,
#                         "rect": {
#                             "top": 90,
#                             "left": 458,
#                             "bottom": 122,
#                             "right": 480
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME15",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "55",
#                         "index": 14,
#                         "rect": {
#                             "top": 89,
#                             "left": 482,
#                             "bottom": 122,
#                             "right": 504
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME16",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "56",
#                         "index": 15,
#                         "rect": {
#                             "top": 90,
#                             "left": 505,
#                             "bottom": 121,
#                             "right": 527
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME17",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "57",
#                         "index": 16,
#                         "rect": {
#                             "top": 90,
#                             "left": 529,
#                             "bottom": 123,
#                             "right": 551
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME18",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "58",
#                         "index": 17,
#                         "rect": {
#                             "top": 89,
#                             "left": 552,
#                             "bottom": 122,
#                             "right": 575
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME19",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "59",
#                         "index": 18,
#                         "rect": {
#                             "top": 90,
#                             "left": 579,
#                             "bottom": 122,
#                             "right": 600
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDLASTNAME20",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "60",
#                         "index": 19,
#                         "rect": {
#                             "top": 92,
#                             "left": 599,
#                             "bottom": 123,
#                             "right": 623
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "CHILDLASTNAME",
#                     "value": "CHILD LAST NAME"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME1",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "61",
#                         "index": 0,
#                         "rect": {
#                             "top": 124,
#                             "left": 149,
#                             "bottom": 155,
#                             "right": 171
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME2",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "62",
#                         "index": 1,
#                         "rect": {
#                             "top": 122,
#                             "left": 172,
#                             "bottom": 155,
#                             "right": 194
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME3",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "63",
#                         "index": 2,
#                         "rect": {
#                             "top": 124,
#                             "left": 197,
#                             "bottom": 157,
#                             "right": 219
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME4",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "64",
#                         "index": 3,
#                         "rect": {
#                             "top": 122,
#                             "left": 220,
#                             "bottom": 156,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME5",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "65",
#                         "index": 4,
#                         "rect": {
#                             "top": 123,
#                             "left": 245,
#                             "bottom": 156,
#                             "right": 266
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME6",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "66",
#                         "index": 5,
#                         "rect": {
#                             "top": 123,
#                             "left": 266,
#                             "bottom": 155,
#                             "right": 290
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME7",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "67",
#                         "index": 6,
#                         "rect": {
#                             "top": 123,
#                             "left": 291,
#                             "bottom": 157,
#                             "right": 313
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME8",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "68",
#                         "index": 7,
#                         "rect": {
#                             "top": 123,
#                             "left": 316,
#                             "bottom": 156,
#                             "right": 338
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME9",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "69",
#                         "index": 8,
#                         "rect": {
#                             "top": 123,
#                             "left": 339,
#                             "bottom": 157,
#                             "right": 361
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME10",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "70",
#                         "index": 9,
#                         "rect": {
#                             "top": 124,
#                             "left": 361,
#                             "bottom": 156,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME11",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "71",
#                         "index": 10,
#                         "rect": {
#                             "top": 123,
#                             "left": 386,
#                             "bottom": 155,
#                             "right": 409
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME12",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "72",
#                         "index": 11,
#                         "rect": {
#                             "top": 123,
#                             "left": 410,
#                             "bottom": 155,
#                             "right": 433
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME13",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "73",
#                         "index": 12,
#                         "rect": {
#                             "top": 125,
#                             "left": 434,
#                             "bottom": 155,
#                             "right": 456
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME14",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "74",
#                         "index": 13,
#                         "rect": {
#                             "top": 122,
#                             "left": 458,
#                             "bottom": 155,
#                             "right": 479
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME15",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "75",
#                         "index": 14,
#                         "rect": {
#                             "top": 123,
#                             "left": 482,
#                             "bottom": 155,
#                             "right": 504
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME16",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "76",
#                         "index": 15,
#                         "rect": {
#                             "top": 124,
#                             "left": 506,
#                             "bottom": 156,
#                             "right": 527
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME17",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "77",
#                         "index": 16,
#                         "rect": {
#                             "top": 123,
#                             "left": 530,
#                             "bottom": 155,
#                             "right": 552
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME18",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "78",
#                         "index": 17,
#                         "rect": {
#                             "top": 123,
#                             "left": 554,
#                             "bottom": 155,
#                             "right": 574
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME19",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "79",
#                         "index": 18,
#                         "rect": {
#                             "top": 123,
#                             "left": 577,
#                             "bottom": 156,
#                             "right": 599
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERFIRSTNAME20",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "80",
#                         "index": 19,
#                         "rect": {
#                             "top": 124,
#                             "left": 601,
#                             "bottom": 154,
#                             "right": 624
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "MOTHERFIRSTNAME",
#                     "value": "MOTHER FIRST NAME"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "MOTHERLASTNAME1",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "81",
#                         "index": 0,
#                         "rect": {
#                             "top": 157,
#                             "left": 147,
#                             "bottom": 187,
#                             "right": 170
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME2",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "82",
#                         "index": 1,
#                         "rect": {
#                             "top": 157,
#                             "left": 173,
#                             "bottom": 189,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME3",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "83",
#                         "index": 2,
#                         "rect": {
#                             "top": 157,
#                             "left": 196,
#                             "bottom": 189,
#                             "right": 219
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME4",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "84",
#                         "index": 3,
#                         "rect": {
#                             "top": 157,
#                             "left": 220,
#                             "bottom": 188,
#                             "right": 241
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME5",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "85",
#                         "index": 4,
#                         "rect": {
#                             "top": 157,
#                             "left": 244,
#                             "bottom": 188,
#                             "right": 266
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME6",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "86",
#                         "index": 5,
#                         "rect": {
#                             "top": 156,
#                             "left": 268,
#                             "bottom": 189,
#                             "right": 290
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME7",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "87",
#                         "index": 6,
#                         "rect": {
#                             "top": 158,
#                             "left": 291,
#                             "bottom": 189,
#                             "right": 313
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME8",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "88",
#                         "index": 7,
#                         "rect": {
#                             "top": 156,
#                             "left": 315,
#                             "bottom": 189,
#                             "right": 337
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME9",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "89",
#                         "index": 8,
#                         "rect": {
#                             "top": 157,
#                             "left": 337,
#                             "bottom": 188,
#                             "right": 361
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME10",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "90",
#                         "index": 9,
#                         "rect": {
#                             "top": 157,
#                             "left": 363,
#                             "bottom": 189,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME11",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "91",
#                         "index": 10,
#                         "rect": {
#                             "top": 157,
#                             "left": 385,
#                             "bottom": 189,
#                             "right": 409
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME12",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "92",
#                         "index": 11,
#                         "rect": {
#                             "top": 156,
#                             "left": 410,
#                             "bottom": 189,
#                             "right": 432
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME13",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "93",
#                         "index": 12,
#                         "rect": {
#                             "top": 156,
#                             "left": 433,
#                             "bottom": 190,
#                             "right": 456
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME14",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "94",
#                         "index": 13,
#                         "rect": {
#                             "top": 156,
#                             "left": 458,
#                             "bottom": 189,
#                             "right": 480
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME15",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "95",
#                         "index": 14,
#                         "rect": {
#                             "top": 156,
#                             "left": 481,
#                             "bottom": 190,
#                             "right": 504
#                         }
#                     },
#                     {
#                         "annotationTags": "MOTHERLASTNAME16",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "96",
#                         "index": 15,
#                         "rect": {
#                             "top": 158,
# ...
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "135",
#                         "index": 14,
#                         "rect": {
#                             "top": 224,
#                             "left": 481,
#                             "bottom": 257,
#                             "right": 502
#                         }
#                     },
#                     {
#                         "annotationTags": "FATHERLASTNAME16",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "136",
#                         "index": 15,
#                         "rect": {
#                             "top": 223,
#                             "left": 504,
#                             "bottom": 257,
#                             "right": 527
#                         }
#                     },
#                     {
#                         "annotationTags": "FATHERLASTNAME17",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "137",
#                         "index": 16,
#                         "rect": {
#                             "top": 223,
#                             "left": 530,
#                             "bottom": 257,
#                             "right": 551
#                         }
#                     },
#                     {
#                         "annotationTags": "FATHERLASTNAME18",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "138",
#                         "index": 17,
#                         "rect": {
#                             "top": 225,
#                             "left": 553,
#                             "bottom": 256,
#                             "right": 575
#                         }
#                     },
#                     {
#                         "annotationTags": "FATHERLASTNAME19",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "139",
#                         "index": 18,
#                         "rect": {
#                             "top": 223,
#                             "left": 578,
#                             "bottom": 257,
#                             "right": 599
#                         }
#                     },
#                     {
#                         "annotationTags": "FATHERLASTNAME20",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "140",
#                         "index": 19,
#                         "rect": {
#                             "top": 224,
#                             "left": 600,
#                             "bottom": 257,
#                             "right": 623
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "FATHERLASTNAME",
#                     "value": "FATHER LAST NAME"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8",
#                 "rois": [
#                     {
#                         "annotationTags": "CHILDADHAARID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "141",
#                         "index": 0,
#                         "rect": {
#                             "top": 258,
#                             "left": 149,
#                             "bottom": 291,
#                             "right": 172
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "142",
#                         "index": 1,
#                         "rect": {
#                             "top": 258,
#                             "left": 173,
#                             "bottom": 289,
#                             "right": 196
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "143",
#                         "index": 2,
#                         "rect": {
#                             "top": 258,
#                             "left": 197,
#                             "bottom": 289,
#                             "right": 219
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "144",
#                         "index": 3,
#                         "rect": {
#                             "top": 258,
#                             "left": 220,
#                             "bottom": 291,
#                             "right": 243
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "145",
#                         "index": 4,
#                         "rect": {
#                             "top": 258,
#                             "left": 243,
#                             "bottom": 291,
#                             "right": 266
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "146",
#                         "index": 5,
#                         "rect": {
#                             "top": 258,
#                             "left": 268,
#                             "bottom": 289,
#                             "right": 289
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "147",
#                         "index": 6,
#                         "rect": {
#                             "top": 259,
#                             "left": 292,
#                             "bottom": 289,
#                             "right": 313
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "148",
#                         "index": 7,
#                         "rect": {
#                             "top": 258,
#                             "left": 314,
#                             "bottom": 290,
#                             "right": 337
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "149",
#                         "index": 8,
#                         "rect": {
#                             "top": 257,
#                             "left": 340,
#                             "bottom": 290,
#                             "right": 360
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "150",
#                         "index": 9,
#                         "rect": {
#                             "top": 258,
#                             "left": 363,
#                             "bottom": 290,
#                             "right": 384
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "151",
#                         "index": 10,
#                         "rect": {
#                             "top": 258,
#                             "left": 386,
#                             "bottom": 290,
#                             "right": 408
#                         }
#                     },
#                     {
#                         "annotationTags": "CHILDADHAARID12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "152",
#                         "index": 11,
#                         "rect": {
#                             "top": 259,
#                             "left": 410,
#                             "bottom": 290,
#                             "right": 431
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "CHILDADHAARID",
#                     "value": "ADHAAR CARD ID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9",
#                 "rois": [
#                     {
#                         "annotationTags": "DOB1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "153",
#                         "index": 0,
#                         "rect": {
#                             "top": 291,
#                             "left": 148,
#                             "bottom": 324,
#                             "right": 171
#                         }
#                     },
#                     {
#                         "annotationTags": "DOB2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "154",
#                         "index": 1,
#                         "rect": {
#                             "top": 291,
#                             "left": 171,
#                             "bottom": 324,
#                             "right": 195
#                         }
#                     },
#                     {
#                         "annotationTags": "DOB3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "155",
#                         "index": 2,
#                         "rect": {
#                             "top": 290,
#                             "left": 197,
#                             "bottom": 324,
#                             "right": 218
#                         }
#                     },
#                     {
#                         "annotationTags": "DOB4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "156",
#                         "index": 3,
#                         "rect": {
#                             "top": 289,
#                             "left": 219,
#                             "bottom": 323,
#                             "right": 242
#                         }
#                     },
#                     {
#                         "annotationTags": "DOB5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "157",
#                         "index": 4,
#                         "rect": {
#                             "top": 290,
#                             "left": 245,
#                             "bottom": 322,
#                             "right": 265
#                         }
#                     },
#                     {
#                         "annotationTags": "DOB6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "158",
#                         "index": 5,
#                         "rect": {
#                             "top": 292,
#                             "left": 267,
#                             "bottom": 323,
#                             "right": 290
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "DOB",
#                     "value": "DOB"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "10",
#                 "rois": [
#                     {
#                         "annotationTags": "CASTE",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "159",
#                         "index": 0,
#                         "rect": {
#                             "top": 324,
#                             "left": 147,
#                             "bottom": 357,
#                             "right": 170
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "CASTE",
#                     "value": "CASTE"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "11",
#                 "rois": [
#                     {
#                         "annotationTags": "RELIGION",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "160",
#                         "index": 0,
#                         "rect": {
#                             "top": 357,
#                             "left": 148,
#                             "bottom": 390,
#                             "right": 171
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "RELIGION",
#                     "value": "RELIGION"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "12",
#                 "rois": [
#                     {
#                         "annotationTags": "GENDER",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "161",
#                         "index": 0,
#                         "rect": {
#                             "top": 391,
#                             "left": 148,
#                             "bottom": 424,
#                             "right": 171
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "GENDER",
#                     "value": "GENDER"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13",
#                 "rois": [
#                     {
#                         "annotationTags": "DISABILITY",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "162",
#                         "index": 0,
#                         "rect": {
#                             "top": 425,
#                             "left": 147,
#                             "bottom": 458,
#                             "right": 171
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "DISABILITY",
#                     "value": "DISABILITY"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
