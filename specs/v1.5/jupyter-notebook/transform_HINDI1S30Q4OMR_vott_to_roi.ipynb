# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("ROLLNUMBER"):
                extractionValue = "NUMERIC_CLASSIFICATION"
            else:
                extractionValue = "CELL_OMR"
            
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            rois.append({

                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""
            
              try:
                  formatName = formatNameLookup[str(tagGroup)]
              except KeyError as ke:
                  formatName = ""

              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": formatName,
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "ANY1S30QOMRMULTICHOICE Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("ANY1S30Q4omr_vottraw.json")

# %%
tagGroups = ["ROLLNUMBER", "QUESTION1","QUESTION2","QUESTION3","QUESTION4","QUESTION5","QUESTION6","QUESTION7","QUESTION8","QUESTION9","QUESTIONTEN","QUESTIONELE","QUESTIONTWL","QUESTIONTHRTN","QUESTIONFORTN","QUESTIONFIFTN","QUESTIONSXTN","QUESTIONSVNTN","QUESTIONEGTN","QUESTIONNINT","QUESTIONTWENTY","QUESTIONTWENONE","QUESTIONTWENTWO","QUESTIONTWENTHREE","QUESTIONTWENFOUR","QUESTIONTTWENFIVE","QUESTIONTWENSIX","QUESTIONTWENSVN","QUESTIONTWENEGTN","QUESTIONTWENINTN","QUESTIONTHRTY"]

formatLookup = {
    'ROLLNUMBER': 'ROLLNUMBER',
    'QUESTION1':'QUESTION 1',
    'QUESTION2':'QUESTION 2',
    'QUESTION3':'QUESTION 3',
    'QUESTION4':'QUESTION 4',
    'QUESTION5':'QUESTION 5',
    'QUESTION6':'QUESTION 6',
    'QUESTION7':'QUESTION 7',
    'QUESTION8':'QUESTION 8',
    'QUESTION9':'QUESTION 9',
    'QUESTIONTEN': 'QUESTION 10',
    'QUESTIONELE': 'QUESTION 11',
    'QUESTIONTWL': 'QUESTION 12',
    'QUESTIONTHRTN': 'QUESTION 13',
    'QUESTIONFORTN': 'QUESTION 14',
    'QUESTIONFIFTN': 'QUESTION 15',
    'QUESTIONSXTN': 'QUESTION 16',
    'QUESTIONSVNTN': 'QUESTION 17',
    'QUESTIONEGTN': 'QUESTION 18',
    'QUESTIONNINT': 'QUESTION 19',
    'QUESTIONTWENTY': 'QUESTION 20',
    'QUESTIONTWENONE': 'QUESTION 21',
    'QUESTIONTWENTWO': 'QUESTION 22',
    'QUESTIONTWENTHREE': 'QUESTION 23',
    'QUESTIONTWENFOUR': 'QUESTION 24',
    'QUESTIONTTWENFIVE': 'QUESTION 25',
    'QUESTIONTWENSIX': 'QUESTION 26',
    'QUESTIONTWENSVN': 'QUESTION 27',
    'QUESTIONTWENEGTN': 'QUESTION 28',
    'QUESTIONTWENINTN': 'QUESTION 29',
    'QUESTIONTHRTY': 'QUESTION 30'
}

formatNameLookup = {
    'ROLLNUMBER': 'ROLLNUMBER',
    'QUESTION1':'QUESTION1',
    'QUESTION2':'QUESTION2',
    'QUESTION3':'QUESTION3',
    'QUESTION4':'QUESTION4',
    'QUESTION5':'QUESTION5',
    'QUESTION6':'QUESTION6',
    'QUESTION7':'QUESTION7',
    'QUESTION8':'QUESTION8',
    'QUESTION9':'QUESTION9',
    'QUESTIONTEN': 'QUESTION10',
    'QUESTIONELE': 'QUESTION11',
    'QUESTIONTWL': 'QUESTION12',
    'QUESTIONTHRTN': 'QUESTION13',
    'QUESTIONFORTN': 'QUESTION14',
    'QUESTIONFIFTN': 'QUESTION15',
    'QUESTIONSXTN': 'QUESTION16',
    'QUESTIONSVNTN': 'QUESTION17',
    'QUESTIONEGTN': 'QUESTION18',
    'QUESTIONNINT': 'QUESTION19',
    'QUESTIONTWENTY': 'QUESTION20',
    'QUESTIONTWENONE': 'QUESTION21',
    'QUESTIONTWENTWO': 'QUESTION22',
    'QUESTIONTWENTHREE': 'QUESTION23',
    'QUESTIONTWENFOUR': 'QUESTION24',
    'QUESTIONTTWENFIVE': 'QUESTION25',
    'QUESTIONTWENSIX': 'QUESTION26',
    'QUESTIONTWENSVN': 'QUESTION27',
    'QUESTIONTWENEGTN': 'QUESTION28',
    'QUESTIONTWENINTN': 'QUESTION29',
    'QUESTIONTHRTY': 'QUESTION 30'

}
formatAnnotationTagLookup = {
    'QUESTIONTEN_1': 'QUESTION10_1',
    'QUESTIONTEN_2': 'QUESTION10_2',
    'QUESTIONTEN_3': 'QUESTION10_3',
    'QUESTIONTEN_4': 'QUESTION10_4',
    'QUESTIONELE_1': 'QUESTION11_1',
    'QUESTIONELE_2': 'QUESTION11_2',
    'QUESTIONELE_3': 'QUESTION11_3',
    'QUESTIONELE_4': 'QUESTION11_4',
    'QUESTIONTWL_1': 'QUESTION12_1',
    'QUESTIONTWL_2': 'QUESTION12_2',
    'QUESTIONTWL_3': 'QUESTION12_3',
    'QUESTIONTWL_4': 'QUESTION12_4',
    'QUESTIONTHRTN_1': 'QUESTION13_1',
    'QUESTIONTHRTN_2': 'QUESTION13_2',
    'QUESTIONTHRTN_3': 'QUESTION13_3',
    'QUESTIONTHRTN_4': 'QUESTION13_4',
    'QUESTIONFORTN_1': 'QUESTION14_1',
    'QUESTIONFORTN_2': 'QUESTION14_2',
    'QUESTIONFORTN_3': 'QUESTION14_3',
    'QUESTIONFORTN_4': 'QUESTION14_4',
    'QUESTIONFIFTN_1': 'QUESTION15_1',
    'QUESTIONFIFTN_2': 'QUESTION15_2',
    'QUESTIONFIFTN_3': 'QUESTION15_3',
    'QUESTIONFIFTN_4': 'QUESTION15_4',
    'QUESTIONSXTN_1': 'QUESTION16_1',
    'QUESTIONSXTN_2': 'QUESTION16_2',
    'QUESTIONSXTN_3': 'QUESTION16_3',
    'QUESTIONSXTN_4': 'QUESTION16_4',
    'QUESTIONSVNTN_1': 'QUESTION17_1',
    'QUESTIONSVNTN_2': 'QUESTION17_2',
    'QUESTIONSVNTN_3': 'QUESTION17_3',
    'QUESTIONSVNTN_4': 'QUESTION17_4',
    'QUESTIONEGTN_1': 'QUESTION18_1',
    'QUESTIONEGTN_2': 'QUESTION18_2',
    'QUESTIONEGTN_3': 'QUESTION18_3',
    'QUESTIONEGTN_4': 'QUESTION18_4',
    'QUESTIONNINT_1': 'QUESTION19_1',
    'QUESTIONNINT_2': 'QUESTION19_2',
    'QUESTIONNINT_3': 'QUESTION19_3',
    'QUESTIONNINT_4': 'QUESTION19_4',
    'QUESTIONTWENTY_1': 'QUESTION20_1',
    'QUESTIONTWENTY_2': 'QUESTION20_2',
    'QUESTIONTWENTY_3': 'QUESTION20_3',
    'QUESTIONTWENTY_4': 'QUESTION20_4',
    'QUESTIONTWENONE_1': 'QUESTION21_1',
    'QUESTIONTWENONE_2': 'QUESTION21_2',
    'QUESTIONTWENONE_3': 'QUESTION21_3',
    'QUESTIONTWENONE_4': 'QUESTION21_4',
    'QUESTIONTWENTWO_1': 'QUESTION22_1',
    'QUESTIONTWENTWO_2': 'QUESTION22_2',
    'QUESTIONTWENTWO_3': 'QUESTION22_3',
    'QUESTIONTWENTWO_4': 'QUESTION22_4',
    'QUESTIONTWENTHREE_1': 'QUESTION23_1',
    'QUESTIONTWENTHREE_2': 'QUESTION23_2',
    'QUESTIONTWENTHREE_3': 'QUESTION23_3',
    'QUESTIONTWENTHREE_4': 'QUESTION23_4',
    'QUESTIONTWENFOUR_1': 'QUESTION24_1',
    'QUESTIONTWENFOUR_2': 'QUESTION24_2',
    'QUESTIONTWENFOUR_3': 'QUESTION24_3',
    'QUESTIONTWENFOUR_4': 'QUESTION24_4',
    'QUESTIONTTWENFIVE_1': 'QUESTION25_1',
    'QUESTIONTTWENFIVE_2': 'QUESTION25_2',
    'QUESTIONTTWENFIVE_3': 'QUESTION25_3',
    'QUESTIONTTWENFIVE_4': 'QUESTION25_4',
    'QUESTIONTWENSIX_1': 'QUESTION26_1',
    'QUESTIONTWENSIX_2': 'QUESTION26_2',
    'QUESTIONTWENSIX_3': 'QUESTION26_3',
    'QUESTIONTWENSIX_4': 'QUESTION26_4',
    'QUESTIONTWENSVN_1': 'QUESTION27_1',
    'QUESTIONTWENSVN_2': 'QUESTION27_2',
    'QUESTIONTWENSVN_3': 'QUESTION27_3', 
    'QUESTIONTWENSVN_4': 'QUESTION27_4', 
    'QUESTIONTWENEGTN_1': 'QUESTION28_1',
    'QUESTIONTWENEGTN_2': 'QUESTION28_2',
    'QUESTIONTWENEGTN_3': 'QUESTION28_3',
    'QUESTIONTWENEGTN_4': 'QUESTION28_4',
    'QUESTIONTWENINTN_1': 'QUESTION29_1',
    'QUESTIONTWENINTN_2': 'QUESTION29_2',
    'QUESTIONTWENINTN_3': 'QUESTION29_4',
    'QUESTIONTWENINTN_4': 'QUESTION29_3',
    'QUESTIONTHRTY_1': 'QUESTION30_1',
    'QUESTIONTHRTY_2': 'QUESTION30_2',
    'QUESTIONTHRTY_3': 'QUESTION30_3',
    'QUESTIONTHRTY_4': 'QUESTION30_4',
}

# %%
cells=get_cells(regions,tagGroups,formatLookup,formatNameLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "ANY1S30QOMRMULTICHOICE Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 27,
#                             "left": 108,
#                             "bottom": 55,
#                             "right": 137
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
# ...
