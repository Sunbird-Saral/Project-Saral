# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']
    
def get_rois(regions,tagGroup,formatAnnotationTagLookup):
    rois = []
    index = 0
    global roiIndex
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            if region['tags'][0].startswith("NAME"):
                extractionValue = "BLOCK_ALPHANUMERIC_CLASSIFICATION"
            elif region['tags'][0].startswith("ADDRESS"):
                extractionValue = "BLOCK_ALPHANUMERIC_CLASSIFICATION"
            else: 
                extractionValue = "NUMERIC_CLASSIFICATION"
                
            try:
                annotationTagsValue = formatAnnotationTagLookup[region['tags'][0]]
            except KeyError as ke:
                annotationTagsValue = region['tags'][0]
            
            rois.append({
                "annotationTags": annotationTagsValue,
                "extractionMethod": extractionValue,
                "roiId": str(roiIndex),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 

    return rois

def get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup):
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = str(tagGroup)

    
              cells_data.append({
                          "cellId": str(cellIndex),
                          "rois": get_rois(regions,tagGroup,formatAnnotationTagLookup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": str(tagGroup),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "Personal Details Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions = get_annotation("PERSONAL_DETAILS_vottraw.json")

# %%
tagGroups = ['IDENTIFIERID1', 'NAME1', 'ADDRESS1', 'PINCODE1', 'CONTACTNO1']


formatLookup = {
    'IDENTIFIERID1' : 'IDENTIFIERID',
    'NAME1' : 'NAME',
    'ADDRESS1' : 'ADDRESS',
    'PINCODE1' : 'PINCODE',
    'CONTACTNO1' : 'CONTACTNO'
}



formatAnnotationTagLookup = {
    'IDENTIFIERID1_TEN' : 'IDENTIFIERID1_10',
    'IDENTIFIERID1_ELE' : 'IDENTIFIERID1_11',
    'IDENTIFIERID1_TWL' : 'IDENTIFIERID1_12',
    'NAME1_TEN' : 'NAME1_10',
    'NAME1_ELE' : 'NAME1_11',
    'NAME1_TWL' : 'NAME1_12',
    'NAME1_THRT' : 'NAME1_13',
    'NAME1_FORT' : 'NAME1_14',
    'NAME1_FIFT' : 'NAME1_15',
    'ADDRESS1_TEN': 'ADDRESS1_10',
    'ADDRESS1_ELE': 'ADDRESS1_11',
    'ADDRESS1_TWL': 'ADDRESS1_12 ',
    'ADDRESS1_THRT': 'ADDRESS1_13',
    'ADDRESS1_FORT': 'ADDRESS1_14',
    'ADDRESS1_FIFT': 'ADDRESS1_15',
    'ADDRESS1_SIXT': 'ADDRESS1_16',
    'ADDRESS1_SVNT': 'ADDRESS1_17',
    'ADDRESS1_EGTN': 'ADDRESS1_18',
    'ADDRESS1_NITN': 'ADDRESS1_19',
    'ADDRESS1_TWTY': 'ADDRESS1_20',
    'ADDRESS1_TWTYONE': 'ADDRESS1_21',
    'ADDRESS1_TWTYTWO': 'ADDRESS1_22',
    'ADDRESS1_TWTYTHREE': 'ADDRESS1_23',
    'ADDRESS1_TWTYFOUR': 'ADDRESS1_24',
    'ADDRESS1_TWTYFIVE': 'ADDRESS1_25',
    'ADDRESS1_TWTYSIX': 'ADDRESS1_26',
    'ADDRESS1_TWTYSVN': 'ADDRESS1_27',
    'ADDRESS1_TWTYEGT': 'ADDRESS1_28',
    'ADDRESS1_TWTYNINE': 'ADDRESS1_29',
    'ADDRESS1_THRTY': 'ADDRESS1_30',
    'ADDRESS1_THRTYONE': 'ADDRESS1_31',
    'ADDRESS1_THRTYTWO': 'ADDRESS1_32',
    'ADDRESS1_THRTYTHREE': 'ADDRESS1_33',
    'ADDRESS1_THRTYFOUR': 'ADDRESS1_34',
    'ADDRESS1_THRTYFIVE': 'ADDRESS1_35',
    'ADDRESS1_THRTYSIX': 'ADDRESS1_36',
    'ADDRESS1_THRTYSVN': 'ADDRESS1_37',
    'ADDRESS1_THRTYEGT': 'ADDRESS1_38',
    'ADDRESS1_THRTYNINE': 'ADDRESS1_39',
    'ADDRESS1_FORTY': 'ADDRESS1_40',
    'ADDRESS1_FORTYONE': 'ADDRESS1_41',
    'ADDRESS1_FORTYTWO': 'ADDRESS1_42',
    'ADDRESS1_FORTYTHREE': 'ADDRESS1_43',
    'ADDRESS1_FORTYFOUR': 'ADDRESS1_44',
    'ADDRESS1_FORTYFIVE': 'ADDRESS1_45',
    'ADDRESS1_FORTYSIX': 'ADDRESS1_46',
    'ADDRESS1_FORTYSVN': 'ADDRESS1_47',
    'ADDRESS1_FORTYEGT': 'ADDRESS1_48',
    'ADDRESS1_FORTYNINE': 'ADDRESS1_49',
    'ADDRESS1_FIFTY': 'ADDRESS1_50',
    'ADDRESS1_FIFTYONE': 'ADDRESS1_51',
    'CONTACTNO1_TEN': 'CONTACTNO1_10',
}

# %%
cells = get_cells(regions,tagGroups,formatLookup,formatAnnotationTagLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "Personal Details Sheet Form",
#         "cells": [
#             {
#                 "cellId": "1",
#                 "rois": [
#                     {
#                         "annotationTags": "IDENTIFIERID1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1",
#                         "index": 0,
#                         "rect": {
#                             "top": 66,
#                             "left": 34,
#                             "bottom": 90,
#                             "right": 54
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2",
#                         "index": 1,
#                         "rect": {
#                             "top": 66,
#                             "left": 56,
#                             "bottom": 90,
#                             "right": 74
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3",
#                         "index": 2,
#                         "rect": {
#                             "top": 67,
#                             "left": 75,
#                             "bottom": 91,
#                             "right": 96
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4",
#                         "index": 3,
#                         "rect": {
#                             "top": 68,
#                             "left": 97,
#                             "bottom": 92,
#                             "right": 117
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5",
#                         "index": 4,
#                         "rect": {
#                             "top": 67,
#                             "left": 117,
#                             "bottom": 92,
#                             "right": 137
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6",
#                         "index": 5,
#                         "rect": {
#                             "top": 67,
#                             "left": 139,
#                             "bottom": 91,
#                             "right": 158
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7",
#                         "index": 6,
#                         "rect": {
#                             "top": 67,
#                             "left": 158,
#                             "bottom": 91,
#                             "right": 178
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8",
#                         "index": 7,
#                         "rect": {
#                             "top": 66,
#                             "left": 181,
#                             "bottom": 92,
#                             "right": 198
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9",
#                         "index": 8,
#                         "rect": {
#                             "top": 67,
#                             "left": 199,
#                             "bottom": 91,
#                             "right": 219
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "10",
#                         "index": 9,
#                         "rect": {
#                             "top": 67,
#                             "left": 219,
#                             "bottom": 91,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "11",
#                         "index": 10,
#                         "rect": {
#                             "top": 67,
#                             "left": 242,
#                             "bottom": 93,
#                             "right": 260
#                         }
#                     },
#                     {
#                         "annotationTags": "IDENTIFIERID1_12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "12",
#                         "index": 11,
#                         "rect": {
#                             "top": 67,
#                             "left": 262,
#                             "bottom": 93,
#                             "right": 282
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "IDENTIFIERID1",
#                     "value": "IDENTIFIERID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2",
#                 "rois": [
#                     {
#                         "annotationTags": "NAME1_1",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "13",
#                         "index": 0,
#                         "rect": {
#                             "top": 146,
#                             "left": 34,
#                             "bottom": 170,
#                             "right": 55
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_2",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "14",
#                         "index": 1,
#                         "rect": {
#                             "top": 147,
#                             "left": 56,
#                             "bottom": 173,
#                             "right": 76
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_3",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "15",
#                         "index": 2,
#                         "rect": {
#                             "top": 147,
#                             "left": 78,
#                             "bottom": 172,
#                             "right": 96
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_4",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "16",
#                         "index": 3,
#                         "rect": {
#                             "top": 147,
#                             "left": 98,
#                             "bottom": 173,
#                             "right": 118
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_5",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "17",
#                         "index": 4,
#                         "rect": {
#                             "top": 147,
#                             "left": 118,
#                             "bottom": 173,
#                             "right": 137
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_6",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "18",
#                         "index": 5,
#                         "rect": {
#                             "top": 147,
#                             "left": 138,
#                             "bottom": 173,
#                             "right": 158
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_7",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "19",
#                         "index": 6,
#                         "rect": {
#                             "top": 148,
#                             "left": 158,
#                             "bottom": 172,
#                             "right": 178
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_8",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "20",
#                         "index": 7,
#                         "rect": {
#                             "top": 146,
#                             "left": 180,
#                             "bottom": 172,
#                             "right": 199
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_9",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "21",
#                         "index": 8,
#                         "rect": {
#                             "top": 148,
#                             "left": 200,
#                             "bottom": 172,
#                             "right": 220
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_10",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "22",
#                         "index": 9,
#                         "rect": {
#                             "top": 148,
#                             "left": 222,
#                             "bottom": 172,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_11",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "23",
#                         "index": 10,
#                         "rect": {
#                             "top": 148,
#                             "left": 242,
#                             "bottom": 172,
#                             "right": 262
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_12",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "24",
#                         "index": 11,
#                         "rect": {
#                             "top": 149,
#                             "left": 262,
#                             "bottom": 172,
#                             "right": 280
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_13",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "25",
#                         "index": 12,
#                         "rect": {
#                             "top": 147,
#                             "left": 281,
#                             "bottom": 172,
#                             "right": 302
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_14",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "26",
#                         "index": 13,
#                         "rect": {
#                             "top": 147,
#                             "left": 304,
#                             "bottom": 173,
#                             "right": 322
#                         }
#                     },
#                     {
#                         "annotationTags": "NAME1_15",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "27",
#                         "index": 14,
#                         "rect": {
#                             "top": 147,
#                             "left": 324,
#                             "bottom": 173,
#                             "right": 342
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "NAME1",
#                     "value": "NAME"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3",
#                 "rois": [
#                     {
#                         "annotationTags": "ADDRESS1_1",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "28",
#                         "index": 0,
#                         "rect": {
#                             "top": 220,
#                             "left": 33,
#                             "bottom": 249,
#                             "right": 56
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_2",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "29",
#                         "index": 1,
#                         "rect": {
#                             "top": 221,
#                             "left": 56,
#                             "bottom": 249,
#                             "right": 78
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_3",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "30",
#                         "index": 2,
#                         "rect": {
#                             "top": 221,
#                             "left": 78,
#                             "bottom": 250,
#                             "right": 102
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_4",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "31",
#                         "index": 3,
#                         "rect": {
#                             "top": 222,
#                             "left": 105,
#                             "bottom": 248,
#                             "right": 127
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_5",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "32",
#                         "index": 4,
#                         "rect": {
#                             "top": 221,
#                             "left": 127,
#                             "bottom": 248,
#                             "right": 148
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_6",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "33",
#                         "index": 5,
#                         "rect": {
#                             "top": 222,
#                             "left": 150,
#                             "bottom": 249,
#                             "right": 170
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_7",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "34",
#                         "index": 6,
#                         "rect": {
#                             "top": 221,
#                             "left": 170,
#                             "bottom": 250,
#                             "right": 192
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_8",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "35",
#                         "index": 7,
#                         "rect": {
#                             "top": 221,
#                             "left": 195,
#                             "bottom": 249,
#                             "right": 217
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_9",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "36",
#                         "index": 8,
#                         "rect": {
#                             "top": 222,
#                             "left": 217,
#                             "bottom": 250,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_10",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "37",
#                         "index": 9,
#                         "rect": {
#                             "top": 221,
#                             "left": 239,
#                             "bottom": 249,
#                             "right": 260
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_11",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "38",
#                         "index": 10,
#                         "rect": {
#                             "top": 222,
#                             "left": 262,
#                             "bottom": 249,
#                             "right": 286
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_12 ",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "39",
#                         "index": 11,
#                         "rect": {
#                             "top": 223,
#                             "left": 286,
#                             "bottom": 250,
#                             "right": 308
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_13",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "40",
#                         "index": 12,
#                         "rect": {
#                             "top": 223,
#                             "left": 309,
#                             "bottom": 249,
#                             "right": 330
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_14",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "41",
#                         "index": 13,
#                         "rect": {
#                             "top": 222,
#                             "left": 332,
#                             "bottom": 249,
#                             "right": 353
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_15",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "42",
#                         "index": 14,
#                         "rect": {
#                             "top": 222,
#                             "left": 355,
#                             "bottom": 250,
#                             "right": 376
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_16",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "43",
#                         "index": 15,
#                         "rect": {
#                             "top": 222,
#                             "left": 376,
#                             "bottom": 249,
#                             "right": 397
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_17",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "44",
#                         "index": 16,
#                         "rect": {
#                             "top": 222,
#                             "left": 398,
#                             "bottom": 250,
#                             "right": 420
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_18",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "45",
#                         "index": 17,
#                         "rect": {
#                             "top": 222,
#                             "left": 421,
#                             "bottom": 249,
#                             "right": 444
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_19",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "46",
#                         "index": 18,
#                         "rect": {
#                             "top": 221,
#                             "left": 446,
#                             "bottom": 248,
#                             "right": 468
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_20",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "47",
#                         "index": 19,
#                         "rect": {
#                             "top": 221,
#                             "left": 469,
#                             "bottom": 248,
#                             "right": 490
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_21",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "48",
#                         "index": 20,
#                         "rect": {
#                             "top": 221,
#                             "left": 491,
#                             "bottom": 249,
#                             "right": 513
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_22",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "49",
#                         "index": 21,
#                         "rect": {
#                             "top": 222,
#                             "left": 514,
#                             "bottom": 249,
#                             "right": 536
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_23",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "50",
#                         "index": 22,
#                         "rect": {
#                             "top": 222,
#                             "left": 536,
#                             "bottom": 250,
#                             "right": 559
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_24",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "51",
#                         "index": 23,
#                         "rect": {
#                             "top": 221,
#                             "left": 562,
#                             "bottom": 249,
#                             "right": 582
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_25",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "52",
#                         "index": 24,
#                         "rect": {
#                             "top": 221,
#                             "left": 582,
#                             "bottom": 248,
#                             "right": 604
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_26",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "53",
#                         "index": 25,
#                         "rect": {
#                             "top": 266,
#                             "left": 34,
#                             "bottom": 294,
#                             "right": 56
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_27",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "54",
#                         "index": 26,
#                         "rect": {
#                             "top": 266,
#                             "left": 57,
#                             "bottom": 294,
#                             "right": 78
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_28",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "55",
#                         "index": 27,
#                         "rect": {
#                             "top": 266,
#                             "left": 80,
#                             "bottom": 294,
#                             "right": 102
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_30",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "56",
#                         "index": 28,
#                         "rect": {
#                             "top": 266,
#                             "left": 104,
#                             "bottom": 294,
#                             "right": 126
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_31",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "57",
#                         "index": 29,
#                         "rect": {
#                             "top": 267,
#                             "left": 127,
#                             "bottom": 295,
#                             "right": 148
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_32",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "58",
#                         "index": 30,
#                         "rect": {
#                             "top": 267,
#                             "left": 151,
#                             "bottom": 295,
#                             "right": 170
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_33",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "59",
#                         "index": 31,
#                         "rect": {
#                             "top": 267,
#                             "left": 171,
#                             "bottom": 294,
#                             "right": 192
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_34",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "60",
#                         "index": 32,
#                         "rect": {
#                             "top": 266,
#                             "left": 194,
#                             "bottom": 295,
#                             "right": 217
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_35",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "61",
#                         "index": 33,
#                         "rect": {
#                             "top": 267,
#                             "left": 216,
#                             "bottom": 294,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_36",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "62",
#                         "index": 34,
#                         "rect": {
#                             "top": 266,
#                             "left": 240,
#                             "bottom": 294,
#                             "right": 260
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_37",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "63",
#                         "index": 35,
#                         "rect": {
#                             "top": 266,
#                             "left": 263,
#                             "bottom": 294,
#                             "right": 285
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_38",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "64",
#                         "index": 36,
#                         "rect": {
#                             "top": 267,
#                             "left": 285,
#                             "bottom": 293,
#                             "right": 308
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_39",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "65",
#                         "index": 37,
#                         "rect": {
#                             "top": 267,
#                             "left": 308,
#                             "bottom": 295,
#                             "right": 330
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_40",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "66",
#                         "index": 38,
#                         "rect": {
#                             "top": 266,
#                             "left": 332,
#                             "bottom": 293,
#                             "right": 352
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_41",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "67",
#                         "index": 39,
#                         "rect": {
#                             "top": 267,
#                             "left": 353,
#                             "bottom": 293,
#                             "right": 373
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_42",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "68",
#                         "index": 40,
#                         "rect": {
#                             "top": 267,
#                             "left": 376,
#                             "bottom": 295,
#                             "right": 396
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_43",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "69",
#                         "index": 41,
#                         "rect": {
#                             "top": 266,
#                             "left": 398,
#                             "bottom": 296,
#                             "right": 420
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_44",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "70",
#                         "index": 42,
#                         "rect": {
#                             "top": 267,
#                             "left": 422,
#                             "bottom": 295,
#                             "right": 444
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_45",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "71",
#                         "index": 43,
#                         "rect": {
#                             "top": 267,
#                             "left": 447,
#                             "bottom": 295,
#                             "right": 467
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_46",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "72",
#                         "index": 44,
#                         "rect": {
#                             "top": 267,
#                             "left": 469,
#                             "bottom": 295,
#                             "right": 490
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_47",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "73",
#                         "index": 45,
#                         "rect": {
#                             "top": 267,
#                             "left": 491,
#                             "bottom": 293,
#                             "right": 512
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_48",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "74",
#                         "index": 46,
#                         "rect": {
#                             "top": 267,
#                             "left": 515,
#                             "bottom": 294,
#                             "right": 537
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_49",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "75",
#                         "index": 47,
#                         "rect": {
#                             "top": 265,
#                             "left": 537,
#                             "bottom": 294,
#                             "right": 559
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_50",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "76",
#                         "index": 48,
#                         "rect": {
#                             "top": 267,
#                             "left": 560,
#                             "bottom": 293,
#                             "right": 581
#                         }
#                     },
#                     {
#                         "annotationTags": "ADDRESS1_51",
#                         "extractionMethod": "BLOCK_ALPHANUMERIC_CLASSIFICATION",
#                         "roiId": "77",
#                         "index": 49,
#                         "rect": {
#                             "top": 266,
#                             "left": 582,
#                             "bottom": 294,
#                             "right": 603
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "ADDRESS1",
#                     "value": "ADDRESS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4",
#                 "rois": [
#                     {
#                         "annotationTags": "PINCODE1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "78",
#                         "index": 0,
#                         "rect": {
#                             "top": 343,
#                             "left": 34,
#                             "bottom": 368,
#                             "right": 55
#                         }
#                     },
#                     {
#                         "annotationTags": "PINCODE1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "79",
#                         "index": 1,
#                         "rect": {
#                             "top": 344,
#                             "left": 56,
#                             "bottom": 369,
#                             "right": 74
#                         }
#                     },
#                     {
#                         "annotationTags": "PINCODE1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "80",
#                         "index": 2,
#                         "rect": {
#                             "top": 343,
#                             "left": 76,
#                             "bottom": 367,
#                             "right": 95
#                         }
#                     },
#                     {
#                         "annotationTags": "PINCODE1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "81",
#                         "index": 3,
#                         "rect": {
#                             "top": 344,
#                             "left": 97,
#                             "bottom": 369,
#                             "right": 117
#                         }
#                     },
#                     {
#                         "annotationTags": "PINCODE1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "82",
#                         "index": 4,
#                         "rect": {
#                             "top": 344,
#                             "left": 118,
#                             "bottom": 369,
#                             "right": 138
#                         }
#                     },
#                     {
#                         "annotationTags": "PINCODE1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "83",
#                         "index": 5,
#                         "rect": {
#                             "top": 343,
#                             "left": 139,
#                             "bottom": 369,
#                             "right": 157
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "PINCODE1",
#                     "value": "PINCODE"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5",
#                 "rois": [
#                     {
#                         "annotationTags": "CONTACTNO1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "84",
#                         "index": 0,
#                         "rect": {
#                             "top": 343,
#                             "left": 189,
#                             "bottom": 370,
#                             "right": 208
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "85",
#                         "index": 1,
#                         "rect": {
#                             "top": 342,
#                             "left": 209,
#                             "bottom": 369,
#                             "right": 229
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "86",
#                         "index": 2,
#                         "rect": {
#                             "top": 343,
#                             "left": 230,
#                             "bottom": 369,
#                             "right": 249
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "87",
#                         "index": 3,
#                         "rect": {
#                             "top": 343,
#                             "left": 251,
#                             "bottom": 369,
#                             "right": 271
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "88",
#                         "index": 4,
#                         "rect": {
#                             "top": 343,
#                             "left": 272,
#                             "bottom": 369,
#                             "right": 289
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "89",
#                         "index": 5,
#                         "rect": {
#                             "top": 343,
#                             "left": 292,
#                             "bottom": 367,
#                             "right": 310
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "90",
#                         "index": 6,
#                         "rect": {
#                             "top": 343,
#                             "left": 313,
#                             "bottom": 369,
#                             "right": 331
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "91",
#                         "index": 7,
#                         "rect": {
#                             "top": 343,
#                             "left": 332,
#                             "bottom": 370,
#                             "right": 351
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "92",
#                         "index": 8,
#                         "rect": {
#                             "top": 343,
#                             "left": 353,
#                             "bottom": 368,
#                             "right": 374
#                         }
#                     },
#                     {
#                         "annotationTags": "CONTACTNO1_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "93",
#                         "index": 9,
#                         "rect": {
#                             "top": 342,
#                             "left": 374,
#                             "bottom": 369,
#                             "right": 392
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "CONTACTNO1",
#                     "value": "CONTACTNO"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
